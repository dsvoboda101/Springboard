# %% [markdown]
# #Capstone 3: Predicting iPSC Donor Differentiation Success
#
# I this project we will use iPSC scRNA-seq data from a dataset of 125 donors to predict endoderm differntiation efficiency. This dataset if from the publication
#
# Cuomo, A.S.E., Seaton, D.D., McCarthy, D.J. *et al.*
# **Single-cell RNA-sequencing of differentiating iPS cells reveals dynamic genetic effects on gene expression.**
# *Nature Communications*, 11, 810 (2020).
# https://doi.org/10.1038/s41467-020-14457-z
#
# The dataset can be dowloaded at: https://zenodo.org/record/3625024#.Xil-0y2cZ0s
#
# The code used in this original publication can be found on Github: https://github.com/single-cell-genetics/singlecell_endodiff_paper/tree/main

# %% [markdown]
# ##Loading Data
#
# In this notebook we will build a predictive model using the scRNAseq counts from day0 cells (aka iPSCs prior to any differentiation) to predict the definitive endoderm (DE) score. This data can be found in the .h5ad file generated in the previous EDA notebook for this project and stored in the Google Drive foler Capstone3_iPSC_EDA.  There are two different DE scores that can be used as the target label, each with it's own dataset.
#
# DEscore = Score derived from high expression of genes associated with endogenous definitive endoderm cells and low expression of genes associated with iPSCs, made using the `score_genes` function in the ScanPy library.
#
# psuedorank = Score derived from the `psuedotime`, function in the ScanPy library which generates a progression from a randomly chosen day0 cell through the most differentiated cell in the dataset.
#
# We'll start with mounting Google Drive, installing and importing the necessary libraries and loading the data files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip install scanpy anndata seaborn
# Out:
# Collecting scanpy
#   Downloading scanpy-1.12-py3-none-any.whl.metadata (8.4 kB)
# Collecting anndata
#   Downloading anndata-0.12.10-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Collecting fast-array-utils>=1.2.1 (from fast-array-utils[accel,sparse]>=1.2.1->scanpy)
#   Downloading fast_array_utils-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=25 in /usr/local/lib/python3.12/dist-packages (from scanpy) (26.0)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.11)
# Collecting array-api-compat>=1.7.1 (from anndata)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->scanpy) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scanpy) (3.6.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9->scanpy) (1.17.0)
# Downloading scanpy-1.12-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.1 MB/s eta 0:00:00
# Downloading anndata-0.12.10-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 12.3 MB/s eta 0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.2 MB/s eta 0:00:00
# Downloading fast_array_utils-1.3.1-py3-none-any.whl (36 kB)
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 19.0 MB/s eta 0:00:00
# Downloading session_info2-0.4-py3-none-any.whl (17 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 83.3 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, fast-array-utils, donfig, array-api-compat, zarr, anndata, scanpy
# Successfully installed anndata-0.12.10 array-api-compat-1.14.0 donfig-0.8.1.post1 fast-array-utils-1.3.1 legacy-api-wrap-1.5 numcodecs-0.16.5 scanpy-1.12 session-info2-0.4 zarr-3.1.5

# %%
# %pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 24.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.inspection import permutation_importance
from scipy.stats import spearmanr, kendalltau
import shap
from collections import Counter
from catboost import Pool

# %%
day0_score = sc.read_h5ad("/content/drive/MyDrive/Springboard/Capstone3_iPSC/Capstone3_iPSC_EDA/adata_DEscores_day0.h5ad")

# %% [markdown]
# ##Convert Day0 data to Pseudobulk
#
# As was shown in the previous notebook, building a predictive model from single cell data was not successfull as the learners focused on the noise in the data.  To address this, we will convert the data to psuedobulk with each donor being one sample.  The standard protocol is to sum the raw counts for each cell from a given donor.

# %%
#Code from https://www.youtube.com/watch?v=Ee0PQUwVH8Q
donors = []
for donor in day0_score.obs["donor"].unique():
  donor_day0 = day0_score[day0_score.obs["donor"] == donor].copy()
  donor_day0.X = donor_day0.layers["counts"] #Access the saved raw counts
  donor_rep = sc.AnnData(X = donor_day0.X.sum(axis=0).reshape(1, -1), var = donor_day0.var)
  donor_rep.obs_names = [donor]
  donor_rep.obs['DEscore_long'] = donor_day0.obs['mean_DEscore_long'].iloc[0]  #use our previously creates average scores from the day3 cells
  donor_rep.obs['DEscore_short'] = donor_day0.obs['mean_DEscore_short'].iloc[0]
  donor_rep.obs['pseudorank'] = donor_day0.obs['mean_pseudorank'].iloc[0]
  donors.append(donor_rep)
donor_adata = sc.concat(donors)

# %%
#Verify our new dataset has the expected shape and columns
donor_adata
# Out:
# AnnData object with n_obs × n_vars = 92 × 11231
#     obs: 'DEscore_long', 'DEscore_short', 'pseudorank'

# %%
#Normalize pseudobulk data
donor_adata.layers['counts'] = donor_adata.X.copy() #Stores raw counts in layer of the adata object so they're not lost during normalization
sc.pp.normalize_total(donor_adata, target_sum=1e4) #Normalize counts
sc.pp.log1p(donor_adata)

# %% [markdown]
# ##Dimension Reduction
#
# We will apply three methods of dimension reduction and compare the utility of the results.
#
# 1) PCA, then use the PCs as features
# 2) Top 100 genes with the greatest correlation to DE Score or pseudorank
# 3) Molecular pathways (ie groups of functionally related genes) with the greatest correlation to DE Score or pseudorank

# %% [markdown]
# ###Dimenion Reduction: PCA

# %%
#Calculate PCs
sc.tl.pca(donor_adata)
sc.pl.pca_variance_ratio(donor_adata, n_pcs=50, log=True) #Plot PC variance ratios

# %%
perc_var = donor_adata.uns['pca']['variance_ratio'] * 100
sc.tl.tsne(donor_adata, use_rep='X_pca', random_state=147)
df = pd.DataFrame({'PC1': donor_adata.obsm['X_pca'][:,0], 'PC2': donor_adata.obsm['X_pca'][:,1], 'score': donor_adata.obs['DEscore_long'].values})

plt.figure(figsize=(6,4))
plt.scatter(df['PC1'], df['PC2'], c=pd.Categorical(df['score']).codes, s=5, alpha=1)
plt.xlabel(f'PC1, {perc_var[0]:.1f}%variance explained')
plt.ylabel(f'PC2, {perc_var[1]:.1f}%variance explained')
plt.title('Donor PCA, colored by score')
plt.show()

# %%
perc_var = donor_adata.uns['pca']['variance_ratio'] * 100
sc.tl.tsne(donor_adata, use_rep='X_pca', random_state=147)
df = pd.DataFrame({'PC1': donor_adata.obsm['X_pca'][:,0], 'PC2': donor_adata.obsm['X_pca'][:,1], 'pseudorank': donor_adata.obs['pseudorank'].values})

plt.figure(figsize=(6,4))
plt.scatter(df['PC1'], df['PC2'], c=pd.Categorical(df['pseudorank']).codes, s=5, alpha=1)
plt.xlabel(f'PC1, {perc_var[0]:.1f}%variance explained')
plt.ylabel(f'PC2, {perc_var[1]:.1f}%variance explained')
plt.title('Donor PCA, colored by score')
plt.show()

# %%
day0_pcs = pd.DataFrame(donor_adata.obsm['X_pca'], index=donor_adata.obs_names, columns=[f'PC{i+1}' for i in range(donor_adata.obsm['X_pca'].shape[1])])
day0_pcs.head()
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# zapk  3.181929  0.660086 -1.156901 -1.338994 -0.100520  3.320299  1.582244
# wibj -2.547690  0.413058 -1.849295  1.165720 -2.684275 -0.665291 -0.199397
# pelm  2.320235  0.362718 -1.002284 -0.824520  0.575587  3.100321  0.103807
# vass -0.807296  3.132881 -2.029991 -1.439614 -0.568322 -0.486264 -1.276130
# paab  1.491555  0.265067  2.365499  6.051101 -1.176274  1.801340 -0.853157
#
#            PC8       PC9      PC10  ...      PC41      PC42      PC43  \
# zapk -0.981706  2.014731 -0.383449  ...  0.617737 -0.222438  0.267443
# wibj -0.281172  1.612072 -3.199867  ... -0.501535  0.391808 -0.144017
# pelm -0.789793  0.468751  0.908636  ... -0.038008 -0.498470  0.023480
# vass -0.728340 -0.438251 -1.202127  ... -1.064911  0.521858  0.131770
# paab -1.687098  1.123861  2.129872  ... -0.714833 -0.330263 -0.688792
#
#           PC44      PC45      PC46      PC47      PC48      PC49      PC50
# zapk  0.314845 -0.733680  0.203613 -0.193274 -0.225907  0.142855 -0.694437
# wibj -0.242051 -0.109650  0.231788 -0.258578 -0.216250  0.406823  0.342120
# pelm  0.185500 -0.152878  0.073034  0.017615  0.187021  0.061215  0.320523
# vass  1.100568  0.025072 -0.221206  0.244479  0.290150  0.021428 -0.045677
# paab  0.111910  0.157670  0.413958 -0.195304 -0.083680  0.197183 -0.876337
#
# [5 rows x 50 columns]

# %% [markdown]
# PCs don't seem to drastically correlate with DE score, based on looking at the color patterns.  Pseudotime score (aka pseudoranks) correlate with PCs a little better, but still not what we were hoping for.
#
# Next, we will finding the genes that correlate with DE score (or psuedorank) the best. Hint: these are most likely not the most variable genes.

# %% [markdown]
# ###Dimension Reduction: Correlating Genes

# %%
# Find genes that correlate with DE scores.
y = donor_adata.obs['DEscore_long'].values
corrs = []
for g in donor_adata.var_names:
  x = donor_adata[:, g].X.flatten()
  r, _ = spearmanr(x,y)
  corrs.append(r)
donor_adata.var['corr_DE'] = corrs

# %%
# Find genes that correlate with pseudoranks.
y = donor_adata.obs['pseudorank'].values
corrs = []
for g in donor_adata.var_names:
  x = donor_adata[:, g].X.flatten()
  r, _ = spearmanr(x,y)
  corrs.append(r)
donor_adata.var['corr_PR'] = corrs

# %%
#Sort donor_adata based on correlation to DE score, collect the 100 genes with the highest correlations
top_genes_score = donor_adata.var['corr_DE'].abs().sort_values(ascending=False).head(100).index

#Sort donor_adata based on correlation to pseudorank, collect the 100 genes with the highest correlations
top_genes_rank = donor_adata.var['corr_PR'].abs().sort_values(ascending=False).head(100).index

#Make new scanpy datasets with only the 100 selected genes correlating with DE_score and pseudorank, respectively
donor_score = donor_adata[:, top_genes_score].copy()
donor_rank = donor_adata[:, top_genes_rank].copy()

# %% [markdown]
# ###Dimension Reduction: Gene Pathways
#
# Here we will curated gene lists from the Broad Institute. These lists are part of the Human MSigDB Collections and are described in the following peer reviewed publication (see citation below).  Here, we are using 50 standard lists describing various normal and well described molecular pathways. Gene lists of this type are used to gleen information on the status and activity of the cells beyond their cellular identity.
#
# Liberzon A, Birger C, Thorvaldsdóttir H, Ghandi M, Mesirov JP, Tamayo P. The Molecular Signatures Database (MSigDB) hallmark gene set collection. Cell Syst. 2015 Dec 23;1(6):417-425. doi: 10.1016/j.cels.2015.12.004. PMID: 26771021; PMCID: PMC4707969.

# %%
#file containing gene lists downloaded from GSEA website https://www.gsea-msigdb.org/gsea/msigdb/human/collections.jsp#H
import json
with open('/content/drive/MyDrive/Springboard/Capstone3_iPSC/h.all.v2026.1.Hs.txt', 'r') as file:
    data = json.load(file)

print(json.dumps(data, indent=4))
# Out:
# {
#     "HALLMARK_TNFA_SIGNALING_VIA_NFKB": {
#         "collection": "H",
#         "systematicName": "M5890",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_TNFA_SIGNALING_VIA_NFKB",
#         "geneSymbols": [
#             "ABCA1",
#             "ACKR3",
#             "AREG",
#             "ATF3",
#             "ATP2B1",
#             "B4GALT1",
#             "B4GALT5",
#             "BCL2A1",
#             "BCL3",
#             "BCL6",
#             "BHLHE40",
#             "BIRC2",
#             "BIRC3",
#             "BMP2",
#             "BTG1",
#             "BTG2",
#             "BTG3",
#             "CCL2",
#             "CCL20",
#             "CCL4",
#             "CCL5",
#             "CCN1",
#             "CCND1",
#             "CCNL1",
#             "CCRL2",
#             "CD44",
#             "CD69",
#             "CD80",
#             "CD83",
#             "CDKN1A",
#             "CEBPB",
#             "CEBPD",
#             "CFLAR",
#             "CLCF1",
#             "CSF1",
#             "CSF2",
#             "CXCL1",
#             "CXCL10",
#             "CXCL11",
#             "CXCL2",
#             "CXCL3",
#             "CXCL6",
#             "DENND5A",
#             "DNAJB4",
#             "DRAM1",
#             "DUSP1",
#             "DUSP2",
#             "DUSP4",
#             "DUSP5",
#             "EDN1",
#             "EFNA1",
#             "EGR1",
#             "EGR2",
#             "EGR3",
#             "EHD1",
#             "EIF1",
#             "ETS2",
#             "F2RL1",
#             "F3",
#             "FJX1",
#             "FOS",
#             "FOSB",
#             "FOSL1",
#             "FOSL2",
#             "FUT4",
#             "G0S2",
#             "GADD45A",
#             "GADD45B",
#             "GCH1",
#             "GEM",
#             "GFPT2",
#             "GPR183",
#             "HBEGF",
#             "HES1",
#             "ICAM1",
#             "ICOSLG",
#             "ID2",
#             "IER2",
#             "IER3",
#             "IER5",
#             "IFIH1",
#             "IFIT2",
#             "IFNGR2",
#             "IL12B",
#             "IL15RA",
#             "IL18",
#             "IL1A",
#             "IL1B",
#             "IL23A",
#             "IL6",
#             "IL6ST",
#             "IL7R",
#             "INHBA",
#             "IRF1",
#             "IRS2",
#             "JAG1",
#             "JUN",
#             "JUNB",
#             "KDM6B",
#             "KLF10",
#             "KLF2",
#             "KLF4",
#             "KLF6",
#             "KLF9",
#             "KYNU",
#             "LAMB3",
#             "LDLR",
#             "LIF",
#             "LITAF",
#             "MAFF",
#             "MAP2K3",
#             "MAP3K8",
#             "MARCKS",
#             "MCL1",
#             "MSC",
#             "MXD1",
#             "MYC",
#             "NAMPT",
#             "NFAT5",
#             "NFE2L2",
#             "NFIL3",
#             "NFKB1",
#             "NFKB2",
#             "NFKBIA",
#             "NFKBIE",
#             "NINJ1",
#             "NR4A1",
#             "NR4A2",
#             "NR4A3",
#             "OLR1",
#             "PANX1",
#             "PDE4B",
#             "PDLIM5",
#             "PER1",
#             "PFKFB3",
#             "PHLDA1",
#             "PHLDA2",
#             "PLAU",
#             "PLAUR",
#             "PLEK",
#             "PLK2",
#             "PLPP3",
#             "PMEPA1",
#             "PNRC1",
#             "PPP1R15A",
#             "PTGER4",
#             "PTGS2",
#             "PTPRE",
#             "PTX3",
#             "RCAN1",
#             "REL",
#             "RELA",
#             "RELB",
#             "RHOB",
#             "RIGI",
#             "RIPK2",
#             "RNF19B",
#             "SAT1",
#             "SDC4",
#             "SERPINB2",
#             "SERPINB8",
#             "SERPINE1",
#             "SGK1",
#             "SIK1",
#             "SLC16A6",
#             "SLC2A3",
#             "SLC2A6",
#             "SMAD3",
#             "SNN",
#             "SOCS3",
#             "SOD2",
#             "SPHK1",
#             "SPSB1",
#             "SQSTM1",
#             "STAT5A",
#             "TANK",
#             "TAP1",
#             "TGIF1",
#             "TIPARP",
#             "TLR2",
#             "TNC",
#             "TNF",
#             "TNFAIP2",
#             "TNFAIP3",
#             "TNFAIP6",
#             "TNFAIP8",
#             "TNFRSF9",
#             "TNFSF9",
#             "TNIP1",
#             "TNIP2",
#             "TRAF1",
#             "TRIB1",
#             "TRIP10",
#             "TSC22D1",
#             "TUBB2A",
#             "VEGFA",
#             "YRDC",
#             "ZBTB10",
#             "ZC3H12A",
#             "ZFP36"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_HYPOXIA": {
#         "collection": "H",
#         "systematicName": "M5891",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_HYPOXIA",
#         "geneSymbols": [
#             "ACKR3",
#             "ADM",
#             "ADORA2B",
#             "AK4",
#             "AKAP12",
#             "ALDOA",
#             "ALDOB",
#             "ALDOC",
#             "AMPD3",
#             "ANGPTL4",
#             "ANKZF1",
#             "ANXA2",
#             "ATF3",
#             "ATP7A",
#             "B3GALT6",
#             "B4GALNT2",
#             "BCAN",
#             "BCL2",
#             "BGN",
#             "BHLHE40",
#             "BNIP3L",
#             "BRS3",
#             "BTG1",
#             "CA12",
#             "CASP6",
#             "CAV1",
#             "CAVIN1",
#             "CAVIN3",
#             "CCN1",
#             "CCN2",
#             "CCN5",
#             "CCNG2",
#             "CDKN1A",
#             "CDKN1B",
#             "CDKN1C",
#             "CHST2",
#             "CHST3",
#             "CITED2",
#             "COL5A1",
#             "CP",
#             "CSRP2",
#             "CXCR4",
#             "DCN",
#             "DDIT3",
#             "DDIT4",
#             "DPYSL4",
#             "DTNA",
#             "DUSP1",
#             "EDN2",
#             "EFNA1",
#             "EFNA3",
#             "EGFR",
#             "ENO1",
#             "ENO2",
#             "ENO3",
#             "ERO1A",
#             "ERRFI1",
#             "ETS1",
#             "EXT1",
#             "F3",
#             "FAM162A",
#             "FBP1",
#             "FOS",
#             "FOSL2",
#             "FOXO3",
#             "GAA",
#             "GALK1",
#             "GAPDH",
#             "GAPDHS",
#             "GBE1",
#             "GCK",
#             "GCNT2",
#             "GLRX",
#             "GPC1",
#             "GPC3",
#             "GPC4",
#             "GPI",
#             "GRHPR",
#             "GYS1",
#             "HAS1",
#             "HDLBP",
#             "HEXA",
#             "HK1",
#             "HK2",
#             "HMOX1",
#             "HOXB9",
#             "HS3ST1",
#             "HSPA5",
#             "IDS",
#             "IER3",
#             "IGFBP1",
#             "IGFBP3",
#             "IL6",
#             "ILVBL",
#             "INHA",
#             "IRS2",
#             "ISG20",
#             "JMJD6",
#             "JUN",
#             "KDELR3",
#             "KDM3A",
#             "KIF5A",
#             "KLF6",
#             "KLF7",
#             "KLHL24",
#             "LALBA",
#             "LARGE1",
#             "LDHA",
#             "LDHC",
#             "LOX",
#             "LXN",
#             "MAFF",
#             "MAP3K1",
#             "MIF",
#             "MT1E",
#             "MT2A",
#             "MXI1",
#             "MYH9",
#             "NAGK",
#             "NCAN",
#             "NDRG1",
#             "NDST1",
#             "NDST2",
#             "NEDD4L",
#             "NFIL3",
#             "NOCT",
#             "NR3C1",
#             "P4HA1",
#             "P4HA2",
#             "PAM",
#             "PCK1",
#             "PDGFB",
#             "PDK1",
#             "PDK3",
#             "PFKFB3",
#             "PFKL",
#             "PFKP",
#             "PGAM2",
#             "PGF",
#             "PGK1",
#             "PGM1",
#             "PGM2",
#             "PHKG1",
#             "PIM1",
#             "PKLR",
#             "PKP1",
#             "PLAC8",
#             "PLAUR",
#             "PLIN2",
#             "PNRC1",
#             "PPARGC1A",
#             "PPFIA4",
#             "PPP1R15A",
#             "PPP1R3C",
#             "PRDX5",
#             "PRKCA",
#             "PYGM",
#             "RBPJ",
#             "RORA",
#             "RRAGD",
#             "S100A4",
#             "SAP30",
#             "SCARB1",
#             "SDC2",
#             "SDC3",
#             "SDC4",
#             "SELENBP1",
#             "SERPINE1",
#             "SIAH2",
#             "SLC25A1",
#             "SLC2A1",
#             "SLC2A3",
#             "SLC2A5",
#             "SLC37A4",
#             "SLC6A6",
#             "SRPX",
#             "STBD1",
#             "STC1",
#             "STC2",
#             "SULT2B1",
#             "TES",
#             "TGFB3",
#             "TGFBI",
#             "TGM2",
#             "TIPARP",
#             "TKTL1",
#             "TMEM45A",
#             "TNFAIP3",
#             "TPBG",
#             "TPD52",
#             "TPI1",
#             "TPST2",
#             "UGP2",
#             "VEGFA",
#             "VHL",
#             "VLDLR",
#             "WSB1",
#             "XPNPEP1",
#             "ZFP36",
#             "ZNF292"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_CHOLESTEROL_HOMEOSTASIS": {
#         "collection": "H",
#         "systematicName": "M5892",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_CHOLESTEROL_HOMEOSTASIS",
#         "geneSymbols": [
#             "ABCA2",
#             "ACAT2",
#             "ACSS2",
#             "ACTG1",
#             "ADH4",
#             "ALCAM",
#             "ALDOC",
#             "ANTXR2",
#             "ANXA13",
#             "ANXA5",
#             "ATF3",
#             "ATF5",
#             "ATXN2",
#             "AVPR1A",
#             "CBS",
#             "CD9",
#             "CHKA",
#             "CLU",
#             "CPEB2",
#             "CTNNB1",
#             "CXCL16",
#             "CYP51A1",
#             "DHCR7",
#             "EBP",
#             "ECH1",
#             "ERRFI1",
#             "ETHE1",
#             "FABP5",
#             "FADS2",
#             "FASN",
#             "FBXO6",
#             "FDFT1",
#             "FDPS",
#             "GLDC",
#             "GNAI1",
#             "GPX8",
#             "GSTM2",
#             "GUSB",
#             "HMGCR",
#             "HMGCS1",
#             "HSD17B7",
#             "IDI1",
#             "JAG1",
#             "LDLR",
#             "LGALS3",
#             "LGMN",
#             "LPL",
#             "LSS",
#             "MAL2",
#             "MVD",
#             "MVK",
#             "NFIL3",
#             "NIBAN1",
#             "NSDHL",
#             "PCYT2",
#             "PDK3",
#             "PLAUR",
#             "PLSCR1",
#             "PMVK",
#             "PNRC1",
#             "PPARG",
#             "S100A11",
#             "SC5D",
#             "SCD",
#             "SEMA3B",
#             "SQLE",
#             "SREBF2",
#             "STARD4",
#             "STX5",
#             "TM7SF2",
#             "TMEM97",
#             "TNFRSF12A",
#             "TP53INP1",
#             "TRIB3"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_MITOTIC_SPINDLE": {
#         "collection": "H",
#         "systematicName": "M5893",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_MITOTIC_SPINDLE",
#         "geneSymbols": [
#             "ABI1",
#             "ABL1",
#             "ABR",
#             "ACTN4",
#             "AKAP13",
#             "ALMS1",
#             "ALS2",
#             "ANLN",
#             "APC",
#             "ARAP3",
#             "ARF6",
#             "ARFGEF1",
#             "ARFIP2",
#             "ARHGAP10",
#             "ARHGAP27",
#             "ARHGAP29",
#             "ARHGAP4",
#             "ARHGAP5",
#             "ARHGDIA",
#             "ARHGEF11",
#             "ARHGEF12",
#             "ARHGEF2",
#             "ARHGEF3",
#             "ARHGEF7",
#             "ARL8A",
#             "ATG4B",
#             "AURKA",
#             "BCAR1",
#             "BCL2L11",
#             "BCR",
#             "BIN1",
#             "BIRC5",
#             "BRCA2",
#             "BUB1",
#             "CAPZB",
#             "CCDC88A",
#             "CCNB2",
#             "CD2AP",
#             "CDC27",
#             "CDC42",
#             "CDC42BPA",
#             "CDC42EP1",
#             "CDC42EP2",
#             "CDC42EP4",
#             "CDK1",
#             "CDK5RAP2",
#             "CENPE",
#             "CENPF",
#             "CEP131",
#             "CEP192",
#             "CEP250",
#             "CEP57",
#             "CEP72",
#             "CKAP5",
#             "CLASP1",
#             "CLIP1",
#             "CLIP2",
#             "CNTRL",
#             "CNTROB",
#             "CPAP",
#             "CSNK1D",
#             "CTTN",
#             "CYTH2",
#             "DLG1",
#             "DLGAP5",
#             "DOCK2",
#             "DOCK4",
#             "DST",
#             "DYNC1H1",
#             "DYNLL2",
#             "ECT2",
#             "EPB41",
#             "EPB41L2",
#             "ESPL1",
#             "EZR",
#             "FARP1",
#             "FBXO5",
#             "FGD4",
#             "FGD6",
#             "FLNA",
#             "FLNB",
#             "FSCN1",
#             "GEMIN4",
#             "GSN",
#             "HDAC6",
#             "HOOK3",
#             "INCENP",
#             "ITSN1",
#             "KATNA1",
#             "KATNB1",
#             "KIF11",
#             "KIF15",
#             "KIF1B",
#             "KIF20B",
#             "KIF22",
#             "KIF23",
#             "KIF2C",
#             "KIF3B",
#             "KIF3C",
#             "KIF4A",
#             "KIF5B",
#             "KIFAP3",
#             "KLC1",
#             "KNTC1",
#             "KPTN",
#             "LATS1",
#             "LLGL1",
#             "LMNB1",
#             "LRPPRC",
#             "MAP1S",
#             "MAP3K11",
#             "MAPRE1",
#             "MARCKS",
#             "MARK4",
#             "MID1",
#             "MID1IP1",
#             "MYH10",
#             "MYH9",
#             "MYO1E",
#             "MYO9B",
#             "NCK1",
#             "NCK2",
#             "NDC80",
#             "NEDD9",
#             "NEK2",
#             "NET1",
#             "NF1",
#             "NIN",
#             "NOTCH2",
#             "NUMA1",
#             "NUSAP1",
#             "OPHN1",
#             "PAFAH1B1",
#             "PALLD",
#             "PCGF5",
#             "PCM1",
#             "PCNT",
#             "PDLIM5",
#             "PIF1",
#             "PKD2",
#             "PLEKHG2",
#             "PLK1",
#             "PPP4R2",
#             "PRC1",
#             "PREX1",
#             "PXN",
#             "RAB3GAP1",
#             "RABGAP1",
#             "RACGAP1",
#             "RALBP1",
#             "RANBP9",
#             "RAPGEF5",
#             "RAPGEF6",
#             "RASA1",
#             "RASA2",
#             "RASAL2",
#             "RFC1",
#             "RHOF",
#             "RHOT2",
#             "RICTOR",
#             "ROCK1",
#             "SAC3D1",
#             "SASS6",
#             "SEPTIN9",
#             "SHROOM1",
#             "SHROOM2",
#             "SMC1A",
#             "SMC3",
#             "SMC4",
#             "SORBS2",
#             "SOS1",
#             "SPTAN1",
#             "SPTBN1",
#             "SSH2",
#             "STAU1",
#             "STK38L",
#             "SUN2",
#             "SYNPO",
#             "TAOK2",
#             "TBCD",
#             "TIAM1",
#             "TLK1",
#             "TOP2A",
#             "TPX2",
#             "TRIO",
#             "TSC1",
#             "TTK",
#             "TUBA4A",
#             "TUBD1",
#             "TUBGCP2",
#             "TUBGCP3",
#             "TUBGCP5",
#             "TUBGCP6",
#             "UXT",
#             "VCL",
#             "WASF1",
#             "WASF2",
#             "WASL",
#             "YWHAE"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_WNT_BETA_CATENIN_SIGNALING": {
#         "collection": "H",
#         "systematicName": "M5895",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_WNT_BETA_CATENIN_SIGNALING",
#         "geneSymbols": [
#             "ADAM17",
#             "AXIN1",
#             "AXIN2",
#             "CCND2",
#             "CSNK1E",
#             "CTNNB1",
#             "CUL1",
#             "DKK1",
#             "DKK4",
#             "DLL1",
#             "DVL2",
#             "FRAT1",
#             "FZD1",
#             "FZD8",
#             "GNAI1",
#             "HDAC11",
#             "HDAC2",
#             "HDAC5",
#             "HEY1",
#             "HEY2",
#             "JAG1",
#             "JAG2",
#             "KAT2A",
#             "LEF1",
#             "MAML1",
#             "MYC",
#             "NCOR2",
#             "NCSTN",
#             "NKD1",
#             "NOTCH1",
#             "NOTCH4",
#             "NUMB",
#             "PPARD",
#             "PSEN2",
#             "PTCH1",
#             "RBPJ",
#             "SKP2",
#             "TCF7",
#             "TP53",
#             "WNT1",
#             "WNT5B",
#             "WNT6"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_TGF_BETA_SIGNALING": {
#         "collection": "H",
#         "systematicName": "M5896",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_TGF_BETA_SIGNALING",
#         "geneSymbols": [
#             "ACVR1",
#             "APC",
#             "ARID4B",
#             "BCAR3",
#             "BMP2",
#             "BMPR1A",
#             "BMPR2",
#             "CDH1",
#             "CDK9",
#             "CDKN1C",
#             "CTNNB1",
#             "ENG",
#             "FKBP1A",
#             "FNTA",
#             "FURIN",
#             "HDAC1",
#             "HIPK2",
#             "ID1",
#             "ID2",
#             "ID3",
#             "IFNGR2",
#             "JUNB",
#             "KLF10",
#             "LEFTY2",
#             "LTBP2",
#             "MAP3K7",
#             "NCOR2",
#             "NOG",
#             "PMEPA1",
#             "PPM1A",
#             "PPP1CA",
#             "PPP1R15A",
#             "RAB31",
#             "RHOA",
#             "SERPINE1",
#             "SKI",
#             "SKIL",
#             "SLC20A1",
#             "SMAD1",
#             "SMAD3",
#             "SMAD6",
#             "SMAD7",
#             "SMURF1",
#             "SMURF2",
#             "SPTBN1",
#             "TGFB1",
#             "TGFBR1",
#             "TGIF1",
#             "THBS1",
#             "TJP1",
#             "TRIM33",
#             "UBE2D3",
#             "WWTR1",
#             "XIAP"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_IL6_JAK_STAT3_SIGNALING": {
#         "collection": "H",
#         "systematicName": "M5897",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_IL6_JAK_STAT3_SIGNALING",
#         "geneSymbols": [
#             "A2M",
#             "ACVR1B",
#             "ACVRL1",
#             "BAK1",
#             "CBL",
#             "CCL7",
#             "CCR1",
#             "CD14",
#             "CD36",
#             "CD38",
#             "CD44",
#             "CD9",
#             "CNTFR",
#             "CRLF2",
#             "CSF1",
#             "CSF2",
#             "CSF2RA",
#             "CSF2RB",
#             "CSF3R",
#             "CXCL1",
#             "CXCL10",
#             "CXCL11",
#             "CXCL13",
#             "CXCL3",
#             "CXCL9",
#             "DNTT",
#             "EBI3",
#             "FAS",
#             "GRB2",
#             "HAX1",
#             "HMOX1",
#             "IFNAR1",
#             "IFNGR1",
#             "IFNGR2",
#             "IL10RB",
#             "IL12RB1",
#             "IL13RA1",
#             "IL15RA",
#             "IL17RA",
#             "IL17RB",
#             "IL18R1",
#             "IL1B",
#             "IL1R1",
#             "IL1R2",
#             "IL2RA",
#             "IL2RG",
#             "IL3RA",
#             "IL4R",
#             "IL6",
#             "IL6ST",
#             "IL7",
#             "IL9R",
#             "INHBE",
#             "IRF1",
#             "IRF9",
#             "ITGA4",
#             "ITGB3",
#             "JUN",
#             "LEPR",
#             "LTB",
#             "LTBR",
#             "MAP3K8",
#             "MYD88",
#             "OSMR",
#             "PDGFC",
#             "PF4",
#             "PIK3R5",
#             "PIM1",
#             "PLA2G2A",
#             "PTPN1",
#             "PTPN11",
#             "PTPN2",
#             "REG1A",
#             "SOCS1",
#             "SOCS3",
#             "STAM2",
#             "STAT1",
#             "STAT2",
#             "STAT3",
#             "TGFB1",
#             "TLR2",
#             "TNF",
#             "TNFRSF12A",
#             "TNFRSF1A",
#             "TNFRSF1B",
#             "TNFRSF21",
#             "TYK2"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_DNA_REPAIR": {
#         "collection": "H",
#         "systematicName": "M5898",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_DNA_REPAIR",
#         "geneSymbols": [
#             "AAAS",
#             "ADA",
#             "ADCY6",
#             "ADRM1",
#             "AGO4",
#             "AK1",
#             "AK3",
#             "ALYREF",
#             "APRT",
#             "ARL6IP1",
#             "BCAM",
#             "BCAP31",
#             "BOLA2",
#             "BRF2",
#             "CANT1",
#             "CCNO",
#             "CDA",
#             "CETN2",
#             "CLP1",
#             "CMPK2",
#             "COX17",
#             "CSTF3",
#             "DAD1",
#             "DCTN4",
#             "DDB1",
#             "DDB2",
#             "DGCR8",
#             "DGUOK",
#             "DUT",
#             "EDF1",
#             "EIF1B",
#             "ELL",
#             "ELOA",
#             "ERCC1",
#             "ERCC2",
#             "ERCC3",
#             "ERCC4",
#             "ERCC5",
#             "ERCC8",
#             "FEN1",
#             "GMPR2",
#             "GPX4",
#             "GSDME",
#             "GTF2A2",
#             "GTF2B",
#             "GTF2F1",
#             "GTF2H1",
#             "GTF2H3",
#             "GTF2H5",
#             "GTF3C5",
#             "GUK1",
#             "HCLS1",
#             "HPRT1",
#             "IMPDH2",
#             "ITPA",
#             "LIG1",
#             "MPC2",
#             "MPG",
#             "MRPL40",
#             "NCBP2",
#             "NELFB",
#             "NELFCD",
#             "NELFE",
#             "NFX1",
#             "NME1",
#             "NME3",
#             "NME4",
#             "NPR2",
#             "NT5C",
#             "NT5C3A",
#             "NUDT21",
#             "NUDT9",
#             "PCNA",
#             "PDE4B",
#             "PDE6G",
#             "PNP",
#             "POLA1",
#             "POLA2",
#             "POLB",
#             "POLD1",
#             "POLD3",
#             "POLD4",
#             "POLE4",
#             "POLH",
#             "POLL",
#             "POLR1C",
#             "POLR1D",
#             "POLR1H",
#             "POLR2A",
#             "POLR2C",
#             "POLR2D",
#             "POLR2E",
#             "POLR2F",
#             "POLR2G",
#             "POLR2H",
#             "POLR2I",
#             "POLR2J",
#             "POLR2K",
#             "POLR3C",
#             "POLR3GL",
#             "POM121",
#             "PRIM1",
#             "RAD51",
#             "RAD52",
#             "RAE1",
#             "RALA",
#             "RBX1",
#             "REV3L",
#             "RFC2",
#             "RFC3",
#             "RFC4",
#             "RFC5",
#             "RNMT",
#             "RPA2",
#             "RPA3",
#             "RRM2B",
#             "SAC3D1",
#             "SDCBP",
#             "SEC61A1",
#             "SF3A3",
#             "SMAD5",
#             "SNAPC4",
#             "SNAPC5",
#             "SRSF6",
#             "SSRP1",
#             "STX3",
#             "SUPT4H1",
#             "SUPT5H",
#             "SURF1",
#             "TAF10",
#             "TAF12",
#             "TAF13",
#             "TAF1C",
#             "TAF6",
#             "TAF9",
#             "TARBP2",
#             "TK2",
#             "TMED2",
#             "TP53",
#             "TSG101",
#             "TYMS",
#             "UMPS",
#             "UPF3B",
#             "USP11",
#             "VPS28",
#             "VPS37B",
#             "VPS37D",
#             "XPC",
#             "ZNF707",
#             "ZWINT"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_G2M_CHECKPOINT": {
#         "collection": "H",
#         "systematicName": "M5901",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_G2M_CHECKPOINT",
#         "geneSymbols": [
#             "ABL1",
#             "AMD1",
#             "ARID4A",
#             "ATF5",
#             "ATRX",
#             "AURKA",
#             "AURKB",
#             "BARD1",
#             "BCL3",
#             "BIRC5",
#             "BRCA2",
#             "BUB1",
#             "BUB3",
#             "CASP8AP2",
#             "CBX1",
#             "CCNA2",
#             "CCNB2",
#             "CCND1",
#             "CCNF",
#             "CCNT1",
#             "CDC20",
#             "CDC25A",
#             "CDC25B",
#             "CDC27",
#             "CDC45",
#             "CDC6",
#             "CDC7",
#             "CDK1",
#             "CDK4",
#             "CDKN1B",
#             "CDKN2C",
#             "CDKN3",
#             "CENPA",
#             "CENPE",
#             "CENPF",
#             "CHAF1A",
#             "CHEK1",
#             "CHMP1A",
#             "CKS1B",
#             "CKS2",
#             "CTCF",
#             "CUL1",
#             "CUL3",
#             "CUL4A",
#             "CUL5",
#             "DBF4",
#             "DDX39A",
#             "DKC1",
#             "DMD",
#             "DR1",
#             "DTYMK",
#             "E2F1",
#             "E2F2",
#             "E2F3",
#             "E2F4",
#             "EFNA5",
#             "EGF",
#             "ESPL1",
#             "EWSR1",
#             "EXO1",
#             "EZH2",
#             "FANCC",
#             "FBXO5",
#             "FOXN3",
#             "G3BP1",
#             "GINS2",
#             "GSPT1",
#             "H2AX",
#             "H2AZ1",
#             "H2AZ2",
#             "H2BC12",
#             "HIF1A",
#             "HIRA",
#             "HMGA1",
#             "HMGB3",
#             "HMGN2",
#             "HMMR",
#             "HNRNPD",
#             "HNRNPU",
#             "HOXC10",
#             "HSPA8",
#             "HUS1",
#             "ILF3",
#             "INCENP",
#             "JPT1",
#             "KATNA1",
#             "KIF11",
#             "KIF15",
#             "KIF20B",
#             "KIF22",
#             "KIF23",
#             "KIF2C",
#             "KIF4A",
#             "KIF5B",
#             "KMT5A",
#             "KNL1",
#             "KPNA2",
#             "KPNB1",
#             "LBR",
#             "LIG3",
#             "LMNB1",
#             "MAD2L1",
#             "MAP3K20",
#             "MAPK14",
#             "MARCKS",
#             "MCM2",
#             "MCM3",
#             "MCM5",
#             "MCM6",
#             "MEIS1",
#             "MEIS2",
#             "MKI67",
#             "MNAT1",
#             "MT2A",
#             "MTF2",
#             "MYBL2",
#             "MYC",
#             "NASP",
#             "NCL",
#             "NDC80",
#             "NEK2",
#             "NOLC1",
#             "NOTCH2",
#             "NSD2",
#             "NUMA1",
#             "NUP50",
#             "NUP98",
#             "NUSAP1",
#             "ODC1",
#             "ODF2",
#             "ORC5",
#             "ORC6",
#             "PAFAH1B1",
#             "PBK",
#             "PDS5B",
#             "PLK1",
#             "PLK4",
#             "PML",
#             "POLA2",
#             "POLE",
#             "POLQ",
#             "PRC1",
#             "PRIM2",
#             "PRMT5",
#             "PRP4K",
#             "PTTG1",
#             "PTTG3P",
#             "PURA",
#             "RACGAP1",
#             "RAD21",
#             "RAD23B",
#             "RAD54L",
#             "RASAL2",
#             "RBL1",
#             "RBM14",
#             "RPA2",
#             "RPS6KA5",
#             "SAP30",
#             "SFPQ",
#             "SLC12A2",
#             "SLC38A1",
#             "SLC7A1",
#             "SLC7A5",
#             "SMAD3",
#             "SMARCC1",
#             "SMC1A",
#             "SMC2",
#             "SMC4",
#             "SNRPD1",
#             "SQLE",
#             "SRSF1",
#             "SRSF10",
#             "SRSF2",
#             "SS18",
#             "STAG1",
#             "STIL",
#             "STMN1",
#             "SUV39H1",
#             "SYNCRIP",
#             "TACC3",
#             "TENT4A",
#             "TFDP1",
#             "TGFB1",
#             "TLE3",
#             "TMPO",
#             "TNPO2",
#             "TOP1",
#             "TOP2A",
#             "TPX2",
#             "TRA2B",
#             "TRAIP",
#             "TROAP",
#             "TTK",
#             "UBE2C",
#             "UBE2S",
#             "UCK2",
#             "UPF1",
#             "WRN",
#             "XPO1",
#             "YTHDC1"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_APOPTOSIS": {
#         "collection": "H",
#         "systematicName": "M5902",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_APOPTOSIS",
#         "geneSymbols": [
#             "ADD1",
#             "AIFM3",
#             "ANKH",
#             "ANXA1",
#             "APP",
#             "ATF3",
#             "AVPR1A",
#             "BAX",
#             "BCAP31",
#             "BCL10",
#             "BCL2L1",
#             "BCL2L10",
#             "BCL2L11",
#             "BCL2L2",
#             "BGN",
#             "BID",
#             "BIK",
#             "BIRC3",
#             "BMF",
#             "BMP2",
#             "BNIP3L",
#             "BRCA1",
#             "BTG2",
#             "BTG3",
#             "CASP1",
#             "CASP2",
#             "CASP3",
#             "CASP4",
#             "CASP6",
#             "CASP7",
#             "CASP8",
#             "CASP9",
#             "CAV1",
#             "CCNA1",
#             "CCND1",
#             "CCND2",
#             "CD14",
#             "CD2",
#             "CD38",
#             "CD44",
#             "CD69",
#             "CDC25B",
#             "CDK2",
#             "CDKN1A",
#             "CDKN1B",
#             "CFLAR",
#             "CLU",
#             "CREBBP",
#             "CTH",
#             "CTNNB1",
#             "CYLD",
#             "DAP",
#             "DAP3",
#             "DCN",
#             "DDIT3",
#             "DFFA",
#             "DIABLO",
#             "DNAJA1",
#             "DNAJC3",
#             "DNM1L",
#             "DPYD",
#             "EBP",
#             "EGR3",
#             "EMP1",
#             "ENO2",
#             "ERBB2",
#             "ERBB3",
#             "EREG",
#             "ETF1",
#             "F2",
#             "F2R",
#             "FAS",
#             "FASLG",
#             "FDXR",
#             "FEZ1",
#             "GADD45A",
#             "GADD45B",
#             "GCH1",
#             "GNA15",
#             "GPX1",
#             "GPX3",
#             "GPX4",
#             "GSN",
#             "GSR",
#             "GSTM1",
#             "GUCY2D",
#             "H1-0",
#             "HGF",
#             "HMGB2",
#             "HMOX1",
#             "HSPB1",
#             "IER3",
#             "IFITM3",
#             "IFNB1",
#             "IFNGR1",
#             "IGF2R",
#             "IGFBP6",
#             "IL18",
#             "IL1A",
#             "IL1B",
#             "IL6",
#             "IRF1",
#             "ISG20",
#             "JUN",
#             "KRT18",
#             "LEF1",
#             "LGALS3",
#             "LMNA",
#             "LUM",
#             "MADD",
#             "MCL1",
#             "MGMT",
#             "MMP2",
#             "NEDD9",
#             "NEFH",
#             "PAK1",
#             "PDCD4",
#             "PDGFRB",
#             "PEA15",
#             "PLAT",
#             "PLCB2",
#             "PLPPR4",
#             "PMAIP1",
#             "PPP2R5B",
#             "PPP3R1",
#             "PPT1",
#             "PRF1",
#             "PSEN1",
#             "PSEN2",
#             "PTK2",
#             "RARA",
#             "RELA",
#             "RETSAT",
#             "RHOB",
#             "RHOT2",
#             "RNASEL",
#             "ROCK1",
#             "SAT1",
#             "SATB1",
#             "SC5D",
#             "SLC20A1",
#             "SMAD7",
#             "SOD1",
#             "SOD2",
#             "SPTAN1",
#             "SQSTM1",
#             "TAP1",
#             "TGFB2",
#             "TGFBR3",
#             "TIMP1",
#             "TIMP2",
#             "TIMP3",
#             "TNF",
#             "TNFRSF12A",
#             "TNFSF10",
#             "TOP2A",
#             "TSPO",
#             "TXNIP",
#             "VDAC2",
#             "WEE1",
#             "XIAP"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_NOTCH_SIGNALING": {
#         "collection": "H",
#         "systematicName": "M5903",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_NOTCH_SIGNALING",
#         "geneSymbols": [
#             "APH1A",
#             "ARRB1",
#             "CCND1",
#             "CUL1",
#             "DLL1",
#             "DTX1",
#             "DTX2",
#             "DTX4",
#             "FBXW11",
#             "FZD1",
#             "FZD5",
#             "FZD7",
#             "HES1",
#             "HEYL",
#             "JAG1",
#             "KAT2A",
#             "LFNG",
#             "MAML2",
#             "NOTCH1",
#             "NOTCH2",
#             "NOTCH3",
#             "PPARD",
#             "PRKCA",
#             "PSEN2",
#             "PSENEN",
#             "RBX1",
#             "SAP30",
#             "SKP1",
#             "ST3GAL6",
#             "TCF7L2",
#             "WNT2",
#             "WNT5A"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_ADIPOGENESIS": {
#         "collection": "H",
#         "systematicName": "M5905",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_ADIPOGENESIS",
#         "geneSymbols": [
#             "ABCA1",
#             "ABCB8",
#             "ACAA2",
#             "ACADL",
#             "ACADM",
#             "ACADS",
#             "ACLY",
#             "ACO2",
#             "ACOX1",
#             "ADCY6",
#             "ADIG",
#             "ADIPOQ",
#             "ADIPOR2",
#             "AGPAT3",
#             "AIFM1",
#             "AK2",
#             "ALDH2",
#             "ALDOA",
#             "ANGPT1",
#             "ANGPTL4",
#             "APLP2",
#             "APOE",
#             "ARAF",
#             "ARL4A",
#             "ATL2",
#             "ATP1B3",
#             "ATP5PO",
#             "BAZ2A",
#             "BCKDHA",
#             "BCL2L13",
#             "BCL6",
#             "C3",
#             "CAT",
#             "CAVIN1",
#             "CAVIN2",
#             "CCNG2",
#             "CD151",
#             "CD302",
#             "CD36",
#             "CDKN2C",
#             "CHCHD10",
#             "CHUK",
#             "CIDEA",
#             "CMBL",
#             "CMPK1",
#             "COL15A1",
#             "COL4A1",
#             "COQ3",
#             "COQ5",
#             "COQ9",
#             "COX6A1",
#             "COX7B",
#             "COX8A",
#             "CPT2",
#             "CRAT",
#             "CS",
#             "CYC1",
#             "CYP4B1",
#             "DBT",
#             "DDT",
#             "DECR1",
#             "DGAT1",
#             "DHCR7",
#             "DHRS7",
#             "DHRS7B",
#             "DLAT",
#             "DLD",
#             "DNAJB9",
#             "DNAJC15",
#             "DRAM2",
#             "ECH1",
#             "ECHS1",
#             "ELMOD3",
#             "ELOVL6",
#             "ENPP2",
#             "EPHX2",
#             "ESRRA",
#             "ESYT1",
#             "ETFB",
#             "FABP4",
#             "FAH",
#             "FZD4",
#             "G3BP2",
#             "GADD45A",
#             "GBE1",
#             "GHITM",
#             "GPAM",
#             "GPAT4",
#             "GPD2",
#             "GPHN",
#             "GPX3",
#             "GPX4",
#             "GRPEL1",
#             "HADH",
#             "HIBCH",
#             "HSPB8",
#             "IDH1",
#             "IDH3A",
#             "IDH3G",
#             "IFNGR1",
#             "IMMT",
#             "ITGA7",
#             "ITIH5",
#             "ITSN1",
#             "JAGN1",
#             "LAMA4",
#             "LEP",
#             "LIFR",
#             "LIPE",
#             "LPCAT3",
#             "LPL",
#             "LTC4S",
#             "MAP4K3",
#             "MCCC1",
#             "MDH2",
#             "ME1",
#             "MGLL",
#             "MGST3",
#             "MIGA2",
#             "MRAP",
#             "MRPL15",
#             "MTARC2",
#             "MTCH2",
#             "MYLK",
#             "NABP1",
#             "NDUFA5",
#             "NDUFAB1",
#             "NDUFB7",
#             "NDUFS3",
#             "NKIRAS1",
#             "NMT1",
#             "OMD",
#             "ORM1",
#             "PDCD4",
#             "PEMT",
#             "PEX14",
#             "PFKFB3",
#             "PFKL",
#             "PGM1",
#             "PHLDB1",
#             "PHYH",
#             "PIM3",
#             "PLIN2",
#             "POR",
#             "PPARG",
#             "PPM1B",
#             "PPP1R15B",
#             "PRDX3",
#             "PREB",
#             "PTCD3",
#             "PTGER3",
#             "QDPR",
#             "RAB34",
#             "REEP5",
#             "REEP6",
#             "RETN",
#             "RETSAT",
#             "RIOK3",
#             "RMDN3",
#             "RNF11",
#             "RREB1",
#             "RTN3",
#             "SAMM50",
#             "SCARB1",
#             "SCP2",
#             "SDHB",
#             "SDHC",
#             "SLC19A1",
#             "SLC1A5",
#             "SLC25A1",
#             "SLC25A10",
#             "SLC27A1",
#             "SLC5A6",
#             "SLC66A3",
#             "SNCG",
#             "SOD1",
#             "SORBS1",
#             "SOWAHC",
#             "SPARCL1",
#             "SQOR",
#             "SSPN",
#             "STAT5A",
#             "STOM",
#             "SUCLG1",
#             "SULT1A1",
#             "TALDO1",
#             "TANK",
#             "TKT",
#             "TOB1",
#             "TST",
#             "UBC",
#             "UBQLN1",
#             "UCK1",
#             "UCP2",
#             "UQCR10",
#             "UQCR11",
#             "UQCRC1",
#             "UQCRQ",
#             "VEGFB",
#             "YWHAG"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_ESTROGEN_RESPONSE_EARLY": {
#         "collection": "H",
#         "systematicName": "M5906",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_ESTROGEN_RESPONSE_EARLY",
#         "geneSymbols": [
#             "ABAT",
#             "ABCA3",
#             "ABHD2",
#             "ABLIM1",
#             "ADCY1",
#             "ADCY9",
#             "ADD3",
#             "AFF1",
#             "AKAP1",
#             "ALDH3B1",
#             "AMFR",
#             "ANXA9",
#             "AQP3",
#             "AR",
#             "AREG",
#             "ARL3",
#             "ASB13",
#             "B4GALT1",
#             "BAG1",
#             "BCL11B",
#             "BCL2",
#             "BHLHE40",
#             "BLVRB",
#             "CA12",
#             "CALB2",
#             "CALCR",
#             "CANT1",
#             "CBFA2T3",
#             "CCN5",
#             "CCND1",
#             "CD44",
#             "CELSR1",
#             "CELSR2",
#             "CHPT1",
#             "CISH",
#             "CLDN7",
#             "CLIC3",
#             "CXCL12",
#             "CYP26B1",
#             "DEPTOR",
#             "DHCR7",
#             "DHRS2",
#             "DHRS3",
#             "DLC1",
#             "DYNLT3",
#             "EEIG1",
#             "EGR3",
#             "ELF1",
#             "ELF3",
#             "ELOVL2",
#             "ELOVL5",
#             "ENDOD1",
#             "ESRP2",
#             "FARP1",
#             "FASN",
#             "FCMR",
#             "FDFT1",
#             "FHL2",
#             "FKBP4",
#             "FKBP5",
#             "FLNB",
#             "FOS",
#             "FOXC1",
#             "FRK",
#             "GAB2",
#             "GFRA1",
#             "GJA1",
#             "GLA",
#             "GREB1",
#             "HES1",
#             "HR",
#             "HSPB8",
#             "IGF1R",
#             "IGFBP4",
#             "IL17RB",
#             "IL6ST",
#             "INHBB",
#             "INPP5F",
#             "ISG20L2",
#             "ITPK1",
#             "JAK2",
#             "KAZN",
#             "KCNK15",
#             "KCNK5",
#             "KDM4B",
#             "KLF10",
#             "KLF4",
#             "KLK10",
#             "KRT13",
#             "KRT15",
#             "KRT18",
#             "KRT19",
#             "KRT8",
#             "LAD1",
#             "LRIG1",
#             "MAPT",
#             "MAST4",
#             "MED13L",
#             "MED24",
#             "MICB",
#             "MINDY1",
#             "MLPH",
#             "MPPED2",
#             "MREG",
#             "MSMB",
#             "MUC1",
#             "MYB",
#             "MYBBP1A",
#             "MYBL1",
#             "MYC",
#             "MYOF",
#             "NADSYN1",
#             "NAV2",
#             "NBL1",
#             "NCOR2",
#             "NHERF1",
#             "NPY1R",
#             "NRIP1",
#             "NXT1",
#             "OLFM1",
#             "OLFML3",
#             "OPN3",
#             "OVOL2",
#             "P2RY2",
#             "PAPSS2",
#             "PDLIM3",
#             "PDZK1",
#             "PEX11A",
#             "PGR",
#             "PLAAT3",
#             "PMAIP1",
#             "PODXL",
#             "PPIF",
#             "PRSS23",
#             "PTGES",
#             "RAB17",
#             "RAB31",
#             "RAPGEFL1",
#             "RARA",
#             "RASGRP1",
#             "RBBP8",
#             "REEP1",
#             "RET",
#             "RETREG1",
#             "RHOBTB3",
#             "RHOD",
#             "RPS6KA2",
#             "RRP12",
#             "SCARB1",
#             "SCNN1A",
#             "SEC14L2",
#             "SEMA3B",
#             "SFN",
#             "SH3BP5",
#             "SIAH2",
#             "SLC16A1",
#             "SLC19A2",
#             "SLC1A1",
#             "SLC1A4",
#             "SLC22A5",
#             "SLC24A3",
#             "SLC26A2",
#             "SLC27A2",
#             "SLC2A1",
#             "SLC37A1",
#             "SLC39A6",
#             "SLC7A2",
#             "SLC7A5",
#             "SNX24",
#             "SOX3",
#             "STC2",
#             "SULT2B1",
#             "SVIL",
#             "SYBU",
#             "SYNGR1",
#             "SYT12",
#             "TBC1D30",
#             "TFAP2C",
#             "TFF1",
#             "TFF3",
#             "TGIF2",
#             "TGM2",
#             "THSD4",
#             "TIAM1",
#             "TIPARP",
#             "TJP3",
#             "TMEM164",
#             "TMPRSS3",
#             "TOB1",
#             "TPBG",
#             "TPD52L1",
#             "TSKU",
#             "TTC39A",
#             "TUBB2B",
#             "UGCG",
#             "UNC119",
#             "WFS1",
#             "WWC1",
#             "XBP1",
#             "ZNF185"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_ESTROGEN_RESPONSE_LATE": {
#         "collection": "H",
#         "systematicName": "M5907",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_ESTROGEN_RESPONSE_LATE",
#         "geneSymbols": [
#             "ABCA3",
#             "ABHD2",
#             "ACOX2",
#             "ADD3",
#             "AFF1",
#             "AGR2",
#             "ALDH3A2",
#             "ALDH3B1",
#             "AMFR",
#             "ANXA9",
#             "AREG",
#             "ARL3",
#             "ASCL1",
#             "ASS1",
#             "ATP2B4",
#             "BAG1",
#             "BATF",
#             "BCL2",
#             "BLVRB",
#             "BTG3",
#             "CA12",
#             "CA2",
#             "CACNA2D2",
#             "CALCR",
#             "CAV1",
#             "CCN5",
#             "CCNA1",
#             "CCND1",
#             "CD44",
#             "CD9",
#             "CDC20",
#             "CDC6",
#             "CDH1",
#             "CELSR2",
#             "CHPT1",
#             "CHST8",
#             "CISH",
#             "CKB",
#             "CLIC3",
#             "COX6C",
#             "CPE",
#             "CXCL12",
#             "CXCL14",
#             "CYP26B1",
#             "CYP4F11",
#             "DCXR",
#             "DHCR7",
#             "DHRS2",
#             "DLG5",
#             "DNAJC1",
#             "DNAJC12",
#             "DUSP2",
#             "DYNLT3",
#             "EEIG1",
#             "EGR3",
#             "ELOVL5",
#             "EMP2",
#             "ETFB",
#             "FABP5",
#             "FARP1",
#             "FDFT1",
#             "FGFR3",
#             "FKBP4",
#             "FKBP5",
#             "FLNB",
#             "FOS",
#             "FOXC1",
#             "FRK",
#             "GAL",
#             "GALE",
#             "GFUS",
#             "GINS2",
#             "GJB3",
#             "GLA",
#             "GPER1",
#             "HMGCS2",
#             "HOMER2",
#             "HPRT1",
#             "HR",
#             "HSPA4L",
#             "HSPB8",
#             "ID2",
#             "IDH2",
#             "IGFBP4",
#             "IGSF1",
#             "IL17RB",
#             "IL6ST",
#             "IMPA2",
#             "ISG20",
#             "ITPK1",
#             "JAK1",
#             "JAK2",
#             "KCNK5",
#             "KIF20A",
#             "KLF4",
#             "KLK10",
#             "KLK11",
#             "KRT13",
#             "KRT19",
#             "LAMC2",
#             "LARGE1",
#             "LLGL2",
#             "LSR",
#             "LTF",
#             "MAPK13",
#             "MAPT",
#             "MDK",
#             "MEST",
#             "METTL3",
#             "MICB",
#             "MOCS2",
#             "MYB",
#             "MYOF",
#             "NAB2",
#             "NBL1",
#             "NCOR2",
#             "NHERF1",
#             "NMU",
#             "NPY1R",
#             "NRIP1",
#             "NXT1",
#             "OLFM1",
#             "OPN3",
#             "OVOL2",
#             "PAPSS2",
#             "PCP4",
#             "PDCD4",
#             "PDLIM3",
#             "PDZK1",
#             "PERP",
#             "PGR",
#             "PKP3",
#             "PLAAT3",
#             "PLAC1",
#             "PLK4",
#             "PLXNB1",
#             "PPIF",
#             "PRKAR2B",
#             "PRLR",
#             "PRSS23",
#             "PTGER3",
#             "PTGES",
#             "PTPN6",
#             "RAB31",
#             "RABEP1",
#             "RAPGEFL1",
#             "RBBP8",
#             "RET",
#             "RNASEH2A",
#             "RPS6KA2",
#             "S100A9",
#             "SCARB1",
#             "SCNN1A",
#             "SCUBE2",
#             "SEMA3B",
#             "SERPINA1",
#             "SERPINA3",
#             "SERPINA5",
#             "SFN",
#             "SGK1",
#             "SIAH2",
#             "SLC16A1",
#             "SLC1A4",
#             "SLC22A5",
#             "SLC24A3",
#             "SLC26A2",
#             "SLC27A2",
#             "SLC29A1",
#             "SLC2A8",
#             "SLC7A5",
#             "SNX10",
#             "SORD",
#             "SOX3",
#             "ST14",
#             "ST6GALNAC2",
#             "STIL",
#             "SULT2B1",
#             "TFAP2C",
#             "TFF1",
#             "TFF3",
#             "TFPI2",
#             "TH",
#             "TIAM1",
#             "TJP3",
#             "TMPRSS3",
#             "TNNC1",
#             "TOB1",
#             "TOP2A",
#             "TPBG",
#             "TPD52L1",
#             "TPSAB1",
#             "TRIM29",
#             "TSPAN13",
#             "TST",
#             "UGDH",
#             "UNC13B",
#             "WFS1",
#             "XBP1",
#             "XRCC3",
#             "ZFP36"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_ANDROGEN_RESPONSE": {
#         "collection": "H",
#         "systematicName": "M5908",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_ANDROGEN_RESPONSE",
#         "geneSymbols": [
#             "ABCC4",
#             "ABHD2",
#             "ACSL3",
#             "ACTN1",
# ...
#             "HLA-E",
#             "HLA-G",
#             "ICAM1",
#             "ICOSLG",
#             "IFNAR2",
#             "IFNG",
#             "IFNGR1",
#             "IFNGR2",
#             "IGSF6",
#             "IKBKB",
#             "IL10",
#             "IL11",
#             "IL12A",
#             "IL12B",
#             "IL12RB1",
#             "IL13",
#             "IL15",
#             "IL16",
#             "IL18",
#             "IL18RAP",
#             "IL1B",
#             "IL2",
#             "IL27RA",
#             "IL2RA",
#             "IL2RB",
#             "IL2RG",
#             "IL4",
#             "IL4R",
#             "IL6",
#             "IL7",
#             "IL9",
#             "INHBA",
#             "INHBB",
#             "IRF4",
#             "IRF7",
#             "IRF8",
#             "ITGAL",
#             "ITGB2",
#             "ITK",
#             "JAK2",
#             "KLRD1",
#             "KRT1",
#             "LCK",
#             "LCP2",
#             "LIF",
#             "LTB",
#             "LY75",
#             "LY86",
#             "LYN",
#             "MAP3K7",
#             "MAP4K1",
#             "MBL2",
#             "MMP9",
#             "MRPL3",
#             "MTIF2",
#             "NCF4",
#             "NCK1",
#             "NCR1",
#             "NLRP3",
#             "NME1",
#             "NOS2",
#             "NPM1",
#             "PF4",
#             "PRF1",
#             "PRKCB",
#             "PRKCG",
#             "PSMB10",
#             "PTPN6",
#             "PTPRC",
#             "RARS1",
#             "RIPK2",
#             "RPL39",
#             "RPL3L",
#             "RPL9",
#             "RPS19",
#             "RPS3A",
#             "RPS9",
#             "SIT1",
#             "SOCS1",
#             "SOCS5",
#             "SPI1",
#             "SRGN",
#             "ST8SIA4",
#             "STAB1",
#             "STAT1",
#             "STAT4",
#             "TAP1",
#             "TAP2",
#             "TAPBP",
#             "TGFB1",
#             "TGFB2",
#             "THY1",
#             "TIMP1",
#             "TLR1",
#             "TLR2",
#             "TLR3",
#             "TLR6",
#             "TNF",
#             "TPD52",
#             "TRAF2",
#             "TRAT1",
#             "UBE2D1",
#             "UBE2N",
#             "WARS1",
#             "WAS",
#             "ZAP70"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_SPERMATOGENESIS": {
#         "collection": "H",
#         "systematicName": "M5951",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_SPERMATOGENESIS",
#         "geneSymbols": [
#             "ACE",
#             "ACRBP",
#             "ACRV1",
#             "ACTL7B",
#             "ADAD1",
#             "ADAM2",
#             "ADCYAP1",
#             "AGFG1",
#             "AKAP4",
#             "ALOX15",
#             "ARL4A",
#             "ART3",
#             "AURKA",
#             "BRAF",
#             "BUB1",
#             "CAMK4",
#             "CCNA1",
#             "CCNB2",
#             "CCT6B",
#             "CDK1",
#             "CDKN3",
#             "CFTR",
#             "CHFR",
#             "CHRM4",
#             "CLGN",
#             "CLPB",
#             "CLVS1",
#             "CNIH2",
#             "COIL",
#             "CRISP2",
#             "CSNK2A2",
#             "CST8",
#             "DBF4",
#             "DCC",
#             "DDX25",
#             "DDX4",
#             "DMC1",
#             "DMRT1",
#             "DNAJB8",
#             "DPEP3",
#             "ELOVL3",
#             "EZH2",
#             "GAD1",
#             "GAPDHS",
#             "GFI1",
#             "GMCL1",
#             "GPR182",
#             "GRM8",
#             "GSG1",
#             "GSTM3",
#             "H1-6",
#             "HBZ",
#             "HOXB1",
#             "HSPA1L",
#             "HSPA2",
#             "HSPA4L",
#             "HTR5A",
#             "IDE",
#             "IFT88",
#             "IL12RB2",
#             "IL13RA2",
#             "IP6K1",
#             "JAM3",
#             "KIF2C",
#             "LDHC",
#             "LPIN1",
#             "MAP7",
#             "MAST2",
#             "MEP1B",
#             "MLF1",
#             "MLLT10",
#             "MTNR1A",
#             "MTOR",
#             "NAA11",
#             "NCAPH",
#             "NEFH",
#             "NEK2",
#             "NF2",
#             "NOS1",
#             "NPHP1",
#             "NPY5R",
#             "OAZ3",
#             "ODF1",
#             "PACRG",
#             "PAPOLB",
#             "PARP2",
#             "PCSK1N",
#             "PCSK4",
#             "PDHA2",
#             "PEBP1",
#             "PGK2",
#             "PGS1",
#             "PHF7",
#             "PHKG2",
#             "PIAS2",
#             "POMC",
#             "PRKAR2A",
#             "PRM2",
#             "PSMG1",
#             "RAD17",
#             "RFC4",
#             "RPL39L",
#             "SCG3",
#             "SCG5",
#             "SEPTIN4",
#             "SHE",
#             "SIRT1",
#             "SLC12A2",
#             "SLC2A5",
#             "SNAP91",
#             "SPATA6",
#             "SPMAP2",
#             "STAM2",
#             "STRBP",
#             "SYCP1",
#             "TALDO1",
#             "TCP11",
#             "TEKT2",
#             "TKTL1",
#             "TLE4",
#             "TNNI3",
#             "TNP1",
#             "TNP2",
#             "TOPBP1",
#             "TSN",
#             "TSSK2",
#             "TTK",
#             "TUBA3C",
#             "TULP2",
#             "VDAC3",
#             "YBX2",
#             "ZC2HC1C",
#             "ZC3H14",
#             "ZNRF4",
#             "ZPBP"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_KRAS_SIGNALING_UP": {
#         "collection": "H",
#         "systematicName": "M5953",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_KRAS_SIGNALING_UP",
#         "geneSymbols": [
#             "ABCB1",
#             "ACE",
#             "ADAM17",
#             "ADAM8",
#             "ADAMDEC1",
#             "ADGRA2",
#             "ADGRL4",
#             "AKAP12",
#             "AKT2",
#             "ALDH1A2",
#             "ALDH1A3",
#             "AMMECR1",
#             "ANGPTL4",
#             "ANKH",
#             "ANO1",
#             "ANXA10",
#             "APOD",
#             "ARG1",
#             "ATG10",
#             "AVL9",
#             "BIRC3",
#             "BMP2",
#             "BPGM",
#             "BTBD3",
#             "BTC",
#             "C3AR1",
#             "CA2",
#             "CAB39L",
#             "CBL",
#             "CBR4",
#             "CBX8",
#             "CCL20",
#             "CCND2",
#             "CCSER2",
#             "CD37",
#             "CDADC1",
#             "CFB",
#             "CFH",
#             "CFHR2",
#             "CIDEA",
#             "CLEC4A",
#             "CMKLR1",
#             "CPE",
#             "CROT",
#             "CSF2",
#             "CSF2RA",
#             "CTSS",
#             "CXCL10",
#             "CXCR4",
#             "DCBLD2",
#             "DNMBP",
#             "DOCK2",
#             "DUSP6",
#             "EMP1",
#             "ENG",
#             "EPB41L3",
#             "EPHB2",
#             "EREG",
#             "ERO1A",
#             "ETS1",
#             "ETV1",
#             "ETV4",
#             "ETV5",
#             "EVI5",
#             "F13A1",
#             "F2RL1",
#             "FBXO4",
#             "FCER1G",
#             "FGF9",
#             "FLT4",
#             "FUCA1",
#             "G0S2",
#             "GABRA3",
#             "GADD45G",
#             "GALNT3",
#             "GFPT2",
#             "GLRX",
#             "GNG11",
#             "GPNMB",
#             "GPRC5B",
#             "GUCY1A1",
#             "GYPC",
#             "H2BC3",
#             "HBEGF",
#             "HDAC9",
#             "HKDC1",
#             "HOXD11",
#             "HSD11B1",
#             "ID2",
#             "IGF2",
#             "IGFBP3",
#             "IKZF1",
#             "IL10RA",
#             "IL1B",
#             "IL1RL2",
#             "IL2RG",
#             "IL33",
#             "IL7R",
#             "INHBA",
#             "IRF8",
#             "ITGA2",
#             "ITGB2",
#             "ITGBL1",
#             "JUP",
#             "KCNN4",
#             "KIF5C",
#             "KLF4",
#             "LAPTM5",
#             "LAT2",
#             "LCP1",
#             "LIF",
#             "LY96",
#             "MAFB",
#             "MALL",
#             "MAP3K1",
#             "MAP4K1",
#             "MAP7",
#             "MMD",
#             "MMP10",
#             "MMP11",
#             "MMP9",
#             "MPZL2",
#             "MTMR10",
#             "MYCN",
#             "NAP1L2",
#             "NGF",
#             "NIN",
#             "NR0B2",
#             "NR1H4",
#             "NRP1",
#             "PCP4",
#             "PCSK1N",
#             "PDCD1LG2",
#             "PECAM1",
#             "PEG3",
#             "PIGR",
#             "PLAT",
#             "PLAU",
#             "PLAUR",
#             "PLEK2",
#             "PLVAP",
#             "PPBP",
#             "PPP1R15A",
#             "PRDM1",
#             "PRELID3B",
#             "PRKG2",
#             "PRRX1",
#             "PSMB8",
#             "PTBP2",
#             "PTCD2",
#             "PTGS2",
#             "PTPRR",
#             "RABGAP1L",
#             "RBM4",
#             "RBP4",
#             "RELN",
#             "RETN",
#             "RGS16",
#             "SATB1",
#             "SCG3",
#             "SCG5",
#             "SCN1B",
#             "SDCCAG8",
#             "SEMA3B",
#             "SERPINA3",
#             "SLPI",
#             "SNAP25",
#             "SNAP91",
#             "SOX9",
#             "SPARCL1",
#             "SPON1",
#             "SPP1",
#             "SPRY2",
#             "ST6GAL1",
#             "STRN",
#             "TFPI",
#             "TLR8",
#             "TMEM100",
#             "TMEM158",
#             "TMEM176A",
#             "TMEM176B",
#             "TNFAIP3",
#             "TNFRSF1B",
#             "TNNT2",
#             "TOR1AIP2",
#             "TPH1",
#             "TRAF1",
#             "TRIB1",
#             "TRIB2",
#             "TSPAN1",
#             "TSPAN13",
#             "TSPAN7",
#             "USH1C",
#             "USP12",
#             "VWA5A",
#             "WDR33",
#             "WNT7A",
#             "YRDC",
#             "ZNF277",
#             "ZNF639"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_KRAS_SIGNALING_DN": {
#         "collection": "H",
#         "systematicName": "M5956",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_KRAS_SIGNALING_DN",
#         "geneSymbols": [
#             "ABCB11",
#             "ABCG4",
#             "ACTC1",
#             "ADRA2C",
#             "AKR1B10",
#             "ALOX12B",
#             "AMBN",
#             "ARHGDIG",
#             "ARPP21",
#             "ASB7",
#             "ATP4A",
#             "ATP6V1B1",
#             "BARD1",
#             "BMPR1B",
#             "BRDT",
#             "BTG2",
#             "C5",
#             "CACNA1F",
#             "CACNG1",
#             "CALCB",
#             "CALML5",
#             "CAMK1D",
#             "CAPN9",
#             "CCDC106",
#             "CCNA1",
#             "CCR8",
#             "CD207",
#             "CD40LG",
#             "CD80",
#             "CDH16",
#             "CDKAL1",
#             "CELSR2",
#             "CHRNG",
#             "CHST2",
#             "CKM",
#             "CLDN16",
#             "CLDN8",
#             "CLPS",
#             "CLSTN3",
#             "CNTFR",
#             "COL2A1",
#             "COPZ2",
#             "COQ8A",
#             "CPA2",
#             "CPB1",
#             "CPEB3",
#             "CYP11B2",
#             "CYP39A1",
#             "DCC",
#             "DLK2",
#             "DTNB",
#             "EDAR",
#             "EDN1",
#             "EDN2",
#             "EFHD1",
#             "EGF",
#             "ENTPD7",
#             "EPHA5",
#             "FGF16",
#             "FGF22",
#             "FGFR3",
#             "FGGY",
#             "FSHB",
#             "GAMT",
#             "GDNF",
#             "GP1BA",
#             "GP2",
#             "GPR19",
#             "GPR3",
#             "GPRC5C",
#             "GRID2",
#             "GTF3C5",
#             "HNF1A",
#             "HSD11B2",
#             "HTR1B",
#             "HTR1D",
#             "IDUA",
#             "IFI44L",
#             "IFNG",
#             "IGFBP2",
#             "IL12B",
#             "IL5",
#             "INSL5",
#             "IRS4",
#             "ITGB1BP2",
#             "ITIH3",
#             "KCND1",
#             "KCNE2",
#             "KCNMB1",
#             "KCNN1",
#             "KCNQ2",
#             "KLHDC8A",
#             "KLK7",
#             "KLK8",
#             "KMT2D",
#             "KRT1",
#             "KRT13",
#             "KRT15",
#             "KRT4",
#             "KRT5",
#             "LFNG",
#             "LGALS7",
#             "LYPD3",
#             "MACROH2A2",
#             "MAGIX",
#             "MAST3",
#             "MEFV",
#             "MFSD6",
#             "MSH5",
#             "MTHFR",
#             "MX1",
#             "MYH7",
#             "MYO15A",
#             "MYOT",
#             "NGB",
#             "NOS1",
#             "NPHS1",
#             "NPY4R",
#             "NR4A2",
#             "NR6A1",
#             "NRIP2",
#             "NTF3",
#             "NUDT11",
#             "OXT",
#             "P2RX6",
#             "P2RY4",
#             "PAX3",
#             "PAX4",
#             "PCDHB1",
#             "PDCD1",
#             "PDE6B",
#             "PDK2",
#             "PKP1",
#             "PLAG1",
#             "PNMT",
#             "PRKN",
#             "PRODH",
#             "PROP1",
#             "PTGFR",
#             "PTPRJ",
#             "RGS11",
#             "RIBC2",
#             "RSAD2",
#             "RYR1",
#             "RYR2",
#             "SCGB1A1",
#             "SCN10A",
#             "SELENOP",
#             "SERPINA10",
#             "SERPINB2",
#             "SGK1",
#             "SHOX2",
#             "SIDT1",
#             "SKIL",
#             "SLC12A3",
#             "SLC16A7",
#             "SLC25A23",
#             "SLC29A3",
#             "SLC30A3",
#             "SLC38A3",
#             "SLC5A5",
#             "SLC6A14",
#             "SLC6A3",
#             "SMPX",
#             "SNCB",
#             "SNN",
#             "SOX10",
#             "SPHK2",
#             "SPRR3",
#             "SPTBN2",
#             "SSTR4",
#             "STAG3",
#             "SYNPO",
#             "TAS2R4",
#             "TCF7L1",
#             "TCL1A",
#             "TENM2",
#             "TENT5C",
#             "TEX15",
#             "TFAP2B",
#             "TFCP2L1",
#             "TFF2",
#             "TG",
#             "TGFB2",
#             "TGM1",
#             "THNSL2",
#             "THRB",
#             "TLX1",
#             "TNNI3",
#             "TSHB",
#             "UGT2B17",
#             "UPK3B",
#             "VPREB1",
#             "VPS50",
#             "WNT16",
#             "YBX2",
#             "YPEL1",
#             "ZBTB16",
#             "ZC2HC1C",
#             "ZNF112"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     },
#     "HALLMARK_PANCREAS_BETA_CELLS": {
#         "collection": "H",
#         "systematicName": "M5957",
#         "pmid": "26771021",
#         "exactSource": "",
#         "externalDetailsURL": "",
#         "msigdbURL": "https://www.gsea-msigdb.org/gsea/msigdb/human/geneset/HALLMARK_PANCREAS_BETA_CELLS",
#         "geneSymbols": [
#             "ABCC8",
#             "AKT3",
#             "CHGA",
#             "DCX",
#             "DPP4",
#             "ELP4",
#             "FOXA2",
#             "FOXO1",
#             "G6PC2",
#             "GCG",
#             "GCK",
#             "HNF1A",
#             "IAPP",
#             "INS",
#             "INSM1",
#             "ISL1",
#             "LMO2",
#             "MAFB",
#             "NEUROD1",
#             "NEUROG3",
#             "NKX2-2",
#             "NKX6-1",
#             "PAK3",
#             "PAX4",
#             "PAX6",
#             "PCSK1",
#             "PCSK2",
#             "PDX1",
#             "PKLR",
#             "SCGN",
#             "SEC11A",
#             "SLC2A2",
#             "SPCS1",
#             "SRP14",
#             "SRP9",
#             "SRPRB",
#             "SST",
#             "STXBP1",
#             "SYT13",
#             "VDR"
#         ],
#         "filteredBySimilarity": [],
#         "externalNamesForSimilarTerms": []
#     }
# }

# %%
#Converts the gene symbols we collected fromthe json to the gene name and ENSG code that is used in the column names of donor_adata
def build_marker_list(symbols, donor_adata):
  markers=[]
  for symbol in symbols:
    matches = [g for g in donor_adata.var_names if g.endswith(f"_{symbol}")]
    if len(matches) == 1:
      markers.append(matches[0])
    elif len(matches) > 1:
      print(f"Multiple matches for {symbol}: {matches}")
    else:
      print(f"No matches for {symbol}")
  return markers

# %%
pathways = pd.DataFrame(data)
pathway_dict = pathways.loc['geneSymbols'].to_dict()
gene_ids = {}
for key in pathway_dict:
  gene_ids[key] = build_marker_list(pathway_dict[key], donor_adata)
# Out:
# No matches for AREG
# No matches for B4GALT5
# No matches for BCL2A1
# No matches for BCL3
# No matches for BCL6
# No matches for BIRC3
# No matches for CCL20
# No matches for CCL4
# No matches for CCL5
# No matches for CCN1
# No matches for CCRL2
# No matches for CD69
# No matches for CD80
# No matches for CEBPD
# No matches for CLCF1
# No matches for CSF1
# No matches for CSF2
# No matches for CXCL1
# No matches for CXCL10
# No matches for CXCL11
# No matches for CXCL2
# No matches for EDN1
# No matches for EGR2
# No matches for EGR3
# No matches for FOSB
# No matches for FOSL2
# No matches for FUT4
# No matches for G0S2
# No matches for GEM
# No matches for GPR183
# No matches for HBEGF
# No matches for ICAM1
# No matches for ICOSLG
# No matches for IFIH1
# No matches for IFIT2
# No matches for IL12B
# No matches for IL15RA
# No matches for IL18
# No matches for IL1A
# No matches for IL1B
# No matches for IL6
# No matches for IL7R
# No matches for INHBA
# No matches for IRS2
# No matches for JAG1
# No matches for KLF2
# No matches for KLF4
# No matches for KLF9
# No matches for KYNU
# No matches for LAMB3
# No matches for LIF
# No matches for MSC
# No matches for MXD1
# No matches for NFIL3
# No matches for NFKB1
# No matches for NFKB2
# No matches for NR4A2
# No matches for NR4A3
# No matches for OLR1
# No matches for PDE4B
# No matches for PLEK
# No matches for PLPP3
# No matches for PTGER4
# No matches for PTGS2
# No matches for PTPRE
# No matches for PTX3
# No matches for RCAN1
# No matches for RIGI
# No matches for RNF19B
# No matches for SERPINB2
# No matches for SERPINB8
# No matches for SIK1
# No matches for SLC16A6
# No matches for SPSB1
# No matches for STAT5A
# No matches for TAP1
# No matches for TLR2
# No matches for TNC
# No matches for TNF
# No matches for TNFAIP3
# No matches for TNFAIP6
# No matches for TNFRSF9
# No matches for TNFSF9
# No matches for TRAF1
# No matches for VEGFA
# No matches for ZBTB10
# No matches for ALDOB
# No matches for AMPD3
# No matches for ATP7A
# No matches for B4GALNT2
# No matches for BCAN
# No matches for BCL2
# No matches for BGN
# No matches for BRS3
# No matches for CA12
# No matches for CAVIN1
# No matches for CAVIN3
# No matches for CCN1
# No matches for CCN2
# No matches for CCN5
# No matches for CHST2
# No matches for CHST3
# No matches for CP
# No matches for DCN
# No matches for EDN2
# No matches for EGFR
# No matches for ERO1A
# No matches for FOSL2
# No matches for HAS1
# No matches for HOXB9
# No matches for HS3ST1
# No matches for IGFBP1
# No matches for IL6
# No matches for INHA
# No matches for IRS2
# No matches for KIF5A
# No matches for LALBA
# No matches for LARGE1
# No matches for LDHC
# No matches for LOX
# No matches for NCAN
# No matches for NDRG1
# No matches for NFIL3
# No matches for NOCT
# No matches for PCK1
# No matches for PHKG1
# No matches for PKLR
# No matches for PKP1
# No matches for PPARGC1A
# No matches for PPFIA4
# No matches for PPP1R3C
# No matches for PYGM
# No matches for SDC3
# No matches for SLC2A5
# No matches for STBD1
# No matches for SULT2B1
# No matches for TGFB3
# No matches for TGM2
# No matches for TKTL1
# No matches for TNFAIP3
# No matches for VEGFA
# No matches for ABCA2
# No matches for ADH4
# No matches for ANXA13
# No matches for AVPR1A
# No matches for CPEB2
# No matches for CXCL16
# No matches for FBXO6
# No matches for JAG1
# No matches for LPL
# No matches for NFIL3
# No matches for NIBAN1
# No matches for PPARG
# No matches for SEMA3B
# No matches for ARAP3
# No matches for ARHGAP27
# No matches for ARHGEF11
# No matches for CEP131
# No matches for CLIP2
# No matches for CPAP
# No matches for DOCK2
# No matches for DYNLL2
# No matches for LLGL1
# No matches for RASAL2
# No matches for SEPTIN9
# No matches for SHROOM1
# No matches for SHROOM2
# No matches for SYNPO
# No matches for DLL1
# No matches for FRAT1
# No matches for FZD1
# No matches for FZD8
# No matches for HEY1
# No matches for JAG1
# No matches for JAG2
# No matches for NOTCH4
# No matches for WNT1
# No matches for WNT6
# No matches for LTBP2
# No matches for SKI
# No matches for A2M
# No matches for ACVRL1
# No matches for CCL7
# No matches for CCR1
# No matches for CD14
# No matches for CD36
# No matches for CD38
# No matches for CRLF2
# No matches for CSF1
# No matches for CSF2
# No matches for CSF2RB
# No matches for CSF3R
# No matches for CXCL1
# No matches for CXCL10
# No matches for CXCL11
# No matches for CXCL13
# No matches for CXCL9
# No matches for DNTT
# No matches for EBI3
# No matches for FAS
# No matches for IL12RB1
# No matches for IL15RA
# No matches for IL18R1
# No matches for IL1B
# No matches for IL1R1
# No matches for IL1R2
# No matches for IL2RA
# No matches for IL2RG
# No matches for IL3RA
# No matches for IL6
# No matches for IL7
# No matches for IL9R
# No matches for INHBE
# No matches for ITGB3
# No matches for LEPR
# No matches for LTB
# No matches for OSMR
# No matches for PDGFC
# No matches for PF4
# No matches for PLA2G2A
# No matches for REG1A
# No matches for TLR2
# No matches for TNF
# No matches for TNFRSF1B
# No matches for ADCY6
# No matches for AGO4
# No matches for CCNO
# No matches for CMPK2
# No matches for ELOA
# No matches for GSDME
# No matches for HCLS1
# No matches for PDE4B
# No matches for POLR1H
# No matches for SNAPC4
# No matches for VPS37D
# No matches for ZNF707
# No matches for BCL3
# No matches for CASP8AP2
# No matches for CDKN2C
# No matches for E2F2
# No matches for EGF
# No matches for H2AX
# No matches for H2AZ1
# No matches for H2AZ2
# No matches for H2BC12
# No matches for HIRA
# No matches for HOXC10
# No matches for JPT1
# No matches for KMT5A
# No matches for KNL1
# No matches for MAP3K20
# No matches for MEIS1
# No matches for MEIS2
# No matches for NSD2
# No matches for PRP4K
# No matches for PTTG3P
# No matches for PURA
# No matches for RASAL2
# No matches for RPS6KA5
# No matches for TENT4A
# No matches for AIFM3
# No matches for AVPR1A
# No matches for BCL2L10
# No matches for BCL2L2
# No matches for BGN
# No matches for BIRC3
# No matches for CASP1
# No matches for CASP4
# No matches for CASP8
# No matches for CCNA1
# No matches for CD14
# No matches for CD2
# No matches for CD38
# No matches for CD69
# No matches for DCN
# No matches for DPYD
# No matches for EGR3
# No matches for EMP1
# No matches for EREG
# No matches for F2
# No matches for FAS
# No matches for FASLG
# No matches for GNA15
# No matches for GUCY2D
# No matches for H1-0
# No matches for HGF
# No matches for IFNB1
# No matches for IL18
# No matches for IL1A
# No matches for IL1B
# No matches for IL6
# No matches for NEFH
# No matches for PDGFRB
# No matches for PLCB2
# No matches for PLPPR4
# No matches for PPP2R5B
# No matches for PPP3R1
# No matches for PRF1
# No matches for RNASEL
# No matches for TAP1
# No matches for TGFB2
# No matches for TGFBR3
# No matches for TIMP2
# No matches for TNF
# No matches for TNFSF10
# No matches for DLL1
# No matches for DTX1
# No matches for DTX4
# No matches for FZD1
# No matches for HEYL
# No matches for JAG1
# No matches for LFNG
# No matches for MAML2
# No matches for WNT2
# No matches for WNT5A
# No matches for ACADL
# No matches for ADCY6
# No matches for ADIG
# No matches for ADIPOQ
# No matches for AGPAT3
# No matches for ANGPT1
# No matches for ATP5PO
# No matches for BCL6
# No matches for CAVIN1
# No matches for CAVIN2
# No matches for CD302
# No matches for CD36
# No matches for CDKN2C
# No matches for CIDEA
# No matches for COL15A1
# No matches for CYP4B1
# No matches for ENPP2
# No matches for FABP4
# No matches for FZD4
# No matches for GPAT4
# No matches for LAMA4
# No matches for LEP
# No matches for LPL
# No matches for MGLL
# No matches for MIGA2
# No matches for MRAP
# No matches for MTARC2
# No matches for OMD
# No matches for ORM1
# No matches for PPARG
# No matches for PTGER3
# No matches for RETN
# No matches for SLC66A3
# No matches for SPARCL1
# No matches for SQOR
# No matches for SSPN
# No matches for STAT5A
# No matches for ABCA3
# No matches for ADCY1
# No matches for ADCY9
# No matches for ALDH3B1
# No matches for ANXA9
# No matches for AQP3
# No matches for AR
# No matches for AREG
# No matches for BCL11B
# No matches for BCL2
# No matches for CA12
# No matches for CALB2
# No matches for CBFA2T3
# No matches for CCN5
# No matches for CELSR1
# No matches for CELSR2
# No matches for CISH
# No matches for CLIC3
# No matches for CYP26B1
# No matches for DEPTOR
# No matches for EEIG1
# No matches for EGR3
# No matches for ELOVL2
# No matches for ENDOD1
# No matches for FCMR
# No matches for FOXC1
# No matches for FRK
# No matches for GFRA1
# No matches for HR
# No matches for INHBB
# No matches for JAK2
# No matches for KCNK15
# No matches for KLF4
# No matches for KLK10
# No matches for KRT13
# No matches for KRT15
# No matches for MAPT
# No matches for MICB
# No matches for MINDY1
# No matches for MPPED2
# No matches for MSMB
# No matches for MUC1
# No matches for MYB
# No matches for MYBL1
# No matches for NHERF1
# No matches for NPY1R
# No matches for NRIP1
# No matches for P2RY2
# No matches for PDZK1
# No matches for PGR
# No matches for PLAAT3
# No matches for RAPGEFL1
# No matches for RASGRP1
# No matches for REEP1
# No matches for RETREG1
# No matches for SEMA3B
# No matches for SFN
# No matches for SLC1A4
# No matches for SLC22A5
# No matches for SLC24A3
# No matches for SLC7A2
# No matches for SOX3
# No matches for SULT2B1
# No matches for SYBU
# No matches for SYT12
# No matches for TBC1D30
# No matches for TFF1
# No matches for TFF3
# No matches for TGM2
# No matches for THSD4
# No matches for TMEM164
# No matches for TMPRSS3
# No matches for ZNF185
# No matches for ABCA3
# No matches for ACOX2
# No matches for AGR2
# No matches for ALDH3B1
# No matches for ANXA9
# No matches for AREG
# No matches for ASCL1
# No matches for BATF
# No matches for BCL2
# No matches for CA12
# No matches for CACNA2D2
# No matches for CCN5
# No matches for CCNA1
# No matches for CELSR2
# No matches for CISH
# No matches for CLIC3
# No matches for CYP26B1
# No matches for CYP4F11
# No matches for DNAJC12
# No matches for EEIG1
# No matches for EGR3
# No matches for FGFR3
# No matches for FOXC1
# No matches for FRK
# No matches for GFUS
# No matches for GJB3
# No matches for GPER1
# No matches for HMGCS2
# No matches for HR
# No matches for JAK2
# No matches for KLF4
# No matches for KLK10
# No matches for KLK11
# No matches for KRT13
# No matches for LAMC2
# No matches for LARGE1
# No matches for LTF
# No matches for MAPT
# No matches for MICB
# No matches for MYB
# No matches for NHERF1
# No matches for NPY1R
# No matches for NRIP1
# No matches for PCP4
# No matches for PDZK1
# No matches for PGR
# No matches for PKP3
# No matches for PLAAT3
# No matches for PLAC1
# No matches for PRLR
# No matches for PTGER3
# No matches for RAPGEFL1
# No matches for S100A9
# No matches for SCUBE2
# No matches for SEMA3B
# No matches for SERPINA1
# No matches for SERPINA3
# No matches for SERPINA5
# No matches for SFN
# No matches for SLC1A4
# No matches for SLC22A5
# No matches for SLC24A3
# No matches for SOX3
# No matches for ST14
# No matches for SULT2B1
# No matches for TFF1
# No matches for TFF3
# No matches for TH
# No matches for TMPRSS3
# No matches for TPSAB1
# No matches for TRIM29
# No matches for ARID5B
# No matches for AZGP1
# No matches for BMPR1B
# No matches for ELK4
# No matches for GPD1L
# No matches for GUCY1A1
# No matches for H1-0
# No matches for HPGD
# No matches for INPP4B
# No matches for KLK2
# No matches for KLK3
# No matches for MAF
# No matches for MAK
# No matches for NDRG1
# No matches for NKX3-1
# No matches for PLPP1
# No matches for PTK2B
# No matches for SELENOP
# No matches for SPDEF
# No matches for SRF
# No matches for STEAP4
# No matches for TARP
# No matches for TMPRSS2
# No matches for ZBTB10
# No matches for ACTN2
# No matches for ACTN3
# No matches for ADAM12
# No matches for ADCY9
# No matches for AGRN
# No matches for ANKRD2
# No matches for APOD
# No matches for BDKRB2
# No matches for CACNA1H
# No matches for CACNG1
# No matches for CAMK2B
# No matches for CASQ1
# No matches for CASQ2
# No matches for CAV3
# No matches for CD36
# No matches for CFD
# No matches for CHRNA1
# No matches for CHRNG
# No matches for COL15A1
# No matches for COL3A1
# No matches for COL6A3
# No matches for COX6A2
# No matches for COX7A1
# No matches for CRYAB
# No matches for CSRP3
# No matches for CTF1
# No matches for DAPK2
# No matches for DENND2B
# No matches for DES
# No matches for FGF2
# No matches for FOXO4
# No matches for FXYD1
# No matches for GJA5
# No matches for GNAO1
# No matches for HBEGF
# No matches for HRC
# No matches for HSPB2
# No matches for IGF1
# No matches for ITGB4
# No matches for KCNH1
# No matches for KCNH2
# No matches for LAMA2
# No matches for LARGE1
# No matches for LDB3
# No matches for LSP1
# No matches for MAPRE3
# No matches for MB
# No matches for MEF2C
# No matches for MEF2D
# No matches for MYBPC3
# No matches for MYBPH
# No matches for MYF6
# No matches for MYH1
# No matches for MYH11
# No matches for MYH2
# No matches for MYH3
# No matches for MYH4
# No matches for MYH7
# No matches for MYH8
# No matches for MYL1
# No matches for MYL11
# No matches for MYL2
# No matches for MYL3
# No matches for MYOG
# No matches for MYOM1
# No matches for MYOM2
# No matches for MYOZ1
# No matches for NOS1
# No matches for PPFIA4
# No matches for PPP1R3C
# No matches for PYGM
# No matches for REEP1
# No matches for RYR1
# No matches for SGCA
# No matches for SGCD
# No matches for SGCG
# No matches for SLN
# No matches for SPDEF
# No matches for SSPN
# No matches for TCAP
# No matches for TNNI1
# No matches for TNNI2
# No matches for TNNT3
# No matches for ATP6V1B1
# No matches for ATP7A
# No matches for DOP1A
# No matches for EGFR
# No matches for OCRL
# No matches for SEC22B
# No matches for SH3GL2
# No matches for SSPN
# No matches for TSPAN8
# No matches for BATF2
# No matches for CASP1
# No matches for CASP8
# No matches for CCRL2
# No matches for CMPK2
# No matches for CSF1
# No matches for CXCL10
# No matches for CXCL11
# No matches for DDX60
# No matches for GBP2
# No matches for GBP4
# No matches for HELZ2
# No matches for HERC6
# No matches for IFI44
# No matches for IFI44L
# No matches for IFIH1
# No matches for IFIT2
# No matches for IFIT3
# No matches for IL15
# No matches for IL7
# No matches for LAMP3
# No matches for OAS1
# No matches for OASL
# No matches for PARP12
# No matches for PARP14
# No matches for PARP9
# No matches for PSMB8
# No matches for PSMB9
# No matches for RSAD2
# No matches for RTP4
# No matches for SAMD9
# No matches for SAMD9L
# No matches for SELL
# No matches for TAP1
# No matches for TENT5A
# No matches for TRIM26
# No matches for UBA7
# No matches for WARS1
# No matches for ARID5B
# No matches for BANK1
# No matches for BATF2
# No matches for C1R
# No matches for CASP1
# No matches for CASP4
# No matches for CASP8
# No matches for CCL5
# No matches for CCL7
# No matches for CD274
# No matches for CD38
# No matches for CD69
# No matches for CD86
# No matches for CFB
# No matches for CFH
# No matches for CIITA
# No matches for CMKLR1
# No matches for CMPK2
# No matches for CSF2RB
# No matches for CXCL10
# No matches for CXCL11
# No matches for CXCL9
# No matches for DDX60
# No matches for EIF4E3
# No matches for FAS
# No matches for FCGR1A
# No matches for FGL2
# No matches for FPR1
# No matches for GBP4
# No matches for GBP6
# No matches for GPR18
# No matches for GZMA
# No matches for HELZ2
# No matches for HERC6
# No matches for HLA-B
# No matches for HLA-DMA
# No matches for HLA-DQA1
# No matches for HLA-G
# No matches for ICAM1
# No matches for IFI44
# No matches for IFI44L
# No matches for IFIH1
# No matches for IFIT1
# No matches for IFIT2
# No matches for IFIT3
# No matches for IL10RA
# No matches for IL15
# No matches for IL15RA
# No matches for IL18BP
# No matches for IL2RB
# No matches for IL6
# No matches for IL7
# No matches for IRF4
# No matches for IRF5
# No matches for IRF8
# No matches for ITGB7
# No matches for JAK2
# No matches for KLRK1
# No matches for LCP2
# No matches for LYSMD2
# No matches for MARCHF1
# No matches for NFKB1
# No matches for NLRC5
# No matches for NOD1
# No matches for OAS2
# No matches for OAS3
# No matches for OASL
# No matches for P2RY14
# No matches for PARP12
# No matches for PARP14
# No matches for PDE4B
# No matches for PLA2G4A
# No matches for PSMB8
# No matches for PSMB9
# No matches for PTGS2
# No matches for RIGI
# No matches for RSAD2
# No matches for RTP4
# No matches for SAMD9L
# No matches for SECTM1
# No matches for SELP
# No matches for SLAMF7
# No matches for SSPN
# No matches for STAT4
# No matches for TAP1
# No matches for TMT1B
# No matches for TNFAIP3
# No matches for TNFAIP6
# No matches for TNFSF10
# No matches for TRIM26
# No matches for VCAM1
# No matches for WARS1
# No matches for XCL1
# No matches for ZBP1
# No matches for ACTN2
# No matches for ACTN3
# No matches for ADAMTS5
# No matches for ADRA1B
# No matches for ALOX15B
# No matches for AMH
# No matches for AMIGO1
# No matches for ARHGEF6
# No matches for ATP1A3
# No matches for CADM3
# No matches for CALB2
# No matches for CD209
# No matches for CD274
# No matches for CD34
# No matches for CD86
# No matches for CDH15
# No matches for CDH4
# No matches for CDSN
# No matches for CLDN14
# No matches for CLDN15
# No matches for CLDN18
# No matches for CLDN19
# No matches for CLDN8
# No matches for CLDN9
# No matches for CNTN1
# No matches for COL16A1
# No matches for COL17A1
# No matches for CX3CL1
# No matches for DMP1
# No matches for DSC1
# No matches for DSC3
# No matches for EGFR
# No matches for FBN1
# No matches for FLNC
# No matches for FYB1
# No matches for ICAM1
# No matches for ICAM2
# No matches for ICAM5
# No matches for IRS1
# No matches for ITGA10
# No matches for ITGA2
# No matches for ITGA3
# No matches for ITGA9
# No matches for ITGB4
# No matches for KCNH2
# No matches for KRT31
# No matches for LAMA3
# No matches for LAMB3
# No matches for LAMC2
# No matches for LAYN
# No matches for MADCAM1
# No matches for MAP3K20
# No matches for MAPK11
# No matches for MPZL2
# No matches for NECTIN1
# No matches for NECTIN2
# No matches for NECTIN3
# No matches for NECTIN4
# No matches for NEGR1
# No matches for NHERF4
# No matches for NLGN3
# No matches for NRAP
# No matches for NRTN
# No matches for NRXN2
# No matches for PALS1
# No matches for PBX2
# No matches for PECAM1
# No matches for PPP2R2C
# No matches for PTPRC
# No matches for SDC3
# No matches for SHROOM2
# No matches for SIRPA
# No matches for SLC30A3
# No matches for SYK
# No matches for TRAF1
# No matches for VAV2
# No matches for VCAM1
# No matches for VWF
# No matches for WNK4
# No matches for AFAP1L2
# No matches for ATP6V0A4
# No matches for CD160
# No matches for CRYBG1
# No matches for CX3CL1
# No matches for GAS1
# No matches for IL2RB
# No matches for IL2RG
# No matches for LYPD3
# No matches for MAL
# No matches for MDGA1
# No matches for NCOA6
# No matches for NTNG1
# No matches for PKHD1
# No matches for RHCG
# No matches for RTN4RL1
# No matches for SCUBE1
# No matches for SHROOM2
# No matches for SLC22A12
# No matches for SLC34A3
# No matches for ADGRG1
# No matches for AMOT
# No matches for CELSR1
# No matches for GLI1
# No matches for HEY1
# No matches for NKX6-1
# No matches for NRCAM
# No matches for PLG
# No matches for RTN1
# No matches for SCG2
# No matches for SHH
# No matches for SLIT1
# No matches for UNC5C
# No matches for VEGFA
# No matches for ACTN2
# No matches for ADRA2B
# No matches for APOA4
# No matches for C1QA
# No matches for C1QC
# No matches for C1R
# No matches for C2
# No matches for C4BPB
# No matches for C9
# No matches for CASP1
# No matches for CASP4
# No matches for CASP5
# No matches for CCL5
# No matches for CD36
# No matches for CD40LG
# No matches for CFB
# No matches for CFH
# No matches for CP
# No matches for CR1
# No matches for CR2
# No matches for CTSO
# No matches for CTSS
# No matches for CXCL1
# No matches for DGKG
# No matches for DGKH
# No matches for DOCK10
# No matches for DOCK9
# No matches for DPP4
# No matches for ERAP2
# No matches for F2
# No matches for F5
# No matches for F7
# No matches for F8
# No matches for FCER1G
# No matches for FCN1
# No matches for GNGT2
# No matches for GP1BA
# No matches for GP9
# No matches for GZMA
# No matches for GZMB
# No matches for GZMK
# No matches for HNF4A
# No matches for HPCAL4
# No matches for IL6
# No matches for ITGAM
# No matches for ITIH1
# No matches for JAK2
# No matches for KCNIP2
# No matches for KCNIP3
# No matches for KLK1
# No matches for KYNU
# No matches for L3MBTL4
# No matches for LCP2
# No matches for LTF
# No matches for MMP12
# No matches for MMP13
# No matches for MMP8
# No matches for MT3
# No matches for NOTCH4
# No matches for OLR1
# No matches for PCLO
# No matches for PHEX
# No matches for PIK3CA
# No matches for PIK3CG
# No matches for PLA2G4A
# No matches for PLEK
# No matches for PLG
# No matches for PRSS3
# No matches for PRSS36
# No matches for PSMB9
# No matches for RASGRP1
# No matches for RBSN
# No matches for S100A12
# No matches for S100A9
# No matches for SERPINA1
# No matches for SERPINB2
# No matches for SERPINC1
# No matches for SPOCK2
# No matches for TIMP2
# No matches for TMPRSS6
# No matches for TNFAIP3
# No matches for VCPIP1
# No matches for WAS
# No matches for ZFPM2
# No matches for DNAJA4
# No matches for EIF2AK3
# No matches for ERO1A
# No matches for H2AX
# No matches for IARS1
# No matches for IFIT1
# No matches for IGFBP1
# No matches for MTREX
# No matches for SKIC3
# No matches for SLC1A4
# No matches for SRPRA
# No matches for TARS1
# No matches for TATDN2
# No matches for VEGFA
# No matches for DAPP1
# No matches for EGFR
# No matches for FASLG
# No matches for FGF22
# No matches for FGF6
# No matches for GNGT1
# No matches for GRK2
# No matches for IL2RG
# No matches for IL4
# No matches for NGF
# No matches for NOD1
# No matches for PRKAA2
# No matches for PRKCB
# No matches for SFN
# No matches for SLA
# No matches for ATP5MC1
# No matches for CFP
# No matches for DAPP1
# No matches for EPRS1
# No matches for ERO1A
# No matches for FGL2
# No matches for IGFBP5
# No matches for ITGB2
# No matches for NFIL3
# No matches for NHERF1
# No matches for NIBAN1
# No matches for NUPR1
# No matches for SLA
# No matches for SLC1A4
# No matches for SLC7A11
# No matches for SYTL2
# No matches for WARS1
# No matches for CDKN2A
# No matches for CDKN2C
# No matches for CNOT9
# No matches for H2AX
# No matches for H2AZ1
# No matches for JPT1
# No matches for MRE11
# No matches for TCF19
# No matches for EPRS1
# No matches for H2AZ1
# No matches for IARS1
# No matches for KARS1
# No matches for PHB1
# No matches for RACK1
# No matches for TOMM70
# No matches for MAP3K6
# No matches for PHB1
# No matches for ABI3BP
# No matches for ADAM12
# No matches for ANPEP
# No matches for AREG
# No matches for BDNF
# No matches for BGN
# No matches for CCN1
# No matches for CCN2
# No matches for COL12A1
# No matches for COL16A1
# No matches for COL3A1
# No matches for COL5A3
# No matches for COL6A3
# No matches for COL7A1
# No matches for COL8A2
# No matches for COMP
# No matches for CTHRC1
# No matches for CXCL1
# No matches for CXCL8
# No matches for DCN
# No matches for ECM1
# No matches for ECM2
# No matches for ELN
# No matches for FAP
# No matches for FAS
# No matches for FBN1
# No matches for FGF2
# No matches for FMOD
# No matches for FOXC2
# No matches for FZD8
# No matches for GAS1
# No matches for GEM
# No matches for GLIPR1
# No matches for GREM1
# No matches for IL15
# No matches for IL32
# No matches for IL6
# No matches for INHBA
# No matches for ITGA2
# No matches for ITGB3
# No matches for LAMA2
# No matches for LAMA3
# No matches for LAMC2
# No matches for LOX
# No matches for LRRC15
# No matches for MAGEE1
# No matches for MGP
# No matches for MMP1
# No matches for MMP3
# No matches for MXRA5
# No matches for NID2
# No matches for NNMT
# No matches for NT5E
# No matches for P3H1
# No matches for PDGFRB
# No matches for POSTN
# No matches for PRRX1
# No matches for PTHLH
# No matches for PTX3
# No matches for RGS4
# No matches for SCG2
# No matches for SFRP4
# No matches for SGCD
# No matches for SGCG
# No matches for SLIT3
# No matches for SNTB1
# No matches for TGFBR3
# No matches for TGM2
# No matches for TNC
# No matches for TNFAIP3
# No matches for VCAM1
# No matches for VEGFA
# No matches for VEGFC
# No matches for WNT5A
# No matches for ADGRE1
# No matches for AHR
# No matches for AQP9
# No matches for BDKRB1
# No matches for BEST1
# No matches for C3AR1
# No matches for CALCRL
# No matches for CCL17
# No matches for CCL20
# No matches for CCL22
# No matches for CCL24
# No matches for CCL5
# No matches for CCL7
# No matches for CCR7
# No matches for CCRL2
# No matches for CD14
# No matches for CD69
# No matches for CHST2
# No matches for CLEC5A
# No matches for CMKLR1
# No matches for CSF1
# No matches for CSF3
# No matches for CSF3R
# No matches for CX3CL1
# No matches for CXCL10
# No matches for CXCL11
# No matches for CXCL8
# No matches for CXCL9
# No matches for CXCR6
# No matches for CYBB
# No matches for EBI3
# No matches for EDN1
# No matches for EREG
# No matches for FFAR2
# No matches for FPR1
# No matches for GNA15
# No matches for GP1BA
# No matches for GPR132
# No matches for GPR183
# No matches for HBEGF
# No matches for HRH1
# No matches for ICAM1
# No matches for ICOSLG
# No matches for IL10
# No matches for IL10RA
# No matches for IL12B
# No matches for IL15
# No matches for IL15RA
# No matches for IL18
# No matches for IL18R1
# No matches for IL18RAP
# No matches for IL1A
# No matches for IL1B
# No matches for IL1R1
# No matches for IL2RB
# No matches for IL6
# No matches for IL7R
# No matches for INHBA
# No matches for IRAK2
# No matches for ITGB3
# No matches for ITGB8
# No matches for KCNA3
# No matches for KCNJ2
# No matches for KCNMB2
# No matches for LAMP3
# No matches for LCP2
# No matches for LIF
# No matches for LTA
# No matches for MARCO
# No matches for MEFV
# No matches for MEP1A
# No matches for MET
# No matches for MXD1
# No matches for NDP
# No matches for NFKB1
# No matches for NLRP3
# No matches for NMUR1
# No matches for NOD2
# No matches for OLR1
# No matches for OPRK1
# No matches for OSM
# No matches for OSMR
# No matches for P2RX7
# No matches for P2RY2
# No matches for PDE4B
# No matches for PROK2
# No matches for PTAFR
# No matches for PTGER2
# No matches for PTGER4
# No matches for PTGIR
# No matches for PTPRE
# No matches for RASGRP1
# No matches for RGS1
# No matches for RNF144B
# No matches for ROS1
# No matches for RTP4
# No matches for SCARF1
# No matches for SCN1B
# No matches for SELE
# No matches for SELENOS
# No matches for SELL
# No matches for SGMS2
# No matches for SLAMF1
# No matches for SLC1A2
# No matches for SLC28A2
# No matches for SLC4A4
# No matches for SLC7A2
# No matches for STAB1
# No matches for TACR1
# No matches for TACR3
# No matches for TLR1
# No matches for TLR2
# No matches for TLR3
# No matches for TNFAIP6
# No matches for TNFRSF1B
# No matches for TNFRSF9
# No matches for TNFSF10
# No matches for TNFSF15
# No matches for TNFSF9
# No matches for VIP
# No matches for ABCC2
# No matches for ABCC3
# No matches for ABCD2
# No matches for ACOX2
# No matches for ACSM1
# No matches for ADH1C
# No matches for ADH7
# No matches for AKR1C2
# No matches for ALDH3A1
# No matches for ANGPTL3
# No matches for AOX1
# No matches for AQP9
# No matches for ARG1
# No matches for ATOH8
# No matches for CCL25
# No matches for CD36
# No matches for CES1
# No matches for CFB
# No matches for CRP
# No matches for CYP17A1
# No matches for CYP1A1
# No matches for CYP1A2
# No matches for CYP2C18
# No matches for CYP2E1
# No matches for CYP2J2
# No matches for CYP4F2
# No matches for DDC
# No matches for ESR1
# No matches for F11
# No matches for FABP1
# No matches for FAS
# No matches for FETUB
# No matches for FMO1
# No matches for FMO3
# No matches for G6PC1
# No matches for GCKR
# No matches for GNMT
# No matches for GSTA3
# No matches for HGFAC
# No matches for HNF4A
# No matches for HSD11B1
# No matches for HSD17B2
# No matches for IGF1
# No matches for IGFBP1
# No matches for IL1R1
# No matches for IRF8
# No matches for ITIH1
# No matches for ITIH4
# No matches for KARS1
# No matches for KYNU
# No matches for LEAP2
# No matches for MAN1A1
# No matches for MAOA
# No matches for MARCHF6
# No matches for MBL2
# No matches for PDK4
# No matches for PLG
# No matches for PTGDS
# No matches for RBP4
# No matches for REG1A
# No matches for SERPINA6
# No matches for SLC22A1
# No matches for SLC35D1
# No matches for SLC6A12
# No matches for TAT
# No matches for TDO2
# No matches for TGFB2
# No matches for TKFC
# No matches for TMEM176B
# No matches for TTPA
# No matches for TYR
# No matches for UPB1
# No matches for VNN1
# No matches for VTN
# No matches for XDH
# No matches for ACADL
# No matches for ACSL5
# No matches for ACSS1
# No matches for ADH1C
# No matches for ADH7
# No matches for ALDH1A1
# No matches for ALDH3A1
# No matches for AOC3
# No matches for AQP7
# No matches for BMPR1B
# No matches for CA4
# No matches for CA6
# No matches for CD36
# No matches for CEL
# No matches for CIDEA
# No matches for CYP1A1
# No matches for CYP4A11
# No matches for CYP4A22
# No matches for FABP1
# No matches for FABP2
# No matches for FMO1
# No matches for G0S2
# No matches for GAD2
# No matches for GPD1
# No matches for H2AZ1
# No matches for HAO2
# No matches for HMGCS2
# No matches for HPGD
# No matches for IL4I1
# No matches for INMT
# No matches for KMT5A
# No matches for MAOA
# No matches for MGLL
# No matches for MIX23
# No matches for RDH16
# No matches for SLC22A5
# No matches for TDO2
# No matches for TP53INP2
# No matches for VNN1
# No matches for XIST
# No matches for ATP5F1A
# No matches for ATP5F1B
# No matches for ATP5F1C
# No matches for ATP5F1D
# No matches for ATP5F1E
# No matches for ATP5MC1
# No matches for ATP5MC2
# No matches for ATP5MC3
# No matches for ATP5ME
# No matches for ATP5MF
# No matches for ATP5MG
# No matches for ATP5PB
# No matches for ATP5PD
# No matches for ATP5PF
# No matches for ATP5PO
# No matches for MAOB
# No matches for PDK4
# No matches for TOMM70
# No matches for AGRN
# No matches for ALDOB
# No matches for ARTN
# No matches for B3GAT1
# No matches for B3GNT3
# No matches for CACNA1H
# No matches for CHST1
# No matches for CHST2
# No matches for CLDN9
# No matches for DCN
# No matches for EGFR
# No matches for ERO1A
# No matches for GFUS
# No matches for GPR87
# No matches for GYS2
# No matches for IDUA
# No matches for IRS2
# No matches for LCT
# No matches for LDHC
# No matches for LHX9
# No matches for MET
# No matches for MIOX
# No matches for NDST3
# No matches for NT5E
# No matches for PFKFB1
# No matches for PPFIA4
# No matches for RARS1
# No matches for SDC3
# No matches for SOX9
# No matches for TFF3
# No matches for TGFA
# No matches for TKTL1
# No matches for VEGFA
# No matches for IPCEF1
# No matches for LSP1
# No matches for MPO
# No matches for PTPA
# No matches for SBNO2
# No matches for SELENOS
# No matches for ALOX15B
# No matches for CASP1
# No matches for CDKN2A
# No matches for CDKN2B
# No matches for CEBPA
# No matches for CLCA2
# No matches for COQ8A
# No matches for ELP1
# No matches for FAS
# No matches for GPX2
# No matches for H1-2
# No matches for H2AC25
# No matches for H2AJ
# No matches for HBEGF
# No matches for IL1A
# No matches for INHBB
# No matches for IRAG2
# No matches for ITGB4
# No matches for JAG2
# No matches for KLF4
# No matches for KRT17
# No matches for LIF
# No matches for MXD1
# No matches for NDRG1
# No matches for NHLH2
# No matches for NUPR1
# No matches for OSGIN1
# No matches for PIDD1
# No matches for PTPRE
# No matches for PVT1
# No matches for RACK1
# No matches for RNF19B
# No matches for RRAD
# No matches for RXRA
# No matches for SERPINB5
# No matches for SFN
# No matches for SLC35D1
# No matches for SLC7A11
# No matches for ST14
# No matches for TAP1
# No matches for TCHH
# No matches for TGFA
# No matches for TM4SF1
# No matches for TNFSF9
# No matches for TNNI1
# No matches for TP63
# No matches for VDR
# No matches for ZBTB16
# No matches for ZMAT3
# No matches for ZNF365
# No matches for ABCB1
# No matches for APOM
# No matches for AQP3
# No matches for C4BPB
# No matches for CCK
# No matches for CDKN2B
# No matches for CXCL2
# No matches for CYP1A1
# No matches for DLG4
# No matches for FGF18
# No matches for FMO1
# No matches for FOSB
# No matches for H2AX
# No matches for HLA-F
# No matches for ICAM1
# No matches for IL6
# No matches for KCNH2
# No matches for LHX2
# No matches for MAOA
# No matches for MAPK8IP2
# No matches for NKX2-5
# No matches for NPTXR
# No matches for NTRK3
# No matches for NUP58
# No matches for PLCL1
# No matches for RASGRP1
# No matches for RRAD
# No matches for RXRB
# No matches for SELENOW
# No matches for SHOX2
# No matches for SLC6A12
# No matches for TACR3
# No matches for TAP1
# No matches for TARS1
# No matches for TCHH
# No matches for TGFBRAP1
# No matches for ADGRL2
# No matches for ATXN1
# No matches for BDNF
# No matches for CACNA1A
# No matches for CCN1
# No matches for CDON
# No matches for COL3A1
# No matches for DMAC2L
# No matches for GRK5
# No matches for IGFBP5
# No matches for INPP4B
# No matches for IRS1
# No matches for ITGB3
# No matches for KCNMA1
# No matches for MET
# No matches for MGLL
# No matches for MMP16
# No matches for NFKB1
# No matches for PDGFRB
# No matches for PIK3CD
# No matches for PLPP3
# No matches for PPARG
# No matches for PRKCE
# No matches for PTGFR
# No matches for RGS4
# No matches for RUNX1
# No matches for RXRA
# No matches for SCN8A
# No matches for SLC67A1
# No matches for SYNE1
# No matches for TENT4A
# No matches for TGFBR2
# No matches for TGFBR3
# No matches for TOGARAM1
# No matches for VAV2
# No matches for APOH
# No matches for COL3A1
# No matches for JAG1
# No matches for JAG2
# No matches for KCNJ8
# No matches for LPL
# No matches for OLR1
# No matches for PF4
# No matches for PGLYRP1
# No matches for POSTN
# No matches for PRG2
# No matches for SERPINA5
# No matches for THBD
# No matches for VAV2
# No matches for VEGFA
# No matches for VTN
# No matches for ABCG2
# No matches for ACKR1
# No matches for ACSL6
# No matches for ALAS2
# No matches for ALDH1L1
# No matches for ANK1
# No matches for AQP3
# No matches for CA1
# No matches for CLIC2
# No matches for CROCCP2
# No matches for CTSE
# No matches for E2F2
# No matches for ENDOD1
# No matches for EPB42
# No matches for ERMAP
# No matches for GATA1
# No matches for H1-0
# No matches for H4C3
# No matches for HBB
# No matches for HBBP1
# No matches for HBD
# No matches for HBZ
# No matches for IGSF3
# No matches for KAT2B
# No matches for KEL
# No matches for KHNYN
# No matches for KLF1
# No matches for LMO2
# No matches for MARCHF2
# No matches for MARCHF8
# No matches for MOCOS
# No matches for NFE2
# No matches for OSBP2
# No matches for PDZK1IP1
# No matches for PPP2R5B
# No matches for RHAG
# No matches for RHCE
# No matches for RHD
# No matches for SLC22A4
# No matches for SLC30A1
# No matches for SLC30A10
# No matches for SLC4A1
# No matches for SLC66A2
# No matches for SLC7A11
# No matches for SPTA1
# No matches for SPTB
# No matches for SYNJ1
# No matches for TAL1
# No matches for TENT5C
# No matches for TMCC2
# No matches for TRIM10
# No matches for TRIM58
# No matches for TSPO2
# No matches for TYR
# No matches for XK
# No matches for A2M
# No matches for ACOX2
# No matches for APOC2
# No matches for APOC3
# No matches for C1QA
# No matches for C1R
# No matches for C2
# No matches for C8A
# No matches for C8B
# No matches for C8G
# No matches for C9
# No matches for CFB
# No matches for CFD
# No matches for CFH
# No matches for CFI
# No matches for COMP
# No matches for CPB2
# No matches for CPN1
# No matches for CTSE
# No matches for CTSO
# No matches for DCT
# No matches for DPP4
# No matches for F11
# No matches for F13B
# No matches for F2
# No matches for F2RL2
# No matches for F8
# No matches for F9
# No matches for FBN1
# No matches for FGA
# No matches for FGG
# No matches for GDA
# No matches for GP1BA
# No matches for GP9
# No matches for HMGCS2
# No matches for HNF4A
# No matches for ITGA2
# No matches for ITGB3
# No matches for ITIH1
# No matches for MASP2
# No matches for MBL2
# No matches for MEP1A
# No matches for MMP1
# No matches for MMP10
# No matches for MMP3
# No matches for MMP7
# No matches for MMP8
# No matches for MST1
# No matches for OLR1
# No matches for PECAM1
# No matches for PF4
# No matches for PLEK
# No matches for PLG
# No matches for PROC
# No matches for PROZ
# No matches for RAPGEF3
# No matches for RGN
# No matches for S100A1
# No matches for SERPINA1
# No matches for SERPINB2
# No matches for SERPINC1
# No matches for SH2B2
# No matches for TF
# No matches for THBD
# No matches for TMPRSS6
# No matches for VWF
# No matches for ABCB1
# No matches for AGER
# No matches for AHR
# No matches for BATF
# No matches for BATF3
# No matches for BCL2
# No matches for CAPN3
# No matches for CCR4
# No matches for CD79B
# No matches for CD86
# No matches for CISH
# No matches for CSF1
# No matches for CSF2
# No matches for CST7
# No matches for CTLA4
# No matches for CTSZ
# No matches for CXCL10
# No matches for DRC1
# No matches for ECM1
# No matches for EEF1AKMT1
# No matches for EMP1
# No matches for ETFBKMT
# No matches for F2RL2
# No matches for FGL2
# No matches for GATA1
# No matches for GBP4
# No matches for GPR65
# No matches for GPR83
# No matches for GUCY1B1
# No matches for HOPX
# No matches for HYCC2
# No matches for ICOS
# No matches for IKZF2
# No matches for IL10
# No matches for IL10RA
# No matches for IL13
# No matches for IL18R1
# No matches for IL1R2
# No matches for IL1RL1
# No matches for IL2RA
# No matches for IL2RB
# No matches for IL3RA
# No matches for IRF4
# No matches for IRF8
# No matches for LIF
# No matches for LRRC8C
# No matches for LTB
# No matches for MAP6
# No matches for MAPKAPK2
# No matches for MUC1
# No matches for MXD1
# No matches for NCS1
# No matches for NDRG1
# No matches for NFIL3
# No matches for NT5E
# No matches for PENK
# No matches for PLEC
# No matches for PLPP1
# No matches for PTGER2
# No matches for PTH1R
# No matches for S100A1
# No matches for SCN9A
# No matches for SELL
# No matches for SELP
# No matches for SERPINC1
# No matches for SHE
# No matches for SMPDL3A
# No matches for SYT11
# No matches for TGM2
# No matches for TLR7
# No matches for TNFRSF18
# No matches for TNFRSF1B
# No matches for TNFRSF4
# No matches for TNFRSF8
# No matches for TNFRSF9
# No matches for TNFSF10
# No matches for TNFSF11
# No matches for TRAF1
# No matches for ABCA2
# No matches for ABCA3
# No matches for ABCA4
# No matches for ABCA6
# No matches for ABCA8
# No matches for ABCA9
# No matches for ABCD2
# No matches for ABCG4
# No matches for ABCG8
# No matches for ACSL5
# No matches for AGXT
# No matches for AKR1D1
# No matches for ALDH1A1
# No matches for ALDH8A1
# No matches for AQP9
# No matches for AR
# No matches for ATXN1
# No matches for BBOX1
# No matches for BMP6
# No matches for CH25H
# No matches for CYP39A1
# No matches for CYP7A1
# No matches for CYP7B1
# No matches for CYP8B1
# No matches for DIO1
# No matches for DIO2
# No matches for GC
# No matches for GNMT
# No matches for HAO1
# No matches for HSD3B1
# No matches for HSD3B7
# No matches for KLF1
# No matches for NR0B2
# No matches for NR1H4
# No matches for NR1I2
# No matches for NR3C2
# No matches for RXRA
# No matches for RXRG
# No matches for SERPINA6
# No matches for SLC23A1
# No matches for SLC67A1
# No matches for SOAT2
# No matches for SULT1B1
# No matches for SULT2B1
# No matches for TFCP2L1
# No matches for TTR
# No matches for ABCB1
# No matches for ABCB4
# No matches for ABCC8
# No matches for ABCD2
# No matches for ACSL5
# No matches for ALB
# No matches for ALDH1A1
# No matches for ATXN1
# No matches for CACNA1B
# No matches for CEL
# No matches for DIO1
# No matches for DLG4
# No matches for ESR2
# No matches for HAO2
# No matches for HSD3B7
# No matches for NR1I2
# No matches for RXRG
# No matches for SCGB1A1
# No matches for SEMA3C
# No matches for SERPINA6
# No matches for STS
# No matches for SULT2B1
# No matches for TTR
# No matches for UGT2B17
# No matches for AARS1
# No matches for BCL3
# No matches for C2
# No matches for CARTPT
# No matches for CCL11
# No matches for CCL13
# No matches for CCL19
# No matches for CCL22
# No matches for CCL4
# No matches for CCL5
# No matches for CCL7
# No matches for CCR1
# No matches for CCR2
# No matches for CCR5
# No matches for CD2
# No matches for CD247
# No matches for CD28
# No matches for CD3D
# No matches for CD3E
# No matches for CD3G
# No matches for CD4
# No matches for CD40LG
# No matches for CD7
# No matches for CD79A
# No matches for CD80
# No matches for CD86
# No matches for CD8A
# No matches for CD8B
# No matches for CD96
# No matches for CDKN2A
# No matches for CFP
# No matches for CRTAM
# No matches for CSF1
# No matches for CTSS
# No matches for CXCL13
# No matches for CXCL9
# No matches for CXCR3
# No matches for DARS1
# No matches for EGFR
# No matches for ELANE
# No matches for ELF4
# No matches for EREG
# No matches for F2
# No matches for FAS
# No matches for FASLG
# No matches for FCGR2B
# No matches for FGR
# No matches for FYB1
# No matches for GBP2
# No matches for GPR65
# No matches for GZMA
# No matches for GZMB
# No matches for HCLS1
# No matches for HDAC9
# No matches for HLA-DMA
# No matches for HLA-DMB
# No matches for HLA-DOA
# No matches for HLA-DOB
# No matches for HLA-DQA1
# No matches for HLA-DRA
# No matches for HLA-G
# No matches for ICAM1
# No matches for ICOSLG
# No matches for IFNG
# No matches for IGSF6
# No matches for IL10
# No matches for IL11
# No matches for IL12A
# No matches for IL12B
# No matches for IL12RB1
# No matches for IL13
# No matches for IL15
# No matches for IL16
# No matches for IL18
# No matches for IL18RAP
# No matches for IL1B
# No matches for IL2
# No matches for IL2RA
# No matches for IL2RB
# No matches for IL2RG
# No matches for IL4
# No matches for IL6
# No matches for IL7
# No matches for IL9
# No matches for INHBA
# No matches for INHBB
# No matches for IRF4
# No matches for IRF8
# No matches for ITGAL
# No matches for ITGB2
# No matches for ITK
# No matches for JAK2
# No matches for KLRD1
# No matches for KRT1
# No matches for LCP2
# No matches for LIF
# No matches for LTB
# No matches for LY75
# No matches for LY86
# No matches for MBL2
# No matches for NCF4
# No matches for NCR1
# No matches for NLRP3
# No matches for NOS2
# No matches for PF4
# No matches for PRF1
# No matches for PRKCB
# No matches for PTPRC
# No matches for RARS1
# No matches for RPL3L
# No matches for SPI1
# No matches for SRGN
# No matches for STAB1
# No matches for STAT4
# No matches for TAP1
# No matches for TAP2
# No matches for TGFB2
# No matches for TLR1
# No matches for TLR2
# No matches for TLR3
# No matches for TLR6
# No matches for TNF
# No matches for TRAT1
# No matches for WARS1
# No matches for WAS
# No matches for ACE
# No matches for ACRBP
# No matches for ACRV1
# No matches for ACTL7B
# No matches for ADAD1
# No matches for ADAM2
# No matches for ADCYAP1
# No matches for AKAP4
# No matches for ALOX15
# No matches for ART3
# No matches for CCNA1
# No matches for CCT6B
# No matches for CHRM4
# No matches for CLVS1
# No matches for CRISP2
# No matches for CST8
# No matches for DCC
# No matches for DDX4
# No matches for DMRT1
# No matches for DNAJB8
# No matches for ELOVL3
# No matches for GFI1
# No matches for GPR182
# No matches for GRM8
# No matches for GSG1
# No matches for H1-6
# No matches for HBZ
# No matches for HOXB1
# No matches for HSPA1L
# No matches for HTR5A
# No matches for IL12RB2
# No matches for IL13RA2
# No matches for LDHC
# No matches for MEP1B
# No matches for MTNR1A
# No matches for NAA11
# No matches for NEFH
# No matches for NOS1
# No matches for NPY5R
# No matches for OAZ3
# No matches for ODF1
# No matches for PACRG
# No matches for PAPOLB
# No matches for PCSK4
# No matches for PDHA2
# No matches for PGK2
# No matches for PRM2
# No matches for SEPTIN4
# No matches for SHE
# No matches for SLC2A5
# No matches for SNAP91
# No matches for SPMAP2
# No matches for TCP11
# No matches for TEKT2
# No matches for TKTL1
# No matches for TNP1
# No matches for TNP2
# No matches for TSSK2
# No matches for TUBA3C
# No matches for TULP2
# No matches for YBX2
# No matches for ZC2HC1C
# No matches for ZNRF4
# No matches for ZPBP
# No matches for ABCB1
# No matches for ACE
# No matches for ADAM8
# No matches for ADAMDEC1
# No matches for ADGRA2
# No matches for ADGRL4
# No matches for ALDH1A2
# No matches for ANO1
# No matches for ANXA10
# No matches for APOD
# No matches for ARG1
# No matches for BIRC3
# No matches for BTC
# No matches for C3AR1
# No matches for CBX8
# No matches for CCL20
# No matches for CD37
# No matches for CFB
# No matches for CFH
# No matches for CFHR2
# No matches for CIDEA
# No matches for CLEC4A
# No matches for CMKLR1
# No matches for CSF2
# No matches for CTSS
# No matches for CXCL10
# No matches for DOCK2
# No matches for EMP1
# No matches for EREG
# No matches for ERO1A
# No matches for F13A1
# No matches for FBXO4
# No matches for FCER1G
# No matches for FGF9
# No matches for FLT4
# No matches for G0S2
# No matches for GALNT3
# No matches for GPNMB
# No matches for GUCY1A1
# No matches for H2BC3
# No matches for HBEGF
# No matches for HDAC9
# No matches for HKDC1
# No matches for HOXD11
# No matches for HSD11B1
# No matches for IKZF1
# No matches for IL10RA
# No matches for IL1B
# No matches for IL1RL2
# No matches for IL2RG
# No matches for IL33
# No matches for IL7R
# No matches for INHBA
# No matches for IRF8
# No matches for ITGA2
# No matches for ITGB2
# No matches for ITGBL1
# No matches for KCNN4
# No matches for KIF5C
# No matches for KLF4
# No matches for LAPTM5
# No matches for LAT2
# No matches for LIF
# No matches for LY96
# No matches for MAFB
# No matches for MMP10
# No matches for MPZL2
# No matches for NAP1L2
# No matches for NGF
# No matches for NR0B2
# No matches for NR1H4
# No matches for PCP4
# No matches for PDCD1LG2
# No matches for PECAM1
# No matches for PEG3
# No matches for PIGR
# No matches for PLEK2
# No matches for PLVAP
# No matches for PPBP
# No matches for PRELID3B
# No matches for PRKG2
# No matches for PRRX1
# No matches for PSMB8
# No matches for PTGS2
# No matches for PTPRR
# No matches for RBP4
# No matches for RELN
# No matches for RETN
# No matches for SCN1B
# No matches for SEMA3B
# No matches for SERPINA3
# No matches for SLPI
# No matches for SNAP25
# No matches for SNAP91
# No matches for SOX9
# No matches for SPARCL1
# No matches for STRN
# No matches for TLR8
# No matches for TMEM100
# No matches for TMEM176A
# No matches for TMEM176B
# No matches for TNFAIP3
# No matches for TNFRSF1B
# No matches for TPH1
# No matches for TRAF1
# No matches for TSPAN1
# No matches for USH1C
# No matches for WNT7A
# No matches for ABCB11
# No matches for ABCG4
# No matches for ADRA2C
# No matches for AKR1B10
# No matches for ALOX12B
# No matches for AMBN
# No matches for ARHGDIG
# No matches for ARPP21
# No matches for ATP4A
# No matches for ATP6V1B1
# No matches for BMPR1B
# No matches for BRDT
# No matches for C5
# No matches for CACNA1F
# No matches for CACNG1
# No matches for CALML5
# No matches for CAPN9
# No matches for CCNA1
# No matches for CCR8
# No matches for CD207
# No matches for CD40LG
# No matches for CD80
# No matches for CDH16
# No matches for CELSR2
# No matches for CHRNG
# No matches for CHST2
# No matches for CLDN16
# No matches for CLDN8
# No matches for CLPS
# No matches for COPZ2
# No matches for COQ8A
# No matches for CPA2
# No matches for CPB1
# No matches for CPEB3
# No matches for CYP11B2
# No matches for CYP39A1
# No matches for DCC
# No matches for DLK2
# No matches for EDAR
# No matches for EDN1
# No matches for EDN2
# No matches for EGF
# No matches for EPHA5
# No matches for FGF16
# No matches for FGF22
# No matches for FGFR3
# No matches for FSHB
# No matches for GDNF
# No matches for GP1BA
# No matches for GP2
# No matches for HNF1A
# No matches for HTR1B
# No matches for HTR1D
# No matches for IDUA
# No matches for IFI44L
# No matches for IFNG
# No matches for IL12B
# No matches for IL5
# No matches for INSL5
# No matches for IRS4
# No matches for ITGB1BP2
# No matches for ITIH3
# No matches for KCND1
# No matches for KCNE2
# No matches for KCNMB1
# No matches for KCNN1
# No matches for KLHDC8A
# No matches for KLK7
# No matches for KRT1
# No matches for KRT13
# No matches for KRT15
# No matches for KRT4
# No matches for KRT5
# No matches for LFNG
# No matches for LGALS7
# No matches for LYPD3
# No matches for MACROH2A2
# No matches for MAGIX
# No matches for MEFV
# No matches for MFSD6
# No matches for MSH5
# No matches for MYH7
# No matches for MYO15A
# No matches for MYOT
# No matches for NGB
# No matches for NOS1
# No matches for NPHS1
# No matches for NPY4R
# No matches for NR4A2
# No matches for NRIP2
# No matches for NTF3
# No matches for OXT
# No matches for P2RX6
# No matches for P2RY4
# No matches for PAX3
# No matches for PAX4
# No matches for PCDHB1
# No matches for PDCD1
# No matches for PKP1
# No matches for PNMT
# No matches for PRKN
# No matches for PROP1
# No matches for PTGFR
# No matches for PTPRJ
# No matches for RGS11
# No matches for RSAD2
# No matches for RYR1
# No matches for RYR2
# No matches for SCGB1A1
# No matches for SCN10A
# No matches for SELENOP
# No matches for SERPINA10
# No matches for SERPINB2
# No matches for SHOX2
# No matches for SIDT1
# No matches for SLC12A3
# No matches for SLC30A3
# No matches for SLC38A3
# No matches for SLC5A5
# No matches for SLC6A14
# No matches for SLC6A3
# No matches for SMPX
# No matches for SOX10
# No matches for SPRR3
# No matches for SSTR4
# No matches for SYNPO
# No matches for TAS2R4
# No matches for TCL1A
# No matches for TENT5C
# No matches for TEX15
# No matches for TFAP2B
# No matches for TFCP2L1
# No matches for TFF2
# No matches for TG
# No matches for TGFB2
# No matches for TGM1
# No matches for THRB
# No matches for TLX1
# No matches for TSHB
# No matches for UGT2B17
# No matches for VPREB1
# No matches for VPS50
# No matches for WNT16
# No matches for YBX2
# No matches for ZBTB16
# No matches for ZC2HC1C
# No matches for ZNF112
# No matches for ABCC8
# No matches for DCX
# No matches for DPP4
# No matches for G6PC2
# No matches for GCG
# No matches for HNF1A
# No matches for IAPP
# No matches for INS
# No matches for INSM1
# No matches for ISL1
# No matches for LMO2
# No matches for MAFB
# No matches for NEUROD1
# No matches for NEUROG3
# No matches for NKX2-2
# No matches for NKX6-1
# No matches for PAK3
# No matches for PAX4
# No matches for PAX6
# No matches for PDX1
# No matches for PKLR
# No matches for SCGN
# No matches for SLC2A2
# No matches for SST
# No matches for SYT13
# No matches for VDR

# %%
#Calculate score for each pathway for each donor
for key in gene_ids:
  sc.tl.score_genes(donor_adata, gene_list=gene_ids[key], score_name=key)
donor_adata.obs.columns
# Out:
# Index(['DEscore_long', 'DEscore_short', 'pseudorank',
#        'HALLMARK_TNFA_SIGNALING_VIA_NFKB', 'HALLMARK_HYPOXIA',
#        'HALLMARK_CHOLESTEROL_HOMEOSTASIS', 'HALLMARK_MITOTIC_SPINDLE',
#        'HALLMARK_WNT_BETA_CATENIN_SIGNALING', 'HALLMARK_TGF_BETA_SIGNALING',
#        'HALLMARK_IL6_JAK_STAT3_SIGNALING', 'HALLMARK_DNA_REPAIR',
#        'HALLMARK_G2M_CHECKPOINT', 'HALLMARK_APOPTOSIS',
#        'HALLMARK_NOTCH_SIGNALING', 'HALLMARK_ADIPOGENESIS',
#        'HALLMARK_ESTROGEN_RESPONSE_EARLY', 'HALLMARK_ESTROGEN_RESPONSE_LATE',
#        'HALLMARK_ANDROGEN_RESPONSE', 'HALLMARK_MYOGENESIS',
#        'HALLMARK_PROTEIN_SECRETION', 'HALLMARK_INTERFERON_ALPHA_RESPONSE',
#        'HALLMARK_INTERFERON_GAMMA_RESPONSE', 'HALLMARK_APICAL_JUNCTION',
#        'HALLMARK_APICAL_SURFACE', 'HALLMARK_HEDGEHOG_SIGNALING',
#        'HALLMARK_COMPLEMENT', 'HALLMARK_UNFOLDED_PROTEIN_RESPONSE',
#        'HALLMARK_PI3K_AKT_MTOR_SIGNALING', 'HALLMARK_MTORC1_SIGNALING',
#        'HALLMARK_E2F_TARGETS', 'HALLMARK_MYC_TARGETS_V1',
#        'HALLMARK_MYC_TARGETS_V2', 'HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION',
#        'HALLMARK_INFLAMMATORY_RESPONSE', 'HALLMARK_XENOBIOTIC_METABOLISM',
#        'HALLMARK_FATTY_ACID_METABOLISM', 'HALLMARK_OXIDATIVE_PHOSPHORYLATION',
#        'HALLMARK_GLYCOLYSIS', 'HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY',
#        'HALLMARK_P53_PATHWAY', 'HALLMARK_UV_RESPONSE_UP',
#        'HALLMARK_UV_RESPONSE_DN', 'HALLMARK_ANGIOGENESIS',
#        'HALLMARK_HEME_METABOLISM', 'HALLMARK_COAGULATION',
#        'HALLMARK_IL2_STAT5_SIGNALING', 'HALLMARK_BILE_ACID_METABOLISM',
#        'HALLMARK_PEROXISOME', 'HALLMARK_ALLOGRAFT_REJECTION',
#        'HALLMARK_SPERMATOGENESIS', 'HALLMARK_KRAS_SIGNALING_UP',
#        'HALLMARK_KRAS_SIGNALING_DN', 'HALLMARK_PANCREAS_BETA_CELLS'],
#       dtype='object')

# %%
# Find pathway scores that correlate with DE scores.
y = donor_adata.obs['DEscore_long'].values
corrs = {}
for pathway in gene_ids.keys():
  x = donor_adata.obs[pathway].values
  r, _ = spearmanr(x,y)
  corrs[pathway] = r
corr_df_score = pd.DataFrame.from_dict(corrs, orient='index', columns=['corr_DE'])
corr_df_score.sort_values(by='corr_DE', ascending=False)
# Out:
#                                              corr_DE
# HALLMARK_MYC_TARGETS_V2                     0.539417
# HALLMARK_DNA_REPAIR                         0.375984
# HALLMARK_E2F_TARGETS                        0.352804
# HALLMARK_MYC_TARGETS_V1                     0.333154
# HALLMARK_G2M_CHECKPOINT                     0.327559
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE          0.262642
# HALLMARK_PANCREAS_BETA_CELLS                0.240772
# HALLMARK_UV_RESPONSE_UP                     0.230106
# HALLMARK_MTORC1_SIGNALING                   0.223109
# HALLMARK_PI3K_AKT_MTOR_SIGNALING            0.180432
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.084614
# HALLMARK_SPERMATOGENESIS                    0.029992
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.012962
# HALLMARK_HEDGEHOG_SIGNALING                 0.002081
# HALLMARK_FATTY_ACID_METABOLISM             -0.007537
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        -0.014534
# HALLMARK_ADIPOGENESIS                      -0.023149
# HALLMARK_BILE_ACID_METABOLISM              -0.046838
# HALLMARK_TGF_BETA_SIGNALING                -0.063668
# HALLMARK_PROTEIN_SECRETION                 -0.080668
# HALLMARK_GLYCOLYSIS                        -0.139297
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   -0.143797
# HALLMARK_ANDROGEN_RESPONSE                 -0.157530
# HALLMARK_PEROXISOME                        -0.158362
# HALLMARK_ESTROGEN_RESPONSE_EARLY           -0.174221
# HALLMARK_MITOTIC_SPINDLE                   -0.186813
# HALLMARK_APICAL_SURFACE                    -0.193780
# HALLMARK_KRAS_SIGNALING_DN                 -0.197648
# HALLMARK_ALLOGRAFT_REJECTION               -0.200099
# HALLMARK_XENOBIOTIC_METABOLISM             -0.220104
# HALLMARK_APOPTOSIS                         -0.224635
# HALLMARK_MYOGENESIS                        -0.245056
# HALLMARK_COMPLEMENT                        -0.246289
# HALLMARK_IL6_JAK_STAT3_SIGNALING           -0.252269
# HALLMARK_ESTROGEN_RESPONSE_LATE            -0.261794
# HALLMARK_INFLAMMATORY_RESPONSE             -0.272968
# HALLMARK_APICAL_JUNCTION                   -0.275897
# HALLMARK_HYPOXIA                           -0.290508
# HALLMARK_COAGULATION                       -0.318666
# HALLMARK_NOTCH_SIGNALING                   -0.333600
# HALLMARK_INTERFERON_GAMMA_RESPONSE         -0.345545
# HALLMARK_IL2_STAT5_SIGNALING               -0.348458
# HALLMARK_HEME_METABOLISM                   -0.358553
# HALLMARK_INTERFERON_ALPHA_RESPONSE         -0.360310
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.367893
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           -0.429774
# HALLMARK_P53_PATHWAY                       -0.430359
# HALLMARK_KRAS_SIGNALING_UP                 -0.436848
# HALLMARK_UV_RESPONSE_DN                    -0.442720
# HALLMARK_ANGIOGENESIS                      -0.488341

# %%
# Find pathway scores that correlate with pseudoranks.
y = donor_adata.obs['pseudorank'].values
corrs = {}
for pathway in gene_ids.keys():
  x = donor_adata.obs[pathway].values
  r, _ = spearmanr(x,y)
  corrs[pathway] = r
corr_df_rank = pd.DataFrame.from_dict(corrs, orient='index', columns=['corr_PR'])
corr_df_rank.sort_values(by='corr_PR', ascending=False)
# Out:
#                                              corr_PR
# HALLMARK_MYC_TARGETS_V2                     0.326526
# HALLMARK_DNA_REPAIR                         0.314874
# HALLMARK_PANCREAS_BETA_CELLS                0.213924
# HALLMARK_MYC_TARGETS_V1                     0.166977
# HALLMARK_E2F_TARGETS                        0.161691
# HALLMARK_G2M_CHECKPOINT                     0.148421
# HALLMARK_MTORC1_SIGNALING                   0.096512
# HALLMARK_CHOLESTEROL_HOMEOSTASIS            0.081038
# HALLMARK_BILE_ACID_METABOLISM               0.027511
# HALLMARK_OXIDATIVE_PHOSPHORYLATION          0.003992
# HALLMARK_UNFOLDED_PROTEIN_RESPONSE         -0.017570
# HALLMARK_MYOGENESIS                        -0.021207
# HALLMARK_COMPLEMENT                        -0.035834
# HALLMARK_UV_RESPONSE_UP                    -0.042661
# HALLMARK_COAGULATION                       -0.077863
# HALLMARK_PEROXISOME                        -0.102369
# HALLMARK_PI3K_AKT_MTOR_SIGNALING           -0.104943
# HALLMARK_APICAL_JUNCTION                   -0.116533
# HALLMARK_HEDGEHOG_SIGNALING                -0.130404
# HALLMARK_FATTY_ACID_METABOLISM             -0.136029
# HALLMARK_ADIPOGENESIS                      -0.138958
# HALLMARK_IL2_STAT5_SIGNALING               -0.141763
# HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.148591
# HALLMARK_XENOBIOTIC_METABOLISM             -0.151473
# HALLMARK_ESTROGEN_RESPONSE_LATE            -0.157221
# HALLMARK_UV_RESPONSE_DN                    -0.163664
# HALLMARK_SPERMATOGENESIS                   -0.173374
# HALLMARK_KRAS_SIGNALING_UP                 -0.182082
# HALLMARK_WNT_BETA_CATENIN_SIGNALING        -0.242113
# HALLMARK_GLYCOLYSIS                        -0.257124
# HALLMARK_ANDROGEN_RESPONSE                 -0.260916
# HALLMARK_IL6_JAK_STAT3_SIGNALING           -0.264923
# HALLMARK_ESTROGEN_RESPONSE_EARLY           -0.275989
# HALLMARK_MITOTIC_SPINDLE                   -0.278732
# HALLMARK_KRAS_SIGNALING_DN                 -0.300125
# HALLMARK_NOTCH_SIGNALING                   -0.305257
# HALLMARK_HEME_METABOLISM                   -0.314643
# HALLMARK_PROTEIN_SECRETION                 -0.333693
# HALLMARK_HYPOXIA                           -0.355563
# HALLMARK_APICAL_SURFACE                    -0.368926
# HALLMARK_ALLOGRAFT_REJECTION               -0.369558
# HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY   -0.380207
# HALLMARK_INTERFERON_GAMMA_RESPONSE         -0.385201
# HALLMARK_TGF_BETA_SIGNALING                -0.409583
# HALLMARK_ANGIOGENESIS                      -0.410709
# HALLMARK_P53_PATHWAY                       -0.430899
# HALLMARK_TNFA_SIGNALING_VIA_NFKB           -0.441240
# HALLMARK_INFLAMMATORY_RESPONSE             -0.478924
# HALLMARK_APOPTOSIS                         -0.510981
# HALLMARK_INTERFERON_ALPHA_RESPONSE         -0.530709

# %%
#Find 20 pathways with the greatest absolute correlation with DE score
corr_df = corr_df_score.merge(corr_df_rank, how='inner', right_index=True, left_index=True)
top_pathways = corr_df['corr_DE'].abs().sort_values(ascending=False).head(20).index
top_pathways
# Out:
# Index(['HALLMARK_MYC_TARGETS_V2', 'HALLMARK_ANGIOGENESIS',
#        'HALLMARK_UV_RESPONSE_DN', 'HALLMARK_KRAS_SIGNALING_UP',
#        'HALLMARK_P53_PATHWAY', 'HALLMARK_TNFA_SIGNALING_VIA_NFKB',
#        'HALLMARK_DNA_REPAIR', 'HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION',
#        'HALLMARK_INTERFERON_ALPHA_RESPONSE', 'HALLMARK_HEME_METABOLISM',
#        'HALLMARK_E2F_TARGETS', 'HALLMARK_IL2_STAT5_SIGNALING',
#        'HALLMARK_INTERFERON_GAMMA_RESPONSE', 'HALLMARK_NOTCH_SIGNALING',
#        'HALLMARK_MYC_TARGETS_V1', 'HALLMARK_G2M_CHECKPOINT',
#        'HALLMARK_COAGULATION', 'HALLMARK_HYPOXIA', 'HALLMARK_APICAL_JUNCTION',
#        'HALLMARK_INFLAMMATORY_RESPONSE'],
#       dtype='object')

# %%
fig, ax = plt.subplots(5, 4, figsize=(20,20))
ax = ax.flatten()
for i, pathway in enumerate(top_pathways):
  sns.scatterplot(x=donor_adata.obs[pathway], y=donor_adata.obs['DEscore_long'], ax=ax[i], s=50, alpha=0.8)
  ax[i].set_title(f'{pathway} vs DE score')
  ax[i].set_xlabel(pathway)
  ax[i].set_ylabel('DE score')
plt.tight_layout()
plt.show()

# %% [markdown]
# We now have three types of features describing the psuedobulk donor counts that we can use to build a data set that can be modelled:
#
# 1) **PCs from PCA on top 500 HVGs.**
# Pros: Unbiased, visually correlates a bit with pseudorank
# Cons: Unintuitive and doesn't correlate very well with DE score.
#
# 2) **Genes with highest absolute value correlations with DE score/pseudorank**
# Pros: More intuitive, and the only features that don't require RNA-seq to reproduce for subsequent datasets.
# Cons: None of the genes had a correlation greater that R2=6%, so modelling might not work.
#
# 3) **Scores based on 50 gene lists describing known genetic pathways.**
# Pros: Very intuitive, since the pathways with the largest and smallest R2 values make biological sense.  Using pathways is also more robust than individual genes since groups of genes are less sensitive to noise and batch vairiation.  Also, the pathways have high enough correlation with DE score and pseudorank that modelling will likely be successful.
# Cons: Analysis is the most complicated and requires full RNAseq to test for the gene lists.

# %% [markdown]
# ##Model Building: Screening Learners
#
# I will test two data set for modelling with regressors, using a tree based approach.
#
# **First**, we will try using the 100 individual genes with the greatest correlations with DE score, as this model would remove the necessity of RNAseq to produce future datasets. These datasets are already saved as `donor_score` and `donor_rank`, respectively.
#
# **Second**, we will build a data set with any pathway with a correleation absolute value of 10 or more (10 is an arbitrary threshold) plus the PC1 through PC10.  We can narrow the features down as we go based on feature importance. These we will save as `pathways_score` and `pathways_rank`, respectively.

# %%
#make list of pathways with correlation of +/- 10% with DE Score and pseudorank.  Compare lists.
selected_pathways_score = corr_df_score.index[abs(corr_df_score['corr_DE']) >= 0.10]
selected_pathways_rank = corr_df_rank.index[abs(corr_df_rank['corr_PR']) >= 0.10]
print(len(selected_pathways_score), len(selected_pathways_rank)) #Get number of pathways in each list
sorted(selected_pathways_score) == sorted(selected_pathways_rank) #Compare lists
# Out:
# 40 41
# False

# %% [markdown]
# Since both lists are the same, we do not need separate dfs for `pathways_score` and `pathways_rank` and can use one dataset, `donor_pathways`.

# %%
#Merge selected pathways with PCs 1-10 for DE score data set
cols = ['DEscore_long', 'DEscore_short', 'pseudorank'] + list(selected_pathways_score)
donor_pathways = pd.DataFrame(donor_adata.obs[cols])
donor_pathways = donor_pathways.merge(day0_pcs.iloc[:, 0:10], left_index=True, right_index=True, how='inner')
donor_pathways.head()
# Out:
#       DEscore_long  DEscore_short  pseudorank  \
# zapk      2.296221       5.776403    0.719840
# wibj      1.908312       5.802939    0.763244
# pelm      1.768026       5.667831    0.690719
# vass      3.160267       8.296805    0.782916
# paab      3.145534      10.150320    0.759001
#
#       HALLMARK_TNFA_SIGNALING_VIA_NFKB  HALLMARK_HYPOXIA  \
# zapk                         -0.134793          0.051612
# wibj                         -0.110360          0.075257
# pelm                         -0.130050          0.048310
# vass                         -0.140513          0.041330
# paab                         -0.096603          0.070862
#
#       HALLMARK_MITOTIC_SPINDLE  HALLMARK_IL6_JAK_STAT3_SIGNALING  \
# zapk                 -0.090113                         -0.053509
# wibj                 -0.083210                         -0.059183
# pelm                 -0.083136                         -0.053200
# vass                 -0.087477                         -0.068831
# paab                 -0.057886                         -0.048852
#
#       HALLMARK_DNA_REPAIR  HALLMARK_G2M_CHECKPOINT  HALLMARK_APOPTOSIS  ...  \
# zapk             0.265365                 0.227457            0.038244  ...
# wibj             0.259668                 0.230118            0.028932  ...
# pelm             0.267120                 0.237066            0.035298  ...
# vass             0.274806                 0.241718            0.041418  ...
# paab             0.223829                 0.220850            0.053053  ...
#
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# zapk  3.181929  0.660086 -1.156901 -1.338994 -0.100520  3.320299  1.582244
# wibj -2.547690  0.413058 -1.849295  1.165720 -2.684275 -0.665291 -0.199397
# pelm  2.320235  0.362718 -1.002284 -0.824520  0.575587  3.100321  0.103807
# vass -0.807296  3.132881 -2.029991 -1.439614 -0.568322 -0.486264 -1.276130
# paab  1.491555  0.265067  2.365499  6.051101 -1.176274  1.801340 -0.853157
#
#            PC8       PC9      PC10
# zapk -0.981706  2.014731 -0.383449
# wibj -0.281172  1.612072 -3.199867
# pelm -0.789793  0.468751  0.908636
# vass -0.728340 -0.438251 -1.202127
# paab -1.687098  1.123861  2.129872
#
# [5 rows x 53 columns]

# %%
donor_pathways.shape
# Out:
# (92, 53)

# %% [markdown]
# Now we can proceed with train, test splits on our final datasets.
#
# Model screening will start with DE score and then we'll test the best learners with pseudorank predictions.

# %%
#For correlating genes, predicting DE score
X = pd.DataFrame(donor_score.X, columns=donor_score.var_names, index=donor_score.obs_names)
y = donor_score.obs['DEscore_long']

X_train_score, X_test_score, y_train_score, y_test_score = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
#For correlating genes, predicting pseudorank
X = pd.DataFrame(donor_rank.X, columns=donor_rank.var_names, index=donor_rank.obs_names)
y = donor_rank.obs['pseudorank']

X_train_rank, X_test_rank, y_train_rank, y_test_rank = train_test_split(X, y, test_size=0.2, random_state=12)

# %% [markdown]
# ### Using Correlating Genes

# %% [markdown]
# ####Predicting DE Score

# %%
#Run default linear regression on dataset
LR = LinearRegression()
LR.fit(X_train_score, y_train_score)
LR.score(X_train_score, y_train_score)
# Out:
# 1.0

# %%
#Determine MAE with test data
y_pred_LR = np.array(LR.predict(X_test_score))
mae_LR = mean_absolute_error(y_test_score, y_pred_LR)
mape_LR = mean_absolute_percentage_error(y_test_score, y_pred_LR)
print(f'Linear Regression MAE: {mae_LR}')
# Out:
# Linear Regression MAE: 0.7321869478333527

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_LR, y=y_test_score)

# Add a line for perfect correlation.
plt.plot([y_test_score.min(), y_test_score.max()],
         [y_test_score.min(), y_test_score.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Multiple Regression Predicted vs Actual DE Score')
plt.show()

# %%
#Run default Random Forest regression on dataset
RF = RandomForestRegressor()
RF.fit(X_train_score, y_train_score)
RF.score(X_train_score, y_train_score)
# Out:
# 0.9225038156835401

# %%
#Determine MAE with test data
y_pred_RF = np.array(RF.predict(X_test_score))
y_pred_RF_score_genes = np.array(RF.predict(X_test_score))
mae_RF = mean_absolute_error(y_test_score, y_pred_RF)
mape_RF = mean_absolute_percentage_error(y_test_score, y_pred_RF)
print(f'Random Forest Regression MAE: {mae_RF}')
# Out:
# Random Forest Regression MAE: 0.5026065352912271

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_RF, y=y_test_score)

# Add a line for perfect correlation.
plt.plot([y_test_score.min(), y_test_score.max()],
         [y_test_score.min(), y_test_score.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Random Forest Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default Grandient Boosting regression on dataset
GB = GradientBoostingRegressor()
GB.fit(X_train_score, y_train_score)
GB.score(X_train_score, y_train_score)
# Out:
# 0.9999454607607309

# %%
#Determine MAE with test data
y_pred_GB = np.array(GB.predict(X_test_score))
mae_GB = mean_absolute_error(y_test_score, y_pred_GB)
mape_GB = mean_absolute_percentage_error(y_test_score, y_pred_GB)
print(f'Grandient Boosting Regression MAE: {mae_GB}')
# Out:
# Grandient Boosting Regression MAE: 0.5442397335083209

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_GB, y=y_test_score)

# Add a line for perfect correlation.
plt.plot([y_test_score.min(), y_test_score.max()],
         [y_test_score.min(), y_test_score.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Grandient Boosting Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default XGBoost regression on dataset
XG = XGBRegressor()
XG.fit(X_train_score, y_train_score)
XG.score(X_train_score, y_train_score)
# Out:
# 0.9999995376794434

# %%
#Determine MAE with test data
y_pred_XG = np.array(XG.predict(X_test_score))
mae_XG = mean_absolute_error(y_test_score, y_pred_XG)
mape_XG = mean_absolute_percentage_error(y_test_score, y_pred_XG)
print(f'XGBoost Regression MAE: {mae_XG}')
# Out:
# XGBoost Regression MAE: 0.5381272424669837

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_XG, y=y_test_score)

# Add a line for perfect correlation.
plt.plot([y_test_score.min(), y_test_score.max()],
         [y_test_score.min(), y_test_score.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('XGBoost Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default CatBoost regression on dataset
CB = CatBoostRegressor()
CB.fit(X_train_score, y_train_score)
CB.score(X_train_score, y_train_score)
# Out:
# Learning rate set to 0.027076
# 0:	learn: 0.5655126	total: 50.5ms	remaining: 50.5s
# 1:	learn: 0.5603560	total: 53ms	remaining: 26.5s
# 2:	learn: 0.5535004	total: 55.2ms	remaining: 18.3s
# 3:	learn: 0.5485384	total: 57.4ms	remaining: 14.3s
# 4:	learn: 0.5413239	total: 59.6ms	remaining: 11.9s
# 5:	learn: 0.5355875	total: 61.7ms	remaining: 10.2s
# 6:	learn: 0.5308172	total: 63.9ms	remaining: 9.06s
# 7:	learn: 0.5248330	total: 66.1ms	remaining: 8.19s
# 8:	learn: 0.5185539	total: 68.2ms	remaining: 7.51s
# 9:	learn: 0.5125877	total: 70.4ms	remaining: 6.97s
# 10:	learn: 0.5084804	total: 72.6ms	remaining: 6.53s
# 11:	learn: 0.5023342	total: 74.8ms	remaining: 6.16s
# 12:	learn: 0.4981414	total: 77ms	remaining: 5.85s
# 13:	learn: 0.4934223	total: 79.2ms	remaining: 5.58s
# 14:	learn: 0.4884472	total: 81.3ms	remaining: 5.34s
# 15:	learn: 0.4836955	total: 83.6ms	remaining: 5.14s
# 16:	learn: 0.4793858	total: 85.7ms	remaining: 4.96s
# 17:	learn: 0.4751639	total: 88ms	remaining: 4.8s
# 18:	learn: 0.4708004	total: 90.2ms	remaining: 4.66s
# 19:	learn: 0.4666509	total: 92.3ms	remaining: 4.52s
# 20:	learn: 0.4612184	total: 94.5ms	remaining: 4.41s
# 21:	learn: 0.4572836	total: 96.7ms	remaining: 4.3s
# 22:	learn: 0.4524045	total: 98.9ms	remaining: 4.2s
# 23:	learn: 0.4481880	total: 101ms	remaining: 4.11s
# 24:	learn: 0.4439808	total: 103ms	remaining: 4.03s
# 25:	learn: 0.4396706	total: 106ms	remaining: 3.95s
# 26:	learn: 0.4355995	total: 108ms	remaining: 3.89s
# 27:	learn: 0.4305544	total: 110ms	remaining: 3.82s
# 28:	learn: 0.4268036	total: 112ms	remaining: 3.76s
# 29:	learn: 0.4227163	total: 115ms	remaining: 3.71s
# 30:	learn: 0.4192374	total: 117ms	remaining: 3.65s
# 31:	learn: 0.4151092	total: 119ms	remaining: 3.6s
# 32:	learn: 0.4118122	total: 121ms	remaining: 3.55s
# 33:	learn: 0.4074201	total: 123ms	remaining: 3.51s
# 34:	learn: 0.4040058	total: 126ms	remaining: 3.46s
# 35:	learn: 0.4000661	total: 128ms	remaining: 3.42s
# 36:	learn: 0.3967145	total: 130ms	remaining: 3.39s
# 37:	learn: 0.3930837	total: 132ms	remaining: 3.35s
# 38:	learn: 0.3896855	total: 135ms	remaining: 3.32s
# 39:	learn: 0.3869875	total: 137ms	remaining: 3.29s
# 40:	learn: 0.3837353	total: 139ms	remaining: 3.25s
# 41:	learn: 0.3804924	total: 141ms	remaining: 3.22s
# 42:	learn: 0.3768511	total: 143ms	remaining: 3.19s
# 43:	learn: 0.3739702	total: 146ms	remaining: 3.16s
# 44:	learn: 0.3712046	total: 148ms	remaining: 3.13s
# 45:	learn: 0.3692416	total: 150ms	remaining: 3.11s
# 46:	learn: 0.3654790	total: 152ms	remaining: 3.09s
# 47:	learn: 0.3621599	total: 154ms	remaining: 3.06s
# 48:	learn: 0.3592537	total: 157ms	remaining: 3.04s
# 49:	learn: 0.3557021	total: 159ms	remaining: 3.02s
# 50:	learn: 0.3526971	total: 161ms	remaining: 3s
# 51:	learn: 0.3500514	total: 163ms	remaining: 2.98s
# 52:	learn: 0.3472014	total: 166ms	remaining: 2.96s
# 53:	learn: 0.3439946	total: 168ms	remaining: 2.94s
# 54:	learn: 0.3405515	total: 170ms	remaining: 2.92s
# 55:	learn: 0.3378539	total: 172ms	remaining: 2.9s
# 56:	learn: 0.3355253	total: 175ms	remaining: 2.89s
# 57:	learn: 0.3328357	total: 177ms	remaining: 2.87s
# 58:	learn: 0.3303461	total: 179ms	remaining: 2.85s
# 59:	learn: 0.3275652	total: 181ms	remaining: 2.84s
# 60:	learn: 0.3254521	total: 183ms	remaining: 2.82s
# 61:	learn: 0.3227646	total: 185ms	remaining: 2.8s
# 62:	learn: 0.3195511	total: 188ms	remaining: 2.79s
# 63:	learn: 0.3167889	total: 190ms	remaining: 2.77s
# 64:	learn: 0.3144231	total: 192ms	remaining: 2.76s
# 65:	learn: 0.3116748	total: 194ms	remaining: 2.75s
# 66:	learn: 0.3089649	total: 197ms	remaining: 2.74s
# 67:	learn: 0.3060070	total: 199ms	remaining: 2.73s
# 68:	learn: 0.3037289	total: 202ms	remaining: 2.72s
# 69:	learn: 0.3011844	total: 204ms	remaining: 2.71s
# 70:	learn: 0.2992683	total: 206ms	remaining: 2.69s
# 71:	learn: 0.2969436	total: 208ms	remaining: 2.68s
# 72:	learn: 0.2945922	total: 210ms	remaining: 2.67s
# 73:	learn: 0.2924480	total: 212ms	remaining: 2.66s
# 74:	learn: 0.2906433	total: 215ms	remaining: 2.65s
# 75:	learn: 0.2887858	total: 217ms	remaining: 2.63s
# 76:	learn: 0.2868974	total: 219ms	remaining: 2.62s
# 77:	learn: 0.2842269	total: 221ms	remaining: 2.61s
# 78:	learn: 0.2816187	total: 223ms	remaining: 2.6s
# 79:	learn: 0.2794305	total: 225ms	remaining: 2.59s
# 80:	learn: 0.2779736	total: 228ms	remaining: 2.58s
# 81:	learn: 0.2750002	total: 230ms	remaining: 2.57s
# 82:	learn: 0.2725199	total: 232ms	remaining: 2.56s
# 83:	learn: 0.2706836	total: 234ms	remaining: 2.55s
# 84:	learn: 0.2682469	total: 236ms	remaining: 2.54s
# 85:	learn: 0.2658617	total: 238ms	remaining: 2.53s
# 86:	learn: 0.2642851	total: 241ms	remaining: 2.52s
# 87:	learn: 0.2623206	total: 243ms	remaining: 2.52s
# 88:	learn: 0.2599983	total: 246ms	remaining: 2.51s
# 89:	learn: 0.2582471	total: 249ms	remaining: 2.52s
# 90:	learn: 0.2559082	total: 251ms	remaining: 2.51s
# 91:	learn: 0.2538579	total: 254ms	remaining: 2.5s
# 92:	learn: 0.2514460	total: 256ms	remaining: 2.5s
# 93:	learn: 0.2491640	total: 258ms	remaining: 2.49s
# 94:	learn: 0.2471570	total: 260ms	remaining: 2.48s
# 95:	learn: 0.2453420	total: 262ms	remaining: 2.47s
# 96:	learn: 0.2431659	total: 265ms	remaining: 2.46s
# 97:	learn: 0.2412755	total: 267ms	remaining: 2.45s
# 98:	learn: 0.2392738	total: 269ms	remaining: 2.45s
# 99:	learn: 0.2379650	total: 271ms	remaining: 2.44s
# 100:	learn: 0.2359745	total: 273ms	remaining: 2.43s
# 101:	learn: 0.2341954	total: 275ms	remaining: 2.42s
# 102:	learn: 0.2331216	total: 277ms	remaining: 2.42s
# 103:	learn: 0.2318517	total: 279ms	remaining: 2.41s
# 104:	learn: 0.2299123	total: 282ms	remaining: 2.4s
# 105:	learn: 0.2278740	total: 284ms	remaining: 2.39s
# 106:	learn: 0.2257834	total: 286ms	remaining: 2.39s
# 107:	learn: 0.2238953	total: 288ms	remaining: 2.38s
# 108:	learn: 0.2221339	total: 290ms	remaining: 2.37s
# 109:	learn: 0.2203789	total: 292ms	remaining: 2.37s
# 110:	learn: 0.2192151	total: 295ms	remaining: 2.36s
# 111:	learn: 0.2177077	total: 297ms	remaining: 2.35s
# 112:	learn: 0.2163319	total: 299ms	remaining: 2.35s
# 113:	learn: 0.2150866	total: 302ms	remaining: 2.34s
# 114:	learn: 0.2133469	total: 304ms	remaining: 2.34s
# 115:	learn: 0.2118510	total: 306ms	remaining: 2.33s
# 116:	learn: 0.2105011	total: 308ms	remaining: 2.32s
# 117:	learn: 0.2092633	total: 310ms	remaining: 2.32s
# 118:	learn: 0.2076280	total: 312ms	remaining: 2.31s
# 119:	learn: 0.2060791	total: 315ms	remaining: 2.31s
# 120:	learn: 0.2048676	total: 317ms	remaining: 2.3s
# 121:	learn: 0.2030567	total: 319ms	remaining: 2.29s
# 122:	learn: 0.2016123	total: 321ms	remaining: 2.29s
# 123:	learn: 0.2000688	total: 323ms	remaining: 2.28s
# 124:	learn: 0.1986175	total: 325ms	remaining: 2.28s
# 125:	learn: 0.1974592	total: 328ms	remaining: 2.27s
# 126:	learn: 0.1959583	total: 330ms	remaining: 2.27s
# 127:	learn: 0.1948387	total: 332ms	remaining: 2.26s
# 128:	learn: 0.1937912	total: 334ms	remaining: 2.26s
# 129:	learn: 0.1923063	total: 336ms	remaining: 2.25s
# 130:	learn: 0.1908228	total: 339ms	remaining: 2.25s
# 131:	learn: 0.1894506	total: 341ms	remaining: 2.24s
# 132:	learn: 0.1880453	total: 343ms	remaining: 2.23s
# 133:	learn: 0.1865301	total: 345ms	remaining: 2.23s
# 134:	learn: 0.1852254	total: 347ms	remaining: 2.22s
# 135:	learn: 0.1840182	total: 349ms	remaining: 2.22s
# 136:	learn: 0.1827032	total: 351ms	remaining: 2.21s
# 137:	learn: 0.1815803	total: 354ms	remaining: 2.21s
# 138:	learn: 0.1799806	total: 356ms	remaining: 2.2s
# 139:	learn: 0.1789578	total: 358ms	remaining: 2.2s
# 140:	learn: 0.1774509	total: 360ms	remaining: 2.19s
# 141:	learn: 0.1758165	total: 362ms	remaining: 2.19s
# 142:	learn: 0.1744499	total: 365ms	remaining: 2.18s
# 143:	learn: 0.1735950	total: 367ms	remaining: 2.18s
# 144:	learn: 0.1720356	total: 369ms	remaining: 2.17s
# 145:	learn: 0.1711051	total: 371ms	remaining: 2.17s
# 146:	learn: 0.1698611	total: 374ms	remaining: 2.17s
# 147:	learn: 0.1686296	total: 376ms	remaining: 2.16s
# 148:	learn: 0.1670116	total: 378ms	remaining: 2.16s
# 149:	learn: 0.1666572	total: 380ms	remaining: 2.15s
# 150:	learn: 0.1652840	total: 382ms	remaining: 2.15s
# 151:	learn: 0.1637726	total: 385ms	remaining: 2.15s
# 152:	learn: 0.1626830	total: 387ms	remaining: 2.14s
# 153:	learn: 0.1616995	total: 389ms	remaining: 2.14s
# 154:	learn: 0.1603371	total: 392ms	remaining: 2.13s
# 155:	learn: 0.1587705	total: 395ms	remaining: 2.14s
# 156:	learn: 0.1579047	total: 398ms	remaining: 2.13s
# 157:	learn: 0.1569313	total: 400ms	remaining: 2.13s
# 158:	learn: 0.1554989	total: 402ms	remaining: 2.13s
# 159:	learn: 0.1543777	total: 404ms	remaining: 2.12s
# 160:	learn: 0.1533023	total: 407ms	remaining: 2.12s
# 161:	learn: 0.1521342	total: 409ms	remaining: 2.11s
# 162:	learn: 0.1513529	total: 411ms	remaining: 2.11s
# 163:	learn: 0.1503015	total: 413ms	remaining: 2.11s
# 164:	learn: 0.1491642	total: 415ms	remaining: 2.1s
# 165:	learn: 0.1481244	total: 418ms	remaining: 2.1s
# 166:	learn: 0.1469525	total: 420ms	remaining: 2.09s
# 167:	learn: 0.1457808	total: 422ms	remaining: 2.09s
# 168:	learn: 0.1445890	total: 424ms	remaining: 2.08s
# 169:	learn: 0.1436520	total: 426ms	remaining: 2.08s
# 170:	learn: 0.1425172	total: 429ms	remaining: 2.08s
# 171:	learn: 0.1416962	total: 431ms	remaining: 2.07s
# 172:	learn: 0.1411190	total: 433ms	remaining: 2.07s
# 173:	learn: 0.1406947	total: 435ms	remaining: 2.06s
# 174:	learn: 0.1396586	total: 437ms	remaining: 2.06s
# 175:	learn: 0.1387084	total: 439ms	remaining: 2.06s
# 176:	learn: 0.1375275	total: 443ms	remaining: 2.06s
# 177:	learn: 0.1363599	total: 445ms	remaining: 2.06s
# 178:	learn: 0.1353261	total: 447ms	remaining: 2.05s
# 179:	learn: 0.1344879	total: 450ms	remaining: 2.05s
# 180:	learn: 0.1336867	total: 452ms	remaining: 2.04s
# 181:	learn: 0.1329160	total: 454ms	remaining: 2.04s
# 182:	learn: 0.1321553	total: 459ms	remaining: 2.05s
# 183:	learn: 0.1310850	total: 461ms	remaining: 2.04s
# 184:	learn: 0.1305171	total: 464ms	remaining: 2.04s
# 185:	learn: 0.1294029	total: 466ms	remaining: 2.04s
# 186:	learn: 0.1284086	total: 469ms	remaining: 2.04s
# 187:	learn: 0.1272886	total: 471ms	remaining: 2.03s
# 188:	learn: 0.1266859	total: 473ms	remaining: 2.03s
# 189:	learn: 0.1257368	total: 476ms	remaining: 2.03s
# 190:	learn: 0.1251005	total: 479ms	remaining: 2.03s
# 191:	learn: 0.1242905	total: 481ms	remaining: 2.02s
# 192:	learn: 0.1236904	total: 484ms	remaining: 2.02s
# 193:	learn: 0.1227365	total: 486ms	remaining: 2.02s
# 194:	learn: 0.1220469	total: 488ms	remaining: 2.02s
# 195:	learn: 0.1210961	total: 491ms	remaining: 2.01s
# 196:	learn: 0.1200775	total: 493ms	remaining: 2.01s
# 197:	learn: 0.1191593	total: 495ms	remaining: 2.01s
# 198:	learn: 0.1182362	total: 498ms	remaining: 2s
# 199:	learn: 0.1175480	total: 500ms	remaining: 2s
# 200:	learn: 0.1162731	total: 502ms	remaining: 2s
# 201:	learn: 0.1154108	total: 504ms	remaining: 1.99s
# 202:	learn: 0.1146527	total: 507ms	remaining: 1.99s
# 203:	learn: 0.1134072	total: 510ms	remaining: 1.99s
# 204:	learn: 0.1126373	total: 512ms	remaining: 1.99s
# 205:	learn: 0.1115787	total: 515ms	remaining: 1.98s
# 206:	learn: 0.1107412	total: 517ms	remaining: 1.98s
# 207:	learn: 0.1102319	total: 519ms	remaining: 1.98s
# 208:	learn: 0.1093980	total: 521ms	remaining: 1.97s
# 209:	learn: 0.1086915	total: 524ms	remaining: 1.97s
# 210:	learn: 0.1076205	total: 526ms	remaining: 1.97s
# 211:	learn: 0.1067691	total: 528ms	remaining: 1.96s
# 212:	learn: 0.1061354	total: 530ms	remaining: 1.96s
# 213:	learn: 0.1053263	total: 532ms	remaining: 1.96s
# 214:	learn: 0.1045906	total: 534ms	remaining: 1.95s
# 215:	learn: 0.1037911	total: 537ms	remaining: 1.95s
# 216:	learn: 0.1027695	total: 539ms	remaining: 1.94s
# 217:	learn: 0.1019433	total: 541ms	remaining: 1.94s
# 218:	learn: 0.1009503	total: 543ms	remaining: 1.94s
# 219:	learn: 0.1001994	total: 545ms	remaining: 1.93s
# 220:	learn: 0.0993699	total: 547ms	remaining: 1.93s
# 221:	learn: 0.0987726	total: 550ms	remaining: 1.93s
# 222:	learn: 0.0981148	total: 552ms	remaining: 1.92s
# 223:	learn: 0.0973331	total: 554ms	remaining: 1.92s
# 224:	learn: 0.0965424	total: 556ms	remaining: 1.92s
# 225:	learn: 0.0955828	total: 558ms	remaining: 1.91s
# 226:	learn: 0.0948543	total: 561ms	remaining: 1.91s
# 227:	learn: 0.0940798	total: 563ms	remaining: 1.91s
# 228:	learn: 0.0935585	total: 565ms	remaining: 1.9s
# 229:	learn: 0.0926996	total: 567ms	remaining: 1.9s
# 230:	learn: 0.0917871	total: 569ms	remaining: 1.9s
# 231:	learn: 0.0910745	total: 572ms	remaining: 1.89s
# 232:	learn: 0.0902726	total: 574ms	remaining: 1.89s
# 233:	learn: 0.0895078	total: 576ms	remaining: 1.88s
# 234:	learn: 0.0891784	total: 578ms	remaining: 1.88s
# 235:	learn: 0.0888062	total: 580ms	remaining: 1.88s
# 236:	learn: 0.0881527	total: 582ms	remaining: 1.87s
# 237:	learn: 0.0873840	total: 584ms	remaining: 1.87s
# 238:	learn: 0.0868982	total: 587ms	remaining: 1.87s
# 239:	learn: 0.0861610	total: 590ms	remaining: 1.87s
# 240:	learn: 0.0857028	total: 593ms	remaining: 1.87s
# 241:	learn: 0.0849345	total: 595ms	remaining: 1.86s
# 242:	learn: 0.0841142	total: 597ms	remaining: 1.86s
# 243:	learn: 0.0834827	total: 599ms	remaining: 1.86s
# 244:	learn: 0.0828179	total: 601ms	remaining: 1.85s
# 245:	learn: 0.0821958	total: 603ms	remaining: 1.85s
# 246:	learn: 0.0817186	total: 606ms	remaining: 1.85s
# 247:	learn: 0.0811805	total: 608ms	remaining: 1.84s
# 248:	learn: 0.0804803	total: 610ms	remaining: 1.84s
# 249:	learn: 0.0797917	total: 612ms	remaining: 1.84s
# 250:	learn: 0.0791816	total: 614ms	remaining: 1.83s
# 251:	learn: 0.0783535	total: 617ms	remaining: 1.83s
# 252:	learn: 0.0778671	total: 619ms	remaining: 1.83s
# 253:	learn: 0.0772222	total: 621ms	remaining: 1.82s
# 254:	learn: 0.0769692	total: 623ms	remaining: 1.82s
# 255:	learn: 0.0763847	total: 626ms	remaining: 1.82s
# 256:	learn: 0.0756280	total: 628ms	remaining: 1.82s
# 257:	learn: 0.0750413	total: 631ms	remaining: 1.81s
# 258:	learn: 0.0745618	total: 633ms	remaining: 1.81s
# 259:	learn: 0.0741064	total: 635ms	remaining: 1.81s
# 260:	learn: 0.0734043	total: 637ms	remaining: 1.8s
# 261:	learn: 0.0730402	total: 640ms	remaining: 1.8s
# 262:	learn: 0.0723487	total: 643ms	remaining: 1.8s
# 263:	learn: 0.0716053	total: 645ms	remaining: 1.8s
# 264:	learn: 0.0712152	total: 647ms	remaining: 1.79s
# 265:	learn: 0.0705980	total: 649ms	remaining: 1.79s
# 266:	learn: 0.0700829	total: 652ms	remaining: 1.79s
# 267:	learn: 0.0696762	total: 654ms	remaining: 1.79s
# 268:	learn: 0.0690773	total: 657ms	remaining: 1.78s
# 269:	learn: 0.0684372	total: 659ms	remaining: 1.78s
# 270:	learn: 0.0680568	total: 661ms	remaining: 1.78s
# 271:	learn: 0.0674790	total: 663ms	remaining: 1.77s
# 272:	learn: 0.0670145	total: 666ms	remaining: 1.77s
# 273:	learn: 0.0663988	total: 668ms	remaining: 1.77s
# 274:	learn: 0.0658877	total: 670ms	remaining: 1.77s
# 275:	learn: 0.0652422	total: 673ms	remaining: 1.76s
# 276:	learn: 0.0646564	total: 675ms	remaining: 1.76s
# 277:	learn: 0.0640678	total: 677ms	remaining: 1.76s
# 278:	learn: 0.0634019	total: 680ms	remaining: 1.76s
# 279:	learn: 0.0628050	total: 682ms	remaining: 1.75s
# 280:	learn: 0.0622917	total: 684ms	remaining: 1.75s
# 281:	learn: 0.0619322	total: 686ms	remaining: 1.75s
# 282:	learn: 0.0612804	total: 688ms	remaining: 1.74s
# 283:	learn: 0.0606448	total: 690ms	remaining: 1.74s
# 284:	learn: 0.0603098	total: 693ms	remaining: 1.74s
# 285:	learn: 0.0598704	total: 695ms	remaining: 1.73s
# 286:	learn: 0.0594295	total: 697ms	remaining: 1.73s
# 287:	learn: 0.0588243	total: 699ms	remaining: 1.73s
# 288:	learn: 0.0583143	total: 701ms	remaining: 1.73s
# 289:	learn: 0.0577914	total: 703ms	remaining: 1.72s
# 290:	learn: 0.0576083	total: 706ms	remaining: 1.72s
# 291:	learn: 0.0571225	total: 708ms	remaining: 1.72s
# 292:	learn: 0.0567901	total: 710ms	remaining: 1.71s
# 293:	learn: 0.0564019	total: 712ms	remaining: 1.71s
# 294:	learn: 0.0560433	total: 714ms	remaining: 1.71s
# 295:	learn: 0.0555476	total: 717ms	remaining: 1.7s
# 296:	learn: 0.0551512	total: 719ms	remaining: 1.7s
# 297:	learn: 0.0547512	total: 721ms	remaining: 1.7s
# 298:	learn: 0.0543495	total: 723ms	remaining: 1.7s
# 299:	learn: 0.0539594	total: 725ms	remaining: 1.69s
# 300:	learn: 0.0534332	total: 728ms	remaining: 1.69s
# 301:	learn: 0.0530624	total: 730ms	remaining: 1.69s
# 302:	learn: 0.0526800	total: 732ms	remaining: 1.68s
# 303:	learn: 0.0523789	total: 734ms	remaining: 1.68s
# 304:	learn: 0.0519340	total: 736ms	remaining: 1.68s
# 305:	learn: 0.0515401	total: 739ms	remaining: 1.68s
# 306:	learn: 0.0512121	total: 741ms	remaining: 1.67s
# 307:	learn: 0.0508301	total: 743ms	remaining: 1.67s
# 308:	learn: 0.0505098	total: 745ms	remaining: 1.67s
# 309:	learn: 0.0501804	total: 748ms	remaining: 1.66s
# 310:	learn: 0.0499111	total: 750ms	remaining: 1.66s
# 311:	learn: 0.0494816	total: 752ms	remaining: 1.66s
# 312:	learn: 0.0489764	total: 754ms	remaining: 1.66s
# 313:	learn: 0.0486906	total: 756ms	remaining: 1.65s
# 314:	learn: 0.0483309	total: 759ms	remaining: 1.65s
# 315:	learn: 0.0478531	total: 761ms	remaining: 1.65s
# 316:	learn: 0.0474594	total: 764ms	remaining: 1.65s
# 317:	learn: 0.0471257	total: 766ms	remaining: 1.64s
# 318:	learn: 0.0468694	total: 768ms	remaining: 1.64s
# 319:	learn: 0.0465128	total: 771ms	remaining: 1.64s
# 320:	learn: 0.0459886	total: 773ms	remaining: 1.63s
# 321:	learn: 0.0455125	total: 775ms	remaining: 1.63s
# 322:	learn: 0.0450888	total: 777ms	remaining: 1.63s
# 323:	learn: 0.0445896	total: 780ms	remaining: 1.63s
# 324:	learn: 0.0443456	total: 783ms	remaining: 1.63s
# 325:	learn: 0.0439379	total: 786ms	remaining: 1.62s
# 326:	learn: 0.0435315	total: 788ms	remaining: 1.62s
# 327:	learn: 0.0431257	total: 790ms	remaining: 1.62s
# 328:	learn: 0.0427408	total: 792ms	remaining: 1.61s
# 329:	learn: 0.0422816	total: 794ms	remaining: 1.61s
# 330:	learn: 0.0419353	total: 796ms	remaining: 1.61s
# 331:	learn: 0.0415645	total: 799ms	remaining: 1.61s
# 332:	learn: 0.0412291	total: 801ms	remaining: 1.6s
# 333:	learn: 0.0408876	total: 803ms	remaining: 1.6s
# 334:	learn: 0.0405254	total: 805ms	remaining: 1.6s
# 335:	learn: 0.0401644	total: 808ms	remaining: 1.6s
# 336:	learn: 0.0399167	total: 810ms	remaining: 1.59s
# 337:	learn: 0.0396738	total: 812ms	remaining: 1.59s
# 338:	learn: 0.0393267	total: 814ms	remaining: 1.59s
# 339:	learn: 0.0390172	total: 816ms	remaining: 1.58s
# 340:	learn: 0.0387018	total: 819ms	remaining: 1.58s
# 341:	learn: 0.0383690	total: 821ms	remaining: 1.58s
# 342:	learn: 0.0380339	total: 823ms	remaining: 1.58s
# 343:	learn: 0.0377385	total: 825ms	remaining: 1.57s
# 344:	learn: 0.0373636	total: 828ms	remaining: 1.57s
# 345:	learn: 0.0370984	total: 830ms	remaining: 1.57s
# 346:	learn: 0.0367942	total: 832ms	remaining: 1.56s
# 347:	learn: 0.0364329	total: 834ms	remaining: 1.56s
# 348:	learn: 0.0360790	total: 837ms	remaining: 1.56s
# 349:	learn: 0.0357113	total: 840ms	remaining: 1.56s
# 350:	learn: 0.0353684	total: 842ms	remaining: 1.56s
# 351:	learn: 0.0350076	total: 844ms	remaining: 1.55s
# 352:	learn: 0.0346754	total: 846ms	remaining: 1.55s
# 353:	learn: 0.0343256	total: 849ms	remaining: 1.55s
# 354:	learn: 0.0340275	total: 851ms	remaining: 1.55s
# 355:	learn: 0.0337090	total: 853ms	remaining: 1.54s
# 356:	learn: 0.0333971	total: 856ms	remaining: 1.54s
# 357:	learn: 0.0330691	total: 858ms	remaining: 1.54s
# 358:	learn: 0.0327969	total: 860ms	remaining: 1.53s
# 359:	learn: 0.0326875	total: 862ms	remaining: 1.53s
# 360:	learn: 0.0323704	total: 864ms	remaining: 1.53s
# 361:	learn: 0.0322636	total: 867ms	remaining: 1.53s
# 362:	learn: 0.0319619	total: 869ms	remaining: 1.52s
# 363:	learn: 0.0316653	total: 871ms	remaining: 1.52s
# 364:	learn: 0.0313600	total: 873ms	remaining: 1.52s
# 365:	learn: 0.0310709	total: 875ms	remaining: 1.51s
# 366:	learn: 0.0307867	total: 877ms	remaining: 1.51s
# 367:	learn: 0.0306867	total: 880ms	remaining: 1.51s
# 368:	learn: 0.0304082	total: 882ms	remaining: 1.51s
# 369:	learn: 0.0301344	total: 884ms	remaining: 1.5s
# 370:	learn: 0.0298653	total: 886ms	remaining: 1.5s
# 371:	learn: 0.0297575	total: 888ms	remaining: 1.5s
# 372:	learn: 0.0295021	total: 890ms	remaining: 1.5s
# 373:	learn: 0.0292414	total: 892ms	remaining: 1.49s
# 374:	learn: 0.0289972	total: 895ms	remaining: 1.49s
# 375:	learn: 0.0288938	total: 897ms	remaining: 1.49s
# 376:	learn: 0.0286542	total: 899ms	remaining: 1.49s
# 377:	learn: 0.0285682	total: 901ms	remaining: 1.48s
# 378:	learn: 0.0283256	total: 903ms	remaining: 1.48s
# 379:	learn: 0.0282027	total: 905ms	remaining: 1.48s
# 380:	learn: 0.0279651	total: 907ms	remaining: 1.47s
# 381:	learn: 0.0278826	total: 910ms	remaining: 1.47s
# 382:	learn: 0.0276526	total: 912ms	remaining: 1.47s
# 383:	learn: 0.0274263	total: 914ms	remaining: 1.47s
# 384:	learn: 0.0271846	total: 916ms	remaining: 1.46s
# 385:	learn: 0.0269602	total: 918ms	remaining: 1.46s
# 386:	learn: 0.0266846	total: 921ms	remaining: 1.46s
# 387:	learn: 0.0264289	total: 923ms	remaining: 1.46s
# 388:	learn: 0.0263517	total: 925ms	remaining: 1.45s
# 389:	learn: 0.0260896	total: 927ms	remaining: 1.45s
# 390:	learn: 0.0260143	total: 929ms	remaining: 1.45s
# 391:	learn: 0.0258303	total: 931ms	remaining: 1.44s
# 392:	learn: 0.0255889	total: 933ms	remaining: 1.44s
# 393:	learn: 0.0253386	total: 936ms	remaining: 1.44s
# 394:	learn: 0.0252663	total: 938ms	remaining: 1.44s
# 395:	learn: 0.0250660	total: 940ms	remaining: 1.43s
# 396:	learn: 0.0249247	total: 942ms	remaining: 1.43s
# 397:	learn: 0.0247854	total: 944ms	remaining: 1.43s
# 398:	learn: 0.0245906	total: 947ms	remaining: 1.43s
# 399:	learn: 0.0244814	total: 949ms	remaining: 1.42s
# 400:	learn: 0.0243238	total: 951ms	remaining: 1.42s
# 401:	learn: 0.0241015	total: 953ms	remaining: 1.42s
# 402:	learn: 0.0239604	total: 955ms	remaining: 1.41s
# 403:	learn: 0.0237382	total: 958ms	remaining: 1.41s
# 404:	learn: 0.0235703	total: 961ms	remaining: 1.41s
# 405:	learn: 0.0234332	total: 963ms	remaining: 1.41s
# 406:	learn: 0.0232917	total: 965ms	remaining: 1.41s
# 407:	learn: 0.0231572	total: 967ms	remaining: 1.4s
# 408:	learn: 0.0230247	total: 969ms	remaining: 1.4s
# 409:	learn: 0.0228897	total: 971ms	remaining: 1.4s
# 410:	learn: 0.0227147	total: 974ms	remaining: 1.4s
# 411:	learn: 0.0225212	total: 976ms	remaining: 1.39s
# 412:	learn: 0.0223197	total: 978ms	remaining: 1.39s
# 413:	learn: 0.0221872	total: 982ms	remaining: 1.39s
# 414:	learn: 0.0219609	total: 984ms	remaining: 1.39s
# 415:	learn: 0.0217545	total: 986ms	remaining: 1.38s
# 416:	learn: 0.0216703	total: 988ms	remaining: 1.38s
# 417:	learn: 0.0214889	total: 991ms	remaining: 1.38s
# 418:	learn: 0.0213634	total: 993ms	remaining: 1.38s
# 419:	learn: 0.0212063	total: 995ms	remaining: 1.37s
# 420:	learn: 0.0210265	total: 997ms	remaining: 1.37s
# 421:	learn: 0.0209042	total: 999ms	remaining: 1.37s
# 422:	learn: 0.0207185	total: 1s	remaining: 1.36s
# 423:	learn: 0.0206394	total: 1s	remaining: 1.36s
# 424:	learn: 0.0204566	total: 1s	remaining: 1.36s
# 425:	learn: 0.0202775	total: 1.01s	remaining: 1.36s
# 426:	learn: 0.0201021	total: 1.01s	remaining: 1.35s
# 427:	learn: 0.0199838	total: 1.01s	remaining: 1.35s
# 428:	learn: 0.0198169	total: 1.01s	remaining: 1.35s
# 429:	learn: 0.0196823	total: 1.02s	remaining: 1.35s
# 430:	learn: 0.0195495	total: 1.02s	remaining: 1.34s
# 431:	learn: 0.0193369	total: 1.02s	remaining: 1.34s
# 432:	learn: 0.0191361	total: 1.02s	remaining: 1.34s
# 433:	learn: 0.0190266	total: 1.02s	remaining: 1.34s
# 434:	learn: 0.0188221	total: 1.03s	remaining: 1.33s
# 435:	learn: 0.0187772	total: 1.03s	remaining: 1.33s
# 436:	learn: 0.0185849	total: 1.03s	remaining: 1.33s
# 437:	learn: 0.0184790	total: 1.03s	remaining: 1.33s
# 438:	learn: 0.0183746	total: 1.04s	remaining: 1.32s
# 439:	learn: 0.0183313	total: 1.04s	remaining: 1.32s
# 440:	learn: 0.0182885	total: 1.04s	remaining: 1.32s
# 441:	learn: 0.0181861	total: 1.04s	remaining: 1.32s
# 442:	learn: 0.0180706	total: 1.04s	remaining: 1.31s
# 443:	learn: 0.0179489	total: 1.05s	remaining: 1.31s
# 444:	learn: 0.0177664	total: 1.05s	remaining: 1.31s
# 445:	learn: 0.0176264	total: 1.05s	remaining: 1.31s
# 446:	learn: 0.0175859	total: 1.05s	remaining: 1.3s
# 447:	learn: 0.0174881	total: 1.06s	remaining: 1.3s
# 448:	learn: 0.0173266	total: 1.06s	remaining: 1.3s
# 449:	learn: 0.0171908	total: 1.06s	remaining: 1.3s
# 450:	learn: 0.0170070	total: 1.06s	remaining: 1.29s
# 451:	learn: 0.0169682	total: 1.06s	remaining: 1.29s
# 452:	learn: 0.0168375	total: 1.07s	remaining: 1.29s
# 453:	learn: 0.0167059	total: 1.07s	remaining: 1.29s
# 454:	learn: 0.0165291	total: 1.07s	remaining: 1.28s
# 455:	learn: 0.0164037	total: 1.07s	remaining: 1.28s
# 456:	learn: 0.0163134	total: 1.08s	remaining: 1.28s
# 457:	learn: 0.0162064	total: 1.08s	remaining: 1.27s
# 458:	learn: 0.0160588	total: 1.08s	remaining: 1.27s
# 459:	learn: 0.0159139	total: 1.08s	remaining: 1.27s
# 460:	learn: 0.0157511	total: 1.08s	remaining: 1.27s
# 461:	learn: 0.0156277	total: 1.09s	remaining: 1.26s
# 462:	learn: 0.0154699	total: 1.09s	remaining: 1.26s
# 463:	learn: 0.0153493	total: 1.09s	remaining: 1.26s
# 464:	learn: 0.0153146	total: 1.09s	remaining: 1.26s
# 465:	learn: 0.0152802	total: 1.09s	remaining: 1.25s
# 466:	learn: 0.0151616	total: 1.1s	remaining: 1.25s
# 467:	learn: 0.0150183	total: 1.1s	remaining: 1.25s
# 468:	learn: 0.0148865	total: 1.1s	remaining: 1.25s
# 469:	learn: 0.0148054	total: 1.1s	remaining: 1.24s
# 470:	learn: 0.0146816	total: 1.11s	remaining: 1.24s
# 471:	learn: 0.0145603	total: 1.11s	remaining: 1.24s
# 472:	learn: 0.0144238	total: 1.11s	remaining: 1.24s
# 473:	learn: 0.0142726	total: 1.11s	remaining: 1.23s
# 474:	learn: 0.0141562	total: 1.11s	remaining: 1.23s
# 475:	learn: 0.0140249	total: 1.12s	remaining: 1.23s
# 476:	learn: 0.0139122	total: 1.12s	remaining: 1.23s
# 477:	learn: 0.0137543	total: 1.12s	remaining: 1.22s
# 478:	learn: 0.0136311	total: 1.12s	remaining: 1.22s
# 479:	learn: 0.0135946	total: 1.13s	remaining: 1.22s
# 480:	learn: 0.0134582	total: 1.13s	remaining: 1.22s
# 481:	learn: 0.0134280	total: 1.13s	remaining: 1.21s
# 482:	learn: 0.0133217	total: 1.13s	remaining: 1.21s
# 483:	learn: 0.0132003	total: 1.13s	remaining: 1.21s
# 484:	learn: 0.0131710	total: 1.14s	remaining: 1.21s
# 485:	learn: 0.0130677	total: 1.14s	remaining: 1.2s
# 486:	learn: 0.0129338	total: 1.14s	remaining: 1.2s
# 487:	learn: 0.0128128	total: 1.14s	remaining: 1.2s
# 488:	learn: 0.0126995	total: 1.15s	remaining: 1.2s
# 489:	learn: 0.0125980	total: 1.15s	remaining: 1.19s
# 490:	learn: 0.0125113	total: 1.15s	remaining: 1.19s
# 491:	learn: 0.0124261	total: 1.15s	remaining: 1.19s
# 492:	learn: 0.0123422	total: 1.15s	remaining: 1.19s
# 493:	learn: 0.0122597	total: 1.16s	remaining: 1.18s
# 494:	learn: 0.0122274	total: 1.16s	remaining: 1.18s
# 495:	learn: 0.0120891	total: 1.16s	remaining: 1.18s
# 496:	learn: 0.0119832	total: 1.16s	remaining: 1.18s
# 497:	learn: 0.0118904	total: 1.16s	remaining: 1.17s
# 498:	learn: 0.0117716	total: 1.17s	remaining: 1.17s
# 499:	learn: 0.0116816	total: 1.17s	remaining: 1.17s
# 500:	learn: 0.0115933	total: 1.17s	remaining: 1.17s
# 501:	learn: 0.0114725	total: 1.17s	remaining: 1.16s
# 502:	learn: 0.0113749	total: 1.18s	remaining: 1.16s
# 503:	learn: 0.0112725	total: 1.18s	remaining: 1.16s
# 504:	learn: 0.0112428	total: 1.18s	remaining: 1.16s
# 505:	learn: 0.0111264	total: 1.18s	remaining: 1.16s
# 506:	learn: 0.0110255	total: 1.19s	remaining: 1.15s
# 507:	learn: 0.0109212	total: 1.19s	remaining: 1.15s
# 508:	learn: 0.0107983	total: 1.19s	remaining: 1.15s
# 509:	learn: 0.0106876	total: 1.19s	remaining: 1.15s
# 510:	learn: 0.0105915	total: 1.2s	remaining: 1.14s
# 511:	learn: 0.0104922	total: 1.2s	remaining: 1.14s
# 512:	learn: 0.0103831	total: 1.2s	remaining: 1.14s
# 513:	learn: 0.0102959	total: 1.2s	remaining: 1.14s
# 514:	learn: 0.0101900	total: 1.2s	remaining: 1.13s
# 515:	learn: 0.0100864	total: 1.21s	remaining: 1.13s
# 516:	learn: 0.0099866	total: 1.21s	remaining: 1.13s
# 517:	learn: 0.0098966	total: 1.21s	remaining: 1.13s
# 518:	learn: 0.0097917	total: 1.21s	remaining: 1.12s
# 519:	learn: 0.0096892	total: 1.22s	remaining: 1.12s
# 520:	learn: 0.0096351	total: 1.22s	remaining: 1.12s
# 521:	learn: 0.0095411	total: 1.22s	remaining: 1.12s
# 522:	learn: 0.0094881	total: 1.22s	remaining: 1.11s
# 523:	learn: 0.0094667	total: 1.22s	remaining: 1.11s
# 524:	learn: 0.0093826	total: 1.23s	remaining: 1.11s
# 525:	learn: 0.0092955	total: 1.23s	remaining: 1.11s
# 526:	learn: 0.0092231	total: 1.23s	remaining: 1.1s
# 527:	learn: 0.0091414	total: 1.23s	remaining: 1.1s
# 528:	learn: 0.0090574	total: 1.24s	remaining: 1.1s
# 529:	learn: 0.0089737	total: 1.24s	remaining: 1.1s
# 530:	learn: 0.0089067	total: 1.24s	remaining: 1.09s
# 531:	learn: 0.0088280	total: 1.24s	remaining: 1.09s
# 532:	learn: 0.0087553	total: 1.24s	remaining: 1.09s
# 533:	learn: 0.0086866	total: 1.25s	remaining: 1.09s
# 534:	learn: 0.0086159	total: 1.25s	remaining: 1.08s
# 535:	learn: 0.0085444	total: 1.25s	remaining: 1.08s
# 536:	learn: 0.0084812	total: 1.25s	remaining: 1.08s
# 537:	learn: 0.0083939	total: 1.25s	remaining: 1.08s
# 538:	learn: 0.0083282	total: 1.26s	remaining: 1.07s
# 539:	learn: 0.0082559	total: 1.26s	remaining: 1.07s
# 540:	learn: 0.0081892	total: 1.26s	remaining: 1.07s
# 541:	learn: 0.0081175	total: 1.26s	remaining: 1.07s
# 542:	learn: 0.0080372	total: 1.27s	remaining: 1.06s
# 543:	learn: 0.0079778	total: 1.27s	remaining: 1.06s
# 544:	learn: 0.0079197	total: 1.27s	remaining: 1.06s
# 545:	learn: 0.0078487	total: 1.27s	remaining: 1.06s
# 546:	learn: 0.0077919	total: 1.27s	remaining: 1.05s
# 547:	learn: 0.0077162	total: 1.28s	remaining: 1.05s
# 548:	learn: 0.0076451	total: 1.28s	remaining: 1.05s
# 549:	learn: 0.0075904	total: 1.28s	remaining: 1.05s
# 550:	learn: 0.0075368	total: 1.28s	remaining: 1.04s
# 551:	learn: 0.0074694	total: 1.28s	remaining: 1.04s
# 552:	learn: 0.0074171	total: 1.29s	remaining: 1.04s
# 553:	learn: 0.0073512	total: 1.29s	remaining: 1.04s
# 554:	learn: 0.0072794	total: 1.29s	remaining: 1.03s
# 555:	learn: 0.0072255	total: 1.29s	remaining: 1.03s
# 556:	learn: 0.0071724	total: 1.3s	remaining: 1.03s
# 557:	learn: 0.0071224	total: 1.3s	remaining: 1.03s
# 558:	learn: 0.0070707	total: 1.3s	remaining: 1.03s
# 559:	learn: 0.0069994	total: 1.3s	remaining: 1.02s
# 560:	learn: 0.0069322	total: 1.3s	remaining: 1.02s
# 561:	learn: 0.0068835	total: 1.31s	remaining: 1.02s
# 562:	learn: 0.0068157	total: 1.31s	remaining: 1.02s
# 563:	learn: 0.0067683	total: 1.31s	remaining: 1.01s
# 564:	learn: 0.0066968	total: 1.31s	remaining: 1.01s
# 565:	learn: 0.0066499	total: 1.31s	remaining: 1.01s
# 566:	learn: 0.0065849	total: 1.32s	remaining: 1.01s
# 567:	learn: 0.0065301	total: 1.32s	remaining: 1s
# 568:	learn: 0.0065096	total: 1.32s	remaining: 1s
# 569:	learn: 0.0064642	total: 1.32s	remaining: 999ms
# 570:	learn: 0.0063993	total: 1.33s	remaining: 997ms
# 571:	learn: 0.0063353	total: 1.33s	remaining: 994ms
# 572:	learn: 0.0062734	total: 1.33s	remaining: 992ms
# 573:	learn: 0.0062565	total: 1.33s	remaining: 989ms
# 574:	learn: 0.0062045	total: 1.33s	remaining: 987ms
# 575:	learn: 0.0061889	total: 1.34s	remaining: 984ms
# 576:	learn: 0.0061316	total: 1.34s	remaining: 982ms
# 577:	learn: 0.0061125	total: 1.34s	remaining: 979ms
# 578:	learn: 0.0060620	total: 1.34s	remaining: 977ms
# 579:	learn: 0.0060025	total: 1.34s	remaining: 975ms
# 580:	learn: 0.0059501	total: 1.35s	remaining: 972ms
# 581:	learn: 0.0059270	total: 1.35s	remaining: 970ms
# 582:	learn: 0.0058675	total: 1.35s	remaining: 967ms
# 583:	learn: 0.0058163	total: 1.35s	remaining: 965ms
# 584:	learn: 0.0057845	total: 1.36s	remaining: 962ms
# 585:	learn: 0.0057404	total: 1.36s	remaining: 960ms
# 586:	learn: 0.0057093	total: 1.36s	remaining: 958ms
# 587:	learn: 0.0056526	total: 1.36s	remaining: 955ms
# 588:	learn: 0.0056223	total: 1.36s	remaining: 953ms
# 589:	learn: 0.0055765	total: 1.37s	remaining: 950ms
# 590:	learn: 0.0055184	total: 1.37s	remaining: 948ms
# 591:	learn: 0.0055046	total: 1.37s	remaining: 945ms
# 592:	learn: 0.0054630	total: 1.37s	remaining: 943ms
# 593:	learn: 0.0054495	total: 1.38s	remaining: 942ms
# 594:	learn: 0.0054206	total: 1.38s	remaining: 940ms
# 595:	learn: 0.0053800	total: 1.38s	remaining: 937ms
# 596:	learn: 0.0053517	total: 1.38s	remaining: 935ms
# 597:	learn: 0.0053033	total: 1.39s	remaining: 933ms
# 598:	learn: 0.0052489	total: 1.39s	remaining: 930ms
# 599:	learn: 0.0052029	total: 1.39s	remaining: 928ms
# 600:	learn: 0.0051901	total: 1.39s	remaining: 925ms
# 601:	learn: 0.0051487	total: 1.4s	remaining: 923ms
# 602:	learn: 0.0051039	total: 1.4s	remaining: 921ms
# 603:	learn: 0.0050915	total: 1.4s	remaining: 918ms
# 604:	learn: 0.0050531	total: 1.4s	remaining: 916ms
# 605:	learn: 0.0050017	total: 1.4s	remaining: 913ms
# 606:	learn: 0.0049617	total: 1.41s	remaining: 911ms
# 607:	learn: 0.0049337	total: 1.41s	remaining: 909ms
# 608:	learn: 0.0048865	total: 1.41s	remaining: 906ms
# 609:	learn: 0.0048403	total: 1.41s	remaining: 904ms
# 610:	learn: 0.0048046	total: 1.42s	remaining: 901ms
# 611:	learn: 0.0047655	total: 1.42s	remaining: 899ms
# 612:	learn: 0.0047209	total: 1.42s	remaining: 897ms
# 613:	learn: 0.0046772	total: 1.42s	remaining: 895ms
# 614:	learn: 0.0046430	total: 1.43s	remaining: 893ms
# 615:	learn: 0.0046004	total: 1.43s	remaining: 891ms
# 616:	learn: 0.0045521	total: 1.43s	remaining: 888ms
# 617:	learn: 0.0045129	total: 1.43s	remaining: 886ms
# 618:	learn: 0.0044780	total: 1.44s	remaining: 883ms
# 619:	learn: 0.0044412	total: 1.44s	remaining: 881ms
# 620:	learn: 0.0044051	total: 1.44s	remaining: 879ms
# 621:	learn: 0.0043652	total: 1.44s	remaining: 876ms
# 622:	learn: 0.0043301	total: 1.44s	remaining: 874ms
# 623:	learn: 0.0043202	total: 1.45s	remaining: 871ms
# 624:	learn: 0.0043104	total: 1.45s	remaining: 869ms
# 625:	learn: 0.0043008	total: 1.45s	remaining: 867ms
# 626:	learn: 0.0042576	total: 1.45s	remaining: 864ms
# 627:	learn: 0.0042153	total: 1.45s	remaining: 862ms
# 628:	learn: 0.0042059	total: 1.46s	remaining: 859ms
# 629:	learn: 0.0041852	total: 1.46s	remaining: 858ms
# 630:	learn: 0.0041760	total: 1.46s	remaining: 856ms
# 631:	learn: 0.0041356	total: 1.47s	remaining: 853ms
# 632:	learn: 0.0041082	total: 1.47s	remaining: 851ms
# 633:	learn: 0.0040881	total: 1.47s	remaining: 849ms
# 634:	learn: 0.0040792	total: 1.47s	remaining: 847ms
# 635:	learn: 0.0040703	total: 1.48s	remaining: 845ms
# 636:	learn: 0.0040506	total: 1.48s	remaining: 843ms
# 637:	learn: 0.0040425	total: 1.48s	remaining: 840ms
# 638:	learn: 0.0040119	total: 1.48s	remaining: 838ms
# 639:	learn: 0.0039926	total: 1.49s	remaining: 836ms
# 640:	learn: 0.0039846	total: 1.49s	remaining: 835ms
# 641:	learn: 0.0039762	total: 1.5s	remaining: 835ms
# 642:	learn: 0.0039469	total: 1.5s	remaining: 833ms
# 643:	learn: 0.0039244	total: 1.5s	remaining: 831ms
# 644:	learn: 0.0039167	total: 1.51s	remaining: 829ms
# 645:	learn: 0.0038928	total: 1.51s	remaining: 827ms
# 646:	learn: 0.0038709	total: 1.51s	remaining: 824ms
# 647:	learn: 0.0038633	total: 1.51s	remaining: 822ms
# 648:	learn: 0.0038436	total: 1.51s	remaining: 819ms
# 649:	learn: 0.0038254	total: 1.52s	remaining: 817ms
# 650:	learn: 0.0038179	total: 1.52s	remaining: 814ms
# 651:	learn: 0.0037941	total: 1.52s	remaining: 812ms
# 652:	learn: 0.0037707	total: 1.52s	remaining: 810ms
# 653:	learn: 0.0037529	total: 1.53s	remaining: 807ms
# 654:	learn: 0.0037238	total: 1.53s	remaining: 805ms
# 655:	learn: 0.0037166	total: 1.53s	remaining: 803ms
# 656:	learn: 0.0037012	total: 1.53s	remaining: 800ms
# 657:	learn: 0.0036783	total: 1.53s	remaining: 798ms
# 658:	learn: 0.0036500	total: 1.54s	remaining: 795ms
# 659:	learn: 0.0036137	total: 1.54s	remaining: 793ms
# 660:	learn: 0.0035908	total: 1.54s	remaining: 790ms
# 661:	learn: 0.0035612	total: 1.54s	remaining: 788ms
# 662:	learn: 0.0035304	total: 1.54s	remaining: 786ms
# 663:	learn: 0.0035002	total: 1.55s	remaining: 783ms
# 664:	learn: 0.0034705	total: 1.55s	remaining: 781ms
# 665:	learn: 0.0034395	total: 1.55s	remaining: 778ms
# 666:	learn: 0.0034105	total: 1.55s	remaining: 776ms
# 667:	learn: 0.0033913	total: 1.56s	remaining: 774ms
# 668:	learn: 0.0033629	total: 1.56s	remaining: 771ms
# 669:	learn: 0.0033272	total: 1.56s	remaining: 769ms
# 670:	learn: 0.0032978	total: 1.56s	remaining: 766ms
# 671:	learn: 0.0032913	total: 1.56s	remaining: 764ms
# 672:	learn: 0.0032717	total: 1.57s	remaining: 761ms
# 673:	learn: 0.0032374	total: 1.57s	remaining: 759ms
# 674:	learn: 0.0032081	total: 1.57s	remaining: 757ms
# 675:	learn: 0.0031840	total: 1.57s	remaining: 755ms
# 676:	learn: 0.0031619	total: 1.58s	remaining: 753ms
# 677:	learn: 0.0031278	total: 1.58s	remaining: 751ms
# 678:	learn: 0.0031215	total: 1.58s	remaining: 748ms
# 679:	learn: 0.0030936	total: 1.58s	remaining: 746ms
# 680:	learn: 0.0030875	total: 1.59s	remaining: 744ms
# 681:	learn: 0.0030626	total: 1.59s	remaining: 741ms
# 682:	learn: 0.0030299	total: 1.59s	remaining: 739ms
# 683:	learn: 0.0030008	total: 1.59s	remaining: 737ms
# 684:	learn: 0.0029724	total: 1.6s	remaining: 734ms
# 685:	learn: 0.0029659	total: 1.6s	remaining: 732ms
# 686:	learn: 0.0029601	total: 1.6s	remaining: 729ms
# 687:	learn: 0.0029325	total: 1.6s	remaining: 727ms
# 688:	learn: 0.0029090	total: 1.6s	remaining: 724ms
# 689:	learn: 0.0028844	total: 1.61s	remaining: 722ms
# 690:	learn: 0.0028782	total: 1.61s	remaining: 720ms
# 691:	learn: 0.0028718	total: 1.61s	remaining: 717ms
# 692:	learn: 0.0028493	total: 1.61s	remaining: 715ms
# 693:	learn: 0.0028273	total: 1.62s	remaining: 713ms
# 694:	learn: 0.0028061	total: 1.62s	remaining: 712ms
# 695:	learn: 0.0028002	total: 1.62s	remaining: 710ms
# 696:	learn: 0.0027719	total: 1.63s	remaining: 707ms
# 697:	learn: 0.0027658	total: 1.63s	remaining: 705ms
# 698:	learn: 0.0027468	total: 1.63s	remaining: 703ms
# 699:	learn: 0.0027261	total: 1.64s	remaining: 701ms
# 700:	learn: 0.0027202	total: 1.64s	remaining: 698ms
# 701:	learn: 0.0027003	total: 1.64s	remaining: 696ms
# 702:	learn: 0.0026796	total: 1.64s	remaining: 694ms
# 703:	learn: 0.0026601	total: 1.64s	remaining: 691ms
# 704:	learn: 0.0026353	total: 1.65s	remaining: 689ms
# 705:	learn: 0.0026136	total: 1.65s	remaining: 687ms
# 706:	learn: 0.0026081	total: 1.65s	remaining: 684ms
# 707:	learn: 0.0025924	total: 1.65s	remaining: 682ms
# 708:	learn: 0.0025663	total: 1.66s	remaining: 679ms
# 709:	learn: 0.0025476	total: 1.66s	remaining: 677ms
# 710:	learn: 0.0025321	total: 1.66s	remaining: 675ms
# 711:	learn: 0.0025125	total: 1.66s	remaining: 672ms
# 712:	learn: 0.0024935	total: 1.66s	remaining: 670ms
# 713:	learn: 0.0024706	total: 1.67s	remaining: 668ms
# 714:	learn: 0.0024561	total: 1.67s	remaining: 665ms
# 715:	learn: 0.0024365	total: 1.67s	remaining: 663ms
# 716:	learn: 0.0024313	total: 1.67s	remaining: 660ms
# 717:	learn: 0.0024038	total: 1.68s	remaining: 658ms
# 718:	learn: 0.0023987	total: 1.68s	remaining: 656ms
# 719:	learn: 0.0023935	total: 1.68s	remaining: 653ms
# 720:	learn: 0.0023667	total: 1.68s	remaining: 651ms
# 721:	learn: 0.0023499	total: 1.68s	remaining: 649ms
# 722:	learn: 0.0023448	total: 1.69s	remaining: 646ms
# 723:	learn: 0.0023274	total: 1.69s	remaining: 644ms
# 724:	learn: 0.0023103	total: 1.69s	remaining: 642ms
# 725:	learn: 0.0022846	total: 1.69s	remaining: 639ms
# 726:	learn: 0.0022663	total: 1.7s	remaining: 637ms
# 727:	learn: 0.0022485	total: 1.7s	remaining: 635ms
# 728:	learn: 0.0022438	total: 1.7s	remaining: 632ms
# 729:	learn: 0.0022275	total: 1.7s	remaining: 630ms
# 730:	learn: 0.0022147	total: 1.71s	remaining: 628ms
# 731:	learn: 0.0021989	total: 1.71s	remaining: 625ms
# 732:	learn: 0.0021864	total: 1.71s	remaining: 623ms
# 733:	learn: 0.0021732	total: 1.71s	remaining: 621ms
# 734:	learn: 0.0021579	total: 1.71s	remaining: 618ms
# 735:	learn: 0.0021435	total: 1.72s	remaining: 616ms
# 736:	learn: 0.0021246	total: 1.72s	remaining: 613ms
# 737:	learn: 0.0021065	total: 1.72s	remaining: 611ms
# 738:	learn: 0.0020882	total: 1.72s	remaining: 609ms
# 739:	learn: 0.0020696	total: 1.73s	remaining: 606ms
# 740:	learn: 0.0020506	total: 1.73s	remaining: 604ms
# 741:	learn: 0.0020322	total: 1.73s	remaining: 602ms
# 742:	learn: 0.0020182	total: 1.73s	remaining: 600ms
# 743:	learn: 0.0020045	total: 1.74s	remaining: 597ms
# 744:	learn: 0.0020007	total: 1.74s	remaining: 595ms
# 745:	learn: 0.0019830	total: 1.74s	remaining: 592ms
# 746:	learn: 0.0019793	total: 1.74s	remaining: 590ms
# 747:	learn: 0.0019757	total: 1.74s	remaining: 588ms
# 748:	learn: 0.0019612	total: 1.75s	remaining: 585ms
# 749:	learn: 0.0019502	total: 1.75s	remaining: 583ms
# 750:	learn: 0.0019332	total: 1.75s	remaining: 581ms
# 751:	learn: 0.0019296	total: 1.75s	remaining: 578ms
# 752:	learn: 0.0019129	total: 1.75s	remaining: 576ms
# 753:	learn: 0.0018956	total: 1.76s	remaining: 573ms
# 754:	learn: 0.0018793	total: 1.76s	remaining: 571ms
# 755:	learn: 0.0018626	total: 1.76s	remaining: 569ms
# 756:	learn: 0.0018471	total: 1.76s	remaining: 566ms
# 757:	learn: 0.0018306	total: 1.77s	remaining: 564ms
# 758:	learn: 0.0018181	total: 1.77s	remaining: 562ms
# 759:	learn: 0.0018081	total: 1.77s	remaining: 560ms
# 760:	learn: 0.0017947	total: 1.77s	remaining: 558ms
# 761:	learn: 0.0017913	total: 1.78s	remaining: 555ms
# 762:	learn: 0.0017880	total: 1.78s	remaining: 553ms
# 763:	learn: 0.0017727	total: 1.78s	remaining: 551ms
# 764:	learn: 0.0017582	total: 1.78s	remaining: 548ms
# 765:	learn: 0.0017453	total: 1.79s	remaining: 546ms
# 766:	learn: 0.0017421	total: 1.79s	remaining: 544ms
# 767:	learn: 0.0017273	total: 1.79s	remaining: 541ms
# 768:	learn: 0.0017133	total: 1.79s	remaining: 539ms
# 769:	learn: 0.0016989	total: 1.8s	remaining: 537ms
# 770:	learn: 0.0016851	total: 1.8s	remaining: 534ms
# 771:	learn: 0.0016821	total: 1.8s	remaining: 532ms
# 772:	learn: 0.0016686	total: 1.8s	remaining: 529ms
# 773:	learn: 0.0016656	total: 1.8s	remaining: 527ms
# 774:	learn: 0.0016517	total: 1.81s	remaining: 525ms
# 775:	learn: 0.0016385	total: 1.81s	remaining: 522ms
# 776:	learn: 0.0016270	total: 1.81s	remaining: 520ms
# 777:	learn: 0.0016143	total: 1.81s	remaining: 517ms
# 778:	learn: 0.0016113	total: 1.82s	remaining: 515ms
# 779:	learn: 0.0015980	total: 1.82s	remaining: 513ms
# 780:	learn: 0.0015813	total: 1.82s	remaining: 511ms
# 781:	learn: 0.0015698	total: 1.82s	remaining: 508ms
# 782:	learn: 0.0015569	total: 1.83s	remaining: 506ms
# 783:	learn: 0.0015442	total: 1.83s	remaining: 504ms
# 784:	learn: 0.0015314	total: 1.83s	remaining: 501ms
# 785:	learn: 0.0015215	total: 1.83s	remaining: 499ms
# 786:	learn: 0.0015091	total: 1.83s	remaining: 497ms
# 787:	learn: 0.0014995	total: 1.84s	remaining: 494ms
# 788:	learn: 0.0014968	total: 1.84s	remaining: 492ms
# 789:	learn: 0.0014847	total: 1.84s	remaining: 490ms
# 790:	learn: 0.0014820	total: 1.84s	remaining: 487ms
# 791:	learn: 0.0014705	total: 1.84s	remaining: 485ms
# 792:	learn: 0.0014674	total: 1.85s	remaining: 482ms
# 793:	learn: 0.0014523	total: 1.85s	remaining: 480ms
# 794:	learn: 0.0014390	total: 1.85s	remaining: 478ms
# 795:	learn: 0.0014360	total: 1.85s	remaining: 475ms
# 796:	learn: 0.0014240	total: 1.86s	remaining: 473ms
# 797:	learn: 0.0014149	total: 1.86s	remaining: 471ms
# 798:	learn: 0.0014035	total: 1.86s	remaining: 468ms
# 799:	learn: 0.0014006	total: 1.86s	remaining: 466ms
# 800:	learn: 0.0013885	total: 1.86s	remaining: 463ms
# 801:	learn: 0.0013778	total: 1.87s	remaining: 461ms
# 802:	learn: 0.0013670	total: 1.87s	remaining: 459ms
# 803:	learn: 0.0013567	total: 1.87s	remaining: 456ms
# 804:	learn: 0.0013462	total: 1.87s	remaining: 454ms
# 805:	learn: 0.0013386	total: 1.88s	remaining: 452ms
# 806:	learn: 0.0013333	total: 1.88s	remaining: 449ms
# 807:	learn: 0.0013223	total: 1.88s	remaining: 447ms
# 808:	learn: 0.0013132	total: 1.88s	remaining: 445ms
# 809:	learn: 0.0013042	total: 1.88s	remaining: 442ms
# 810:	learn: 0.0012936	total: 1.89s	remaining: 440ms
# 811:	learn: 0.0012832	total: 1.89s	remaining: 437ms
# 812:	learn: 0.0012753	total: 1.89s	remaining: 435ms
# 813:	learn: 0.0012655	total: 1.89s	remaining: 433ms
# 814:	learn: 0.0012615	total: 1.9s	remaining: 430ms
# 815:	learn: 0.0012527	total: 1.9s	remaining: 428ms
# 816:	learn: 0.0012459	total: 1.9s	remaining: 426ms
# 817:	learn: 0.0012372	total: 1.9s	remaining: 423ms
# 818:	learn: 0.0012333	total: 1.9s	remaining: 421ms
# 819:	learn: 0.0012247	total: 1.91s	remaining: 419ms
# 820:	learn: 0.0012209	total: 1.91s	remaining: 416ms
# 821:	learn: 0.0012125	total: 1.91s	remaining: 414ms
# 822:	learn: 0.0012087	total: 1.91s	remaining: 412ms
# 823:	learn: 0.0012005	total: 1.92s	remaining: 409ms
# 824:	learn: 0.0011967	total: 1.92s	remaining: 407ms
# 825:	learn: 0.0011903	total: 1.92s	remaining: 405ms
# 826:	learn: 0.0011823	total: 1.92s	remaining: 402ms
# 827:	learn: 0.0011744	total: 1.93s	remaining: 400ms
# 828:	learn: 0.0011707	total: 1.93s	remaining: 398ms
# 829:	learn: 0.0011629	total: 1.93s	remaining: 396ms
# 830:	learn: 0.0011593	total: 1.93s	remaining: 393ms
# 831:	learn: 0.0011517	total: 1.94s	remaining: 391ms
# 832:	learn: 0.0011481	total: 1.94s	remaining: 388ms
# 833:	learn: 0.0011406	total: 1.94s	remaining: 386ms
# 834:	learn: 0.0011346	total: 1.94s	remaining: 384ms
# 835:	learn: 0.0011272	total: 1.94s	remaining: 381ms
# 836:	learn: 0.0011237	total: 1.95s	remaining: 379ms
# 837:	learn: 0.0011165	total: 1.95s	remaining: 377ms
# 838:	learn: 0.0011131	total: 1.95s	remaining: 374ms
# 839:	learn: 0.0011071	total: 1.95s	remaining: 372ms
# 840:	learn: 0.0011037	total: 1.95s	remaining: 370ms
# 841:	learn: 0.0010962	total: 1.96s	remaining: 367ms
# 842:	learn: 0.0010928	total: 1.96s	remaining: 365ms
# 843:	learn: 0.0010870	total: 1.96s	remaining: 363ms
# 844:	learn: 0.0010837	total: 1.96s	remaining: 360ms
# 845:	learn: 0.0010768	total: 1.97s	remaining: 358ms
# 846:	learn: 0.0010711	total: 1.97s	remaining: 355ms
# 847:	learn: 0.0010679	total: 1.97s	remaining: 353ms
# 848:	learn: 0.0010622	total: 1.97s	remaining: 351ms
# 849:	learn: 0.0010590	total: 1.98s	remaining: 349ms
# 850:	learn: 0.0010532	total: 1.98s	remaining: 346ms
# 851:	learn: 0.0010465	total: 1.98s	remaining: 344ms
# 852:	learn: 0.0010410	total: 1.98s	remaining: 342ms
# 853:	learn: 0.0010346	total: 1.98s	remaining: 339ms
# 854:	learn: 0.0010315	total: 1.99s	remaining: 337ms
# 855:	learn: 0.0010270	total: 1.99s	remaining: 335ms
# 856:	learn: 0.0010169	total: 1.99s	remaining: 332ms
# 857:	learn: 0.0010070	total: 1.99s	remaining: 330ms
# 858:	learn: 0.0010027	total: 1.99s	remaining: 327ms
# 859:	learn: 0.0009941	total: 2s	remaining: 325ms
# 860:	learn: 0.0009879	total: 2s	remaining: 323ms
# 861:	learn: 0.0009801	total: 2s	remaining: 320ms
# 862:	learn: 0.0009751	total: 2s	remaining: 318ms
# 863:	learn: 0.0009689	total: 2s	remaining: 316ms
# 864:	learn: 0.0009591	total: 2.01s	remaining: 313ms
# 865:	learn: 0.0009488	total: 2.01s	remaining: 311ms
# 866:	learn: 0.0009440	total: 2.01s	remaining: 309ms
# 867:	learn: 0.0009350	total: 2.02s	remaining: 307ms
# 868:	learn: 0.0009285	total: 2.02s	remaining: 304ms
# 869:	learn: 0.0009179	total: 2.02s	remaining: 302ms
# 870:	learn: 0.0009092	total: 2.02s	remaining: 300ms
# 871:	learn: 0.0008998	total: 2.02s	remaining: 297ms
# 872:	learn: 0.0008936	total: 2.03s	remaining: 295ms
# 873:	learn: 0.0008866	total: 2.03s	remaining: 293ms
# 874:	learn: 0.0008806	total: 2.03s	remaining: 290ms
# 875:	learn: 0.0008737	total: 2.03s	remaining: 288ms
# 876:	learn: 0.0008645	total: 2.04s	remaining: 285ms
# 877:	learn: 0.0008576	total: 2.04s	remaining: 283ms
# 878:	learn: 0.0008519	total: 2.04s	remaining: 281ms
# 879:	learn: 0.0008430	total: 2.04s	remaining: 278ms
# 880:	learn: 0.0008363	total: 2.04s	remaining: 276ms
# 881:	learn: 0.0008269	total: 2.05s	remaining: 274ms
# 882:	learn: 0.0008202	total: 2.05s	remaining: 271ms
# 883:	learn: 0.0008137	total: 2.05s	remaining: 269ms
# 884:	learn: 0.0008071	total: 2.05s	remaining: 267ms
# 885:	learn: 0.0008007	total: 2.05s	remaining: 264ms
# 886:	learn: 0.0007918	total: 2.06s	remaining: 262ms
# 887:	learn: 0.0007830	total: 2.06s	remaining: 260ms
# 888:	learn: 0.0007769	total: 2.06s	remaining: 257ms
# 889:	learn: 0.0007706	total: 2.06s	remaining: 255ms
# 890:	learn: 0.0007639	total: 2.06s	remaining: 253ms
# 891:	learn: 0.0007571	total: 2.07s	remaining: 250ms
# 892:	learn: 0.0007513	total: 2.07s	remaining: 248ms
# 893:	learn: 0.0007448	total: 2.07s	remaining: 246ms
# 894:	learn: 0.0007390	total: 2.07s	remaining: 243ms
# 895:	learn: 0.0007314	total: 2.08s	remaining: 241ms
# 896:	learn: 0.0007248	total: 2.08s	remaining: 239ms
# 897:	learn: 0.0007190	total: 2.08s	remaining: 236ms
# 898:	learn: 0.0007129	total: 2.08s	remaining: 234ms
# 899:	learn: 0.0007070	total: 2.08s	remaining: 232ms
# 900:	learn: 0.0007009	total: 2.09s	remaining: 229ms
# 901:	learn: 0.0006966	total: 2.09s	remaining: 227ms
# 902:	learn: 0.0006904	total: 2.09s	remaining: 225ms
# 903:	learn: 0.0006839	total: 2.09s	remaining: 222ms
# 904:	learn: 0.0006764	total: 2.1s	remaining: 220ms
# 905:	learn: 0.0006693	total: 2.1s	remaining: 218ms
# 906:	learn: 0.0006621	total: 2.1s	remaining: 215ms
# 907:	learn: 0.0006594	total: 2.1s	remaining: 213ms
# 908:	learn: 0.0006526	total: 2.1s	remaining: 211ms
# 909:	learn: 0.0006453	total: 2.11s	remaining: 208ms
# 910:	learn: 0.0006407	total: 2.11s	remaining: 206ms
# 911:	learn: 0.0006377	total: 2.11s	remaining: 204ms
# 912:	learn: 0.0006326	total: 2.11s	remaining: 201ms
# 913:	learn: 0.0006261	total: 2.11s	remaining: 199ms
# 914:	learn: 0.0006216	total: 2.12s	remaining: 197ms
# 915:	learn: 0.0006161	total: 2.12s	remaining: 194ms
# 916:	learn: 0.0006113	total: 2.12s	remaining: 192ms
# 917:	learn: 0.0006048	total: 2.12s	remaining: 190ms
# 918:	learn: 0.0006021	total: 2.13s	remaining: 187ms
# 919:	learn: 0.0005975	total: 2.13s	remaining: 185ms
# 920:	learn: 0.0005947	total: 2.13s	remaining: 183ms
# 921:	learn: 0.0005904	total: 2.13s	remaining: 180ms
# 922:	learn: 0.0005852	total: 2.13s	remaining: 178ms
# 923:	learn: 0.0005795	total: 2.14s	remaining: 176ms
# 924:	learn: 0.0005770	total: 2.14s	remaining: 173ms
# 925:	learn: 0.0005725	total: 2.14s	remaining: 171ms
# 926:	learn: 0.0005674	total: 2.14s	remaining: 169ms
# 927:	learn: 0.0005618	total: 2.14s	remaining: 166ms
# 928:	learn: 0.0005594	total: 2.15s	remaining: 164ms
# 929:	learn: 0.0005570	total: 2.15s	remaining: 162ms
# 930:	learn: 0.0005520	total: 2.15s	remaining: 159ms
# 931:	learn: 0.0005478	total: 2.15s	remaining: 157ms
# 932:	learn: 0.0005455	total: 2.15s	remaining: 155ms
# 933:	learn: 0.0005407	total: 2.16s	remaining: 152ms
# 934:	learn: 0.0005358	total: 2.16s	remaining: 150ms
# 935:	learn: 0.0005312	total: 2.16s	remaining: 148ms
# 936:	learn: 0.0005298	total: 2.16s	remaining: 146ms
# 937:	learn: 0.0005252	total: 2.17s	remaining: 143ms
# 938:	learn: 0.0005204	total: 2.17s	remaining: 141ms
# 939:	learn: 0.0005161	total: 2.17s	remaining: 139ms
# 940:	learn: 0.0005127	total: 2.17s	remaining: 136ms
# 941:	learn: 0.0005113	total: 2.18s	remaining: 134ms
# 942:	learn: 0.0005073	total: 2.18s	remaining: 132ms
# 943:	learn: 0.0005038	total: 2.18s	remaining: 129ms
# 944:	learn: 0.0005025	total: 2.18s	remaining: 127ms
# 945:	learn: 0.0004991	total: 2.19s	remaining: 125ms
# 946:	learn: 0.0004947	total: 2.19s	remaining: 122ms
# 947:	learn: 0.0004908	total: 2.19s	remaining: 120ms
# 948:	learn: 0.0004887	total: 2.19s	remaining: 118ms
# 949:	learn: 0.0004874	total: 2.19s	remaining: 116ms
# 950:	learn: 0.0004837	total: 2.2s	remaining: 113ms
# 951:	learn: 0.0004791	total: 2.2s	remaining: 111ms
# 952:	learn: 0.0004746	total: 2.2s	remaining: 109ms
# 953:	learn: 0.0004718	total: 2.2s	remaining: 106ms
# 954:	learn: 0.0004680	total: 2.21s	remaining: 104ms
# 955:	learn: 0.0004642	total: 2.21s	remaining: 102ms
# 956:	learn: 0.0004593	total: 2.21s	remaining: 99.3ms
# 957:	learn: 0.0004559	total: 2.21s	remaining: 97ms
# 958:	learn: 0.0004523	total: 2.21s	remaining: 94.7ms
# 959:	learn: 0.0004491	total: 2.22s	remaining: 92.4ms
# 960:	learn: 0.0004449	total: 2.22s	remaining: 90.1ms
# 961:	learn: 0.0004412	total: 2.22s	remaining: 87.8ms
# 962:	learn: 0.0004367	total: 2.22s	remaining: 85.5ms
# 963:	learn: 0.0004333	total: 2.23s	remaining: 83.1ms
# 964:	learn: 0.0004308	total: 2.23s	remaining: 80.8ms
# 965:	learn: 0.0004276	total: 2.23s	remaining: 78.5ms
# 966:	learn: 0.0004247	total: 2.23s	remaining: 76.2ms
# 967:	learn: 0.0004211	total: 2.23s	remaining: 73.9ms
# 968:	learn: 0.0004169	total: 2.24s	remaining: 71.6ms
# 969:	learn: 0.0004132	total: 2.24s	remaining: 69.3ms
# 970:	learn: 0.0004091	total: 2.24s	remaining: 66.9ms
# 971:	learn: 0.0004060	total: 2.24s	remaining: 64.6ms
# 972:	learn: 0.0004029	total: 2.25s	remaining: 62.3ms
# 973:	learn: 0.0003989	total: 2.25s	remaining: 60ms
# 974:	learn: 0.0003960	total: 2.25s	remaining: 57.7ms
# 975:	learn: 0.0003926	total: 2.25s	remaining: 55.4ms
# 976:	learn: 0.0003887	total: 2.25s	remaining: 53.1ms
# 977:	learn: 0.0003871	total: 2.26s	remaining: 50.8ms
# 978:	learn: 0.0003856	total: 2.26s	remaining: 48.4ms
# 979:	learn: 0.0003846	total: 2.26s	remaining: 46.1ms
# 980:	learn: 0.0003812	total: 2.26s	remaining: 43.8ms
# 981:	learn: 0.0003784	total: 2.27s	remaining: 41.5ms
# 982:	learn: 0.0003756	total: 2.27s	remaining: 39.2ms
# 983:	learn: 0.0003728	total: 2.27s	remaining: 36.9ms
# 984:	learn: 0.0003690	total: 2.27s	remaining: 34.6ms
# 985:	learn: 0.0003654	total: 2.27s	remaining: 32.3ms
# 986:	learn: 0.0003628	total: 2.28s	remaining: 30ms
# 987:	learn: 0.0003613	total: 2.28s	remaining: 27.7ms
# 988:	learn: 0.0003578	total: 2.28s	remaining: 25.4ms
# 989:	learn: 0.0003543	total: 2.28s	remaining: 23.1ms
# 990:	learn: 0.0003528	total: 2.28s	remaining: 20.7ms
# 991:	learn: 0.0003502	total: 2.29s	remaining: 18.4ms
# 992:	learn: 0.0003487	total: 2.29s	remaining: 16.1ms
# 993:	learn: 0.0003471	total: 2.29s	remaining: 13.8ms
# 994:	learn: 0.0003461	total: 2.29s	remaining: 11.5ms
# 995:	learn: 0.0003428	total: 2.29s	remaining: 9.22ms
# 996:	learn: 0.0003401	total: 2.3s	remaining: 6.91ms
# 997:	learn: 0.0003387	total: 2.3s	remaining: 4.61ms
# 998:	learn: 0.0003371	total: 2.3s	remaining: 2.3ms
# 999:	learn: 0.0003349	total: 2.3s	remaining: 0us
# np.float64(0.9999996567926562)

# %%
#Determine MAE with test data
y_pred_CB = np.array(CB.predict(X_test_score))
y_pred_CB_score_genes = np.array(CB.predict(X_test_score))
mae_CB = mean_absolute_error(y_test_score, y_pred_CB)
mape_CB = mean_absolute_percentage_error(y_test_score, y_pred_CB)
print(f'Grandient Boosting Regression MAE: {mae_CB}')
# Out:
# Grandient Boosting Regression MAE: 0.4958867072369231

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_CB, y=y_test_score)

# Add a line for perfect correlation.
plt.plot([y_test_score.min(), y_test_score.max()],
         [y_test_score.min(), y_test_score.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('CatBoost Regressor Predicted vs Actual DE Score')
plt.show()

# %%
MAE_dict = {'Multiple Linear Regression': mae_LR, 'Random Forest Regressor': mae_RF, 'Gradient Boost Regressor': mae_GB, 'XGBoost Regressor': mae_XG, 'CatBoost Regressor': mae_CB}
MAPE_dict = {'Multiple Linear Regression': mape_LR, 'Random Forest Regressor': mape_RF, 'Gradient Boost Regressor': mape_GB, 'XGBoost Regressor': mape_XG, 'CatBoost Regressor': mape_CB}
Rsquared_dict = {'Multiple Linear Regression': LR.score(X_train_score, y_train_score), 'Random Forest Regressor': RF.score(X_train_score, y_train_score), 'Gradient Boost Regressor': GB.score(X_train_score, y_train_score),
                 'XGBoost Regressor': XG.score(X_train_score, y_train_score), 'CatBoost Regressor': CB.score(X_train_score, y_train_score)}
summary_genes_score = pd.DataFrame({'MAE': MAE_dict, 'MAPE': MAPE_dict, 'R²': Rsquared_dict})
summary_genes_score
# Out:
#                                  MAE      MAPE        R²
# Multiple Linear Regression  0.732187  0.278879  1.000000
# Random Forest Regressor     0.502607  0.220917  0.922504
# Gradient Boost Regressor    0.544240  0.233837  0.999945
# XGBoost Regressor           0.538127  0.229096  1.000000
# CatBoost Regressor          0.495887  0.217116  1.000000

# %% [markdown]
# ####Predicting Pseudorank

# %%
#Run default linear regression on dataset
LR = LinearRegression()
LR.fit(X_train_rank, y_train_rank)
LR.score(X_train_rank, y_train_rank)
# Out:
# 1.0

# %%
#Determine MAE with test data
y_pred_LR = np.array(LR.predict(X_test_rank))
mae_LR = mean_absolute_error(y_test_rank, y_pred_LR)
mape_LR = mean_absolute_percentage_error(y_test_rank, y_pred_LR)
print(f'Linear Regression MAE: {mae_LR}')
# Out:
# Linear Regression MAE: 0.032924937504532174

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_LR, y=y_test_rank)

# Add a line for perfect correlation.
plt.plot([y_test_rank.min(), y_test_rank.max()],
         [y_test_rank.min(), y_test_rank.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Multiple Regression Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default Random Forest regression on dataset
RF = RandomForestRegressor()
RF.fit(X_train_rank, y_train_rank)
RF.score(X_train_rank, y_train_rank)
# Out:
# 0.9327457876833324

# %%
#Determine MAE with test data
y_pred_RF = np.array(RF.predict(X_test_rank))
y_pred_RF_rank_genes = np.array(RF.predict(X_test_rank))
mae_RF = mean_absolute_error(y_test_rank, y_pred_RF)
mape_RF = mean_absolute_percentage_error(y_test_rank, y_pred_RF)
print(f'Random Forest Regression MAE: {mae_RF}')
# Out:
# Random Forest Regression MAE: 0.016534989884025183

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_RF, y=y_test_rank)

# Add a line for perfect correlation.
plt.plot([y_test_rank.min(), y_test_rank.max()],
         [y_test_rank.min(), y_test_rank.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Random Forest Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default Grandient Boosting regression on dataset
GB = GradientBoostingRegressor()
GB.fit(X_train_rank, y_train_rank)
GB.score(X_train_rank, y_train_rank)
# Out:
# 0.9999735882740347

# %%
#Determine MAE with test data
y_pred_GB = np.array(GB.predict(X_test_rank))
mae_GB = mean_absolute_error(y_test_rank, y_pred_GB)
mape_GB = mean_absolute_percentage_error(y_test_rank, y_pred_GB)
print(f'Grandient Boosting Regression MAE: {mae_GB}')
# Out:
# Grandient Boosting Regression MAE: 0.017312238573267757

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_GB, y=y_test_rank)

# Add a line for perfect correlation.
plt.plot([y_test_rank.min(), y_test_rank.max()],
         [y_test_rank.min(), y_test_rank.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Grandient Boosting Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default XGBoost regression on dataset
XG = XGBRegressor()
XG.fit(X_train_rank, y_train_rank)
XG.score(X_train_rank, y_train_rank)
# Out:
# 0.999701201915741

# %%
#Determine MAE with test data
y_pred_XG = np.array(XG.predict(X_test_rank))
mae_XG = mean_absolute_error(y_test_rank, y_pred_XG)
mape_XG = mean_absolute_percentage_error(y_test_rank, y_pred_XG)
print(f'XGBoost Regression MAE: {mae_XG}')
# Out:
# XGBoost Regression MAE: 0.016227254644036293

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_XG, y=y_test_rank)

# Add a line for perfect correlation.
plt.plot([y_test_rank.min(), y_test_rank.max()],
         [y_test_rank.min(), y_test_rank.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('XGBoost Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default CatBoost regression on dataset
CB = CatBoostRegressor()
CB.fit(X_train_rank, y_train_rank)
CB.score(X_train_rank, y_train_rank)
# Out:
# Learning rate set to 0.027076
# 0:	learn: 0.0234327	total: 3.86ms	remaining: 3.86s
# 1:	learn: 0.0231863	total: 6.11ms	remaining: 3.05s
# 2:	learn: 0.0228744	total: 8.46ms	remaining: 2.81s
# 3:	learn: 0.0226019	total: 10.6ms	remaining: 2.65s
# 4:	learn: 0.0223655	total: 12.8ms	remaining: 2.56s
# 5:	learn: 0.0221189	total: 15.1ms	remaining: 2.5s
# 6:	learn: 0.0218564	total: 17.4ms	remaining: 2.46s
# 7:	learn: 0.0216440	total: 19.5ms	remaining: 2.42s
# 8:	learn: 0.0214646	total: 21.8ms	remaining: 2.4s
# 9:	learn: 0.0212425	total: 24ms	remaining: 2.37s
# 10:	learn: 0.0210931	total: 26.3ms	remaining: 2.36s
# 11:	learn: 0.0208869	total: 29ms	remaining: 2.39s
# 12:	learn: 0.0207079	total: 31.3ms	remaining: 2.37s
# 13:	learn: 0.0204622	total: 33.5ms	remaining: 2.36s
# 14:	learn: 0.0202388	total: 35.8ms	remaining: 2.35s
# 15:	learn: 0.0200215	total: 38ms	remaining: 2.34s
# 16:	learn: 0.0198103	total: 40.3ms	remaining: 2.33s
# 17:	learn: 0.0196041	total: 43ms	remaining: 2.35s
# 18:	learn: 0.0193699	total: 45.4ms	remaining: 2.34s
# 19:	learn: 0.0191947	total: 47.6ms	remaining: 2.33s
# 20:	learn: 0.0190024	total: 49.8ms	remaining: 2.32s
# 21:	learn: 0.0188222	total: 52.1ms	remaining: 2.31s
# 22:	learn: 0.0186300	total: 54.3ms	remaining: 2.3s
# 23:	learn: 0.0184690	total: 56.6ms	remaining: 2.3s
# 24:	learn: 0.0183302	total: 58.9ms	remaining: 2.3s
# 25:	learn: 0.0181507	total: 61.2ms	remaining: 2.29s
# 26:	learn: 0.0179669	total: 63.4ms	remaining: 2.29s
# 27:	learn: 0.0178128	total: 65.7ms	remaining: 2.28s
# 28:	learn: 0.0176288	total: 67.9ms	remaining: 2.27s
# 29:	learn: 0.0174743	total: 70.3ms	remaining: 2.27s
# 30:	learn: 0.0173092	total: 72.6ms	remaining: 2.27s
# 31:	learn: 0.0171199	total: 74.9ms	remaining: 2.26s
# 32:	learn: 0.0169648	total: 77.1ms	remaining: 2.26s
# 33:	learn: 0.0167824	total: 79.4ms	remaining: 2.25s
# 34:	learn: 0.0166286	total: 81.6ms	remaining: 2.25s
# 35:	learn: 0.0164936	total: 83.9ms	remaining: 2.25s
# 36:	learn: 0.0163152	total: 86.2ms	remaining: 2.24s
# 37:	learn: 0.0161669	total: 88.5ms	remaining: 2.24s
# 38:	learn: 0.0160446	total: 90.8ms	remaining: 2.24s
# 39:	learn: 0.0158772	total: 93ms	remaining: 2.23s
# 40:	learn: 0.0157396	total: 95.3ms	remaining: 2.23s
# 41:	learn: 0.0155712	total: 97.5ms	remaining: 2.22s
# 42:	learn: 0.0154192	total: 99.6ms	remaining: 2.22s
# 43:	learn: 0.0152784	total: 102ms	remaining: 2.21s
# 44:	learn: 0.0151705	total: 104ms	remaining: 2.21s
# 45:	learn: 0.0150378	total: 106ms	remaining: 2.2s
# 46:	learn: 0.0149032	total: 109ms	remaining: 2.21s
# 47:	learn: 0.0147833	total: 111ms	remaining: 2.2s
# 48:	learn: 0.0146441	total: 113ms	remaining: 2.19s
# 49:	learn: 0.0145014	total: 115ms	remaining: 2.19s
# 50:	learn: 0.0143592	total: 117ms	remaining: 2.18s
# 51:	learn: 0.0142672	total: 120ms	remaining: 2.18s
# 52:	learn: 0.0141469	total: 122ms	remaining: 2.17s
# 53:	learn: 0.0140277	total: 124ms	remaining: 2.17s
# 54:	learn: 0.0138812	total: 126ms	remaining: 2.17s
# 55:	learn: 0.0137716	total: 128ms	remaining: 2.16s
# 56:	learn: 0.0136514	total: 130ms	remaining: 2.15s
# 57:	learn: 0.0135328	total: 132ms	remaining: 2.15s
# 58:	learn: 0.0133954	total: 135ms	remaining: 2.15s
# 59:	learn: 0.0132557	total: 137ms	remaining: 2.14s
# 60:	learn: 0.0131457	total: 139ms	remaining: 2.14s
# 61:	learn: 0.0130231	total: 141ms	remaining: 2.14s
# 62:	learn: 0.0129029	total: 144ms	remaining: 2.13s
# 63:	learn: 0.0127801	total: 146ms	remaining: 2.13s
# 64:	learn: 0.0126432	total: 148ms	remaining: 2.13s
# 65:	learn: 0.0125489	total: 150ms	remaining: 2.12s
# 66:	learn: 0.0124422	total: 152ms	remaining: 2.12s
# 67:	learn: 0.0123284	total: 154ms	remaining: 2.12s
# 68:	learn: 0.0122489	total: 157ms	remaining: 2.12s
# 69:	learn: 0.0121419	total: 159ms	remaining: 2.12s
# 70:	learn: 0.0120201	total: 162ms	remaining: 2.12s
# 71:	learn: 0.0119032	total: 165ms	remaining: 2.12s
# 72:	learn: 0.0117954	total: 167ms	remaining: 2.12s
# 73:	learn: 0.0116983	total: 169ms	remaining: 2.12s
# 74:	learn: 0.0115787	total: 171ms	remaining: 2.11s
# 75:	learn: 0.0114927	total: 173ms	remaining: 2.11s
# 76:	learn: 0.0114215	total: 176ms	remaining: 2.1s
# 77:	learn: 0.0113028	total: 178ms	remaining: 2.1s
# 78:	learn: 0.0112179	total: 180ms	remaining: 2.1s
# 79:	learn: 0.0111003	total: 182ms	remaining: 2.1s
# 80:	learn: 0.0110248	total: 185ms	remaining: 2.09s
# 81:	learn: 0.0109623	total: 187ms	remaining: 2.09s
# 82:	learn: 0.0108564	total: 189ms	remaining: 2.09s
# 83:	learn: 0.0107541	total: 191ms	remaining: 2.08s
# 84:	learn: 0.0106581	total: 194ms	remaining: 2.09s
# 85:	learn: 0.0105465	total: 197ms	remaining: 2.09s
# 86:	learn: 0.0104606	total: 199ms	remaining: 2.09s
# 87:	learn: 0.0103764	total: 201ms	remaining: 2.08s
# 88:	learn: 0.0102876	total: 203ms	remaining: 2.08s
# 89:	learn: 0.0101951	total: 206ms	remaining: 2.08s
# 90:	learn: 0.0101061	total: 208ms	remaining: 2.07s
# 91:	learn: 0.0100486	total: 210ms	remaining: 2.07s
# 92:	learn: 0.0099601	total: 212ms	remaining: 2.07s
# 93:	learn: 0.0098888	total: 214ms	remaining: 2.06s
# 94:	learn: 0.0098246	total: 216ms	remaining: 2.06s
# 95:	learn: 0.0097469	total: 219ms	remaining: 2.06s
# 96:	learn: 0.0096712	total: 221ms	remaining: 2.06s
# 97:	learn: 0.0095873	total: 223ms	remaining: 2.05s
# 98:	learn: 0.0095074	total: 225ms	remaining: 2.05s
# 99:	learn: 0.0094190	total: 227ms	remaining: 2.05s
# 100:	learn: 0.0093464	total: 230ms	remaining: 2.04s
# 101:	learn: 0.0092525	total: 232ms	remaining: 2.04s
# 102:	learn: 0.0091819	total: 234ms	remaining: 2.04s
# 103:	learn: 0.0091167	total: 237ms	remaining: 2.04s
# 104:	learn: 0.0090438	total: 239ms	remaining: 2.04s
# 105:	learn: 0.0089692	total: 242ms	remaining: 2.04s
# 106:	learn: 0.0089029	total: 245ms	remaining: 2.04s
# 107:	learn: 0.0088238	total: 247ms	remaining: 2.04s
# 108:	learn: 0.0087442	total: 249ms	remaining: 2.04s
# 109:	learn: 0.0086894	total: 252ms	remaining: 2.04s
# 110:	learn: 0.0086214	total: 254ms	remaining: 2.04s
# 111:	learn: 0.0085575	total: 257ms	remaining: 2.03s
# 112:	learn: 0.0084934	total: 259ms	remaining: 2.03s
# 113:	learn: 0.0084272	total: 262ms	remaining: 2.03s
# 114:	learn: 0.0083496	total: 264ms	remaining: 2.03s
# 115:	learn: 0.0082981	total: 266ms	remaining: 2.03s
# 116:	learn: 0.0082353	total: 269ms	remaining: 2.03s
# 117:	learn: 0.0081612	total: 271ms	remaining: 2.02s
# 118:	learn: 0.0081013	total: 273ms	remaining: 2.02s
# 119:	learn: 0.0080422	total: 279ms	remaining: 2.04s
# 120:	learn: 0.0079829	total: 284ms	remaining: 2.06s
# 121:	learn: 0.0079306	total: 289ms	remaining: 2.08s
# 122:	learn: 0.0078778	total: 292ms	remaining: 2.08s
# 123:	learn: 0.0078222	total: 294ms	remaining: 2.07s
# 124:	learn: 0.0077620	total: 296ms	remaining: 2.07s
# 125:	learn: 0.0077057	total: 298ms	remaining: 2.07s
# 126:	learn: 0.0076186	total: 300ms	remaining: 2.06s
# 127:	learn: 0.0075690	total: 303ms	remaining: 2.06s
# 128:	learn: 0.0075183	total: 305ms	remaining: 2.06s
# 129:	learn: 0.0074621	total: 307ms	remaining: 2.06s
# 130:	learn: 0.0074134	total: 310ms	remaining: 2.05s
# 131:	learn: 0.0073427	total: 312ms	remaining: 2.05s
# 132:	learn: 0.0072814	total: 314ms	remaining: 2.05s
# 133:	learn: 0.0072335	total: 316ms	remaining: 2.04s
# 134:	learn: 0.0071602	total: 319ms	remaining: 2.04s
# 135:	learn: 0.0071121	total: 321ms	remaining: 2.04s
# 136:	learn: 0.0070489	total: 323ms	remaining: 2.04s
# 137:	learn: 0.0069795	total: 326ms	remaining: 2.03s
# 138:	learn: 0.0069258	total: 328ms	remaining: 2.03s
# 139:	learn: 0.0068712	total: 330ms	remaining: 2.03s
# 140:	learn: 0.0068228	total: 332ms	remaining: 2.02s
# 141:	learn: 0.0067603	total: 334ms	remaining: 2.02s
# 142:	learn: 0.0067065	total: 337ms	remaining: 2.02s
# 143:	learn: 0.0066618	total: 339ms	remaining: 2.01s
# 144:	learn: 0.0066158	total: 341ms	remaining: 2.01s
# 145:	learn: 0.0065736	total: 343ms	remaining: 2.01s
# 146:	learn: 0.0065077	total: 345ms	remaining: 2s
# 147:	learn: 0.0064685	total: 347ms	remaining: 2s
# 148:	learn: 0.0064120	total: 350ms	remaining: 2s
# 149:	learn: 0.0063489	total: 352ms	remaining: 1.99s
# 150:	learn: 0.0063171	total: 354ms	remaining: 1.99s
# 151:	learn: 0.0062721	total: 356ms	remaining: 1.99s
# 152:	learn: 0.0062244	total: 358ms	remaining: 1.98s
# 153:	learn: 0.0061729	total: 361ms	remaining: 1.98s
# 154:	learn: 0.0061164	total: 363ms	remaining: 1.98s
# 155:	learn: 0.0060575	total: 365ms	remaining: 1.97s
# 156:	learn: 0.0060200	total: 367ms	remaining: 1.97s
# 157:	learn: 0.0059864	total: 369ms	remaining: 1.97s
# 158:	learn: 0.0059309	total: 371ms	remaining: 1.96s
# 159:	learn: 0.0058919	total: 374ms	remaining: 1.96s
# 160:	learn: 0.0058475	total: 376ms	remaining: 1.96s
# 161:	learn: 0.0058200	total: 378ms	remaining: 1.96s
# 162:	learn: 0.0057658	total: 380ms	remaining: 1.95s
# 163:	learn: 0.0057245	total: 383ms	remaining: 1.95s
# 164:	learn: 0.0056851	total: 385ms	remaining: 1.95s
# 165:	learn: 0.0056527	total: 387ms	remaining: 1.94s
# 166:	learn: 0.0055960	total: 389ms	remaining: 1.94s
# 167:	learn: 0.0055517	total: 392ms	remaining: 1.94s
# 168:	learn: 0.0055272	total: 395ms	remaining: 1.94s
# 169:	learn: 0.0055035	total: 398ms	remaining: 1.94s
# 170:	learn: 0.0054699	total: 400ms	remaining: 1.94s
# 171:	learn: 0.0054292	total: 402ms	remaining: 1.94s
# 172:	learn: 0.0053872	total: 404ms	remaining: 1.93s
# 173:	learn: 0.0053471	total: 406ms	remaining: 1.93s
# 174:	learn: 0.0053171	total: 409ms	remaining: 1.93s
# 175:	learn: 0.0052698	total: 411ms	remaining: 1.92s
# 176:	learn: 0.0052396	total: 413ms	remaining: 1.92s
# 177:	learn: 0.0051984	total: 415ms	remaining: 1.92s
# 178:	learn: 0.0051612	total: 417ms	remaining: 1.91s
# 179:	learn: 0.0051259	total: 419ms	remaining: 1.91s
# 180:	learn: 0.0050851	total: 422ms	remaining: 1.91s
# 181:	learn: 0.0050465	total: 425ms	remaining: 1.91s
# 182:	learn: 0.0050056	total: 427ms	remaining: 1.91s
# 183:	learn: 0.0049573	total: 430ms	remaining: 1.91s
# 184:	learn: 0.0049182	total: 432ms	remaining: 1.9s
# 185:	learn: 0.0048750	total: 435ms	remaining: 1.9s
# 186:	learn: 0.0048436	total: 437ms	remaining: 1.9s
# 187:	learn: 0.0048090	total: 439ms	remaining: 1.9s
# 188:	learn: 0.0047850	total: 442ms	remaining: 1.89s
# 189:	learn: 0.0047526	total: 444ms	remaining: 1.89s
# 190:	learn: 0.0047159	total: 446ms	remaining: 1.89s
# 191:	learn: 0.0046798	total: 448ms	remaining: 1.89s
# 192:	learn: 0.0046499	total: 450ms	remaining: 1.88s
# 193:	learn: 0.0046242	total: 452ms	remaining: 1.88s
# 194:	learn: 0.0045953	total: 455ms	remaining: 1.88s
# 195:	learn: 0.0045616	total: 457ms	remaining: 1.87s
# 196:	learn: 0.0045258	total: 459ms	remaining: 1.87s
# 197:	learn: 0.0044871	total: 461ms	remaining: 1.87s
# 198:	learn: 0.0044537	total: 463ms	remaining: 1.86s
# 199:	learn: 0.0044164	total: 466ms	remaining: 1.86s
# 200:	learn: 0.0043789	total: 468ms	remaining: 1.86s
# 201:	learn: 0.0043556	total: 470ms	remaining: 1.86s
# 202:	learn: 0.0043270	total: 472ms	remaining: 1.85s
# 203:	learn: 0.0042883	total: 474ms	remaining: 1.85s
# 204:	learn: 0.0042532	total: 477ms	remaining: 1.85s
# 205:	learn: 0.0042213	total: 479ms	remaining: 1.84s
# 206:	learn: 0.0042018	total: 481ms	remaining: 1.84s
# 207:	learn: 0.0041598	total: 483ms	remaining: 1.84s
# 208:	learn: 0.0041260	total: 485ms	remaining: 1.84s
# 209:	learn: 0.0041003	total: 488ms	remaining: 1.83s
# 210:	learn: 0.0040681	total: 490ms	remaining: 1.83s
# 211:	learn: 0.0040298	total: 492ms	remaining: 1.83s
# 212:	learn: 0.0039965	total: 494ms	remaining: 1.82s
# 213:	learn: 0.0039618	total: 496ms	remaining: 1.82s
# 214:	learn: 0.0039429	total: 498ms	remaining: 1.82s
# 215:	learn: 0.0039134	total: 501ms	remaining: 1.82s
# 216:	learn: 0.0038838	total: 503ms	remaining: 1.81s
# 217:	learn: 0.0038498	total: 505ms	remaining: 1.81s
# 218:	learn: 0.0038245	total: 507ms	remaining: 1.81s
# 219:	learn: 0.0037971	total: 509ms	remaining: 1.81s
# 220:	learn: 0.0037648	total: 512ms	remaining: 1.8s
# 221:	learn: 0.0037317	total: 514ms	remaining: 1.8s
# 222:	learn: 0.0037035	total: 516ms	remaining: 1.8s
# 223:	learn: 0.0036728	total: 518ms	remaining: 1.79s
# 224:	learn: 0.0036358	total: 520ms	remaining: 1.79s
# 225:	learn: 0.0036081	total: 522ms	remaining: 1.79s
# 226:	learn: 0.0035833	total: 525ms	remaining: 1.79s
# 227:	learn: 0.0035515	total: 527ms	remaining: 1.78s
# 228:	learn: 0.0035267	total: 529ms	remaining: 1.78s
# 229:	learn: 0.0034963	total: 531ms	remaining: 1.78s
# 230:	learn: 0.0034600	total: 533ms	remaining: 1.77s
# 231:	learn: 0.0034361	total: 535ms	remaining: 1.77s
# 232:	learn: 0.0034053	total: 538ms	remaining: 1.77s
# 233:	learn: 0.0033703	total: 540ms	remaining: 1.77s
# 234:	learn: 0.0033412	total: 542ms	remaining: 1.76s
# 235:	learn: 0.0033082	total: 544ms	remaining: 1.76s
# 236:	learn: 0.0032887	total: 546ms	remaining: 1.76s
# 237:	learn: 0.0032645	total: 549ms	remaining: 1.76s
# 238:	learn: 0.0032382	total: 551ms	remaining: 1.75s
# 239:	learn: 0.0032196	total: 553ms	remaining: 1.75s
# 240:	learn: 0.0031928	total: 555ms	remaining: 1.75s
# 241:	learn: 0.0031717	total: 558ms	remaining: 1.75s
# 242:	learn: 0.0031436	total: 560ms	remaining: 1.74s
# 243:	learn: 0.0031235	total: 562ms	remaining: 1.74s
# 244:	learn: 0.0031085	total: 564ms	remaining: 1.74s
# 245:	learn: 0.0030827	total: 567ms	remaining: 1.74s
# 246:	learn: 0.0030575	total: 569ms	remaining: 1.73s
# 247:	learn: 0.0030288	total: 571ms	remaining: 1.73s
# 248:	learn: 0.0030113	total: 573ms	remaining: 1.73s
# 249:	learn: 0.0029880	total: 575ms	remaining: 1.73s
# 250:	learn: 0.0029649	total: 578ms	remaining: 1.72s
# 251:	learn: 0.0029435	total: 580ms	remaining: 1.72s
# 252:	learn: 0.0029193	total: 582ms	remaining: 1.72s
# 253:	learn: 0.0028984	total: 584ms	remaining: 1.72s
# 254:	learn: 0.0028755	total: 587ms	remaining: 1.72s
# 255:	learn: 0.0028573	total: 590ms	remaining: 1.71s
# 256:	learn: 0.0028310	total: 593ms	remaining: 1.71s
# 257:	learn: 0.0028078	total: 595ms	remaining: 1.71s
# 258:	learn: 0.0027922	total: 597ms	remaining: 1.71s
# 259:	learn: 0.0027696	total: 600ms	remaining: 1.71s
# 260:	learn: 0.0027426	total: 602ms	remaining: 1.7s
# 261:	learn: 0.0027178	total: 604ms	remaining: 1.7s
# 262:	learn: 0.0027049	total: 606ms	remaining: 1.7s
# 263:	learn: 0.0026825	total: 608ms	remaining: 1.7s
# 264:	learn: 0.0026610	total: 611ms	remaining: 1.69s
# 265:	learn: 0.0026429	total: 613ms	remaining: 1.69s
# 266:	learn: 0.0026271	total: 615ms	remaining: 1.69s
# 267:	learn: 0.0026147	total: 617ms	remaining: 1.69s
# 268:	learn: 0.0025914	total: 620ms	remaining: 1.68s
# 269:	learn: 0.0025722	total: 622ms	remaining: 1.68s
# 270:	learn: 0.0025518	total: 624ms	remaining: 1.68s
# 271:	learn: 0.0025282	total: 629ms	remaining: 1.68s
# 272:	learn: 0.0025157	total: 631ms	remaining: 1.68s
# 273:	learn: 0.0024975	total: 633ms	remaining: 1.68s
# 274:	learn: 0.0024787	total: 636ms	remaining: 1.68s
# 275:	learn: 0.0024575	total: 638ms	remaining: 1.67s
# 276:	learn: 0.0024416	total: 640ms	remaining: 1.67s
# 277:	learn: 0.0024229	total: 642ms	remaining: 1.67s
# 278:	learn: 0.0024049	total: 644ms	remaining: 1.67s
# 279:	learn: 0.0023910	total: 647ms	remaining: 1.66s
# 280:	learn: 0.0023781	total: 649ms	remaining: 1.66s
# 281:	learn: 0.0023594	total: 652ms	remaining: 1.66s
# 282:	learn: 0.0023417	total: 655ms	remaining: 1.66s
# 283:	learn: 0.0023248	total: 657ms	remaining: 1.66s
# 284:	learn: 0.0023129	total: 660ms	remaining: 1.65s
# 285:	learn: 0.0022968	total: 662ms	remaining: 1.65s
# 286:	learn: 0.0022764	total: 664ms	remaining: 1.65s
# 287:	learn: 0.0022574	total: 666ms	remaining: 1.65s
# 288:	learn: 0.0022391	total: 668ms	remaining: 1.64s
# 289:	learn: 0.0022219	total: 671ms	remaining: 1.64s
# 290:	learn: 0.0022038	total: 673ms	remaining: 1.64s
# 291:	learn: 0.0021861	total: 675ms	remaining: 1.64s
# 292:	learn: 0.0021746	total: 677ms	remaining: 1.63s
# 293:	learn: 0.0021582	total: 679ms	remaining: 1.63s
# 294:	learn: 0.0021440	total: 682ms	remaining: 1.63s
# 295:	learn: 0.0021252	total: 684ms	remaining: 1.63s
# 296:	learn: 0.0021063	total: 686ms	remaining: 1.62s
# 297:	learn: 0.0020926	total: 688ms	remaining: 1.62s
# 298:	learn: 0.0020752	total: 691ms	remaining: 1.62s
# 299:	learn: 0.0020644	total: 693ms	remaining: 1.62s
# 300:	learn: 0.0020504	total: 695ms	remaining: 1.61s
# 301:	learn: 0.0020367	total: 697ms	remaining: 1.61s
# 302:	learn: 0.0020189	total: 699ms	remaining: 1.61s
# 303:	learn: 0.0020029	total: 701ms	remaining: 1.6s
# 304:	learn: 0.0019911	total: 704ms	remaining: 1.6s
# 305:	learn: 0.0019765	total: 706ms	remaining: 1.6s
# 306:	learn: 0.0019664	total: 708ms	remaining: 1.6s
# 307:	learn: 0.0019513	total: 710ms	remaining: 1.59s
# 308:	learn: 0.0019389	total: 712ms	remaining: 1.59s
# 309:	learn: 0.0019251	total: 715ms	remaining: 1.59s
# 310:	learn: 0.0019110	total: 717ms	remaining: 1.59s
# 311:	learn: 0.0019003	total: 719ms	remaining: 1.58s
# 312:	learn: 0.0018866	total: 721ms	remaining: 1.58s
# 313:	learn: 0.0018762	total: 723ms	remaining: 1.58s
# 314:	learn: 0.0018666	total: 726ms	remaining: 1.58s
# 315:	learn: 0.0018579	total: 728ms	remaining: 1.57s
# 316:	learn: 0.0018477	total: 730ms	remaining: 1.57s
# 317:	learn: 0.0018369	total: 732ms	remaining: 1.57s
# 318:	learn: 0.0018255	total: 734ms	remaining: 1.57s
# 319:	learn: 0.0018155	total: 736ms	remaining: 1.56s
# 320:	learn: 0.0018034	total: 738ms	remaining: 1.56s
# 321:	learn: 0.0017918	total: 740ms	remaining: 1.56s
# 322:	learn: 0.0017831	total: 743ms	remaining: 1.56s
# 323:	learn: 0.0017718	total: 745ms	remaining: 1.55s
# 324:	learn: 0.0017604	total: 747ms	remaining: 1.55s
# 325:	learn: 0.0017452	total: 749ms	remaining: 1.55s
# 326:	learn: 0.0017332	total: 751ms	remaining: 1.55s
# 327:	learn: 0.0017248	total: 754ms	remaining: 1.54s
# 328:	learn: 0.0017140	total: 756ms	remaining: 1.54s
# 329:	learn: 0.0017030	total: 758ms	remaining: 1.54s
# 330:	learn: 0.0016916	total: 760ms	remaining: 1.54s
# 331:	learn: 0.0016761	total: 763ms	remaining: 1.53s
# 332:	learn: 0.0016621	total: 765ms	remaining: 1.53s
# 333:	learn: 0.0016526	total: 767ms	remaining: 1.53s
# 334:	learn: 0.0016388	total: 769ms	remaining: 1.53s
# 335:	learn: 0.0016305	total: 771ms	remaining: 1.52s
# 336:	learn: 0.0016151	total: 773ms	remaining: 1.52s
# 337:	learn: 0.0016051	total: 776ms	remaining: 1.52s
# 338:	learn: 0.0015949	total: 778ms	remaining: 1.52s
# 339:	learn: 0.0015806	total: 780ms	remaining: 1.51s
# 340:	learn: 0.0015672	total: 782ms	remaining: 1.51s
# 341:	learn: 0.0015596	total: 785ms	remaining: 1.51s
# 342:	learn: 0.0015465	total: 788ms	remaining: 1.51s
# 343:	learn: 0.0015362	total: 790ms	remaining: 1.51s
# 344:	learn: 0.0015266	total: 792ms	remaining: 1.5s
# 345:	learn: 0.0015138	total: 794ms	remaining: 1.5s
# 346:	learn: 0.0015043	total: 797ms	remaining: 1.5s
# 347:	learn: 0.0014949	total: 799ms	remaining: 1.5s
# 348:	learn: 0.0014857	total: 801ms	remaining: 1.49s
# 349:	learn: 0.0014734	total: 803ms	remaining: 1.49s
# 350:	learn: 0.0014596	total: 805ms	remaining: 1.49s
# 351:	learn: 0.0014485	total: 808ms	remaining: 1.49s
# 352:	learn: 0.0014372	total: 810ms	remaining: 1.48s
# 353:	learn: 0.0014260	total: 812ms	remaining: 1.48s
# 354:	learn: 0.0014151	total: 814ms	remaining: 1.48s
# 355:	learn: 0.0014034	total: 816ms	remaining: 1.48s
# 356:	learn: 0.0013928	total: 819ms	remaining: 1.47s
# 357:	learn: 0.0013821	total: 821ms	remaining: 1.47s
# 358:	learn: 0.0013717	total: 823ms	remaining: 1.47s
# 359:	learn: 0.0013613	total: 826ms	remaining: 1.47s
# 360:	learn: 0.0013553	total: 828ms	remaining: 1.47s
# 361:	learn: 0.0013492	total: 831ms	remaining: 1.46s
# 362:	learn: 0.0013391	total: 833ms	remaining: 1.46s
# 363:	learn: 0.0013332	total: 835ms	remaining: 1.46s
# 364:	learn: 0.0013273	total: 837ms	remaining: 1.46s
# 365:	learn: 0.0013151	total: 840ms	remaining: 1.45s
# 366:	learn: 0.0013094	total: 842ms	remaining: 1.45s
# 367:	learn: 0.0013014	total: 844ms	remaining: 1.45s
# 368:	learn: 0.0012894	total: 846ms	remaining: 1.45s
# 369:	learn: 0.0012810	total: 848ms	remaining: 1.44s
# 370:	learn: 0.0012707	total: 851ms	remaining: 1.44s
# 371:	learn: 0.0012625	total: 853ms	remaining: 1.44s
# 372:	learn: 0.0012544	total: 855ms	remaining: 1.44s
# 373:	learn: 0.0012430	total: 857ms	remaining: 1.44s
# 374:	learn: 0.0012351	total: 860ms	remaining: 1.43s
# 375:	learn: 0.0012262	total: 862ms	remaining: 1.43s
# 376:	learn: 0.0012208	total: 864ms	remaining: 1.43s
# 377:	learn: 0.0012155	total: 866ms	remaining: 1.43s
# 378:	learn: 0.0012078	total: 868ms	remaining: 1.42s
# 379:	learn: 0.0011992	total: 871ms	remaining: 1.42s
# 380:	learn: 0.0011916	total: 873ms	remaining: 1.42s
# 381:	learn: 0.0011815	total: 875ms	remaining: 1.42s
# 382:	learn: 0.0011741	total: 877ms	remaining: 1.41s
# 383:	learn: 0.0011690	total: 879ms	remaining: 1.41s
# 384:	learn: 0.0011582	total: 882ms	remaining: 1.41s
# 385:	learn: 0.0011481	total: 885ms	remaining: 1.41s
# 386:	learn: 0.0011416	total: 887ms	remaining: 1.41s
# 387:	learn: 0.0011367	total: 889ms	remaining: 1.4s
# 388:	learn: 0.0011296	total: 891ms	remaining: 1.4s
# 389:	learn: 0.0011186	total: 894ms	remaining: 1.4s
# 390:	learn: 0.0011116	total: 896ms	remaining: 1.4s
# 391:	learn: 0.0011019	total: 898ms	remaining: 1.39s
# 392:	learn: 0.0010936	total: 900ms	remaining: 1.39s
# 393:	learn: 0.0010842	total: 902ms	remaining: 1.39s
# 394:	learn: 0.0010781	total: 905ms	remaining: 1.39s
# 395:	learn: 0.0010689	total: 907ms	remaining: 1.38s
# 396:	learn: 0.0010609	total: 909ms	remaining: 1.38s
# 397:	learn: 0.0010515	total: 911ms	remaining: 1.38s
# 398:	learn: 0.0010418	total: 913ms	remaining: 1.38s
# 399:	learn: 0.0010328	total: 915ms	remaining: 1.37s
# 400:	learn: 0.0010238	total: 918ms	remaining: 1.37s
# 401:	learn: 0.0010154	total: 920ms	remaining: 1.37s
# 402:	learn: 0.0010066	total: 922ms	remaining: 1.36s
# 403:	learn: 0.0009970	total: 924ms	remaining: 1.36s
# 404:	learn: 0.0009905	total: 926ms	remaining: 1.36s
# 405:	learn: 0.0009811	total: 928ms	remaining: 1.36s
# 406:	learn: 0.0009731	total: 930ms	remaining: 1.35s
# 407:	learn: 0.0009654	total: 933ms	remaining: 1.35s
# 408:	learn: 0.0009563	total: 935ms	remaining: 1.35s
# 409:	learn: 0.0009512	total: 937ms	remaining: 1.35s
# 410:	learn: 0.0009432	total: 939ms	remaining: 1.34s
# 411:	learn: 0.0009371	total: 941ms	remaining: 1.34s
# 412:	learn: 0.0009295	total: 943ms	remaining: 1.34s
# 413:	learn: 0.0009249	total: 946ms	remaining: 1.34s
# 414:	learn: 0.0009163	total: 948ms	remaining: 1.33s
# 415:	learn: 0.0009099	total: 950ms	remaining: 1.33s
# 416:	learn: 0.0009054	total: 952ms	remaining: 1.33s
# 417:	learn: 0.0008991	total: 954ms	remaining: 1.33s
# 418:	learn: 0.0008947	total: 956ms	remaining: 1.33s
# 419:	learn: 0.0008885	total: 959ms	remaining: 1.32s
# 420:	learn: 0.0008814	total: 961ms	remaining: 1.32s
# 421:	learn: 0.0008758	total: 963ms	remaining: 1.32s
# 422:	learn: 0.0008697	total: 965ms	remaining: 1.32s
# 423:	learn: 0.0008625	total: 967ms	remaining: 1.31s
# 424:	learn: 0.0008582	total: 970ms	remaining: 1.31s
# 425:	learn: 0.0008523	total: 972ms	remaining: 1.31s
# 426:	learn: 0.0008454	total: 974ms	remaining: 1.31s
# 427:	learn: 0.0008387	total: 976ms	remaining: 1.3s
# 428:	learn: 0.0008346	total: 978ms	remaining: 1.3s
# 429:	learn: 0.0008270	total: 981ms	remaining: 1.3s
# 430:	learn: 0.0008213	total: 984ms	remaining: 1.3s
# 431:	learn: 0.0008174	total: 986ms	remaining: 1.3s
# 432:	learn: 0.0008118	total: 989ms	remaining: 1.29s
# 433:	learn: 0.0008071	total: 991ms	remaining: 1.29s
# 434:	learn: 0.0008015	total: 993ms	remaining: 1.29s
# 435:	learn: 0.0007951	total: 995ms	remaining: 1.29s
# 436:	learn: 0.0007902	total: 997ms	remaining: 1.28s
# 437:	learn: 0.0007849	total: 1000ms	remaining: 1.28s
# 438:	learn: 0.0007801	total: 1s	remaining: 1.28s
# 439:	learn: 0.0007749	total: 1s	remaining: 1.28s
# 440:	learn: 0.0007684	total: 1.01s	remaining: 1.27s
# 441:	learn: 0.0007634	total: 1.01s	remaining: 1.27s
# 442:	learn: 0.0007590	total: 1.01s	remaining: 1.27s
# 443:	learn: 0.0007523	total: 1.01s	remaining: 1.27s
# 444:	learn: 0.0007471	total: 1.01s	remaining: 1.26s
# 445:	learn: 0.0007410	total: 1.02s	remaining: 1.26s
# 446:	learn: 0.0007373	total: 1.02s	remaining: 1.26s
# 447:	learn: 0.0007315	total: 1.02s	remaining: 1.26s
# 448:	learn: 0.0007259	total: 1.02s	remaining: 1.26s
# 449:	learn: 0.0007223	total: 1.03s	remaining: 1.25s
# 450:	learn: 0.0007166	total: 1.03s	remaining: 1.25s
# 451:	learn: 0.0007119	total: 1.03s	remaining: 1.25s
# 452:	learn: 0.0007082	total: 1.03s	remaining: 1.25s
# 453:	learn: 0.0007027	total: 1.03s	remaining: 1.25s
# 454:	learn: 0.0006962	total: 1.04s	remaining: 1.24s
# 455:	learn: 0.0006923	total: 1.04s	remaining: 1.24s
# 456:	learn: 0.0006883	total: 1.04s	remaining: 1.24s
# 457:	learn: 0.0006847	total: 1.04s	remaining: 1.24s
# 458:	learn: 0.0006794	total: 1.05s	remaining: 1.23s
# 459:	learn: 0.0006743	total: 1.05s	remaining: 1.23s
# 460:	learn: 0.0006690	total: 1.05s	remaining: 1.23s
# 461:	learn: 0.0006658	total: 1.05s	remaining: 1.23s
# 462:	learn: 0.0006607	total: 1.05s	remaining: 1.22s
# 463:	learn: 0.0006580	total: 1.06s	remaining: 1.22s
# 464:	learn: 0.0006544	total: 1.06s	remaining: 1.22s
# 465:	learn: 0.0006505	total: 1.06s	remaining: 1.22s
# 466:	learn: 0.0006465	total: 1.06s	remaining: 1.21s
# 467:	learn: 0.0006407	total: 1.06s	remaining: 1.21s
# 468:	learn: 0.0006376	total: 1.07s	remaining: 1.21s
# 469:	learn: 0.0006350	total: 1.07s	remaining: 1.21s
# 470:	learn: 0.0006298	total: 1.07s	remaining: 1.2s
# 471:	learn: 0.0006267	total: 1.07s	remaining: 1.2s
# 472:	learn: 0.0006215	total: 1.08s	remaining: 1.2s
# 473:	learn: 0.0006177	total: 1.08s	remaining: 1.2s
# 474:	learn: 0.0006120	total: 1.08s	remaining: 1.19s
# 475:	learn: 0.0006095	total: 1.08s	remaining: 1.19s
# 476:	learn: 0.0006058	total: 1.08s	remaining: 1.19s
# 477:	learn: 0.0006029	total: 1.09s	remaining: 1.19s
# 478:	learn: 0.0006004	total: 1.09s	remaining: 1.19s
# 479:	learn: 0.0005962	total: 1.09s	remaining: 1.18s
# 480:	learn: 0.0005919	total: 1.09s	remaining: 1.18s
# 481:	learn: 0.0005894	total: 1.1s	remaining: 1.18s
# 482:	learn: 0.0005851	total: 1.1s	remaining: 1.18s
# 483:	learn: 0.0005828	total: 1.1s	remaining: 1.17s
# 484:	learn: 0.0005804	total: 1.1s	remaining: 1.17s
# 485:	learn: 0.0005772	total: 1.1s	remaining: 1.17s
# 486:	learn: 0.0005730	total: 1.11s	remaining: 1.17s
# 487:	learn: 0.0005704	total: 1.11s	remaining: 1.16s
# 488:	learn: 0.0005673	total: 1.11s	remaining: 1.16s
# 489:	learn: 0.0005620	total: 1.11s	remaining: 1.16s
# 490:	learn: 0.0005590	total: 1.12s	remaining: 1.16s
# 491:	learn: 0.0005541	total: 1.12s	remaining: 1.15s
# 492:	learn: 0.0005508	total: 1.12s	remaining: 1.15s
# 493:	learn: 0.0005460	total: 1.12s	remaining: 1.15s
# 494:	learn: 0.0005426	total: 1.13s	remaining: 1.15s
# 495:	learn: 0.0005396	total: 1.13s	remaining: 1.15s
# 496:	learn: 0.0005348	total: 1.13s	remaining: 1.14s
# 497:	learn: 0.0005295	total: 1.13s	remaining: 1.14s
# 498:	learn: 0.0005270	total: 1.13s	remaining: 1.14s
# 499:	learn: 0.0005228	total: 1.14s	remaining: 1.14s
# 500:	learn: 0.0005199	total: 1.14s	remaining: 1.13s
# 501:	learn: 0.0005175	total: 1.14s	remaining: 1.13s
# 502:	learn: 0.0005151	total: 1.14s	remaining: 1.13s
# 503:	learn: 0.0005106	total: 1.15s	remaining: 1.13s
# 504:	learn: 0.0005076	total: 1.15s	remaining: 1.13s
# 505:	learn: 0.0005036	total: 1.15s	remaining: 1.12s
# 506:	learn: 0.0005009	total: 1.15s	remaining: 1.12s
# 507:	learn: 0.0004979	total: 1.15s	remaining: 1.12s
# 508:	learn: 0.0004952	total: 1.16s	remaining: 1.11s
# 509:	learn: 0.0004918	total: 1.16s	remaining: 1.11s
# 510:	learn: 0.0004883	total: 1.16s	remaining: 1.11s
# 511:	learn: 0.0004841	total: 1.16s	remaining: 1.11s
# 512:	learn: 0.0004803	total: 1.17s	remaining: 1.11s
# 513:	learn: 0.0004775	total: 1.17s	remaining: 1.1s
# 514:	learn: 0.0004749	total: 1.17s	remaining: 1.1s
# 515:	learn: 0.0004722	total: 1.17s	remaining: 1.1s
# 516:	learn: 0.0004694	total: 1.17s	remaining: 1.1s
# 517:	learn: 0.0004669	total: 1.18s	remaining: 1.09s
# 518:	learn: 0.0004630	total: 1.18s	remaining: 1.09s
# 519:	learn: 0.0004589	total: 1.18s	remaining: 1.09s
# 520:	learn: 0.0004561	total: 1.18s	remaining: 1.09s
# 521:	learn: 0.0004525	total: 1.19s	remaining: 1.09s
# 522:	learn: 0.0004499	total: 1.19s	remaining: 1.08s
# 523:	learn: 0.0004473	total: 1.19s	remaining: 1.08s
# 524:	learn: 0.0004447	total: 1.19s	remaining: 1.08s
# 525:	learn: 0.0004423	total: 1.2s	remaining: 1.08s
# 526:	learn: 0.0004398	total: 1.2s	remaining: 1.07s
# 527:	learn: 0.0004375	total: 1.2s	remaining: 1.07s
# 528:	learn: 0.0004349	total: 1.2s	remaining: 1.07s
# 529:	learn: 0.0004326	total: 1.2s	remaining: 1.07s
# 530:	learn: 0.0004301	total: 1.21s	remaining: 1.06s
# 531:	learn: 0.0004259	total: 1.21s	remaining: 1.06s
# 532:	learn: 0.0004229	total: 1.21s	remaining: 1.06s
# 533:	learn: 0.0004200	total: 1.21s	remaining: 1.06s
# 534:	learn: 0.0004158	total: 1.21s	remaining: 1.05s
# 535:	learn: 0.0004129	total: 1.22s	remaining: 1.05s
# 536:	learn: 0.0004101	total: 1.22s	remaining: 1.05s
# 537:	learn: 0.0004066	total: 1.22s	remaining: 1.05s
# 538:	learn: 0.0004038	total: 1.23s	remaining: 1.05s
# 539:	learn: 0.0004016	total: 1.23s	remaining: 1.05s
# 540:	learn: 0.0003988	total: 1.23s	remaining: 1.04s
# 541:	learn: 0.0003961	total: 1.23s	remaining: 1.04s
# 542:	learn: 0.0003931	total: 1.23s	remaining: 1.04s
# 543:	learn: 0.0003910	total: 1.24s	remaining: 1.04s
# 544:	learn: 0.0003892	total: 1.24s	remaining: 1.03s
# 545:	learn: 0.0003871	total: 1.24s	remaining: 1.03s
# 546:	learn: 0.0003853	total: 1.24s	remaining: 1.03s
# 547:	learn: 0.0003824	total: 1.25s	remaining: 1.03s
# 548:	learn: 0.0003798	total: 1.25s	remaining: 1.02s
# 549:	learn: 0.0003767	total: 1.25s	remaining: 1.02s
# 550:	learn: 0.0003736	total: 1.25s	remaining: 1.02s
# 551:	learn: 0.0003706	total: 1.25s	remaining: 1.02s
# 552:	learn: 0.0003671	total: 1.26s	remaining: 1.02s
# 553:	learn: 0.0003642	total: 1.26s	remaining: 1.01s
# 554:	learn: 0.0003613	total: 1.26s	remaining: 1.01s
# 555:	learn: 0.0003592	total: 1.27s	remaining: 1.01s
# 556:	learn: 0.0003563	total: 1.27s	remaining: 1.01s
# 557:	learn: 0.0003532	total: 1.27s	remaining: 1.01s
# 558:	learn: 0.0003505	total: 1.27s	remaining: 1s
# 559:	learn: 0.0003484	total: 1.28s	remaining: 1s
# 560:	learn: 0.0003457	total: 1.28s	remaining: 1s
# 561:	learn: 0.0003437	total: 1.28s	remaining: 1s
# 562:	learn: 0.0003412	total: 1.29s	remaining: 999ms
# 563:	learn: 0.0003393	total: 1.29s	remaining: 997ms
# 564:	learn: 0.0003361	total: 1.29s	remaining: 995ms
# 565:	learn: 0.0003334	total: 1.29s	remaining: 992ms
# 566:	learn: 0.0003310	total: 1.3s	remaining: 990ms
# 567:	learn: 0.0003281	total: 1.3s	remaining: 988ms
# 568:	learn: 0.0003262	total: 1.3s	remaining: 986ms
# 569:	learn: 0.0003235	total: 1.3s	remaining: 983ms
# 570:	learn: 0.0003211	total: 1.3s	remaining: 981ms
# 571:	learn: 0.0003191	total: 1.31s	remaining: 979ms
# 572:	learn: 0.0003176	total: 1.31s	remaining: 976ms
# 573:	learn: 0.0003151	total: 1.31s	remaining: 974ms
# 574:	learn: 0.0003131	total: 1.31s	remaining: 972ms
# 575:	learn: 0.0003102	total: 1.32s	remaining: 969ms
# 576:	learn: 0.0003083	total: 1.32s	remaining: 967ms
# 577:	learn: 0.0003069	total: 1.32s	remaining: 965ms
# 578:	learn: 0.0003049	total: 1.32s	remaining: 962ms
# 579:	learn: 0.0003035	total: 1.32s	remaining: 960ms
# 580:	learn: 0.0003016	total: 1.33s	remaining: 958ms
# 581:	learn: 0.0002990	total: 1.33s	remaining: 955ms
# 582:	learn: 0.0002973	total: 1.33s	remaining: 953ms
# 583:	learn: 0.0002955	total: 1.33s	remaining: 951ms
# 584:	learn: 0.0002929	total: 1.34s	remaining: 948ms
# 585:	learn: 0.0002908	total: 1.34s	remaining: 946ms
# 586:	learn: 0.0002895	total: 1.34s	remaining: 943ms
# 587:	learn: 0.0002877	total: 1.34s	remaining: 941ms
# 588:	learn: 0.0002861	total: 1.34s	remaining: 939ms
# 589:	learn: 0.0002837	total: 1.35s	remaining: 936ms
# 590:	learn: 0.0002819	total: 1.35s	remaining: 934ms
# 591:	learn: 0.0002801	total: 1.35s	remaining: 932ms
# 592:	learn: 0.0002777	total: 1.35s	remaining: 930ms
# 593:	learn: 0.0002760	total: 1.36s	remaining: 927ms
# 594:	learn: 0.0002743	total: 1.36s	remaining: 925ms
# 595:	learn: 0.0002722	total: 1.36s	remaining: 923ms
# 596:	learn: 0.0002705	total: 1.36s	remaining: 921ms
# 597:	learn: 0.0002684	total: 1.36s	remaining: 918ms
# 598:	learn: 0.0002668	total: 1.37s	remaining: 916ms
# 599:	learn: 0.0002645	total: 1.37s	remaining: 914ms
# 600:	learn: 0.0002624	total: 1.37s	remaining: 912ms
# 601:	learn: 0.0002603	total: 1.38s	remaining: 910ms
# 602:	learn: 0.0002589	total: 1.38s	remaining: 908ms
# 603:	learn: 0.0002575	total: 1.38s	remaining: 905ms
# 604:	learn: 0.0002553	total: 1.38s	remaining: 903ms
# 605:	learn: 0.0002533	total: 1.39s	remaining: 901ms
# 606:	learn: 0.0002514	total: 1.39s	remaining: 898ms
# 607:	learn: 0.0002500	total: 1.39s	remaining: 896ms
# 608:	learn: 0.0002479	total: 1.39s	remaining: 894ms
# 609:	learn: 0.0002463	total: 1.4s	remaining: 892ms
# 610:	learn: 0.0002443	total: 1.4s	remaining: 890ms
# 611:	learn: 0.0002427	total: 1.4s	remaining: 887ms
# 612:	learn: 0.0002407	total: 1.4s	remaining: 885ms
# 613:	learn: 0.0002393	total: 1.4s	remaining: 883ms
# 614:	learn: 0.0002373	total: 1.41s	remaining: 881ms
# 615:	learn: 0.0002354	total: 1.41s	remaining: 878ms
# 616:	learn: 0.0002333	total: 1.41s	remaining: 876ms
# 617:	learn: 0.0002320	total: 1.42s	remaining: 875ms
# 618:	learn: 0.0002309	total: 1.42s	remaining: 873ms
# 619:	learn: 0.0002298	total: 1.42s	remaining: 871ms
# 620:	learn: 0.0002285	total: 1.42s	remaining: 868ms
# 621:	learn: 0.0002274	total: 1.42s	remaining: 866ms
# 622:	learn: 0.0002263	total: 1.43s	remaining: 864ms
# 623:	learn: 0.0002250	total: 1.43s	remaining: 861ms
# 624:	learn: 0.0002239	total: 1.43s	remaining: 859ms
# 625:	learn: 0.0002226	total: 1.43s	remaining: 857ms
# 626:	learn: 0.0002213	total: 1.44s	remaining: 854ms
# 627:	learn: 0.0002193	total: 1.44s	remaining: 852ms
# 628:	learn: 0.0002179	total: 1.44s	remaining: 850ms
# 629:	learn: 0.0002167	total: 1.44s	remaining: 847ms
# 630:	learn: 0.0002148	total: 1.44s	remaining: 845ms
# 631:	learn: 0.0002138	total: 1.45s	remaining: 843ms
# 632:	learn: 0.0002123	total: 1.45s	remaining: 840ms
# 633:	learn: 0.0002104	total: 1.45s	remaining: 838ms
# 634:	learn: 0.0002086	total: 1.45s	remaining: 835ms
# 635:	learn: 0.0002075	total: 1.46s	remaining: 833ms
# 636:	learn: 0.0002062	total: 1.46s	remaining: 831ms
# 637:	learn: 0.0002052	total: 1.46s	remaining: 828ms
# 638:	learn: 0.0002042	total: 1.46s	remaining: 826ms
# 639:	learn: 0.0002029	total: 1.46s	remaining: 824ms
# 640:	learn: 0.0002013	total: 1.47s	remaining: 821ms
# 641:	learn: 0.0002003	total: 1.47s	remaining: 819ms
# 642:	learn: 0.0001989	total: 1.47s	remaining: 817ms
# 643:	learn: 0.0001974	total: 1.47s	remaining: 814ms
# 644:	learn: 0.0001964	total: 1.48s	remaining: 812ms
# 645:	learn: 0.0001955	total: 1.48s	remaining: 810ms
# 646:	learn: 0.0001939	total: 1.48s	remaining: 807ms
# 647:	learn: 0.0001924	total: 1.48s	remaining: 805ms
# 648:	learn: 0.0001913	total: 1.48s	remaining: 803ms
# 649:	learn: 0.0001899	total: 1.49s	remaining: 800ms
# 650:	learn: 0.0001885	total: 1.49s	remaining: 798ms
# 651:	learn: 0.0001873	total: 1.49s	remaining: 796ms
# 652:	learn: 0.0001860	total: 1.49s	remaining: 794ms
# 653:	learn: 0.0001846	total: 1.5s	remaining: 791ms
# 654:	learn: 0.0001832	total: 1.5s	remaining: 789ms
# 655:	learn: 0.0001819	total: 1.5s	remaining: 787ms
# 656:	learn: 0.0001808	total: 1.5s	remaining: 784ms
# 657:	learn: 0.0001797	total: 1.5s	remaining: 782ms
# 658:	learn: 0.0001788	total: 1.51s	remaining: 780ms
# 659:	learn: 0.0001771	total: 1.51s	remaining: 777ms
# 660:	learn: 0.0001758	total: 1.51s	remaining: 775ms
# 661:	learn: 0.0001745	total: 1.51s	remaining: 773ms
# 662:	learn: 0.0001733	total: 1.51s	remaining: 770ms
# 663:	learn: 0.0001726	total: 1.52s	remaining: 768ms
# 664:	learn: 0.0001715	total: 1.52s	remaining: 766ms
# 665:	learn: 0.0001705	total: 1.52s	remaining: 763ms
# 666:	learn: 0.0001695	total: 1.52s	remaining: 761ms
# 667:	learn: 0.0001686	total: 1.53s	remaining: 759ms
# 668:	learn: 0.0001674	total: 1.53s	remaining: 756ms
# 669:	learn: 0.0001663	total: 1.53s	remaining: 754ms
# 670:	learn: 0.0001654	total: 1.53s	remaining: 752ms
# 671:	learn: 0.0001647	total: 1.53s	remaining: 749ms
# 672:	learn: 0.0001637	total: 1.54s	remaining: 747ms
# 673:	learn: 0.0001630	total: 1.54s	remaining: 745ms
# 674:	learn: 0.0001622	total: 1.54s	remaining: 742ms
# 675:	learn: 0.0001613	total: 1.54s	remaining: 740ms
# 676:	learn: 0.0001599	total: 1.55s	remaining: 738ms
# 677:	learn: 0.0001588	total: 1.55s	remaining: 735ms
# 678:	learn: 0.0001581	total: 1.55s	remaining: 733ms
# 679:	learn: 0.0001571	total: 1.55s	remaining: 731ms
# 680:	learn: 0.0001562	total: 1.55s	remaining: 729ms
# 681:	learn: 0.0001548	total: 1.56s	remaining: 726ms
# 682:	learn: 0.0001538	total: 1.56s	remaining: 724ms
# 683:	learn: 0.0001528	total: 1.56s	remaining: 722ms
# 684:	learn: 0.0001517	total: 1.56s	remaining: 719ms
# 685:	learn: 0.0001508	total: 1.57s	remaining: 717ms
# 686:	learn: 0.0001498	total: 1.57s	remaining: 716ms
# 687:	learn: 0.0001488	total: 1.57s	remaining: 714ms
# 688:	learn: 0.0001478	total: 1.58s	remaining: 712ms
# 689:	learn: 0.0001469	total: 1.58s	remaining: 709ms
# 690:	learn: 0.0001460	total: 1.58s	remaining: 707ms
# 691:	learn: 0.0001450	total: 1.58s	remaining: 705ms
# 692:	learn: 0.0001442	total: 1.58s	remaining: 703ms
# 693:	learn: 0.0001429	total: 1.59s	remaining: 700ms
# 694:	learn: 0.0001420	total: 1.59s	remaining: 698ms
# 695:	learn: 0.0001411	total: 1.59s	remaining: 696ms
# 696:	learn: 0.0001397	total: 1.6s	remaining: 694ms
# 697:	learn: 0.0001388	total: 1.6s	remaining: 692ms
# 698:	learn: 0.0001380	total: 1.6s	remaining: 689ms
# 699:	learn: 0.0001367	total: 1.6s	remaining: 687ms
# 700:	learn: 0.0001358	total: 1.6s	remaining: 685ms
# 701:	learn: 0.0001350	total: 1.61s	remaining: 682ms
# 702:	learn: 0.0001337	total: 1.61s	remaining: 680ms
# 703:	learn: 0.0001327	total: 1.61s	remaining: 679ms
# 704:	learn: 0.0001318	total: 1.62s	remaining: 676ms
# 705:	learn: 0.0001309	total: 1.62s	remaining: 674ms
# 706:	learn: 0.0001297	total: 1.62s	remaining: 672ms
# 707:	learn: 0.0001286	total: 1.62s	remaining: 669ms
# 708:	learn: 0.0001275	total: 1.63s	remaining: 667ms
# 709:	learn: 0.0001265	total: 1.63s	remaining: 665ms
# 710:	learn: 0.0001257	total: 1.63s	remaining: 663ms
# 711:	learn: 0.0001246	total: 1.63s	remaining: 660ms
# 712:	learn: 0.0001238	total: 1.63s	remaining: 658ms
# 713:	learn: 0.0001229	total: 1.64s	remaining: 656ms
# 714:	learn: 0.0001221	total: 1.64s	remaining: 653ms
# 715:	learn: 0.0001214	total: 1.64s	remaining: 651ms
# 716:	learn: 0.0001204	total: 1.64s	remaining: 649ms
# 717:	learn: 0.0001193	total: 1.65s	remaining: 646ms
# 718:	learn: 0.0001188	total: 1.65s	remaining: 644ms
# 719:	learn: 0.0001183	total: 1.65s	remaining: 642ms
# 720:	learn: 0.0001173	total: 1.65s	remaining: 640ms
# 721:	learn: 0.0001164	total: 1.65s	remaining: 637ms
# 722:	learn: 0.0001157	total: 1.66s	remaining: 635ms
# 723:	learn: 0.0001149	total: 1.66s	remaining: 633ms
# 724:	learn: 0.0001142	total: 1.66s	remaining: 630ms
# 725:	learn: 0.0001134	total: 1.66s	remaining: 628ms
# 726:	learn: 0.0001128	total: 1.67s	remaining: 626ms
# 727:	learn: 0.0001121	total: 1.67s	remaining: 623ms
# 728:	learn: 0.0001115	total: 1.67s	remaining: 621ms
# 729:	learn: 0.0001107	total: 1.67s	remaining: 619ms
# 730:	learn: 0.0001101	total: 1.68s	remaining: 617ms
# 731:	learn: 0.0001093	total: 1.68s	remaining: 614ms
# 732:	learn: 0.0001088	total: 1.68s	remaining: 612ms
# 733:	learn: 0.0001081	total: 1.68s	remaining: 610ms
# 734:	learn: 0.0001076	total: 1.68s	remaining: 607ms
# 735:	learn: 0.0001069	total: 1.69s	remaining: 605ms
# 736:	learn: 0.0001064	total: 1.69s	remaining: 603ms
# 737:	learn: 0.0001056	total: 1.69s	remaining: 600ms
# 738:	learn: 0.0001048	total: 1.69s	remaining: 598ms
# 739:	learn: 0.0001039	total: 1.7s	remaining: 596ms
# 740:	learn: 0.0001032	total: 1.7s	remaining: 593ms
# 741:	learn: 0.0001024	total: 1.7s	remaining: 591ms
# 742:	learn: 0.0001016	total: 1.7s	remaining: 589ms
# 743:	learn: 0.0001010	total: 1.7s	remaining: 587ms
# 744:	learn: 0.0001004	total: 1.71s	remaining: 584ms
# 745:	learn: 0.0000998	total: 1.71s	remaining: 582ms
# 746:	learn: 0.0000990	total: 1.71s	remaining: 580ms
# 747:	learn: 0.0000984	total: 1.71s	remaining: 577ms
# 748:	learn: 0.0000978	total: 1.72s	remaining: 575ms
# 749:	learn: 0.0000973	total: 1.72s	remaining: 573ms
# 750:	learn: 0.0000965	total: 1.72s	remaining: 571ms
# 751:	learn: 0.0000961	total: 1.72s	remaining: 568ms
# 752:	learn: 0.0000955	total: 1.73s	remaining: 566ms
# 753:	learn: 0.0000949	total: 1.73s	remaining: 564ms
# 754:	learn: 0.0000942	total: 1.73s	remaining: 561ms
# 755:	learn: 0.0000936	total: 1.73s	remaining: 559ms
# 756:	learn: 0.0000930	total: 1.73s	remaining: 557ms
# 757:	learn: 0.0000925	total: 1.74s	remaining: 554ms
# 758:	learn: 0.0000917	total: 1.74s	remaining: 552ms
# 759:	learn: 0.0000912	total: 1.74s	remaining: 550ms
# 760:	learn: 0.0000906	total: 1.74s	remaining: 548ms
# 761:	learn: 0.0000899	total: 1.75s	remaining: 545ms
# 762:	learn: 0.0000892	total: 1.75s	remaining: 543ms
# 763:	learn: 0.0000886	total: 1.75s	remaining: 541ms
# 764:	learn: 0.0000881	total: 1.75s	remaining: 538ms
# 765:	learn: 0.0000874	total: 1.75s	remaining: 536ms
# 766:	learn: 0.0000868	total: 1.76s	remaining: 534ms
# 767:	learn: 0.0000860	total: 1.76s	remaining: 531ms
# 768:	learn: 0.0000854	total: 1.76s	remaining: 529ms
# 769:	learn: 0.0000848	total: 1.76s	remaining: 527ms
# 770:	learn: 0.0000842	total: 1.77s	remaining: 525ms
# 771:	learn: 0.0000836	total: 1.77s	remaining: 523ms
# 772:	learn: 0.0000829	total: 1.77s	remaining: 521ms
# 773:	learn: 0.0000824	total: 1.78s	remaining: 519ms
# 774:	learn: 0.0000817	total: 1.78s	remaining: 516ms
# 775:	learn: 0.0000811	total: 1.78s	remaining: 514ms
# 776:	learn: 0.0000806	total: 1.78s	remaining: 512ms
# 777:	learn: 0.0000800	total: 1.78s	remaining: 510ms
# 778:	learn: 0.0000793	total: 1.79s	remaining: 507ms
# 779:	learn: 0.0000788	total: 1.79s	remaining: 505ms
# 780:	learn: 0.0000784	total: 1.79s	remaining: 503ms
# 781:	learn: 0.0000779	total: 1.79s	remaining: 500ms
# 782:	learn: 0.0000775	total: 1.8s	remaining: 498ms
# 783:	learn: 0.0000768	total: 1.8s	remaining: 496ms
# 784:	learn: 0.0000762	total: 1.8s	remaining: 493ms
# 785:	learn: 0.0000758	total: 1.8s	remaining: 491ms
# 786:	learn: 0.0000752	total: 1.81s	remaining: 489ms
# 787:	learn: 0.0000748	total: 1.81s	remaining: 487ms
# 788:	learn: 0.0000742	total: 1.82s	remaining: 486ms
# 789:	learn: 0.0000738	total: 1.82s	remaining: 483ms
# 790:	learn: 0.0000733	total: 1.82s	remaining: 481ms
# 791:	learn: 0.0000727	total: 1.82s	remaining: 479ms
# 792:	learn: 0.0000724	total: 1.82s	remaining: 476ms
# 793:	learn: 0.0000718	total: 1.83s	remaining: 474ms
# 794:	learn: 0.0000713	total: 1.83s	remaining: 472ms
# 795:	learn: 0.0000710	total: 1.83s	remaining: 469ms
# 796:	learn: 0.0000705	total: 1.83s	remaining: 467ms
# 797:	learn: 0.0000700	total: 1.84s	remaining: 465ms
# 798:	learn: 0.0000696	total: 1.84s	remaining: 462ms
# 799:	learn: 0.0000693	total: 1.84s	remaining: 460ms
# 800:	learn: 0.0000688	total: 1.84s	remaining: 458ms
# 801:	learn: 0.0000683	total: 1.84s	remaining: 455ms
# 802:	learn: 0.0000678	total: 1.85s	remaining: 453ms
# 803:	learn: 0.0000675	total: 1.85s	remaining: 451ms
# 804:	learn: 0.0000671	total: 1.85s	remaining: 449ms
# 805:	learn: 0.0000666	total: 1.85s	remaining: 446ms
# 806:	learn: 0.0000662	total: 1.85s	remaining: 444ms
# 807:	learn: 0.0000658	total: 1.86s	remaining: 442ms
# 808:	learn: 0.0000654	total: 1.86s	remaining: 439ms
# 809:	learn: 0.0000651	total: 1.86s	remaining: 437ms
# 810:	learn: 0.0000647	total: 1.86s	remaining: 435ms
# 811:	learn: 0.0000643	total: 1.87s	remaining: 432ms
# 812:	learn: 0.0000641	total: 1.87s	remaining: 430ms
# 813:	learn: 0.0000637	total: 1.87s	remaining: 428ms
# 814:	learn: 0.0000634	total: 1.87s	remaining: 425ms
# 815:	learn: 0.0000629	total: 1.88s	remaining: 423ms
# 816:	learn: 0.0000627	total: 1.88s	remaining: 421ms
# 817:	learn: 0.0000623	total: 1.88s	remaining: 418ms
# 818:	learn: 0.0000618	total: 1.88s	remaining: 416ms
# 819:	learn: 0.0000615	total: 1.88s	remaining: 414ms
# 820:	learn: 0.0000612	total: 1.89s	remaining: 411ms
# 821:	learn: 0.0000610	total: 1.89s	remaining: 409ms
# 822:	learn: 0.0000606	total: 1.89s	remaining: 407ms
# 823:	learn: 0.0000603	total: 1.89s	remaining: 404ms
# 824:	learn: 0.0000600	total: 1.9s	remaining: 402ms
# 825:	learn: 0.0000597	total: 1.9s	remaining: 400ms
# 826:	learn: 0.0000593	total: 1.9s	remaining: 397ms
# 827:	learn: 0.0000590	total: 1.9s	remaining: 395ms
# 828:	learn: 0.0000587	total: 1.9s	remaining: 393ms
# 829:	learn: 0.0000583	total: 1.91s	remaining: 391ms
# 830:	learn: 0.0000581	total: 1.91s	remaining: 388ms
# 831:	learn: 0.0000578	total: 1.91s	remaining: 386ms
# 832:	learn: 0.0000575	total: 1.91s	remaining: 384ms
# 833:	learn: 0.0000571	total: 1.92s	remaining: 381ms
# 834:	learn: 0.0000568	total: 1.92s	remaining: 379ms
# 835:	learn: 0.0000565	total: 1.92s	remaining: 377ms
# 836:	learn: 0.0000562	total: 1.92s	remaining: 374ms
# 837:	learn: 0.0000557	total: 1.92s	remaining: 372ms
# 838:	learn: 0.0000554	total: 1.93s	remaining: 370ms
# 839:	learn: 0.0000549	total: 1.93s	remaining: 367ms
# 840:	learn: 0.0000546	total: 1.93s	remaining: 365ms
# 841:	learn: 0.0000542	total: 1.93s	remaining: 363ms
# 842:	learn: 0.0000537	total: 1.94s	remaining: 360ms
# 843:	learn: 0.0000534	total: 1.94s	remaining: 358ms
# 844:	learn: 0.0000530	total: 1.94s	remaining: 356ms
# 845:	learn: 0.0000527	total: 1.94s	remaining: 353ms
# 846:	learn: 0.0000523	total: 1.94s	remaining: 351ms
# 847:	learn: 0.0000519	total: 1.95s	remaining: 349ms
# 848:	learn: 0.0000515	total: 1.95s	remaining: 346ms
# 849:	learn: 0.0000510	total: 1.95s	remaining: 344ms
# 850:	learn: 0.0000508	total: 1.95s	remaining: 342ms
# 851:	learn: 0.0000504	total: 1.95s	remaining: 340ms
# 852:	learn: 0.0000501	total: 1.96s	remaining: 337ms
# 853:	learn: 0.0000498	total: 1.96s	remaining: 335ms
# 854:	learn: 0.0000496	total: 1.96s	remaining: 333ms
# 855:	learn: 0.0000493	total: 1.97s	remaining: 331ms
# 856:	learn: 0.0000491	total: 1.97s	remaining: 328ms
# 857:	learn: 0.0000486	total: 1.97s	remaining: 326ms
# 858:	learn: 0.0000482	total: 1.97s	remaining: 324ms
# 859:	learn: 0.0000478	total: 1.97s	remaining: 321ms
# 860:	learn: 0.0000474	total: 1.98s	remaining: 319ms
# 861:	learn: 0.0000470	total: 1.98s	remaining: 317ms
# 862:	learn: 0.0000466	total: 1.98s	remaining: 315ms
# 863:	learn: 0.0000462	total: 1.98s	remaining: 312ms
# 864:	learn: 0.0000460	total: 1.99s	remaining: 310ms
# 865:	learn: 0.0000457	total: 1.99s	remaining: 308ms
# 866:	learn: 0.0000454	total: 1.99s	remaining: 305ms
# 867:	learn: 0.0000452	total: 1.99s	remaining: 303ms
# 868:	learn: 0.0000450	total: 1.99s	remaining: 301ms
# 869:	learn: 0.0000448	total: 2s	remaining: 298ms
# 870:	learn: 0.0000445	total: 2s	remaining: 296ms
# 871:	learn: 0.0000443	total: 2s	remaining: 294ms
# 872:	learn: 0.0000441	total: 2s	remaining: 292ms
# 873:	learn: 0.0000439	total: 2.01s	remaining: 290ms
# 874:	learn: 0.0000436	total: 2.01s	remaining: 287ms
# 875:	learn: 0.0000434	total: 2.01s	remaining: 285ms
# 876:	learn: 0.0000432	total: 2.01s	remaining: 283ms
# 877:	learn: 0.0000430	total: 2.02s	remaining: 280ms
# 878:	learn: 0.0000428	total: 2.02s	remaining: 278ms
# 879:	learn: 0.0000426	total: 2.02s	remaining: 276ms
# 880:	learn: 0.0000424	total: 2.02s	remaining: 273ms
# 881:	learn: 0.0000422	total: 2.02s	remaining: 271ms
# 882:	learn: 0.0000420	total: 2.03s	remaining: 269ms
# 883:	learn: 0.0000418	total: 2.03s	remaining: 266ms
# 884:	learn: 0.0000415	total: 2.03s	remaining: 264ms
# 885:	learn: 0.0000413	total: 2.03s	remaining: 262ms
# 886:	learn: 0.0000411	total: 2.04s	remaining: 260ms
# 887:	learn: 0.0000410	total: 2.04s	remaining: 257ms
# 888:	learn: 0.0000408	total: 2.04s	remaining: 255ms
# 889:	learn: 0.0000405	total: 2.04s	remaining: 253ms
# 890:	learn: 0.0000404	total: 2.04s	remaining: 250ms
# 891:	learn: 0.0000402	total: 2.05s	remaining: 248ms
# 892:	learn: 0.0000400	total: 2.05s	remaining: 246ms
# 893:	learn: 0.0000398	total: 2.05s	remaining: 243ms
# 894:	learn: 0.0000396	total: 2.05s	remaining: 241ms
# 895:	learn: 0.0000394	total: 2.06s	remaining: 239ms
# 896:	learn: 0.0000392	total: 2.06s	remaining: 236ms
# 897:	learn: 0.0000388	total: 2.06s	remaining: 234ms
# 898:	learn: 0.0000387	total: 2.06s	remaining: 232ms
# 899:	learn: 0.0000385	total: 2.06s	remaining: 230ms
# 900:	learn: 0.0000381	total: 2.07s	remaining: 227ms
# 901:	learn: 0.0000378	total: 2.07s	remaining: 225ms
# 902:	learn: 0.0000374	total: 2.07s	remaining: 223ms
# 903:	learn: 0.0000372	total: 2.07s	remaining: 220ms
# 904:	learn: 0.0000368	total: 2.08s	remaining: 218ms
# 905:	learn: 0.0000366	total: 2.08s	remaining: 216ms
# 906:	learn: 0.0000363	total: 2.08s	remaining: 213ms
# 907:	learn: 0.0000360	total: 2.08s	remaining: 211ms
# 908:	learn: 0.0000357	total: 2.08s	remaining: 209ms
# 909:	learn: 0.0000355	total: 2.09s	remaining: 206ms
# 910:	learn: 0.0000352	total: 2.09s	remaining: 204ms
# 911:	learn: 0.0000350	total: 2.09s	remaining: 202ms
# 912:	learn: 0.0000346	total: 2.09s	remaining: 200ms
# 913:	learn: 0.0000344	total: 2.1s	remaining: 197ms
# 914:	learn: 0.0000342	total: 2.1s	remaining: 195ms
# 915:	learn: 0.0000339	total: 2.1s	remaining: 193ms
# 916:	learn: 0.0000337	total: 2.1s	remaining: 190ms
# 917:	learn: 0.0000334	total: 2.1s	remaining: 188ms
# 918:	learn: 0.0000332	total: 2.11s	remaining: 186ms
# 919:	learn: 0.0000329	total: 2.11s	remaining: 183ms
# 920:	learn: 0.0000327	total: 2.11s	remaining: 181ms
# 921:	learn: 0.0000325	total: 2.11s	remaining: 179ms
# 922:	learn: 0.0000323	total: 2.12s	remaining: 177ms
# 923:	learn: 0.0000321	total: 2.12s	remaining: 174ms
# 924:	learn: 0.0000319	total: 2.12s	remaining: 172ms
# 925:	learn: 0.0000317	total: 2.12s	remaining: 170ms
# 926:	learn: 0.0000316	total: 2.13s	remaining: 167ms
# 927:	learn: 0.0000314	total: 2.13s	remaining: 165ms
# 928:	learn: 0.0000312	total: 2.13s	remaining: 163ms
# 929:	learn: 0.0000311	total: 2.13s	remaining: 160ms
# 930:	learn: 0.0000309	total: 2.13s	remaining: 158ms
# 931:	learn: 0.0000307	total: 2.14s	remaining: 156ms
# 932:	learn: 0.0000305	total: 2.15s	remaining: 154ms
# 933:	learn: 0.0000303	total: 2.15s	remaining: 152ms
# 934:	learn: 0.0000301	total: 2.15s	remaining: 150ms
# 935:	learn: 0.0000299	total: 2.16s	remaining: 148ms
# 936:	learn: 0.0000298	total: 2.16s	remaining: 146ms
# 937:	learn: 0.0000296	total: 2.17s	remaining: 143ms
# 938:	learn: 0.0000294	total: 2.17s	remaining: 141ms
# 939:	learn: 0.0000292	total: 2.17s	remaining: 139ms
# 940:	learn: 0.0000290	total: 2.17s	remaining: 136ms
# 941:	learn: 0.0000288	total: 2.18s	remaining: 134ms
# 942:	learn: 0.0000287	total: 2.18s	remaining: 132ms
# 943:	learn: 0.0000285	total: 2.18s	remaining: 129ms
# 944:	learn: 0.0000283	total: 2.19s	remaining: 127ms
# 945:	learn: 0.0000282	total: 2.19s	remaining: 125ms
# 946:	learn: 0.0000280	total: 2.19s	remaining: 123ms
# 947:	learn: 0.0000278	total: 2.19s	remaining: 120ms
# 948:	learn: 0.0000277	total: 2.19s	remaining: 118ms
# 949:	learn: 0.0000275	total: 2.2s	remaining: 116ms
# 950:	learn: 0.0000273	total: 2.2s	remaining: 114ms
# 951:	learn: 0.0000271	total: 2.21s	remaining: 111ms
# 952:	learn: 0.0000270	total: 2.21s	remaining: 109ms
# 953:	learn: 0.0000268	total: 2.21s	remaining: 107ms
# 954:	learn: 0.0000267	total: 2.21s	remaining: 104ms
# 955:	learn: 0.0000266	total: 2.22s	remaining: 102ms
# 956:	learn: 0.0000264	total: 2.22s	remaining: 99.9ms
# 957:	learn: 0.0000263	total: 2.23s	remaining: 97.6ms
# 958:	learn: 0.0000262	total: 2.23s	remaining: 95.3ms
# 959:	learn: 0.0000261	total: 2.23s	remaining: 93ms
# 960:	learn: 0.0000259	total: 2.23s	remaining: 90.7ms
# 961:	learn: 0.0000258	total: 2.24s	remaining: 88.4ms
# 962:	learn: 0.0000257	total: 2.24s	remaining: 86.1ms
# 963:	learn: 0.0000256	total: 2.24s	remaining: 83.8ms
# 964:	learn: 0.0000255	total: 2.25s	remaining: 81.5ms
# 965:	learn: 0.0000254	total: 2.25s	remaining: 79.2ms
# 966:	learn: 0.0000253	total: 2.25s	remaining: 76.9ms
# 967:	learn: 0.0000251	total: 2.26s	remaining: 74.6ms
# 968:	learn: 0.0000250	total: 2.26s	remaining: 72.3ms
# 969:	learn: 0.0000248	total: 2.26s	remaining: 70ms
# 970:	learn: 0.0000247	total: 2.27s	remaining: 67.7ms
# 971:	learn: 0.0000245	total: 2.27s	remaining: 65.4ms
# 972:	learn: 0.0000244	total: 2.27s	remaining: 63.1ms
# 973:	learn: 0.0000243	total: 2.28s	remaining: 60.8ms
# 974:	learn: 0.0000241	total: 2.28s	remaining: 58.5ms
# 975:	learn: 0.0000240	total: 2.28s	remaining: 56.1ms
# 976:	learn: 0.0000239	total: 2.28s	remaining: 53.8ms
# 977:	learn: 0.0000238	total: 2.29s	remaining: 51.5ms
# 978:	learn: 0.0000237	total: 2.29s	remaining: 49.2ms
# 979:	learn: 0.0000236	total: 2.3s	remaining: 46.9ms
# 980:	learn: 0.0000235	total: 2.3s	remaining: 44.5ms
# 981:	learn: 0.0000233	total: 2.3s	remaining: 42.2ms
# 982:	learn: 0.0000232	total: 2.3s	remaining: 39.9ms
# 983:	learn: 0.0000231	total: 2.31s	remaining: 37.5ms
# 984:	learn: 0.0000230	total: 2.31s	remaining: 35.2ms
# 985:	learn: 0.0000229	total: 2.31s	remaining: 32.8ms
# 986:	learn: 0.0000227	total: 2.31s	remaining: 30.5ms
# 987:	learn: 0.0000226	total: 2.32s	remaining: 28.1ms
# 988:	learn: 0.0000225	total: 2.32s	remaining: 25.8ms
# 989:	learn: 0.0000224	total: 2.32s	remaining: 23.5ms
# 990:	learn: 0.0000222	total: 2.32s	remaining: 21.1ms
# 991:	learn: 0.0000221	total: 2.33s	remaining: 18.8ms
# 992:	learn: 0.0000219	total: 2.33s	remaining: 16.4ms
# 993:	learn: 0.0000218	total: 2.33s	remaining: 14.1ms
# 994:	learn: 0.0000217	total: 2.33s	remaining: 11.7ms
# 995:	learn: 0.0000216	total: 2.34s	remaining: 9.39ms
# 996:	learn: 0.0000214	total: 2.34s	remaining: 7.04ms
# 997:	learn: 0.0000213	total: 2.34s	remaining: 4.69ms
# 998:	learn: 0.0000212	total: 2.34s	remaining: 2.35ms
# 999:	learn: 0.0000211	total: 2.35s	remaining: 0us
# np.float64(0.9999992088195696)

# %%
#Determine MAE with test data
y_pred_CB = np.array(CB.predict(X_test_rank))
y_pred_CB_rank_genes = np.array(CB.predict(X_test_rank))
mae_CB = mean_absolute_error(y_test_rank, y_pred_CB)
mape_CB = mean_absolute_percentage_error(y_test_rank, y_pred_CB)
print(f'Grandient Boosting Regression MAE: {mae_CB}')
# Out:
# Grandient Boosting Regression MAE: 0.015454971064300044

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_CB, y=y_test_rank)

# Add a line for perfect correlation.
plt.plot([y_test_rank.min(), y_test_rank.max()],
         [y_test_rank.min(), y_test_rank.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('CatBoost Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
MAE_dict = {'Multiple Linear Regression': mae_LR, 'Random Forest Regressor': mae_RF, 'Gradient Boost Regressor': mae_GB, 'XGBoost Regressor': mae_XG, 'CatBoost Regressor': mae_CB}
MAPE_dict = {'Multiple Linear Regression': mape_LR, 'Random Forest Regressor': mape_RF, 'Gradient Boost Regressor': mape_GB, 'XGBoost Regressor': mape_XG, 'CatBoost Regressor': mape_CB}
Rsquared_dict = {'Multiple Linear Regression': LR.score(X_train_rank, y_train_rank), 'Random Forest Regressor': RF.score(X_train_rank, y_train_rank), 'Gradient Boost Regressor': GB.score(X_train_rank, y_train_rank),
                 'XGBoost Regressor': XG.score(X_train_rank, y_train_rank), 'CatBoost Regressor': CB.score(X_train_rank, y_train_rank)}
summary_genes_rank = pd.DataFrame({'MAE': MAE_dict, 'MAPE': MAPE_dict, 'R²': Rsquared_dict})
summary_genes_rank
# Out:
#                                  MAE      MAPE        R²
# Multiple Linear Regression  0.032925  0.042867  1.000000
# Random Forest Regressor     0.016535  0.022109  0.932746
# Gradient Boost Regressor    0.017312  0.023144  0.999974
# XGBoost Regressor           0.016227  0.021817  0.999701
# CatBoost Regressor          0.015455  0.020755  0.999999

# %% [markdown]
# ###Using Correlating Pathways

# %% [markdown]
# ####Predicting DE Score

# %%
X = donor_pathways.drop(columns=['DEscore_long', 'DEscore_short', 'pseudorank'])
y = donor_pathways['DEscore_long']

X_train_path, X_test_path, y_train_path, y_test_path = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
#Run default linear regression on dataset
LR = LinearRegression()
LR.fit(X_train_path, y_train_path)
LR.score(X_train_path, y_train_path)
# Out:
# 0.9262341153518265

# %%
#Determine MAE with test data
y_pred_LR = np.array(LR.predict(X_test_path))
mae_LR = mean_absolute_error(y_test_path, y_pred_LR)
mape_LR = mean_absolute_percentage_error(y_test_path, y_pred_LR)
print(f'Linear Regression MAE: {mae_LR}')
# Out:
# Linear Regression MAE: 0.6309353836827138

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_LR, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Multiple Regression Predicted vs Actual Score')
plt.show()

# %%
#Run default Random Forest regression on dataset
RF = RandomForestRegressor()
RF.fit(X_train_path, y_train_path)
RF.score(X_train_path, y_train_path)
# Out:
# 0.9180610269060815

# %%
#Determine MAE with test data
y_pred_RF = np.array(RF.predict(X_test_path))
y_pred_RF_score_paths = np.array(RF.predict(X_test_path))
mae_RF = mean_absolute_error(y_test_path, y_pred_RF)
mape_RF = mean_absolute_percentage_error(y_test_path, y_pred_RF)
print(f'Random Forest Regression MAE: {mae_RF}')
# Out:
# Random Forest Regression MAE: 0.4776580736414983

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_RF, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Random Forest Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default Grandient Boosting regression on dataset
GB = GradientBoostingRegressor()
GB.fit(X_train_path, y_train_path)
GB.score(X_train_path, y_train_path)
# Out:
# 0.999622727136566

# %%
#Determine MAE with test data
y_pred_GB = np.array(GB.predict(X_test_path))
mae_GB = mean_absolute_error(y_test_path, y_pred_GB)
mape_GB = mean_absolute_percentage_error(y_test_path, y_pred_GB)
print(f'Grandient Boosting Regression MAE: {mae_GB}')
# Out:
# Grandient Boosting Regression MAE: 0.47410785011958095

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_GB, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('Grandient Boosting Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default XGBoost regression on dataset
XG = XGBRegressor()
XG.fit(X_train_path, y_train_path)
XG.score(X_train_path, y_train_path)
# Out:
# 0.9999994649775835

# %%
#Determine MAE with test data
y_pred_XG = np.array(XG.predict(X_test_path))
mae_XG = mean_absolute_error(y_test_path, y_pred_XG)
mape_XG = mean_absolute_percentage_error(y_test_path, y_pred_XG)
print(f'XGBoost Regression MAE: {mae_XG}')
# Out:
# XGBoost Regression MAE: 0.5322624887899718

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_XG, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('XGBoost Regressor Predicted vs Actual DE Score')
plt.show()

# %%
#Run default CatBoost regression on dataset
CB = CatBoostRegressor()
CB.fit(X_train_path, y_train_path)
CB.score(X_train_path, y_train_path)
# Out:
# Learning rate set to 0.027076
# 0:	learn: 0.5671925	total: 2.26ms	remaining: 2.25s
# 1:	learn: 0.5613828	total: 3.7ms	remaining: 1.85s
# 2:	learn: 0.5572395	total: 5.08ms	remaining: 1.69s
# 3:	learn: 0.5525826	total: 6.47ms	remaining: 1.61s
# 4:	learn: 0.5480339	total: 7.87ms	remaining: 1.56s
# 5:	learn: 0.5429579	total: 9.3ms	remaining: 1.54s
# 6:	learn: 0.5386095	total: 10.6ms	remaining: 1.5s
# 7:	learn: 0.5350248	total: 11.9ms	remaining: 1.48s
# 8:	learn: 0.5305351	total: 13.3ms	remaining: 1.46s
# 9:	learn: 0.5256792	total: 14.9ms	remaining: 1.48s
# 10:	learn: 0.5215186	total: 16.3ms	remaining: 1.47s
# 11:	learn: 0.5185829	total: 17.6ms	remaining: 1.45s
# 12:	learn: 0.5142013	total: 18.9ms	remaining: 1.44s
# 13:	learn: 0.5096063	total: 20.2ms	remaining: 1.42s
# 14:	learn: 0.5058600	total: 21.6ms	remaining: 1.42s
# 15:	learn: 0.5013887	total: 23ms	remaining: 1.41s
# 16:	learn: 0.4969815	total: 24.4ms	remaining: 1.41s
# 17:	learn: 0.4931429	total: 26ms	remaining: 1.42s
# 18:	learn: 0.4892105	total: 27.7ms	remaining: 1.43s
# 19:	learn: 0.4859800	total: 29.6ms	remaining: 1.45s
# 20:	learn: 0.4818087	total: 31ms	remaining: 1.45s
# 21:	learn: 0.4779941	total: 32.4ms	remaining: 1.44s
# 22:	learn: 0.4748820	total: 33.8ms	remaining: 1.44s
# 23:	learn: 0.4714812	total: 35.2ms	remaining: 1.43s
# 24:	learn: 0.4676505	total: 36.6ms	remaining: 1.43s
# 25:	learn: 0.4643687	total: 38.2ms	remaining: 1.43s
# 26:	learn: 0.4605648	total: 39.6ms	remaining: 1.43s
# 27:	learn: 0.4568506	total: 41ms	remaining: 1.42s
# 28:	learn: 0.4532356	total: 42.2ms	remaining: 1.41s
# 29:	learn: 0.4482152	total: 43.5ms	remaining: 1.41s
# 30:	learn: 0.4446805	total: 45.2ms	remaining: 1.41s
# 31:	learn: 0.4412121	total: 46.6ms	remaining: 1.41s
# 32:	learn: 0.4381406	total: 48.1ms	remaining: 1.41s
# 33:	learn: 0.4339509	total: 49.4ms	remaining: 1.4s
# 34:	learn: 0.4306321	total: 51.6ms	remaining: 1.42s
# 35:	learn: 0.4279423	total: 52.9ms	remaining: 1.42s
# 36:	learn: 0.4247782	total: 54.3ms	remaining: 1.41s
# 37:	learn: 0.4216976	total: 55.6ms	remaining: 1.41s
# 38:	learn: 0.4182269	total: 57ms	remaining: 1.4s
# 39:	learn: 0.4153111	total: 58.5ms	remaining: 1.4s
# 40:	learn: 0.4123221	total: 59.9ms	remaining: 1.4s
# 41:	learn: 0.4081631	total: 61.3ms	remaining: 1.4s
# 42:	learn: 0.4049352	total: 62.6ms	remaining: 1.39s
# 43:	learn: 0.4017682	total: 63.9ms	remaining: 1.39s
# 44:	learn: 0.3984765	total: 65.2ms	remaining: 1.38s
# 45:	learn: 0.3959324	total: 66.6ms	remaining: 1.38s
# 46:	learn: 0.3930001	total: 68ms	remaining: 1.38s
# 47:	learn: 0.3897350	total: 69.3ms	remaining: 1.37s
# 48:	learn: 0.3866295	total: 70.6ms	remaining: 1.37s
# 49:	learn: 0.3839763	total: 72ms	remaining: 1.37s
# 50:	learn: 0.3810333	total: 73.3ms	remaining: 1.36s
# 51:	learn: 0.3777959	total: 74.7ms	remaining: 1.36s
# 52:	learn: 0.3752852	total: 76ms	remaining: 1.36s
# 53:	learn: 0.3730122	total: 77.4ms	remaining: 1.35s
# 54:	learn: 0.3697461	total: 78.8ms	remaining: 1.35s
# 55:	learn: 0.3665550	total: 80.1ms	remaining: 1.35s
# 56:	learn: 0.3640929	total: 81.4ms	remaining: 1.35s
# 57:	learn: 0.3612634	total: 82.7ms	remaining: 1.34s
# 58:	learn: 0.3582127	total: 84.2ms	remaining: 1.34s
# 59:	learn: 0.3552972	total: 85.8ms	remaining: 1.34s
# 60:	learn: 0.3530168	total: 87.3ms	remaining: 1.34s
# 61:	learn: 0.3506450	total: 88.6ms	remaining: 1.34s
# 62:	learn: 0.3481932	total: 90ms	remaining: 1.34s
# 63:	learn: 0.3459311	total: 91.4ms	remaining: 1.34s
# 64:	learn: 0.3424888	total: 92.7ms	remaining: 1.33s
# 65:	learn: 0.3394934	total: 94.1ms	remaining: 1.33s
# 66:	learn: 0.3378145	total: 95.3ms	remaining: 1.33s
# 67:	learn: 0.3357881	total: 96.6ms	remaining: 1.32s
# 68:	learn: 0.3332649	total: 97.9ms	remaining: 1.32s
# 69:	learn: 0.3308336	total: 99.2ms	remaining: 1.32s
# 70:	learn: 0.3284409	total: 101ms	remaining: 1.31s
# 71:	learn: 0.3258813	total: 102ms	remaining: 1.31s
# 72:	learn: 0.3233774	total: 103ms	remaining: 1.31s
# 73:	learn: 0.3206915	total: 104ms	remaining: 1.31s
# 74:	learn: 0.3184112	total: 106ms	remaining: 1.3s
# 75:	learn: 0.3155542	total: 107ms	remaining: 1.3s
# 76:	learn: 0.3127346	total: 109ms	remaining: 1.3s
# 77:	learn: 0.3106031	total: 110ms	remaining: 1.3s
# 78:	learn: 0.3083658	total: 111ms	remaining: 1.3s
# 79:	learn: 0.3059634	total: 113ms	remaining: 1.29s
# 80:	learn: 0.3039481	total: 114ms	remaining: 1.29s
# 81:	learn: 0.3015839	total: 115ms	remaining: 1.29s
# 82:	learn: 0.2994259	total: 117ms	remaining: 1.29s
# 83:	learn: 0.2971348	total: 118ms	remaining: 1.29s
# 84:	learn: 0.2956651	total: 120ms	remaining: 1.29s
# 85:	learn: 0.2935710	total: 121ms	remaining: 1.28s
# 86:	learn: 0.2909822	total: 122ms	remaining: 1.28s
# 87:	learn: 0.2892290	total: 124ms	remaining: 1.28s
# 88:	learn: 0.2869329	total: 125ms	remaining: 1.28s
# 89:	learn: 0.2846816	total: 126ms	remaining: 1.28s
# 90:	learn: 0.2825943	total: 128ms	remaining: 1.27s
# 91:	learn: 0.2810028	total: 129ms	remaining: 1.27s
# 92:	learn: 0.2793540	total: 130ms	remaining: 1.27s
# 93:	learn: 0.2776485	total: 132ms	remaining: 1.27s
# 94:	learn: 0.2758020	total: 133ms	remaining: 1.27s
# 95:	learn: 0.2736603	total: 134ms	remaining: 1.26s
# 96:	learn: 0.2716417	total: 136ms	remaining: 1.26s
# 97:	learn: 0.2697394	total: 137ms	remaining: 1.26s
# 98:	learn: 0.2675888	total: 138ms	remaining: 1.26s
# 99:	learn: 0.2657122	total: 140ms	remaining: 1.26s
# 100:	learn: 0.2643800	total: 141ms	remaining: 1.25s
# 101:	learn: 0.2625984	total: 142ms	remaining: 1.25s
# 102:	learn: 0.2613904	total: 144ms	remaining: 1.25s
# 103:	learn: 0.2600939	total: 145ms	remaining: 1.25s
# 104:	learn: 0.2582601	total: 147ms	remaining: 1.25s
# 105:	learn: 0.2563764	total: 148ms	remaining: 1.25s
# 106:	learn: 0.2550308	total: 149ms	remaining: 1.25s
# 107:	learn: 0.2535070	total: 151ms	remaining: 1.24s
# 108:	learn: 0.2519224	total: 152ms	remaining: 1.24s
# 109:	learn: 0.2507678	total: 153ms	remaining: 1.24s
# 110:	learn: 0.2489447	total: 155ms	remaining: 1.24s
# 111:	learn: 0.2479109	total: 156ms	remaining: 1.24s
# 112:	learn: 0.2465924	total: 158ms	remaining: 1.24s
# 113:	learn: 0.2449242	total: 159ms	remaining: 1.23s
# 114:	learn: 0.2431920	total: 160ms	remaining: 1.23s
# 115:	learn: 0.2415224	total: 162ms	remaining: 1.23s
# 116:	learn: 0.2402510	total: 163ms	remaining: 1.23s
# 117:	learn: 0.2388010	total: 165ms	remaining: 1.23s
# 118:	learn: 0.2371616	total: 166ms	remaining: 1.23s
# 119:	learn: 0.2349944	total: 168ms	remaining: 1.23s
# 120:	learn: 0.2334207	total: 169ms	remaining: 1.23s
# 121:	learn: 0.2318832	total: 171ms	remaining: 1.23s
# 122:	learn: 0.2302127	total: 172ms	remaining: 1.23s
# 123:	learn: 0.2290853	total: 173ms	remaining: 1.22s
# 124:	learn: 0.2276689	total: 174ms	remaining: 1.22s
# 125:	learn: 0.2265452	total: 176ms	remaining: 1.22s
# 126:	learn: 0.2247857	total: 177ms	remaining: 1.22s
# 127:	learn: 0.2232774	total: 179ms	remaining: 1.22s
# 128:	learn: 0.2216717	total: 180ms	remaining: 1.22s
# 129:	learn: 0.2207512	total: 182ms	remaining: 1.22s
# 130:	learn: 0.2192718	total: 183ms	remaining: 1.22s
# 131:	learn: 0.2180516	total: 185ms	remaining: 1.22s
# 132:	learn: 0.2168279	total: 187ms	remaining: 1.22s
# 133:	learn: 0.2156552	total: 189ms	remaining: 1.22s
# 134:	learn: 0.2144001	total: 191ms	remaining: 1.22s
# 135:	learn: 0.2131007	total: 194ms	remaining: 1.23s
# 136:	learn: 0.2112871	total: 195ms	remaining: 1.23s
# 137:	learn: 0.2101557	total: 197ms	remaining: 1.23s
# 138:	learn: 0.2089360	total: 198ms	remaining: 1.23s
# 139:	learn: 0.2076134	total: 200ms	remaining: 1.23s
# 140:	learn: 0.2061530	total: 201ms	remaining: 1.23s
# 141:	learn: 0.2049079	total: 203ms	remaining: 1.23s
# 142:	learn: 0.2036731	total: 204ms	remaining: 1.22s
# 143:	learn: 0.2022934	total: 205ms	remaining: 1.22s
# 144:	learn: 0.2007213	total: 207ms	remaining: 1.22s
# 145:	learn: 0.1993335	total: 208ms	remaining: 1.22s
# 146:	learn: 0.1976938	total: 210ms	remaining: 1.22s
# 147:	learn: 0.1965456	total: 211ms	remaining: 1.21s
# 148:	learn: 0.1956492	total: 212ms	remaining: 1.21s
# 149:	learn: 0.1943347	total: 214ms	remaining: 1.21s
# 150:	learn: 0.1928686	total: 215ms	remaining: 1.21s
# 151:	learn: 0.1918872	total: 217ms	remaining: 1.21s
# 152:	learn: 0.1904985	total: 219ms	remaining: 1.21s
# 153:	learn: 0.1890402	total: 221ms	remaining: 1.21s
# 154:	learn: 0.1874826	total: 222ms	remaining: 1.21s
# 155:	learn: 0.1862289	total: 223ms	remaining: 1.21s
# 156:	learn: 0.1849347	total: 225ms	remaining: 1.21s
# 157:	learn: 0.1835714	total: 226ms	remaining: 1.21s
# 158:	learn: 0.1824695	total: 228ms	remaining: 1.2s
# 159:	learn: 0.1811297	total: 229ms	remaining: 1.2s
# 160:	learn: 0.1800638	total: 230ms	remaining: 1.2s
# 161:	learn: 0.1789597	total: 232ms	remaining: 1.2s
# 162:	learn: 0.1778060	total: 233ms	remaining: 1.2s
# 163:	learn: 0.1767062	total: 234ms	remaining: 1.19s
# 164:	learn: 0.1757771	total: 236ms	remaining: 1.19s
# 165:	learn: 0.1746111	total: 237ms	remaining: 1.19s
# 166:	learn: 0.1735686	total: 238ms	remaining: 1.19s
# 167:	learn: 0.1723386	total: 240ms	remaining: 1.19s
# 168:	learn: 0.1711550	total: 241ms	remaining: 1.18s
# 169:	learn: 0.1698060	total: 242ms	remaining: 1.18s
# 170:	learn: 0.1689559	total: 244ms	remaining: 1.18s
# 171:	learn: 0.1673854	total: 245ms	remaining: 1.18s
# 172:	learn: 0.1663205	total: 247ms	remaining: 1.18s
# 173:	learn: 0.1651154	total: 248ms	remaining: 1.18s
# 174:	learn: 0.1638795	total: 249ms	remaining: 1.18s
# 175:	learn: 0.1626830	total: 251ms	remaining: 1.17s
# 176:	learn: 0.1618220	total: 252ms	remaining: 1.17s
# 177:	learn: 0.1607319	total: 253ms	remaining: 1.17s
# 178:	learn: 0.1595137	total: 255ms	remaining: 1.17s
# 179:	learn: 0.1580623	total: 256ms	remaining: 1.17s
# 180:	learn: 0.1570855	total: 258ms	remaining: 1.17s
# 181:	learn: 0.1558495	total: 259ms	remaining: 1.16s
# 182:	learn: 0.1550444	total: 260ms	remaining: 1.16s
# 183:	learn: 0.1544337	total: 262ms	remaining: 1.16s
# 184:	learn: 0.1534078	total: 263ms	remaining: 1.16s
# 185:	learn: 0.1524564	total: 264ms	remaining: 1.16s
# 186:	learn: 0.1514616	total: 266ms	remaining: 1.16s
# 187:	learn: 0.1501895	total: 267ms	remaining: 1.15s
# 188:	learn: 0.1495447	total: 268ms	remaining: 1.15s
# 189:	learn: 0.1487337	total: 270ms	remaining: 1.15s
# 190:	learn: 0.1476811	total: 271ms	remaining: 1.15s
# 191:	learn: 0.1466720	total: 272ms	remaining: 1.15s
# 192:	learn: 0.1458063	total: 274ms	remaining: 1.15s
# 193:	learn: 0.1447713	total: 275ms	remaining: 1.14s
# 194:	learn: 0.1436962	total: 277ms	remaining: 1.14s
# 195:	learn: 0.1426844	total: 278ms	remaining: 1.14s
# 196:	learn: 0.1416832	total: 279ms	remaining: 1.14s
# 197:	learn: 0.1407987	total: 281ms	remaining: 1.14s
# 198:	learn: 0.1398841	total: 282ms	remaining: 1.14s
# 199:	learn: 0.1387419	total: 284ms	remaining: 1.13s
# 200:	learn: 0.1374952	total: 286ms	remaining: 1.14s
# 201:	learn: 0.1365508	total: 289ms	remaining: 1.14s
# 202:	learn: 0.1355086	total: 290ms	remaining: 1.14s
# 203:	learn: 0.1344514	total: 291ms	remaining: 1.14s
# 204:	learn: 0.1334456	total: 293ms	remaining: 1.14s
# 205:	learn: 0.1325402	total: 294ms	remaining: 1.13s
# 206:	learn: 0.1315989	total: 295ms	remaining: 1.13s
# 207:	learn: 0.1306845	total: 297ms	remaining: 1.13s
# 208:	learn: 0.1295893	total: 298ms	remaining: 1.13s
# 209:	learn: 0.1286291	total: 299ms	remaining: 1.13s
# 210:	learn: 0.1279745	total: 301ms	remaining: 1.12s
# 211:	learn: 0.1269921	total: 302ms	remaining: 1.12s
# 212:	learn: 0.1260294	total: 304ms	remaining: 1.12s
# 213:	learn: 0.1250352	total: 305ms	remaining: 1.12s
# 214:	learn: 0.1241865	total: 306ms	remaining: 1.12s
# 215:	learn: 0.1232378	total: 308ms	remaining: 1.12s
# 216:	learn: 0.1223500	total: 309ms	remaining: 1.11s
# 217:	learn: 0.1214383	total: 310ms	remaining: 1.11s
# 218:	learn: 0.1205885	total: 312ms	remaining: 1.11s
# 219:	learn: 0.1198278	total: 313ms	remaining: 1.11s
# 220:	learn: 0.1191702	total: 314ms	remaining: 1.11s
# 221:	learn: 0.1184248	total: 316ms	remaining: 1.11s
# 222:	learn: 0.1176306	total: 317ms	remaining: 1.1s
# 223:	learn: 0.1167476	total: 318ms	remaining: 1.1s
# 224:	learn: 0.1159268	total: 320ms	remaining: 1.1s
# 225:	learn: 0.1149400	total: 322ms	remaining: 1.1s
# 226:	learn: 0.1140939	total: 323ms	remaining: 1.1s
# 227:	learn: 0.1132548	total: 324ms	remaining: 1.1s
# 228:	learn: 0.1124318	total: 326ms	remaining: 1.1s
# 229:	learn: 0.1117746	total: 327ms	remaining: 1.09s
# 230:	learn: 0.1108943	total: 329ms	remaining: 1.09s
# 231:	learn: 0.1100820	total: 330ms	remaining: 1.09s
# 232:	learn: 0.1095309	total: 331ms	remaining: 1.09s
# 233:	learn: 0.1086723	total: 333ms	remaining: 1.09s
# 234:	learn: 0.1078124	total: 334ms	remaining: 1.09s
# 235:	learn: 0.1070099	total: 335ms	remaining: 1.08s
# 236:	learn: 0.1064573	total: 337ms	remaining: 1.08s
# 237:	learn: 0.1055007	total: 338ms	remaining: 1.08s
# 238:	learn: 0.1046119	total: 339ms	remaining: 1.08s
# 239:	learn: 0.1039407	total: 341ms	remaining: 1.08s
# 240:	learn: 0.1033045	total: 342ms	remaining: 1.08s
# 241:	learn: 0.1026371	total: 343ms	remaining: 1.07s
# 242:	learn: 0.1018996	total: 345ms	remaining: 1.07s
# 243:	learn: 0.1009981	total: 346ms	remaining: 1.07s
# 244:	learn: 0.1000906	total: 348ms	remaining: 1.07s
# 245:	learn: 0.0994992	total: 349ms	remaining: 1.07s
# 246:	learn: 0.0987156	total: 351ms	remaining: 1.07s
# 247:	learn: 0.0981347	total: 352ms	remaining: 1.07s
# 248:	learn: 0.0973910	total: 354ms	remaining: 1.07s
# 249:	learn: 0.0966640	total: 355ms	remaining: 1.07s
# 250:	learn: 0.0960065	total: 357ms	remaining: 1.06s
# 251:	learn: 0.0951829	total: 358ms	remaining: 1.06s
# 252:	learn: 0.0943544	total: 359ms	remaining: 1.06s
# 253:	learn: 0.0937756	total: 361ms	remaining: 1.06s
# 254:	learn: 0.0929851	total: 362ms	remaining: 1.06s
# 255:	learn: 0.0922281	total: 365ms	remaining: 1.06s
# 256:	learn: 0.0915122	total: 366ms	remaining: 1.06s
# 257:	learn: 0.0910141	total: 367ms	remaining: 1.06s
# 258:	learn: 0.0904349	total: 369ms	remaining: 1.05s
# 259:	learn: 0.0896899	total: 370ms	remaining: 1.05s
# 260:	learn: 0.0890029	total: 372ms	remaining: 1.05s
# 261:	learn: 0.0882487	total: 373ms	remaining: 1.05s
# 262:	learn: 0.0877285	total: 375ms	remaining: 1.05s
# 263:	learn: 0.0872461	total: 376ms	remaining: 1.05s
# 264:	learn: 0.0866584	total: 377ms	remaining: 1.05s
# 265:	learn: 0.0860342	total: 379ms	remaining: 1.04s
# 266:	learn: 0.0854420	total: 380ms	remaining: 1.04s
# 267:	learn: 0.0846933	total: 382ms	remaining: 1.04s
# 268:	learn: 0.0839737	total: 383ms	remaining: 1.04s
# 269:	learn: 0.0833120	total: 385ms	remaining: 1.04s
# 270:	learn: 0.0825903	total: 387ms	remaining: 1.04s
# 271:	learn: 0.0820257	total: 388ms	remaining: 1.04s
# 272:	learn: 0.0815214	total: 390ms	remaining: 1.04s
# 273:	learn: 0.0807751	total: 394ms	remaining: 1.04s
# 274:	learn: 0.0800494	total: 396ms	remaining: 1.04s
# 275:	learn: 0.0793887	total: 397ms	remaining: 1.04s
# 276:	learn: 0.0788910	total: 399ms	remaining: 1.04s
# 277:	learn: 0.0784025	total: 400ms	remaining: 1.04s
# 278:	learn: 0.0777462	total: 402ms	remaining: 1.04s
# 279:	learn: 0.0771211	total: 403ms	remaining: 1.04s
# 280:	learn: 0.0765989	total: 404ms	remaining: 1.03s
# 281:	learn: 0.0761361	total: 406ms	remaining: 1.03s
# 282:	learn: 0.0754426	total: 407ms	remaining: 1.03s
# 283:	learn: 0.0749705	total: 408ms	remaining: 1.03s
# 284:	learn: 0.0743814	total: 410ms	remaining: 1.03s
# 285:	learn: 0.0737478	total: 412ms	remaining: 1.03s
# 286:	learn: 0.0732516	total: 414ms	remaining: 1.03s
# 287:	learn: 0.0726150	total: 415ms	remaining: 1.03s
# 288:	learn: 0.0719916	total: 417ms	remaining: 1.02s
# 289:	learn: 0.0714114	total: 418ms	remaining: 1.02s
# 290:	learn: 0.0708557	total: 420ms	remaining: 1.02s
# 291:	learn: 0.0702585	total: 421ms	remaining: 1.02s
# 292:	learn: 0.0696779	total: 422ms	remaining: 1.02s
# 293:	learn: 0.0693307	total: 424ms	remaining: 1.02s
# 294:	learn: 0.0687508	total: 425ms	remaining: 1.01s
# 295:	learn: 0.0681693	total: 427ms	remaining: 1.01s
# 296:	learn: 0.0677616	total: 428ms	remaining: 1.01s
# 297:	learn: 0.0671407	total: 430ms	remaining: 1.01s
# 298:	learn: 0.0667885	total: 431ms	remaining: 1.01s
# 299:	learn: 0.0663040	total: 433ms	remaining: 1.01s
# 300:	learn: 0.0657874	total: 434ms	remaining: 1.01s
# 301:	learn: 0.0652739	total: 436ms	remaining: 1.01s
# 302:	learn: 0.0647991	total: 437ms	remaining: 1s
# 303:	learn: 0.0642711	total: 438ms	remaining: 1s
# 304:	learn: 0.0637521	total: 440ms	remaining: 1s
# 305:	learn: 0.0633296	total: 441ms	remaining: 1s
# 306:	learn: 0.0628053	total: 443ms	remaining: 1s
# 307:	learn: 0.0622445	total: 445ms	remaining: 999ms
# 308:	learn: 0.0617705	total: 446ms	remaining: 998ms
# 309:	learn: 0.0612255	total: 448ms	remaining: 996ms
# 310:	learn: 0.0606967	total: 449ms	remaining: 995ms
# 311:	learn: 0.0602582	total: 451ms	remaining: 994ms
# 312:	learn: 0.0598211	total: 452ms	remaining: 992ms
# 313:	learn: 0.0593715	total: 453ms	remaining: 990ms
# 314:	learn: 0.0588439	total: 455ms	remaining: 988ms
# 315:	learn: 0.0583351	total: 456ms	remaining: 987ms
# 316:	learn: 0.0578945	total: 458ms	remaining: 986ms
# 317:	learn: 0.0574849	total: 459ms	remaining: 985ms
# 318:	learn: 0.0570609	total: 461ms	remaining: 983ms
# 319:	learn: 0.0565997	total: 462ms	remaining: 983ms
# 320:	learn: 0.0561808	total: 464ms	remaining: 981ms
# 321:	learn: 0.0557716	total: 465ms	remaining: 980ms
# 322:	learn: 0.0553636	total: 466ms	remaining: 978ms
# 323:	learn: 0.0549217	total: 468ms	remaining: 976ms
# 324:	learn: 0.0544778	total: 469ms	remaining: 975ms
# 325:	learn: 0.0540425	total: 471ms	remaining: 973ms
# 326:	learn: 0.0536132	total: 472ms	remaining: 971ms
# 327:	learn: 0.0532201	total: 474ms	remaining: 971ms
# 328:	learn: 0.0527987	total: 475ms	remaining: 970ms
# 329:	learn: 0.0524162	total: 477ms	remaining: 968ms
# 330:	learn: 0.0520333	total: 478ms	remaining: 967ms
# 331:	learn: 0.0516278	total: 480ms	remaining: 965ms
# 332:	learn: 0.0512298	total: 481ms	remaining: 963ms
# 333:	learn: 0.0508720	total: 482ms	remaining: 962ms
# 334:	learn: 0.0505142	total: 484ms	remaining: 960ms
# 335:	learn: 0.0501182	total: 486ms	remaining: 960ms
# 336:	learn: 0.0497705	total: 487ms	remaining: 958ms
# 337:	learn: 0.0493630	total: 488ms	remaining: 957ms
# 338:	learn: 0.0489400	total: 490ms	remaining: 955ms
# 339:	learn: 0.0485606	total: 491ms	remaining: 953ms
# 340:	learn: 0.0482166	total: 493ms	remaining: 952ms
# 341:	learn: 0.0478492	total: 494ms	remaining: 950ms
# 342:	learn: 0.0474740	total: 495ms	remaining: 949ms
# 343:	learn: 0.0470737	total: 497ms	remaining: 947ms
# 344:	learn: 0.0467133	total: 498ms	remaining: 946ms
# 345:	learn: 0.0463771	total: 499ms	remaining: 944ms
# 346:	learn: 0.0460248	total: 501ms	remaining: 943ms
# 347:	learn: 0.0456726	total: 503ms	remaining: 942ms
# 348:	learn: 0.0453296	total: 505ms	remaining: 941ms
# 349:	learn: 0.0450233	total: 506ms	remaining: 940ms
# 350:	learn: 0.0446888	total: 508ms	remaining: 939ms
# 351:	learn: 0.0443628	total: 509ms	remaining: 937ms
# 352:	learn: 0.0440543	total: 510ms	remaining: 935ms
# 353:	learn: 0.0437594	total: 512ms	remaining: 934ms
# 354:	learn: 0.0434381	total: 514ms	remaining: 933ms
# 355:	learn: 0.0431085	total: 516ms	remaining: 933ms
# 356:	learn: 0.0427807	total: 518ms	remaining: 933ms
# 357:	learn: 0.0424974	total: 520ms	remaining: 932ms
# 358:	learn: 0.0421512	total: 521ms	remaining: 931ms
# 359:	learn: 0.0418420	total: 523ms	remaining: 929ms
# 360:	learn: 0.0416486	total: 524ms	remaining: 928ms
# 361:	learn: 0.0413719	total: 526ms	remaining: 926ms
# 362:	learn: 0.0410373	total: 527ms	remaining: 925ms
# 363:	learn: 0.0407712	total: 528ms	remaining: 923ms
# 364:	learn: 0.0405973	total: 530ms	remaining: 922ms
# 365:	learn: 0.0402772	total: 531ms	remaining: 920ms
# 366:	learn: 0.0400063	total: 533ms	remaining: 919ms
# 367:	learn: 0.0397067	total: 534ms	remaining: 918ms
# 368:	learn: 0.0394099	total: 536ms	remaining: 916ms
# 369:	learn: 0.0391475	total: 537ms	remaining: 915ms
# 370:	learn: 0.0389817	total: 539ms	remaining: 913ms
# 371:	learn: 0.0386781	total: 540ms	remaining: 912ms
# 372:	learn: 0.0385157	total: 542ms	remaining: 910ms
# 373:	learn: 0.0382698	total: 543ms	remaining: 909ms
# 374:	learn: 0.0379736	total: 544ms	remaining: 907ms
# 375:	learn: 0.0377326	total: 546ms	remaining: 906ms
# 376:	learn: 0.0375757	total: 548ms	remaining: 905ms
# 377:	learn: 0.0373304	total: 549ms	remaining: 903ms
# 378:	learn: 0.0370215	total: 550ms	remaining: 902ms
# 379:	learn: 0.0367303	total: 552ms	remaining: 900ms
# 380:	learn: 0.0364427	total: 553ms	remaining: 899ms
# 381:	learn: 0.0361639	total: 555ms	remaining: 898ms
# 382:	learn: 0.0358978	total: 556ms	remaining: 896ms
# 383:	learn: 0.0356526	total: 558ms	remaining: 895ms
# 384:	learn: 0.0353755	total: 559ms	remaining: 893ms
# 385:	learn: 0.0351526	total: 561ms	remaining: 892ms
# 386:	learn: 0.0350089	total: 562ms	remaining: 891ms
# 387:	learn: 0.0347895	total: 564ms	remaining: 889ms
# 388:	learn: 0.0345364	total: 565ms	remaining: 887ms
# 389:	learn: 0.0343016	total: 566ms	remaining: 886ms
# 390:	learn: 0.0340914	total: 568ms	remaining: 884ms
# 391:	learn: 0.0338333	total: 569ms	remaining: 882ms
# 392:	learn: 0.0336102	total: 570ms	remaining: 881ms
# 393:	learn: 0.0334051	total: 572ms	remaining: 879ms
# 394:	learn: 0.0331799	total: 574ms	remaining: 879ms
# 395:	learn: 0.0329370	total: 576ms	remaining: 879ms
# 396:	learn: 0.0327372	total: 580ms	remaining: 880ms
# 397:	learn: 0.0325356	total: 582ms	remaining: 881ms
# 398:	learn: 0.0322948	total: 584ms	remaining: 879ms
# 399:	learn: 0.0320216	total: 585ms	remaining: 878ms
# 400:	learn: 0.0318227	total: 586ms	remaining: 876ms
# 401:	learn: 0.0316825	total: 588ms	remaining: 874ms
# 402:	learn: 0.0314170	total: 589ms	remaining: 873ms
# 403:	learn: 0.0311981	total: 590ms	remaining: 871ms
# 404:	learn: 0.0309479	total: 591ms	remaining: 869ms
# 405:	learn: 0.0307399	total: 593ms	remaining: 867ms
# 406:	learn: 0.0305335	total: 594ms	remaining: 865ms
# 407:	learn: 0.0302911	total: 595ms	remaining: 864ms
# 408:	learn: 0.0300813	total: 597ms	remaining: 862ms
# 409:	learn: 0.0298998	total: 598ms	remaining: 860ms
# 410:	learn: 0.0296940	total: 599ms	remaining: 859ms
# 411:	learn: 0.0294586	total: 600ms	remaining: 857ms
# 412:	learn: 0.0292570	total: 602ms	remaining: 855ms
# 413:	learn: 0.0290633	total: 603ms	remaining: 853ms
# 414:	learn: 0.0288347	total: 604ms	remaining: 851ms
# 415:	learn: 0.0286384	total: 606ms	remaining: 851ms
# 416:	learn: 0.0284482	total: 608ms	remaining: 850ms
# 417:	learn: 0.0283694	total: 609ms	remaining: 848ms
# 418:	learn: 0.0282916	total: 610ms	remaining: 846ms
# 419:	learn: 0.0280838	total: 612ms	remaining: 845ms
# 420:	learn: 0.0278979	total: 613ms	remaining: 843ms
# 421:	learn: 0.0277011	total: 614ms	remaining: 841ms
# 422:	learn: 0.0275185	total: 615ms	remaining: 839ms
# 423:	learn: 0.0273372	total: 616ms	remaining: 837ms
# 424:	learn: 0.0272626	total: 618ms	remaining: 836ms
# 425:	learn: 0.0270640	total: 619ms	remaining: 834ms
# 426:	learn: 0.0268749	total: 620ms	remaining: 832ms
# 427:	learn: 0.0266992	total: 621ms	remaining: 830ms
# 428:	learn: 0.0265257	total: 622ms	remaining: 829ms
# 429:	learn: 0.0264365	total: 624ms	remaining: 827ms
# 430:	learn: 0.0263488	total: 625ms	remaining: 825ms
# 431:	learn: 0.0261361	total: 626ms	remaining: 823ms
# 432:	learn: 0.0259263	total: 628ms	remaining: 822ms
# 433:	learn: 0.0257256	total: 629ms	remaining: 820ms
# 434:	learn: 0.0255481	total: 630ms	remaining: 818ms
# 435:	learn: 0.0253820	total: 631ms	remaining: 817ms
# 436:	learn: 0.0252182	total: 633ms	remaining: 815ms
# 437:	learn: 0.0251353	total: 634ms	remaining: 813ms
# 438:	learn: 0.0250462	total: 635ms	remaining: 812ms
# 439:	learn: 0.0248961	total: 636ms	remaining: 810ms
# 440:	learn: 0.0247345	total: 638ms	remaining: 808ms
# 441:	learn: 0.0245874	total: 639ms	remaining: 807ms
# 442:	learn: 0.0244287	total: 640ms	remaining: 805ms
# 443:	learn: 0.0242696	total: 641ms	remaining: 803ms
# 444:	learn: 0.0241993	total: 643ms	remaining: 801ms
# 445:	learn: 0.0240562	total: 644ms	remaining: 800ms
# 446:	learn: 0.0239077	total: 645ms	remaining: 798ms
# 447:	learn: 0.0237672	total: 646ms	remaining: 797ms
# 448:	learn: 0.0236264	total: 648ms	remaining: 795ms
# 449:	learn: 0.0234811	total: 649ms	remaining: 793ms
# 450:	learn: 0.0233428	total: 650ms	remaining: 792ms
# 451:	learn: 0.0231935	total: 651ms	remaining: 790ms
# 452:	learn: 0.0230459	total: 653ms	remaining: 788ms
# 453:	learn: 0.0229051	total: 654ms	remaining: 787ms
# 454:	learn: 0.0227727	total: 655ms	remaining: 785ms
# 455:	learn: 0.0225920	total: 656ms	remaining: 783ms
# 456:	learn: 0.0224546	total: 658ms	remaining: 781ms
# 457:	learn: 0.0223242	total: 659ms	remaining: 780ms
# 458:	learn: 0.0221747	total: 660ms	remaining: 778ms
# 459:	learn: 0.0220292	total: 661ms	remaining: 776ms
# 460:	learn: 0.0218596	total: 663ms	remaining: 775ms
# 461:	learn: 0.0216997	total: 664ms	remaining: 773ms
# 462:	learn: 0.0215790	total: 665ms	remaining: 771ms
# 463:	learn: 0.0215224	total: 666ms	remaining: 770ms
# 464:	learn: 0.0214037	total: 668ms	remaining: 768ms
# 465:	learn: 0.0213416	total: 669ms	remaining: 766ms
# 466:	learn: 0.0212734	total: 670ms	remaining: 765ms
# 467:	learn: 0.0211388	total: 671ms	remaining: 763ms
# 468:	learn: 0.0210786	total: 672ms	remaining: 761ms
# 469:	learn: 0.0209504	total: 674ms	remaining: 760ms
# 470:	learn: 0.0208186	total: 675ms	remaining: 758ms
# 471:	learn: 0.0206843	total: 676ms	remaining: 756ms
# 472:	learn: 0.0206315	total: 677ms	remaining: 755ms
# 473:	learn: 0.0204831	total: 679ms	remaining: 753ms
# 474:	learn: 0.0203808	total: 680ms	remaining: 751ms
# 475:	learn: 0.0202702	total: 681ms	remaining: 750ms
# 476:	learn: 0.0201700	total: 682ms	remaining: 748ms
# 477:	learn: 0.0200475	total: 684ms	remaining: 747ms
# 478:	learn: 0.0199273	total: 685ms	remaining: 745ms
# 479:	learn: 0.0198068	total: 686ms	remaining: 743ms
# 480:	learn: 0.0196669	total: 687ms	remaining: 742ms
# 481:	learn: 0.0195706	total: 689ms	remaining: 741ms
# 482:	learn: 0.0194457	total: 691ms	remaining: 739ms
# 483:	learn: 0.0193287	total: 693ms	remaining: 739ms
# 484:	learn: 0.0192260	total: 694ms	remaining: 737ms
# 485:	learn: 0.0191042	total: 696ms	remaining: 736ms
# 486:	learn: 0.0190039	total: 697ms	remaining: 734ms
# 487:	learn: 0.0188921	total: 698ms	remaining: 732ms
# 488:	learn: 0.0187737	total: 699ms	remaining: 731ms
# 489:	learn: 0.0186638	total: 700ms	remaining: 729ms
# 490:	learn: 0.0185338	total: 702ms	remaining: 728ms
# 491:	learn: 0.0184231	total: 703ms	remaining: 726ms
# 492:	learn: 0.0182950	total: 704ms	remaining: 724ms
# 493:	learn: 0.0181818	total: 706ms	remaining: 723ms
# 494:	learn: 0.0180854	total: 707ms	remaining: 721ms
# 495:	learn: 0.0179920	total: 708ms	remaining: 719ms
# 496:	learn: 0.0178851	total: 709ms	remaining: 718ms
# 497:	learn: 0.0177696	total: 711ms	remaining: 716ms
# 498:	learn: 0.0176663	total: 712ms	remaining: 715ms
# 499:	learn: 0.0176150	total: 713ms	remaining: 713ms
# 500:	learn: 0.0175108	total: 714ms	remaining: 711ms
# 501:	learn: 0.0174079	total: 715ms	remaining: 710ms
# 502:	learn: 0.0173070	total: 717ms	remaining: 708ms
# 503:	learn: 0.0172076	total: 718ms	remaining: 706ms
# 504:	learn: 0.0170894	total: 719ms	remaining: 705ms
# 505:	learn: 0.0169909	total: 720ms	remaining: 703ms
# 506:	learn: 0.0168941	total: 722ms	remaining: 702ms
# 507:	learn: 0.0167855	total: 723ms	remaining: 700ms
# 508:	learn: 0.0166872	total: 724ms	remaining: 698ms
# 509:	learn: 0.0165807	total: 725ms	remaining: 697ms
# 510:	learn: 0.0164801	total: 727ms	remaining: 695ms
# 511:	learn: 0.0163854	total: 728ms	remaining: 694ms
# 512:	learn: 0.0162899	total: 729ms	remaining: 692ms
# 513:	learn: 0.0161978	total: 730ms	remaining: 691ms
# 514:	learn: 0.0161155	total: 732ms	remaining: 689ms
# 515:	learn: 0.0160087	total: 733ms	remaining: 687ms
# 516:	learn: 0.0159181	total: 734ms	remaining: 686ms
# 517:	learn: 0.0158274	total: 735ms	remaining: 684ms
# 518:	learn: 0.0157359	total: 737ms	remaining: 683ms
# 519:	learn: 0.0156470	total: 738ms	remaining: 681ms
# 520:	learn: 0.0155758	total: 739ms	remaining: 680ms
# 521:	learn: 0.0154652	total: 740ms	remaining: 678ms
# 522:	learn: 0.0153585	total: 742ms	remaining: 677ms
# 523:	learn: 0.0152433	total: 743ms	remaining: 675ms
# 524:	learn: 0.0152001	total: 744ms	remaining: 673ms
# 525:	learn: 0.0150931	total: 746ms	remaining: 672ms
# 526:	learn: 0.0149895	total: 747ms	remaining: 670ms
# 527:	learn: 0.0149085	total: 748ms	remaining: 669ms
# 528:	learn: 0.0148044	total: 749ms	remaining: 667ms
# 529:	learn: 0.0147033	total: 751ms	remaining: 666ms
# 530:	learn: 0.0146036	total: 752ms	remaining: 664ms
# 531:	learn: 0.0145250	total: 753ms	remaining: 662ms
# 532:	learn: 0.0144190	total: 754ms	remaining: 661ms
# 533:	learn: 0.0143192	total: 755ms	remaining: 659ms
# 534:	learn: 0.0142225	total: 757ms	remaining: 658ms
# 535:	learn: 0.0141170	total: 758ms	remaining: 656ms
# 536:	learn: 0.0140328	total: 759ms	remaining: 655ms
# 537:	learn: 0.0139166	total: 760ms	remaining: 653ms
# 538:	learn: 0.0138487	total: 762ms	remaining: 651ms
# 539:	learn: 0.0137831	total: 763ms	remaining: 650ms
# 540:	learn: 0.0136701	total: 764ms	remaining: 648ms
# 541:	learn: 0.0136041	total: 765ms	remaining: 647ms
# 542:	learn: 0.0135402	total: 767ms	remaining: 645ms
# 543:	learn: 0.0134724	total: 768ms	remaining: 644ms
# 544:	learn: 0.0133617	total: 769ms	remaining: 642ms
# 545:	learn: 0.0132794	total: 771ms	remaining: 641ms
# 546:	learn: 0.0131824	total: 774ms	remaining: 641ms
# 547:	learn: 0.0130850	total: 775ms	remaining: 639ms
# 548:	learn: 0.0129905	total: 777ms	remaining: 638ms
# 549:	learn: 0.0128851	total: 778ms	remaining: 636ms
# 550:	learn: 0.0127921	total: 779ms	remaining: 635ms
# 551:	learn: 0.0126991	total: 780ms	remaining: 633ms
# 552:	learn: 0.0126081	total: 782ms	remaining: 632ms
# 553:	learn: 0.0125601	total: 783ms	remaining: 630ms
# 554:	learn: 0.0124678	total: 784ms	remaining: 629ms
# 555:	learn: 0.0123938	total: 785ms	remaining: 627ms
# 556:	learn: 0.0123469	total: 786ms	remaining: 625ms
# 557:	learn: 0.0122594	total: 788ms	remaining: 624ms
# 558:	learn: 0.0121711	total: 789ms	remaining: 622ms
# 559:	learn: 0.0120943	total: 790ms	remaining: 621ms
# 560:	learn: 0.0120233	total: 791ms	remaining: 619ms
# 561:	learn: 0.0119454	total: 793ms	remaining: 618ms
# 562:	learn: 0.0119006	total: 794ms	remaining: 616ms
# 563:	learn: 0.0118132	total: 795ms	remaining: 615ms
# 564:	learn: 0.0117393	total: 797ms	remaining: 614ms
# 565:	learn: 0.0116641	total: 799ms	remaining: 613ms
# 566:	learn: 0.0115899	total: 801ms	remaining: 611ms
# 567:	learn: 0.0115073	total: 802ms	remaining: 610ms
# 568:	learn: 0.0114233	total: 803ms	remaining: 608ms
# 569:	learn: 0.0113485	total: 804ms	remaining: 607ms
# 570:	learn: 0.0113185	total: 806ms	remaining: 605ms
# 571:	learn: 0.0112385	total: 807ms	remaining: 604ms
# 572:	learn: 0.0111639	total: 808ms	remaining: 602ms
# 573:	learn: 0.0110848	total: 809ms	remaining: 601ms
# 574:	learn: 0.0110069	total: 811ms	remaining: 599ms
# 575:	learn: 0.0109354	total: 812ms	remaining: 598ms
# 576:	learn: 0.0108741	total: 813ms	remaining: 596ms
# 577:	learn: 0.0107984	total: 815ms	remaining: 595ms
# 578:	learn: 0.0107269	total: 816ms	remaining: 593ms
# 579:	learn: 0.0106578	total: 817ms	remaining: 592ms
# 580:	learn: 0.0105985	total: 818ms	remaining: 590ms
# 581:	learn: 0.0105437	total: 820ms	remaining: 589ms
# 582:	learn: 0.0105160	total: 821ms	remaining: 587ms
# 583:	learn: 0.0104466	total: 822ms	remaining: 586ms
# 584:	learn: 0.0103781	total: 824ms	remaining: 584ms
# 585:	learn: 0.0103116	total: 825ms	remaining: 583ms
# 586:	learn: 0.0102434	total: 826ms	remaining: 581ms
# 587:	learn: 0.0101938	total: 827ms	remaining: 580ms
# 588:	learn: 0.0101203	total: 828ms	remaining: 578ms
# 589:	learn: 0.0100477	total: 830ms	remaining: 577ms
# 590:	learn: 0.0099627	total: 831ms	remaining: 575ms
# 591:	learn: 0.0099366	total: 832ms	remaining: 574ms
# 592:	learn: 0.0098656	total: 833ms	remaining: 572ms
# 593:	learn: 0.0098215	total: 835ms	remaining: 570ms
# 594:	learn: 0.0097574	total: 836ms	remaining: 569ms
# 595:	learn: 0.0096940	total: 837ms	remaining: 567ms
# 596:	learn: 0.0096320	total: 838ms	remaining: 566ms
# 597:	learn: 0.0095735	total: 840ms	remaining: 564ms
# 598:	learn: 0.0095054	total: 841ms	remaining: 563ms
# 599:	learn: 0.0094806	total: 842ms	remaining: 561ms
# 600:	learn: 0.0094281	total: 843ms	remaining: 560ms
# 601:	learn: 0.0093593	total: 845ms	remaining: 558ms
# 602:	learn: 0.0092987	total: 846ms	remaining: 557ms
# 603:	learn: 0.0092280	total: 847ms	remaining: 555ms
# 604:	learn: 0.0091674	total: 848ms	remaining: 554ms
# 605:	learn: 0.0090976	total: 850ms	remaining: 552ms
# 606:	learn: 0.0090681	total: 851ms	remaining: 551ms
# 607:	learn: 0.0089898	total: 852ms	remaining: 549ms
# 608:	learn: 0.0089313	total: 853ms	remaining: 548ms
# 609:	learn: 0.0089082	total: 855ms	remaining: 546ms
# 610:	learn: 0.0088408	total: 856ms	remaining: 545ms
# 611:	learn: 0.0087837	total: 857ms	remaining: 543ms
# 612:	learn: 0.0087423	total: 858ms	remaining: 542ms
# 613:	learn: 0.0086757	total: 860ms	remaining: 540ms
# 614:	learn: 0.0086101	total: 861ms	remaining: 539ms
# 615:	learn: 0.0085524	total: 862ms	remaining: 537ms
# 616:	learn: 0.0084977	total: 863ms	remaining: 536ms
# 617:	learn: 0.0084439	total: 865ms	remaining: 534ms
# 618:	learn: 0.0083876	total: 866ms	remaining: 533ms
# 619:	learn: 0.0083371	total: 867ms	remaining: 531ms
# 620:	learn: 0.0082874	total: 868ms	remaining: 530ms
# 621:	learn: 0.0082386	total: 870ms	remaining: 528ms
# 622:	learn: 0.0081803	total: 871ms	remaining: 527ms
# 623:	learn: 0.0081516	total: 872ms	remaining: 526ms
# 624:	learn: 0.0080973	total: 874ms	remaining: 524ms
# 625:	learn: 0.0080500	total: 875ms	remaining: 523ms
# 626:	learn: 0.0080058	total: 876ms	remaining: 521ms
# 627:	learn: 0.0079596	total: 878ms	remaining: 520ms
# 628:	learn: 0.0079077	total: 879ms	remaining: 518ms
# 629:	learn: 0.0078647	total: 880ms	remaining: 517ms
# 630:	learn: 0.0078062	total: 881ms	remaining: 515ms
# 631:	learn: 0.0077487	total: 883ms	remaining: 514ms
# 632:	learn: 0.0076924	total: 884ms	remaining: 513ms
# 633:	learn: 0.0076534	total: 885ms	remaining: 511ms
# 634:	learn: 0.0076268	total: 887ms	remaining: 510ms
# 635:	learn: 0.0075770	total: 888ms	remaining: 508ms
# 636:	learn: 0.0075252	total: 889ms	remaining: 507ms
# 637:	learn: 0.0074818	total: 890ms	remaining: 505ms
# 638:	learn: 0.0074392	total: 892ms	remaining: 504ms
# 639:	learn: 0.0073912	total: 893ms	remaining: 502ms
# 640:	learn: 0.0073660	total: 894ms	remaining: 501ms
# 641:	learn: 0.0073161	total: 896ms	remaining: 499ms
# 642:	learn: 0.0072684	total: 897ms	remaining: 498ms
# 643:	learn: 0.0072219	total: 898ms	remaining: 496ms
# 644:	learn: 0.0071976	total: 899ms	remaining: 495ms
# 645:	learn: 0.0071485	total: 900ms	remaining: 493ms
# 646:	learn: 0.0070955	total: 902ms	remaining: 492ms
# 647:	learn: 0.0070428	total: 903ms	remaining: 490ms
# 648:	learn: 0.0069961	total: 904ms	remaining: 489ms
# 649:	learn: 0.0069453	total: 906ms	remaining: 488ms
# 650:	learn: 0.0068985	total: 907ms	remaining: 486ms
# 651:	learn: 0.0068524	total: 908ms	remaining: 485ms
# 652:	learn: 0.0068026	total: 909ms	remaining: 483ms
# 653:	learn: 0.0067569	total: 910ms	remaining: 482ms
# 654:	learn: 0.0067102	total: 912ms	remaining: 480ms
# 655:	learn: 0.0066622	total: 913ms	remaining: 479ms
# 656:	learn: 0.0066186	total: 914ms	remaining: 477ms
# 657:	learn: 0.0065745	total: 915ms	remaining: 476ms
# 658:	learn: 0.0065320	total: 917ms	remaining: 474ms
# 659:	learn: 0.0064850	total: 918ms	remaining: 473ms
# 660:	learn: 0.0064634	total: 919ms	remaining: 472ms
# 661:	learn: 0.0064250	total: 921ms	remaining: 470ms
# 662:	learn: 0.0064039	total: 922ms	remaining: 469ms
# 663:	learn: 0.0063611	total: 923ms	remaining: 467ms
# 664:	learn: 0.0063217	total: 925ms	remaining: 466ms
# 665:	learn: 0.0062798	total: 926ms	remaining: 464ms
# 666:	learn: 0.0062399	total: 928ms	remaining: 463ms
# 667:	learn: 0.0062015	total: 929ms	remaining: 462ms
# 668:	learn: 0.0061626	total: 930ms	remaining: 460ms
# 669:	learn: 0.0061157	total: 932ms	remaining: 459ms
# 670:	learn: 0.0060791	total: 933ms	remaining: 457ms
# 671:	learn: 0.0060429	total: 934ms	remaining: 456ms
# 672:	learn: 0.0059981	total: 935ms	remaining: 454ms
# 673:	learn: 0.0059585	total: 936ms	remaining: 453ms
# 674:	learn: 0.0059152	total: 938ms	remaining: 452ms
# 675:	learn: 0.0058802	total: 939ms	remaining: 450ms
# 676:	learn: 0.0058427	total: 940ms	remaining: 449ms
# 677:	learn: 0.0058072	total: 941ms	remaining: 447ms
# 678:	learn: 0.0057694	total: 943ms	remaining: 446ms
# 679:	learn: 0.0057291	total: 944ms	remaining: 444ms
# 680:	learn: 0.0056940	total: 945ms	remaining: 443ms
# 681:	learn: 0.0056550	total: 946ms	remaining: 441ms
# 682:	learn: 0.0056146	total: 947ms	remaining: 440ms
# 683:	learn: 0.0055780	total: 949ms	remaining: 438ms
# 684:	learn: 0.0055385	total: 950ms	remaining: 437ms
# 685:	learn: 0.0055025	total: 951ms	remaining: 435ms
# 686:	learn: 0.0054668	total: 952ms	remaining: 434ms
# 687:	learn: 0.0054317	total: 954ms	remaining: 432ms
# 688:	learn: 0.0053966	total: 955ms	remaining: 431ms
# 689:	learn: 0.0053610	total: 956ms	remaining: 430ms
# 690:	learn: 0.0053265	total: 957ms	remaining: 428ms
# 691:	learn: 0.0052925	total: 959ms	remaining: 427ms
# 692:	learn: 0.0052599	total: 960ms	remaining: 425ms
# 693:	learn: 0.0052274	total: 961ms	remaining: 424ms
# 694:	learn: 0.0051887	total: 964ms	remaining: 423ms
# 695:	learn: 0.0051579	total: 965ms	remaining: 422ms
# 696:	learn: 0.0051159	total: 967ms	remaining: 420ms
# 697:	learn: 0.0050825	total: 968ms	remaining: 419ms
# 698:	learn: 0.0050466	total: 969ms	remaining: 417ms
# 699:	learn: 0.0050155	total: 971ms	remaining: 416ms
# 700:	learn: 0.0049810	total: 972ms	remaining: 415ms
# 701:	learn: 0.0049466	total: 973ms	remaining: 413ms
# 702:	learn: 0.0049065	total: 974ms	remaining: 412ms
# 703:	learn: 0.0048737	total: 976ms	remaining: 410ms
# 704:	learn: 0.0048370	total: 977ms	remaining: 409ms
# 705:	learn: 0.0048037	total: 978ms	remaining: 407ms
# 706:	learn: 0.0047709	total: 979ms	remaining: 406ms
# 707:	learn: 0.0047443	total: 981ms	remaining: 404ms
# 708:	learn: 0.0047124	total: 982ms	remaining: 403ms
# 709:	learn: 0.0046806	total: 983ms	remaining: 402ms
# 710:	learn: 0.0046494	total: 984ms	remaining: 400ms
# 711:	learn: 0.0046178	total: 986ms	remaining: 399ms
# 712:	learn: 0.0045839	total: 987ms	remaining: 397ms
# 713:	learn: 0.0045534	total: 989ms	remaining: 396ms
# 714:	learn: 0.0045238	total: 991ms	remaining: 395ms
# 715:	learn: 0.0044939	total: 993ms	remaining: 394ms
# 716:	learn: 0.0044556	total: 994ms	remaining: 392ms
# 717:	learn: 0.0044176	total: 996ms	remaining: 391ms
# 718:	learn: 0.0043886	total: 997ms	remaining: 390ms
# 719:	learn: 0.0043539	total: 998ms	remaining: 388ms
# 720:	learn: 0.0043274	total: 1000ms	remaining: 387ms
# 721:	learn: 0.0043014	total: 1s	remaining: 385ms
# 722:	learn: 0.0042759	total: 1s	remaining: 384ms
# 723:	learn: 0.0042612	total: 1s	remaining: 383ms
# 724:	learn: 0.0042489	total: 1s	remaining: 381ms
# 725:	learn: 0.0042205	total: 1.01s	remaining: 380ms
# 726:	learn: 0.0041928	total: 1.01s	remaining: 378ms
# 727:	learn: 0.0041651	total: 1.01s	remaining: 377ms
# 728:	learn: 0.0041399	total: 1.01s	remaining: 375ms
# 729:	learn: 0.0041129	total: 1.01s	remaining: 374ms
# 730:	learn: 0.0040880	total: 1.01s	remaining: 373ms
# 731:	learn: 0.0040615	total: 1.01s	remaining: 371ms
# 732:	learn: 0.0040272	total: 1.01s	remaining: 370ms
# 733:	learn: 0.0039988	total: 1.02s	remaining: 368ms
# 734:	learn: 0.0039711	total: 1.02s	remaining: 367ms
# 735:	learn: 0.0039596	total: 1.02s	remaining: 365ms
# 736:	learn: 0.0039401	total: 1.02s	remaining: 364ms
# 737:	learn: 0.0039160	total: 1.02s	remaining: 363ms
# 738:	learn: 0.0038971	total: 1.02s	remaining: 361ms
# 739:	learn: 0.0038735	total: 1.02s	remaining: 360ms
# 740:	learn: 0.0038501	total: 1.02s	remaining: 358ms
# 741:	learn: 0.0038270	total: 1.03s	remaining: 357ms
# 742:	learn: 0.0038161	total: 1.03s	remaining: 355ms
# 743:	learn: 0.0037914	total: 1.03s	remaining: 354ms
# 744:	learn: 0.0037664	total: 1.03s	remaining: 353ms
# 745:	learn: 0.0037439	total: 1.03s	remaining: 351ms
# 746:	learn: 0.0037217	total: 1.03s	remaining: 350ms
# 747:	learn: 0.0037006	total: 1.03s	remaining: 348ms
# 748:	learn: 0.0036839	total: 1.03s	remaining: 347ms
# 749:	learn: 0.0036620	total: 1.04s	remaining: 345ms
# 750:	learn: 0.0036356	total: 1.04s	remaining: 344ms
# 751:	learn: 0.0036096	total: 1.04s	remaining: 343ms
# 752:	learn: 0.0035846	total: 1.04s	remaining: 341ms
# 753:	learn: 0.0035676	total: 1.04s	remaining: 340ms
# 754:	learn: 0.0035471	total: 1.04s	remaining: 338ms
# 755:	learn: 0.0035268	total: 1.04s	remaining: 337ms
# 756:	learn: 0.0034980	total: 1.04s	remaining: 335ms
# 757:	learn: 0.0034815	total: 1.04s	remaining: 334ms
# 758:	learn: 0.0034574	total: 1.05s	remaining: 333ms
# 759:	learn: 0.0034355	total: 1.05s	remaining: 331ms
# 760:	learn: 0.0034152	total: 1.05s	remaining: 330ms
# 761:	learn: 0.0033917	total: 1.05s	remaining: 328ms
# 762:	learn: 0.0033705	total: 1.05s	remaining: 327ms
# 763:	learn: 0.0033553	total: 1.05s	remaining: 325ms
# 764:	learn: 0.0033403	total: 1.05s	remaining: 324ms
# 765:	learn: 0.0033208	total: 1.05s	remaining: 323ms
# 766:	learn: 0.0033061	total: 1.06s	remaining: 321ms
# 767:	learn: 0.0032846	total: 1.06s	remaining: 320ms
# 768:	learn: 0.0032581	total: 1.06s	remaining: 318ms
# 769:	learn: 0.0032350	total: 1.06s	remaining: 317ms
# 770:	learn: 0.0032122	total: 1.06s	remaining: 315ms
# 771:	learn: 0.0031897	total: 1.06s	remaining: 314ms
# 772:	learn: 0.0031695	total: 1.06s	remaining: 313ms
# 773:	learn: 0.0031490	total: 1.06s	remaining: 311ms
# 774:	learn: 0.0031294	total: 1.07s	remaining: 310ms
# 775:	learn: 0.0031101	total: 1.07s	remaining: 308ms
# 776:	learn: 0.0030945	total: 1.07s	remaining: 307ms
# 777:	learn: 0.0030792	total: 1.07s	remaining: 306ms
# 778:	learn: 0.0030582	total: 1.07s	remaining: 304ms
# 779:	learn: 0.0030368	total: 1.07s	remaining: 303ms
# 780:	learn: 0.0030158	total: 1.07s	remaining: 301ms
# 781:	learn: 0.0029970	total: 1.07s	remaining: 300ms
# 782:	learn: 0.0029773	total: 1.08s	remaining: 298ms
# 783:	learn: 0.0029571	total: 1.08s	remaining: 297ms
# 784:	learn: 0.0029389	total: 1.08s	remaining: 296ms
# 785:	learn: 0.0029194	total: 1.08s	remaining: 294ms
# 786:	learn: 0.0029015	total: 1.08s	remaining: 293ms
# 787:	learn: 0.0028763	total: 1.08s	remaining: 291ms
# 788:	learn: 0.0028569	total: 1.08s	remaining: 290ms
# 789:	learn: 0.0028417	total: 1.08s	remaining: 289ms
# 790:	learn: 0.0028244	total: 1.09s	remaining: 287ms
# 791:	learn: 0.0028056	total: 1.09s	remaining: 286ms
# 792:	learn: 0.0027887	total: 1.09s	remaining: 284ms
# 793:	learn: 0.0027705	total: 1.09s	remaining: 283ms
# 794:	learn: 0.0027540	total: 1.09s	remaining: 282ms
# 795:	learn: 0.0027379	total: 1.09s	remaining: 280ms
# 796:	learn: 0.0027168	total: 1.09s	remaining: 279ms
# 797:	learn: 0.0026962	total: 1.09s	remaining: 277ms
# 798:	learn: 0.0026802	total: 1.1s	remaining: 276ms
# 799:	learn: 0.0026641	total: 1.1s	remaining: 275ms
# 800:	learn: 0.0026509	total: 1.1s	remaining: 273ms
# 801:	learn: 0.0026380	total: 1.1s	remaining: 272ms
# 802:	learn: 0.0026209	total: 1.1s	remaining: 270ms
# 803:	learn: 0.0026039	total: 1.1s	remaining: 269ms
# 804:	learn: 0.0025912	total: 1.1s	remaining: 268ms
# 805:	learn: 0.0025719	total: 1.1s	remaining: 266ms
# 806:	learn: 0.0025595	total: 1.11s	remaining: 265ms
# 807:	learn: 0.0025459	total: 1.11s	remaining: 263ms
# 808:	learn: 0.0025312	total: 1.11s	remaining: 262ms
# 809:	learn: 0.0025191	total: 1.11s	remaining: 261ms
# 810:	learn: 0.0025031	total: 1.11s	remaining: 259ms
# 811:	learn: 0.0024870	total: 1.11s	remaining: 258ms
# 812:	learn: 0.0024752	total: 1.11s	remaining: 257ms
# 813:	learn: 0.0024637	total: 1.12s	remaining: 255ms
# 814:	learn: 0.0024482	total: 1.12s	remaining: 254ms
# 815:	learn: 0.0024325	total: 1.12s	remaining: 252ms
# 816:	learn: 0.0024244	total: 1.12s	remaining: 251ms
# 817:	learn: 0.0024131	total: 1.12s	remaining: 250ms
# 818:	learn: 0.0023963	total: 1.12s	remaining: 248ms
# 819:	learn: 0.0023854	total: 1.12s	remaining: 247ms
# 820:	learn: 0.0023690	total: 1.13s	remaining: 245ms
# 821:	learn: 0.0023586	total: 1.13s	remaining: 244ms
# 822:	learn: 0.0023485	total: 1.13s	remaining: 243ms
# 823:	learn: 0.0023327	total: 1.13s	remaining: 241ms
# 824:	learn: 0.0023203	total: 1.13s	remaining: 240ms
# 825:	learn: 0.0023050	total: 1.13s	remaining: 238ms
# 826:	learn: 0.0022900	total: 1.13s	remaining: 237ms
# 827:	learn: 0.0022779	total: 1.13s	remaining: 236ms
# 828:	learn: 0.0022663	total: 1.14s	remaining: 234ms
# 829:	learn: 0.0022511	total: 1.14s	remaining: 233ms
# 830:	learn: 0.0022370	total: 1.14s	remaining: 231ms
# 831:	learn: 0.0022252	total: 1.14s	remaining: 230ms
# 832:	learn: 0.0022104	total: 1.14s	remaining: 229ms
# 833:	learn: 0.0021990	total: 1.14s	remaining: 227ms
# 834:	learn: 0.0021847	total: 1.14s	remaining: 226ms
# 835:	learn: 0.0021734	total: 1.14s	remaining: 224ms
# 836:	learn: 0.0021558	total: 1.15s	remaining: 223ms
# 837:	learn: 0.0021418	total: 1.15s	remaining: 222ms
# 838:	learn: 0.0021308	total: 1.15s	remaining: 220ms
# 839:	learn: 0.0021237	total: 1.15s	remaining: 219ms
# 840:	learn: 0.0021066	total: 1.15s	remaining: 217ms
# 841:	learn: 0.0020930	total: 1.15s	remaining: 216ms
# 842:	learn: 0.0020823	total: 1.15s	remaining: 215ms
# 843:	learn: 0.0020656	total: 1.15s	remaining: 213ms
# 844:	learn: 0.0020517	total: 1.16s	remaining: 212ms
# 845:	learn: 0.0020413	total: 1.16s	remaining: 211ms
# 846:	learn: 0.0020345	total: 1.16s	remaining: 210ms
# 847:	learn: 0.0020215	total: 1.16s	remaining: 209ms
# 848:	learn: 0.0020114	total: 1.17s	remaining: 207ms
# 849:	learn: 0.0019953	total: 1.17s	remaining: 206ms
# 850:	learn: 0.0019870	total: 1.17s	remaining: 205ms
# 851:	learn: 0.0019737	total: 1.17s	remaining: 204ms
# 852:	learn: 0.0019655	total: 1.17s	remaining: 202ms
# 853:	learn: 0.0019495	total: 1.18s	remaining: 201ms
# 854:	learn: 0.0019431	total: 1.18s	remaining: 200ms
# 855:	learn: 0.0019367	total: 1.18s	remaining: 198ms
# 856:	learn: 0.0019224	total: 1.18s	remaining: 197ms
# 857:	learn: 0.0019097	total: 1.18s	remaining: 195ms
# 858:	learn: 0.0019002	total: 1.18s	remaining: 194ms
# 859:	learn: 0.0018940	total: 1.19s	remaining: 193ms
# 860:	learn: 0.0018790	total: 1.19s	remaining: 192ms
# 861:	learn: 0.0018641	total: 1.19s	remaining: 190ms
# 862:	learn: 0.0018523	total: 1.19s	remaining: 189ms
# 863:	learn: 0.0018389	total: 1.19s	remaining: 187ms
# 864:	learn: 0.0018244	total: 1.19s	remaining: 186ms
# 865:	learn: 0.0018124	total: 1.19s	remaining: 185ms
# 866:	learn: 0.0018060	total: 1.19s	remaining: 183ms
# 867:	learn: 0.0017946	total: 1.2s	remaining: 182ms
# 868:	learn: 0.0017889	total: 1.2s	remaining: 180ms
# 869:	learn: 0.0017832	total: 1.2s	remaining: 179ms
# 870:	learn: 0.0017664	total: 1.2s	remaining: 178ms
# 871:	learn: 0.0017608	total: 1.2s	remaining: 176ms
# 872:	learn: 0.0017552	total: 1.2s	remaining: 175ms
# 873:	learn: 0.0017438	total: 1.2s	remaining: 173ms
# 874:	learn: 0.0017325	total: 1.2s	remaining: 172ms
# 875:	learn: 0.0017270	total: 1.21s	remaining: 171ms
# 876:	learn: 0.0017145	total: 1.21s	remaining: 169ms
# 877:	learn: 0.0017035	total: 1.21s	remaining: 168ms
# 878:	learn: 0.0016982	total: 1.21s	remaining: 166ms
# 879:	learn: 0.0016850	total: 1.21s	remaining: 165ms
# 880:	learn: 0.0016798	total: 1.21s	remaining: 164ms
# 881:	learn: 0.0016690	total: 1.21s	remaining: 162ms
# 882:	learn: 0.0016582	total: 1.21s	remaining: 161ms
# 883:	learn: 0.0016454	total: 1.22s	remaining: 159ms
# 884:	learn: 0.0016329	total: 1.22s	remaining: 158ms
# 885:	learn: 0.0016234	total: 1.22s	remaining: 157ms
# 886:	learn: 0.0016111	total: 1.22s	remaining: 155ms
# 887:	learn: 0.0016049	total: 1.22s	remaining: 154ms
# 888:	learn: 0.0015946	total: 1.22s	remaining: 152ms
# 889:	learn: 0.0015827	total: 1.22s	remaining: 151ms
# 890:	learn: 0.0015735	total: 1.22s	remaining: 150ms
# 891:	learn: 0.0015619	total: 1.23s	remaining: 148ms
# 892:	learn: 0.0015521	total: 1.23s	remaining: 147ms
# 893:	learn: 0.0015408	total: 1.23s	remaining: 146ms
# 894:	learn: 0.0015319	total: 1.23s	remaining: 144ms
# 895:	learn: 0.0015224	total: 1.23s	remaining: 143ms
# 896:	learn: 0.0015115	total: 1.23s	remaining: 141ms
# 897:	learn: 0.0015002	total: 1.23s	remaining: 140ms
# 898:	learn: 0.0014893	total: 1.23s	remaining: 139ms
# 899:	learn: 0.0014836	total: 1.24s	remaining: 137ms
# 900:	learn: 0.0014729	total: 1.24s	remaining: 136ms
# 901:	learn: 0.0014628	total: 1.24s	remaining: 134ms
# 902:	learn: 0.0014508	total: 1.24s	remaining: 133ms
# 903:	learn: 0.0014452	total: 1.24s	remaining: 132ms
# 904:	learn: 0.0014350	total: 1.24s	remaining: 130ms
# 905:	learn: 0.0014233	total: 1.24s	remaining: 129ms
# 906:	learn: 0.0014119	total: 1.24s	remaining: 128ms
# 907:	learn: 0.0013971	total: 1.25s	remaining: 126ms
# 908:	learn: 0.0013911	total: 1.25s	remaining: 125ms
# 909:	learn: 0.0013814	total: 1.25s	remaining: 123ms
# 910:	learn: 0.0013692	total: 1.25s	remaining: 122ms
# 911:	learn: 0.0013600	total: 1.25s	remaining: 121ms
# 912:	learn: 0.0013535	total: 1.25s	remaining: 119ms
# 913:	learn: 0.0013452	total: 1.25s	remaining: 118ms
# 914:	learn: 0.0013375	total: 1.25s	remaining: 116ms
# 915:	learn: 0.0013256	total: 1.25s	remaining: 115ms
# 916:	learn: 0.0013141	total: 1.26s	remaining: 114ms
# 917:	learn: 0.0013017	total: 1.26s	remaining: 112ms
# 918:	learn: 0.0012896	total: 1.26s	remaining: 111ms
# 919:	learn: 0.0012836	total: 1.26s	remaining: 110ms
# 920:	learn: 0.0012748	total: 1.26s	remaining: 108ms
# 921:	learn: 0.0012709	total: 1.26s	remaining: 107ms
# 922:	learn: 0.0012620	total: 1.26s	remaining: 105ms
# 923:	learn: 0.0012534	total: 1.26s	remaining: 104ms
# 924:	learn: 0.0012497	total: 1.27s	remaining: 103ms
# 925:	learn: 0.0012390	total: 1.27s	remaining: 101ms
# 926:	learn: 0.0012284	total: 1.27s	remaining: 99.9ms
# 927:	learn: 0.0012227	total: 1.27s	remaining: 98.5ms
# 928:	learn: 0.0012124	total: 1.27s	remaining: 97.2ms
# 929:	learn: 0.0012069	total: 1.27s	remaining: 95.8ms
# 930:	learn: 0.0011959	total: 1.27s	remaining: 94.4ms
# 931:	learn: 0.0011905	total: 1.27s	remaining: 93ms
# 932:	learn: 0.0011806	total: 1.28s	remaining: 91.7ms
# 933:	learn: 0.0011708	total: 1.28s	remaining: 90.3ms
# 934:	learn: 0.0011611	total: 1.28s	remaining: 88.9ms
# 935:	learn: 0.0011501	total: 1.28s	remaining: 87.5ms
# 936:	learn: 0.0011467	total: 1.28s	remaining: 86.1ms
# 937:	learn: 0.0011433	total: 1.28s	remaining: 84.8ms
# 938:	learn: 0.0011345	total: 1.28s	remaining: 83.4ms
# 939:	learn: 0.0011311	total: 1.28s	remaining: 82ms
# 940:	learn: 0.0011247	total: 1.29s	remaining: 80.6ms
# 941:	learn: 0.0011161	total: 1.29s	remaining: 79.3ms
# 942:	learn: 0.0011128	total: 1.29s	remaining: 77.9ms
# 943:	learn: 0.0011033	total: 1.29s	remaining: 76.5ms
# 944:	learn: 0.0010989	total: 1.29s	remaining: 75.1ms
# 945:	learn: 0.0010943	total: 1.29s	remaining: 73.8ms
# 946:	learn: 0.0010881	total: 1.29s	remaining: 72.4ms
# 947:	learn: 0.0010786	total: 1.29s	remaining: 71ms
# 948:	learn: 0.0010746	total: 1.3s	remaining: 69.7ms
# 949:	learn: 0.0010677	total: 1.3s	remaining: 68.3ms
# 950:	learn: 0.0010588	total: 1.3s	remaining: 66.9ms
# 951:	learn: 0.0010542	total: 1.3s	remaining: 65.5ms
# 952:	learn: 0.0010499	total: 1.3s	remaining: 64.2ms
# 953:	learn: 0.0010454	total: 1.3s	remaining: 62.8ms
# 954:	learn: 0.0010416	total: 1.3s	remaining: 61.4ms
# 955:	learn: 0.0010356	total: 1.3s	remaining: 60.1ms
# 956:	learn: 0.0010312	total: 1.31s	remaining: 58.7ms
# 957:	learn: 0.0010268	total: 1.31s	remaining: 57.3ms
# 958:	learn: 0.0010203	total: 1.31s	remaining: 56ms
# 959:	learn: 0.0010159	total: 1.31s	remaining: 54.6ms
# 960:	learn: 0.0010080	total: 1.31s	remaining: 53.2ms
# 961:	learn: 0.0010016	total: 1.31s	remaining: 51.9ms
# 962:	learn: 0.0009939	total: 1.31s	remaining: 50.5ms
# 963:	learn: 0.0009888	total: 1.31s	remaining: 49.1ms
# 964:	learn: 0.0009806	total: 1.32s	remaining: 47.8ms
# 965:	learn: 0.0009731	total: 1.32s	remaining: 46.4ms
# 966:	learn: 0.0009647	total: 1.32s	remaining: 45ms
# 967:	learn: 0.0009565	total: 1.32s	remaining: 43.6ms
# 968:	learn: 0.0009532	total: 1.32s	remaining: 42.3ms
# 969:	learn: 0.0009453	total: 1.32s	remaining: 40.9ms
# 970:	learn: 0.0009372	total: 1.32s	remaining: 39.5ms
# 971:	learn: 0.0009294	total: 1.32s	remaining: 38.2ms
# 972:	learn: 0.0009262	total: 1.33s	remaining: 36.8ms
# 973:	learn: 0.0009186	total: 1.33s	remaining: 35.4ms
# 974:	learn: 0.0009145	total: 1.33s	remaining: 34.1ms
# 975:	learn: 0.0009113	total: 1.33s	remaining: 32.7ms
# 976:	learn: 0.0009044	total: 1.33s	remaining: 31.3ms
# 977:	learn: 0.0008969	total: 1.33s	remaining: 30ms
# 978:	learn: 0.0008930	total: 1.33s	remaining: 28.6ms
# 979:	learn: 0.0008882	total: 1.33s	remaining: 27.2ms
# 980:	learn: 0.0008815	total: 1.34s	remaining: 25.9ms
# 981:	learn: 0.0008743	total: 1.34s	remaining: 24.5ms
# 982:	learn: 0.0008685	total: 1.34s	remaining: 23.2ms
# 983:	learn: 0.0008606	total: 1.34s	remaining: 21.8ms
# 984:	learn: 0.0008541	total: 1.34s	remaining: 20.4ms
# 985:	learn: 0.0008472	total: 1.34s	remaining: 19.1ms
# 986:	learn: 0.0008431	total: 1.34s	remaining: 17.7ms
# 987:	learn: 0.0008355	total: 1.34s	remaining: 16.3ms
# 988:	learn: 0.0008292	total: 1.35s	remaining: 15ms
# 989:	learn: 0.0008228	total: 1.35s	remaining: 13.6ms
# 990:	learn: 0.0008162	total: 1.35s	remaining: 12.3ms
# 991:	learn: 0.0008112	total: 1.35s	remaining: 10.9ms
# 992:	learn: 0.0008048	total: 1.35s	remaining: 9.53ms
# 993:	learn: 0.0007986	total: 1.35s	remaining: 8.18ms
# 994:	learn: 0.0007933	total: 1.36s	remaining: 6.83ms
# 995:	learn: 0.0007873	total: 1.36s	remaining: 5.46ms
# 996:	learn: 0.0007834	total: 1.36s	remaining: 4.1ms
# 997:	learn: 0.0007782	total: 1.36s	remaining: 2.73ms
# 998:	learn: 0.0007735	total: 1.36s	remaining: 1.37ms
# 999:	learn: 0.0007685	total: 1.37s	remaining: 0us
# np.float64(0.999998192102737)

# %%
#Determine MAE with test data
y_pred_CB = np.array(CB.predict(X_test_path))
y_pred_CB_score_paths = np.array(CB.predict(X_test_path))
mae_CB = mean_absolute_error(y_test_path, y_pred_CB)
mape_CB = mean_absolute_percentage_error(y_test_path, y_pred_CB)
print(f'Grandient Boosting Regression MAE: {mae_CB}')
# Out:
# Grandient Boosting Regression MAE: 0.5109905037535393

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_CB, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted DE Score')
plt.ylabel('Actual DE Score')
plt.title('CatBoost Regressor Predicted vs Actual DE Score')
plt.show()

# %%
MAE_dict = {'Multiple Linear Regression': mae_LR, 'Random Forest Regressor': mae_RF, 'Gradient Boost Regressor': mae_GB, 'XGBoost Regressor': mae_XG, 'CatBoost Regressor': mae_CB}
MAPE_dict = {'Multiple Linear Regression': mape_LR, 'Random Forest Regressor': mape_RF, 'Gradient Boost Regressor': mape_GB, 'XGBoost Regressor': mape_XG, 'CatBoost Regressor': mape_CB}
Rsquared_dict = {'Multiple Linear Regression': LR.score(X_train_path, y_train_path), 'Random Forest Regressor': RF.score(X_train_path, y_train_path), 'Gradient Boost Regressor': GB.score(X_train_path, y_train_path),
                 'XGBoost Regressor': XG.score(X_train_path, y_train_path), 'CatBoost Regressor': CB.score(X_train_path, y_train_path)}
summary_pathways_score = pd.DataFrame({'MAE': MAE_dict, 'MAPE': MAPE_dict, 'R²': Rsquared_dict})
summary_pathways_score
# Out:
#                                  MAE      MAPE        R²
# Multiple Linear Regression  0.630935  0.302210  0.926234
# Random Forest Regressor     0.477658  0.215585  0.918061
# Gradient Boost Regressor    0.474108  0.216221  0.999623
# XGBoost Regressor           0.532262  0.230050  0.999999
# CatBoost Regressor          0.510991  0.230386  0.999998

# %% [markdown]
# ####Predicting Pseudorank

# %%
X = donor_pathways.drop(columns=['DEscore_long', 'DEscore_short', 'pseudorank'])
y = donor_pathways['pseudorank']

X_train_path, X_test_path, y_train_path, y_test_path = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
#Run default linear regression on dataset
LR = LinearRegression()
LR.fit(X_train_path, y_train_path)
LR.score(X_train_path, y_train_path)
# Out:
# 0.856043043276243

# %%
#Determine MAE with test data
y_pred_LR = np.array(LR.predict(X_test_path))
mae_LR = mean_absolute_error(y_test_path, y_pred_LR)
mape_LR = mean_absolute_percentage_error(y_test_path, y_pred_LR)
print(f'Linear Regression MAE: {mae_LR}')
# Out:
# Linear Regression MAE: 0.03678222059441476

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_LR, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Multiple Regression Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default Random Forest regression on dataset
RF = RandomForestRegressor()
RF.fit(X_train_path, y_train_path)
RF.score(X_train_path, y_train_path)
# Out:
# 0.8853698947228643

# %%
#Determine MAE with test data
y_pred_RF = np.array(RF.predict(X_test_path))
y_pred_RF_rank_paths = np.array(RF.predict(X_test_path))
mae_RF = mean_absolute_error(y_test_path, y_pred_RF)
mape_RF = mean_absolute_percentage_error(y_test_path, y_pred_RF)
print(f'Random Forest Regression MAE: {mae_RF}')
# Out:
# Random Forest Regression MAE: 0.02023346267248455

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_RF, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Random Forest Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default Grandient Boosting regression on dataset
GB = GradientBoostingRegressor()
GB.fit(X_train_path, y_train_path)
GB.score(X_train_path, y_train_path)
# Out:
# 0.9997597306730636

# %%
#Determine MAE with test data
y_pred_GB = np.array(GB.predict(X_test_path))
mae_GB = mean_absolute_error(y_test_path, y_pred_GB)
mape_GB = mean_absolute_percentage_error(y_test_path, y_pred_GB)
print(f'Grandient Boosting Regression MAE: {mae_GB}')
# Out:
# Grandient Boosting Regression MAE: 0.019064126878448086

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_GB, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('Gradient Boosting Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default XGBoost regression on dataset
XG = XGBRegressor()
XG.fit(X_train_path, y_train_path)
XG.score(X_train_path, y_train_path)
# Out:
# 0.9996902942657471

# %%
#Determine MAE with test data
y_pred_XG = np.array(XG.predict(X_test_path))
mae_XG = mean_absolute_error(y_test_path, y_pred_XG)
mape_XG = mean_absolute_percentage_error(y_test_path, y_pred_XG)
print(f'XGBoost Regression MAE: {mae_XG}')
# Out:
# XGBoost Regression MAE: 0.021313892677426338

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_XG, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('XGBoost Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
#Run default CatBoost regression on dataset
CB = CatBoostRegressor()
CB.fit(X_train_path, y_train_path)
CB.score(X_train_path, y_train_path)
# Out:
# Learning rate set to 0.027076
# 0:	learn: 0.0234627	total: 1.53ms	remaining: 1.53s
# 1:	learn: 0.0232710	total: 2.81ms	remaining: 1.4s
# 2:	learn: 0.0230782	total: 4.06ms	remaining: 1.35s
# 3:	learn: 0.0229289	total: 5.27ms	remaining: 1.31s
# 4:	learn: 0.0226926	total: 6.47ms	remaining: 1.29s
# 5:	learn: 0.0225316	total: 7.76ms	remaining: 1.29s
# 6:	learn: 0.0223165	total: 8.97ms	remaining: 1.27s
# 7:	learn: 0.0221499	total: 10.2ms	remaining: 1.26s
# 8:	learn: 0.0219586	total: 11.4ms	remaining: 1.26s
# 9:	learn: 0.0217767	total: 12.6ms	remaining: 1.25s
# 10:	learn: 0.0215806	total: 13.8ms	remaining: 1.24s
# 11:	learn: 0.0213960	total: 15.1ms	remaining: 1.24s
# 12:	learn: 0.0212753	total: 16.4ms	remaining: 1.24s
# 13:	learn: 0.0211522	total: 17.6ms	remaining: 1.24s
# 14:	learn: 0.0209138	total: 18.8ms	remaining: 1.24s
# 15:	learn: 0.0207622	total: 20ms	remaining: 1.23s
# 16:	learn: 0.0206038	total: 21.3ms	remaining: 1.23s
# 17:	learn: 0.0204066	total: 22.6ms	remaining: 1.23s
# 18:	learn: 0.0202193	total: 23.8ms	remaining: 1.23s
# 19:	learn: 0.0200389	total: 25ms	remaining: 1.22s
# 20:	learn: 0.0198800	total: 26.2ms	remaining: 1.22s
# 21:	learn: 0.0197296	total: 27.4ms	remaining: 1.22s
# 22:	learn: 0.0195763	total: 29.1ms	remaining: 1.24s
# 23:	learn: 0.0193810	total: 30.4ms	remaining: 1.24s
# 24:	learn: 0.0192311	total: 31.7ms	remaining: 1.23s
# 25:	learn: 0.0191261	total: 32.9ms	remaining: 1.23s
# 26:	learn: 0.0189741	total: 34.1ms	remaining: 1.23s
# 27:	learn: 0.0188354	total: 35.4ms	remaining: 1.23s
# 28:	learn: 0.0187012	total: 36.6ms	remaining: 1.23s
# 29:	learn: 0.0186092	total: 37.8ms	remaining: 1.22s
# 30:	learn: 0.0184332	total: 39.7ms	remaining: 1.24s
# 31:	learn: 0.0182778	total: 41.4ms	remaining: 1.25s
# 32:	learn: 0.0181484	total: 42.7ms	remaining: 1.25s
# 33:	learn: 0.0179982	total: 44ms	remaining: 1.25s
# 34:	learn: 0.0178636	total: 45.2ms	remaining: 1.25s
# 35:	learn: 0.0177240	total: 46.4ms	remaining: 1.24s
# 36:	learn: 0.0175390	total: 47.7ms	remaining: 1.24s
# 37:	learn: 0.0174240	total: 48.9ms	remaining: 1.24s
# 38:	learn: 0.0172513	total: 50.1ms	remaining: 1.24s
# 39:	learn: 0.0171190	total: 51.3ms	remaining: 1.23s
# 40:	learn: 0.0169712	total: 52.6ms	remaining: 1.23s
# 41:	learn: 0.0168190	total: 53.8ms	remaining: 1.23s
# 42:	learn: 0.0166705	total: 54.9ms	remaining: 1.22s
# 43:	learn: 0.0165347	total: 56.3ms	remaining: 1.22s
# 44:	learn: 0.0163593	total: 57.6ms	remaining: 1.22s
# 45:	learn: 0.0162387	total: 58.8ms	remaining: 1.22s
# 46:	learn: 0.0161100	total: 60ms	remaining: 1.22s
# 47:	learn: 0.0159769	total: 61.2ms	remaining: 1.21s
# 48:	learn: 0.0159010	total: 62.4ms	remaining: 1.21s
# 49:	learn: 0.0157999	total: 63.6ms	remaining: 1.21s
# 50:	learn: 0.0156824	total: 64.8ms	remaining: 1.2s
# 51:	learn: 0.0155456	total: 66ms	remaining: 1.2s
# 52:	learn: 0.0153951	total: 67.3ms	remaining: 1.2s
# 53:	learn: 0.0152804	total: 68.5ms	remaining: 1.2s
# 54:	learn: 0.0151643	total: 69.7ms	remaining: 1.2s
# 55:	learn: 0.0150287	total: 70.9ms	remaining: 1.2s
# 56:	learn: 0.0149164	total: 72.1ms	remaining: 1.19s
# 57:	learn: 0.0148105	total: 73.4ms	remaining: 1.19s
# 58:	learn: 0.0146786	total: 75.1ms	remaining: 1.2s
# 59:	learn: 0.0145428	total: 76.4ms	remaining: 1.2s
# 60:	learn: 0.0144233	total: 77.6ms	remaining: 1.2s
# 61:	learn: 0.0143203	total: 78.9ms	remaining: 1.19s
# 62:	learn: 0.0142061	total: 80.2ms	remaining: 1.19s
# 63:	learn: 0.0140577	total: 81.4ms	remaining: 1.19s
# 64:	learn: 0.0139711	total: 82.6ms	remaining: 1.19s
# 65:	learn: 0.0138880	total: 83.8ms	remaining: 1.19s
# 66:	learn: 0.0137794	total: 85.1ms	remaining: 1.18s
# 67:	learn: 0.0136897	total: 86.3ms	remaining: 1.18s
# 68:	learn: 0.0135949	total: 87.7ms	remaining: 1.18s
# 69:	learn: 0.0134957	total: 88.8ms	remaining: 1.18s
# 70:	learn: 0.0133886	total: 90.1ms	remaining: 1.18s
# 71:	learn: 0.0132861	total: 91.3ms	remaining: 1.18s
# 72:	learn: 0.0131815	total: 92.5ms	remaining: 1.17s
# 73:	learn: 0.0131190	total: 93.7ms	remaining: 1.17s
# 74:	learn: 0.0130223	total: 94.9ms	remaining: 1.17s
# 75:	learn: 0.0129202	total: 96.1ms	remaining: 1.17s
# 76:	learn: 0.0128039	total: 97.4ms	remaining: 1.17s
# 77:	learn: 0.0127243	total: 98.6ms	remaining: 1.17s
# 78:	learn: 0.0126117	total: 99.9ms	remaining: 1.16s
# 79:	learn: 0.0125117	total: 101ms	remaining: 1.16s
# 80:	learn: 0.0124429	total: 102ms	remaining: 1.16s
# 81:	learn: 0.0123279	total: 104ms	remaining: 1.16s
# 82:	learn: 0.0122342	total: 105ms	remaining: 1.16s
# 83:	learn: 0.0121471	total: 106ms	remaining: 1.16s
# 84:	learn: 0.0120527	total: 107ms	remaining: 1.16s
# 85:	learn: 0.0119742	total: 109ms	remaining: 1.15s
# 86:	learn: 0.0118792	total: 110ms	remaining: 1.15s
# 87:	learn: 0.0118193	total: 111ms	remaining: 1.15s
# 88:	learn: 0.0117348	total: 112ms	remaining: 1.14s
# 89:	learn: 0.0116633	total: 113ms	remaining: 1.14s
# 90:	learn: 0.0115749	total: 114ms	remaining: 1.14s
# 91:	learn: 0.0114906	total: 116ms	remaining: 1.14s
# 92:	learn: 0.0113737	total: 117ms	remaining: 1.14s
# 93:	learn: 0.0113088	total: 118ms	remaining: 1.14s
# 94:	learn: 0.0112284	total: 119ms	remaining: 1.14s
# 95:	learn: 0.0111422	total: 121ms	remaining: 1.14s
# 96:	learn: 0.0110791	total: 122ms	remaining: 1.13s
# 97:	learn: 0.0110109	total: 123ms	remaining: 1.13s
# 98:	learn: 0.0109396	total: 124ms	remaining: 1.13s
# 99:	learn: 0.0108484	total: 126ms	remaining: 1.13s
# 100:	learn: 0.0107803	total: 127ms	remaining: 1.13s
# 101:	learn: 0.0106814	total: 128ms	remaining: 1.13s
# 102:	learn: 0.0106106	total: 129ms	remaining: 1.13s
# 103:	learn: 0.0105186	total: 131ms	remaining: 1.12s
# 104:	learn: 0.0104405	total: 132ms	remaining: 1.12s
# 105:	learn: 0.0103553	total: 133ms	remaining: 1.12s
# 106:	learn: 0.0102820	total: 134ms	remaining: 1.12s
# 107:	learn: 0.0102365	total: 135ms	remaining: 1.12s
# 108:	learn: 0.0101449	total: 137ms	remaining: 1.12s
# 109:	learn: 0.0100640	total: 138ms	remaining: 1.11s
# 110:	learn: 0.0099941	total: 139ms	remaining: 1.11s
# 111:	learn: 0.0099063	total: 140ms	remaining: 1.11s
# 112:	learn: 0.0098583	total: 142ms	remaining: 1.11s
# 113:	learn: 0.0097925	total: 143ms	remaining: 1.11s
# 114:	learn: 0.0097071	total: 144ms	remaining: 1.11s
# 115:	learn: 0.0096457	total: 146ms	remaining: 1.11s
# 116:	learn: 0.0095776	total: 147ms	remaining: 1.11s
# 117:	learn: 0.0095249	total: 149ms	remaining: 1.11s
# 118:	learn: 0.0094523	total: 150ms	remaining: 1.11s
# 119:	learn: 0.0093817	total: 152ms	remaining: 1.12s
# 120:	learn: 0.0093437	total: 154ms	remaining: 1.12s
# 121:	learn: 0.0092750	total: 155ms	remaining: 1.12s
# 122:	learn: 0.0091995	total: 156ms	remaining: 1.11s
# 123:	learn: 0.0091148	total: 158ms	remaining: 1.11s
# 124:	learn: 0.0090421	total: 159ms	remaining: 1.11s
# 125:	learn: 0.0089651	total: 160ms	remaining: 1.11s
# 126:	learn: 0.0088987	total: 162ms	remaining: 1.11s
# 127:	learn: 0.0088215	total: 163ms	remaining: 1.11s
# 128:	learn: 0.0087575	total: 164ms	remaining: 1.11s
# 129:	learn: 0.0086846	total: 165ms	remaining: 1.11s
# 130:	learn: 0.0086159	total: 167ms	remaining: 1.1s
# 131:	learn: 0.0085361	total: 168ms	remaining: 1.1s
# 132:	learn: 0.0084781	total: 169ms	remaining: 1.1s
# 133:	learn: 0.0084234	total: 170ms	remaining: 1.1s
# 134:	learn: 0.0083582	total: 172ms	remaining: 1.1s
# 135:	learn: 0.0083202	total: 173ms	remaining: 1.1s
# 136:	learn: 0.0082676	total: 174ms	remaining: 1.1s
# 137:	learn: 0.0082025	total: 176ms	remaining: 1.1s
# 138:	learn: 0.0081418	total: 177ms	remaining: 1.09s
# 139:	learn: 0.0080829	total: 178ms	remaining: 1.09s
# 140:	learn: 0.0080213	total: 179ms	remaining: 1.09s
# 141:	learn: 0.0079715	total: 181ms	remaining: 1.09s
# 142:	learn: 0.0079050	total: 182ms	remaining: 1.09s
# 143:	learn: 0.0078658	total: 183ms	remaining: 1.09s
# 144:	learn: 0.0078066	total: 184ms	remaining: 1.09s
# 145:	learn: 0.0077619	total: 186ms	remaining: 1.08s
# 146:	learn: 0.0077253	total: 187ms	remaining: 1.08s
# 147:	learn: 0.0076727	total: 188ms	remaining: 1.08s
# 148:	learn: 0.0076285	total: 188ms	remaining: 1.08s
# 149:	learn: 0.0075830	total: 190ms	remaining: 1.08s
# 150:	learn: 0.0075175	total: 192ms	remaining: 1.08s
# 151:	learn: 0.0074560	total: 195ms	remaining: 1.08s
# 152:	learn: 0.0074041	total: 196ms	remaining: 1.08s
# 153:	learn: 0.0073397	total: 197ms	remaining: 1.08s
# 154:	learn: 0.0072892	total: 198ms	remaining: 1.08s
# 155:	learn: 0.0072308	total: 200ms	remaining: 1.08s
# 156:	learn: 0.0071932	total: 201ms	remaining: 1.08s
# 157:	learn: 0.0071470	total: 202ms	remaining: 1.08s
# 158:	learn: 0.0070837	total: 204ms	remaining: 1.08s
# 159:	learn: 0.0070327	total: 205ms	remaining: 1.07s
# 160:	learn: 0.0069810	total: 206ms	remaining: 1.07s
# 161:	learn: 0.0069471	total: 207ms	remaining: 1.07s
# 162:	learn: 0.0069069	total: 209ms	remaining: 1.07s
# 163:	learn: 0.0068687	total: 210ms	remaining: 1.07s
# 164:	learn: 0.0068256	total: 211ms	remaining: 1.07s
# 165:	learn: 0.0067673	total: 213ms	remaining: 1.07s
# 166:	learn: 0.0067436	total: 214ms	remaining: 1.07s
# 167:	learn: 0.0067103	total: 215ms	remaining: 1.06s
# 168:	learn: 0.0066658	total: 216ms	remaining: 1.06s
# 169:	learn: 0.0066292	total: 217ms	remaining: 1.06s
# 170:	learn: 0.0065922	total: 218ms	remaining: 1.06s
# 171:	learn: 0.0065466	total: 219ms	remaining: 1.05s
# 172:	learn: 0.0065083	total: 220ms	remaining: 1.05s
# 173:	learn: 0.0064652	total: 222ms	remaining: 1.05s
# 174:	learn: 0.0064192	total: 223ms	remaining: 1.05s
# 175:	learn: 0.0063872	total: 224ms	remaining: 1.05s
# 176:	learn: 0.0063549	total: 225ms	remaining: 1.05s
# 177:	learn: 0.0063036	total: 226ms	remaining: 1.04s
# 178:	learn: 0.0062671	total: 228ms	remaining: 1.04s
# 179:	learn: 0.0062135	total: 229ms	remaining: 1.04s
# 180:	learn: 0.0061848	total: 230ms	remaining: 1.04s
# 181:	learn: 0.0061626	total: 232ms	remaining: 1.04s
# 182:	learn: 0.0061294	total: 234ms	remaining: 1.04s
# 183:	learn: 0.0060942	total: 235ms	remaining: 1.04s
# 184:	learn: 0.0060468	total: 236ms	remaining: 1.04s
# 185:	learn: 0.0060080	total: 237ms	remaining: 1.04s
# 186:	learn: 0.0059762	total: 239ms	remaining: 1.04s
# 187:	learn: 0.0059354	total: 240ms	remaining: 1.03s
# 188:	learn: 0.0058968	total: 241ms	remaining: 1.03s
# 189:	learn: 0.0058536	total: 242ms	remaining: 1.03s
# 190:	learn: 0.0058195	total: 244ms	remaining: 1.03s
# 191:	learn: 0.0057886	total: 245ms	remaining: 1.03s
# 192:	learn: 0.0057549	total: 246ms	remaining: 1.03s
# 193:	learn: 0.0057175	total: 247ms	remaining: 1.03s
# 194:	learn: 0.0056716	total: 249ms	remaining: 1.03s
# 195:	learn: 0.0056208	total: 250ms	remaining: 1.02s
# 196:	learn: 0.0055843	total: 251ms	remaining: 1.02s
# 197:	learn: 0.0055440	total: 252ms	remaining: 1.02s
# 198:	learn: 0.0055238	total: 253ms	remaining: 1.02s
# 199:	learn: 0.0054891	total: 255ms	remaining: 1.02s
# 200:	learn: 0.0054657	total: 256ms	remaining: 1.02s
# 201:	learn: 0.0054214	total: 257ms	remaining: 1.01s
# 202:	learn: 0.0053750	total: 258ms	remaining: 1.01s
# 203:	learn: 0.0053213	total: 259ms	remaining: 1.01s
# 204:	learn: 0.0052963	total: 261ms	remaining: 1.01s
# 205:	learn: 0.0052486	total: 262ms	remaining: 1.01s
# 206:	learn: 0.0052074	total: 263ms	remaining: 1.01s
# 207:	learn: 0.0051881	total: 264ms	remaining: 1.01s
# 208:	learn: 0.0051471	total: 266ms	remaining: 1s
# 209:	learn: 0.0051091	total: 267ms	remaining: 1s
# 210:	learn: 0.0050919	total: 268ms	remaining: 1s
# 211:	learn: 0.0050656	total: 269ms	remaining: 1s
# 212:	learn: 0.0050259	total: 270ms	remaining: 999ms
# 213:	learn: 0.0049967	total: 272ms	remaining: 998ms
# 214:	learn: 0.0049588	total: 273ms	remaining: 997ms
# 215:	learn: 0.0049237	total: 274ms	remaining: 996ms
# 216:	learn: 0.0048903	total: 276ms	remaining: 994ms
# 217:	learn: 0.0048626	total: 277ms	remaining: 993ms
# 218:	learn: 0.0048307	total: 278ms	remaining: 991ms
# 219:	learn: 0.0048103	total: 279ms	remaining: 990ms
# 220:	learn: 0.0047778	total: 281ms	remaining: 989ms
# 221:	learn: 0.0047376	total: 282ms	remaining: 988ms
# 222:	learn: 0.0046964	total: 283ms	remaining: 986ms
# 223:	learn: 0.0046816	total: 284ms	remaining: 985ms
# 224:	learn: 0.0046440	total: 286ms	remaining: 984ms
# 225:	learn: 0.0046064	total: 287ms	remaining: 982ms
# 226:	learn: 0.0045716	total: 288ms	remaining: 981ms
# 227:	learn: 0.0045359	total: 289ms	remaining: 979ms
# 228:	learn: 0.0044920	total: 290ms	remaining: 978ms
# 229:	learn: 0.0044569	total: 292ms	remaining: 977ms
# 230:	learn: 0.0044232	total: 293ms	remaining: 975ms
# 231:	learn: 0.0043905	total: 294ms	remaining: 974ms
# 232:	learn: 0.0043555	total: 295ms	remaining: 972ms
# 233:	learn: 0.0043292	total: 297ms	remaining: 971ms
# 234:	learn: 0.0043133	total: 298ms	remaining: 970ms
# 235:	learn: 0.0042768	total: 299ms	remaining: 968ms
# 236:	learn: 0.0042422	total: 300ms	remaining: 967ms
# 237:	learn: 0.0042233	total: 302ms	remaining: 966ms
# 238:	learn: 0.0042016	total: 303ms	remaining: 964ms
# 239:	learn: 0.0041789	total: 304ms	remaining: 963ms
# 240:	learn: 0.0041496	total: 305ms	remaining: 961ms
# 241:	learn: 0.0041200	total: 307ms	remaining: 960ms
# 242:	learn: 0.0040874	total: 308ms	remaining: 959ms
# 243:	learn: 0.0040749	total: 309ms	remaining: 957ms
# 244:	learn: 0.0040439	total: 310ms	remaining: 956ms
# 245:	learn: 0.0040255	total: 311ms	remaining: 954ms
# 246:	learn: 0.0039977	total: 313ms	remaining: 953ms
# 247:	learn: 0.0039668	total: 314ms	remaining: 952ms
# 248:	learn: 0.0039402	total: 316ms	remaining: 953ms
# 249:	learn: 0.0039038	total: 317ms	remaining: 951ms
# 250:	learn: 0.0038709	total: 318ms	remaining: 950ms
# 251:	learn: 0.0038438	total: 320ms	remaining: 949ms
# 252:	learn: 0.0038100	total: 321ms	remaining: 947ms
# 253:	learn: 0.0037830	total: 322ms	remaining: 946ms
# 254:	learn: 0.0037499	total: 323ms	remaining: 945ms
# 255:	learn: 0.0037218	total: 325ms	remaining: 943ms
# 256:	learn: 0.0036916	total: 326ms	remaining: 942ms
# 257:	learn: 0.0036648	total: 327ms	remaining: 941ms
# 258:	learn: 0.0036412	total: 328ms	remaining: 940ms
# 259:	learn: 0.0036142	total: 330ms	remaining: 938ms
# 260:	learn: 0.0035883	total: 331ms	remaining: 937ms
# 261:	learn: 0.0035665	total: 332ms	remaining: 935ms
# 262:	learn: 0.0035379	total: 333ms	remaining: 934ms
# 263:	learn: 0.0035143	total: 335ms	remaining: 933ms
# 264:	learn: 0.0034876	total: 336ms	remaining: 932ms
# 265:	learn: 0.0034615	total: 337ms	remaining: 930ms
# 266:	learn: 0.0034308	total: 338ms	remaining: 929ms
# 267:	learn: 0.0034061	total: 340ms	remaining: 928ms
# 268:	learn: 0.0033762	total: 341ms	remaining: 926ms
# 269:	learn: 0.0033561	total: 343ms	remaining: 926ms
# 270:	learn: 0.0033298	total: 344ms	remaining: 925ms
# 271:	learn: 0.0033054	total: 345ms	remaining: 924ms
# 272:	learn: 0.0032774	total: 346ms	remaining: 922ms
# 273:	learn: 0.0032535	total: 348ms	remaining: 921ms
# 274:	learn: 0.0032361	total: 349ms	remaining: 920ms
# 275:	learn: 0.0032116	total: 350ms	remaining: 919ms
# 276:	learn: 0.0031849	total: 351ms	remaining: 917ms
# 277:	learn: 0.0031646	total: 353ms	remaining: 916ms
# 278:	learn: 0.0031443	total: 354ms	remaining: 915ms
# 279:	learn: 0.0031204	total: 355ms	remaining: 914ms
# 280:	learn: 0.0030952	total: 357ms	remaining: 912ms
# 281:	learn: 0.0030726	total: 358ms	remaining: 911ms
# 282:	learn: 0.0030479	total: 359ms	remaining: 910ms
# 283:	learn: 0.0030229	total: 360ms	remaining: 909ms
# 284:	learn: 0.0029991	total: 362ms	remaining: 907ms
# 285:	learn: 0.0029779	total: 363ms	remaining: 906ms
# 286:	learn: 0.0029569	total: 364ms	remaining: 905ms
# 287:	learn: 0.0029356	total: 366ms	remaining: 904ms
# 288:	learn: 0.0029191	total: 367ms	remaining: 903ms
# 289:	learn: 0.0028959	total: 368ms	remaining: 901ms
# 290:	learn: 0.0028724	total: 369ms	remaining: 900ms
# 291:	learn: 0.0028510	total: 371ms	remaining: 898ms
# 292:	learn: 0.0028288	total: 372ms	remaining: 897ms
# 293:	learn: 0.0028113	total: 373ms	remaining: 896ms
# 294:	learn: 0.0027910	total: 374ms	remaining: 895ms
# 295:	learn: 0.0027681	total: 376ms	remaining: 893ms
# 296:	learn: 0.0027475	total: 377ms	remaining: 892ms
# 297:	learn: 0.0027267	total: 378ms	remaining: 891ms
# 298:	learn: 0.0027086	total: 379ms	remaining: 890ms
# 299:	learn: 0.0026924	total: 381ms	remaining: 888ms
# 300:	learn: 0.0026736	total: 383ms	remaining: 890ms
# 301:	learn: 0.0026561	total: 386ms	remaining: 892ms
# 302:	learn: 0.0026374	total: 387ms	remaining: 891ms
# 303:	learn: 0.0026194	total: 389ms	remaining: 890ms
# 304:	learn: 0.0025990	total: 390ms	remaining: 888ms
# 305:	learn: 0.0025810	total: 391ms	remaining: 887ms
# 306:	learn: 0.0025629	total: 392ms	remaining: 885ms
# 307:	learn: 0.0025414	total: 393ms	remaining: 884ms
# 308:	learn: 0.0025254	total: 395ms	remaining: 883ms
# 309:	learn: 0.0025044	total: 396ms	remaining: 881ms
# 310:	learn: 0.0024872	total: 397ms	remaining: 880ms
# 311:	learn: 0.0024699	total: 398ms	remaining: 878ms
# 312:	learn: 0.0024494	total: 400ms	remaining: 877ms
# 313:	learn: 0.0024348	total: 401ms	remaining: 876ms
# 314:	learn: 0.0024220	total: 402ms	remaining: 874ms
# 315:	learn: 0.0024003	total: 403ms	remaining: 873ms
# 316:	learn: 0.0023880	total: 405ms	remaining: 872ms
# 317:	learn: 0.0023683	total: 406ms	remaining: 870ms
# 318:	learn: 0.0023538	total: 407ms	remaining: 869ms
# 319:	learn: 0.0023327	total: 408ms	remaining: 868ms
# 320:	learn: 0.0023207	total: 410ms	remaining: 866ms
# 321:	learn: 0.0023019	total: 411ms	remaining: 865ms
# 322:	learn: 0.0022807	total: 412ms	remaining: 864ms
# 323:	learn: 0.0022682	total: 413ms	remaining: 862ms
# 324:	learn: 0.0022499	total: 415ms	remaining: 861ms
# 325:	learn: 0.0022358	total: 416ms	remaining: 860ms
# 326:	learn: 0.0022252	total: 417ms	remaining: 858ms
# 327:	learn: 0.0022085	total: 418ms	remaining: 857ms
# 328:	learn: 0.0021931	total: 419ms	remaining: 856ms
# 329:	learn: 0.0021788	total: 421ms	remaining: 854ms
# 330:	learn: 0.0021620	total: 422ms	remaining: 853ms
# 331:	learn: 0.0021495	total: 423ms	remaining: 852ms
# 332:	learn: 0.0021310	total: 425ms	remaining: 852ms
# 333:	learn: 0.0021149	total: 428ms	remaining: 853ms
# 334:	learn: 0.0021013	total: 430ms	remaining: 853ms
# 335:	learn: 0.0020835	total: 431ms	remaining: 852ms
# 336:	learn: 0.0020688	total: 432ms	remaining: 850ms
# 337:	learn: 0.0020545	total: 433ms	remaining: 849ms
# 338:	learn: 0.0020447	total: 435ms	remaining: 848ms
# 339:	learn: 0.0020290	total: 436ms	remaining: 846ms
# 340:	learn: 0.0020137	total: 437ms	remaining: 845ms
# 341:	learn: 0.0020009	total: 438ms	remaining: 844ms
# 342:	learn: 0.0019881	total: 440ms	remaining: 842ms
# 343:	learn: 0.0019768	total: 441ms	remaining: 842ms
# 344:	learn: 0.0019651	total: 443ms	remaining: 840ms
# 345:	learn: 0.0019508	total: 444ms	remaining: 839ms
# 346:	learn: 0.0019393	total: 445ms	remaining: 837ms
# 347:	learn: 0.0019257	total: 446ms	remaining: 836ms
# 348:	learn: 0.0019144	total: 448ms	remaining: 835ms
# 349:	learn: 0.0019045	total: 449ms	remaining: 833ms
# 350:	learn: 0.0018948	total: 450ms	remaining: 832ms
# 351:	learn: 0.0018803	total: 451ms	remaining: 831ms
# 352:	learn: 0.0018645	total: 452ms	remaining: 829ms
# 353:	learn: 0.0018550	total: 454ms	remaining: 828ms
# 354:	learn: 0.0018395	total: 455ms	remaining: 826ms
# 355:	learn: 0.0018302	total: 456ms	remaining: 825ms
# 356:	learn: 0.0018191	total: 457ms	remaining: 824ms
# 357:	learn: 0.0018099	total: 459ms	remaining: 822ms
# 358:	learn: 0.0017974	total: 460ms	remaining: 821ms
# 359:	learn: 0.0017884	total: 461ms	remaining: 820ms
# 360:	learn: 0.0017796	total: 462ms	remaining: 818ms
# 361:	learn: 0.0017705	total: 464ms	remaining: 817ms
# 362:	learn: 0.0017561	total: 465ms	remaining: 816ms
# 363:	learn: 0.0017474	total: 466ms	remaining: 814ms
# 364:	learn: 0.0017389	total: 467ms	remaining: 813ms
# 365:	learn: 0.0017267	total: 469ms	remaining: 812ms
# 366:	learn: 0.0017186	total: 470ms	remaining: 810ms
# 367:	learn: 0.0017068	total: 471ms	remaining: 809ms
# 368:	learn: 0.0016985	total: 472ms	remaining: 808ms
# 369:	learn: 0.0016904	total: 474ms	remaining: 806ms
# 370:	learn: 0.0016796	total: 475ms	remaining: 805ms
# 371:	learn: 0.0016671	total: 476ms	remaining: 804ms
# 372:	learn: 0.0016590	total: 477ms	remaining: 802ms
# 373:	learn: 0.0016486	total: 479ms	remaining: 801ms
# 374:	learn: 0.0016354	total: 481ms	remaining: 802ms
# 375:	learn: 0.0016247	total: 482ms	remaining: 801ms
# 376:	learn: 0.0016134	total: 484ms	remaining: 799ms
# 377:	learn: 0.0016059	total: 485ms	remaining: 798ms
# 378:	learn: 0.0015949	total: 486ms	remaining: 797ms
# 379:	learn: 0.0015841	total: 488ms	remaining: 795ms
# 380:	learn: 0.0015712	total: 489ms	remaining: 794ms
# 381:	learn: 0.0015595	total: 490ms	remaining: 793ms
# 382:	learn: 0.0015484	total: 492ms	remaining: 792ms
# 383:	learn: 0.0015377	total: 494ms	remaining: 792ms
# 384:	learn: 0.0015264	total: 495ms	remaining: 791ms
# 385:	learn: 0.0015159	total: 497ms	remaining: 790ms
# 386:	learn: 0.0015046	total: 498ms	remaining: 789ms
# 387:	learn: 0.0014936	total: 499ms	remaining: 787ms
# 388:	learn: 0.0014836	total: 500ms	remaining: 786ms
# 389:	learn: 0.0014733	total: 502ms	remaining: 785ms
# 390:	learn: 0.0014618	total: 503ms	remaining: 783ms
# 391:	learn: 0.0014518	total: 504ms	remaining: 782ms
# 392:	learn: 0.0014426	total: 506ms	remaining: 781ms
# 393:	learn: 0.0014360	total: 507ms	remaining: 779ms
# 394:	learn: 0.0014269	total: 508ms	remaining: 778ms
# 395:	learn: 0.0014174	total: 509ms	remaining: 777ms
# 396:	learn: 0.0014087	total: 511ms	remaining: 776ms
# 397:	learn: 0.0013982	total: 512ms	remaining: 774ms
# 398:	learn: 0.0013906	total: 513ms	remaining: 773ms
# 399:	learn: 0.0013812	total: 514ms	remaining: 771ms
# 400:	learn: 0.0013712	total: 516ms	remaining: 770ms
# 401:	learn: 0.0013622	total: 517ms	remaining: 769ms
# 402:	learn: 0.0013540	total: 518ms	remaining: 767ms
# 403:	learn: 0.0013456	total: 519ms	remaining: 766ms
# 404:	learn: 0.0013400	total: 520ms	remaining: 765ms
# 405:	learn: 0.0013302	total: 522ms	remaining: 763ms
# 406:	learn: 0.0013215	total: 523ms	remaining: 762ms
# 407:	learn: 0.0013127	total: 524ms	remaining: 761ms
# 408:	learn: 0.0013072	total: 525ms	remaining: 759ms
# 409:	learn: 0.0013005	total: 527ms	remaining: 758ms
# 410:	learn: 0.0012904	total: 528ms	remaining: 756ms
# 411:	learn: 0.0012827	total: 529ms	remaining: 755ms
# 412:	learn: 0.0012761	total: 530ms	remaining: 754ms
# 413:	learn: 0.0012645	total: 532ms	remaining: 752ms
# 414:	learn: 0.0012564	total: 533ms	remaining: 751ms
# 415:	learn: 0.0012488	total: 534ms	remaining: 750ms
# 416:	learn: 0.0012455	total: 535ms	remaining: 748ms
# 417:	learn: 0.0012373	total: 536ms	remaining: 747ms
# 418:	learn: 0.0012299	total: 538ms	remaining: 746ms
# 419:	learn: 0.0012218	total: 539ms	remaining: 744ms
# 420:	learn: 0.0012109	total: 540ms	remaining: 743ms
# 421:	learn: 0.0012022	total: 541ms	remaining: 741ms
# 422:	learn: 0.0011991	total: 543ms	remaining: 740ms
# 423:	learn: 0.0011884	total: 544ms	remaining: 739ms
# 424:	learn: 0.0011821	total: 545ms	remaining: 738ms
# 425:	learn: 0.0011754	total: 546ms	remaining: 736ms
# 426:	learn: 0.0011669	total: 548ms	remaining: 735ms
# 427:	learn: 0.0011583	total: 549ms	remaining: 734ms
# 428:	learn: 0.0011519	total: 550ms	remaining: 732ms
# 429:	learn: 0.0011450	total: 551ms	remaining: 731ms
# 430:	learn: 0.0011385	total: 553ms	remaining: 730ms
# 431:	learn: 0.0011289	total: 554ms	remaining: 728ms
# 432:	learn: 0.0011215	total: 555ms	remaining: 727ms
# 433:	learn: 0.0011142	total: 556ms	remaining: 725ms
# 434:	learn: 0.0011070	total: 557ms	remaining: 724ms
# 435:	learn: 0.0010988	total: 559ms	remaining: 723ms
# 436:	learn: 0.0010927	total: 560ms	remaining: 721ms
# 437:	learn: 0.0010857	total: 561ms	remaining: 720ms
# 438:	learn: 0.0010777	total: 562ms	remaining: 719ms
# 439:	learn: 0.0010715	total: 564ms	remaining: 717ms
# 440:	learn: 0.0010646	total: 565ms	remaining: 716ms
# 441:	learn: 0.0010579	total: 566ms	remaining: 715ms
# 442:	learn: 0.0010502	total: 567ms	remaining: 713ms
# 443:	learn: 0.0010432	total: 569ms	remaining: 712ms
# 444:	learn: 0.0010374	total: 570ms	remaining: 711ms
# 445:	learn: 0.0010299	total: 571ms	remaining: 710ms
# 446:	learn: 0.0010230	total: 572ms	remaining: 708ms
# 447:	learn: 0.0010163	total: 574ms	remaining: 707ms
# 448:	learn: 0.0010097	total: 576ms	remaining: 707ms
# 449:	learn: 0.0010008	total: 578ms	remaining: 706ms
# 450:	learn: 0.0009945	total: 579ms	remaining: 705ms
# 451:	learn: 0.0009883	total: 580ms	remaining: 704ms
# 452:	learn: 0.0009811	total: 582ms	remaining: 702ms
# 453:	learn: 0.0009747	total: 583ms	remaining: 701ms
# 454:	learn: 0.0009685	total: 584ms	remaining: 700ms
# 455:	learn: 0.0009623	total: 586ms	remaining: 699ms
# 456:	learn: 0.0009565	total: 587ms	remaining: 697ms
# 457:	learn: 0.0009505	total: 588ms	remaining: 696ms
# 458:	learn: 0.0009443	total: 589ms	remaining: 695ms
# 459:	learn: 0.0009361	total: 591ms	remaining: 693ms
# 460:	learn: 0.0009321	total: 592ms	remaining: 692ms
# 461:	learn: 0.0009254	total: 593ms	remaining: 691ms
# 462:	learn: 0.0009215	total: 595ms	remaining: 690ms
# 463:	learn: 0.0009160	total: 596ms	remaining: 688ms
# 464:	learn: 0.0009106	total: 597ms	remaining: 687ms
# 465:	learn: 0.0009053	total: 598ms	remaining: 686ms
# 466:	learn: 0.0008998	total: 600ms	remaining: 684ms
# 467:	learn: 0.0008939	total: 601ms	remaining: 683ms
# 468:	learn: 0.0008910	total: 602ms	remaining: 682ms
# 469:	learn: 0.0008848	total: 603ms	remaining: 680ms
# 470:	learn: 0.0008789	total: 605ms	remaining: 679ms
# 471:	learn: 0.0008760	total: 606ms	remaining: 678ms
# 472:	learn: 0.0008700	total: 608ms	remaining: 678ms
# 473:	learn: 0.0008674	total: 611ms	remaining: 679ms
# 474:	learn: 0.0008614	total: 614ms	remaining: 679ms
# 475:	learn: 0.0008589	total: 618ms	remaining: 680ms
# 476:	learn: 0.0008532	total: 621ms	remaining: 681ms
# 477:	learn: 0.0008471	total: 622ms	remaining: 680ms
# 478:	learn: 0.0008402	total: 624ms	remaining: 679ms
# 479:	learn: 0.0008362	total: 627ms	remaining: 679ms
# 480:	learn: 0.0008323	total: 628ms	remaining: 678ms
# 481:	learn: 0.0008284	total: 629ms	remaining: 676ms
# 482:	learn: 0.0008245	total: 631ms	remaining: 675ms
# 483:	learn: 0.0008207	total: 633ms	remaining: 675ms
# 484:	learn: 0.0008169	total: 635ms	remaining: 674ms
# 485:	learn: 0.0008129	total: 636ms	remaining: 673ms
# 486:	learn: 0.0008072	total: 637ms	remaining: 671ms
# 487:	learn: 0.0008016	total: 639ms	remaining: 670ms
# 488:	learn: 0.0007971	total: 641ms	remaining: 669ms
# 489:	learn: 0.0007917	total: 642ms	remaining: 668ms
# 490:	learn: 0.0007864	total: 643ms	remaining: 667ms
# 491:	learn: 0.0007812	total: 645ms	remaining: 666ms
# 492:	learn: 0.0007756	total: 647ms	remaining: 665ms
# 493:	learn: 0.0007705	total: 648ms	remaining: 664ms
# 494:	learn: 0.0007651	total: 650ms	remaining: 663ms
# 495:	learn: 0.0007601	total: 651ms	remaining: 662ms
# 496:	learn: 0.0007548	total: 652ms	remaining: 660ms
# 497:	learn: 0.0007499	total: 654ms	remaining: 659ms
# 498:	learn: 0.0007447	total: 655ms	remaining: 657ms
# 499:	learn: 0.0007400	total: 656ms	remaining: 656ms
# 500:	learn: 0.0007349	total: 657ms	remaining: 655ms
# 501:	learn: 0.0007301	total: 659ms	remaining: 653ms
# 502:	learn: 0.0007251	total: 660ms	remaining: 652ms
# 503:	learn: 0.0007202	total: 661ms	remaining: 651ms
# 504:	learn: 0.0007154	total: 662ms	remaining: 649ms
# 505:	learn: 0.0007099	total: 664ms	remaining: 648ms
# 506:	learn: 0.0007056	total: 665ms	remaining: 646ms
# 507:	learn: 0.0007003	total: 666ms	remaining: 645ms
# 508:	learn: 0.0006964	total: 667ms	remaining: 644ms
# 509:	learn: 0.0006923	total: 668ms	remaining: 642ms
# 510:	learn: 0.0006876	total: 670ms	remaining: 641ms
# 511:	learn: 0.0006827	total: 671ms	remaining: 640ms
# 512:	learn: 0.0006789	total: 672ms	remaining: 638ms
# 513:	learn: 0.0006751	total: 674ms	remaining: 637ms
# 514:	learn: 0.0006714	total: 675ms	remaining: 636ms
# 515:	learn: 0.0006676	total: 676ms	remaining: 634ms
# 516:	learn: 0.0006632	total: 677ms	remaining: 633ms
# 517:	learn: 0.0006595	total: 679ms	remaining: 632ms
# 518:	learn: 0.0006569	total: 680ms	remaining: 630ms
# 519:	learn: 0.0006525	total: 681ms	remaining: 629ms
# 520:	learn: 0.0006488	total: 683ms	remaining: 628ms
# 521:	learn: 0.0006437	total: 684ms	remaining: 626ms
# 522:	learn: 0.0006399	total: 685ms	remaining: 625ms
# 523:	learn: 0.0006364	total: 686ms	remaining: 623ms
# 524:	learn: 0.0006333	total: 688ms	remaining: 622ms
# 525:	learn: 0.0006292	total: 689ms	remaining: 621ms
# 526:	learn: 0.0006270	total: 690ms	remaining: 619ms
# 527:	learn: 0.0006235	total: 691ms	remaining: 618ms
# 528:	learn: 0.0006187	total: 693ms	remaining: 617ms
# 529:	learn: 0.0006166	total: 694ms	remaining: 616ms
# 530:	learn: 0.0006141	total: 697ms	remaining: 615ms
# 531:	learn: 0.0006109	total: 698ms	remaining: 614ms
# 532:	learn: 0.0006074	total: 699ms	remaining: 613ms
# 533:	learn: 0.0006034	total: 700ms	remaining: 611ms
# 534:	learn: 0.0006002	total: 702ms	remaining: 610ms
# 535:	learn: 0.0005971	total: 703ms	remaining: 609ms
# 536:	learn: 0.0005923	total: 704ms	remaining: 607ms
# 537:	learn: 0.0005870	total: 705ms	remaining: 606ms
# 538:	learn: 0.0005818	total: 707ms	remaining: 604ms
# 539:	learn: 0.0005778	total: 708ms	remaining: 603ms
# 540:	learn: 0.0005729	total: 709ms	remaining: 602ms
# 541:	learn: 0.0005693	total: 711ms	remaining: 600ms
# 542:	learn: 0.0005657	total: 712ms	remaining: 599ms
# 543:	learn: 0.0005614	total: 713ms	remaining: 598ms
# 544:	learn: 0.0005575	total: 714ms	remaining: 596ms
# 545:	learn: 0.0005529	total: 715ms	remaining: 595ms
# 546:	learn: 0.0005499	total: 717ms	remaining: 593ms
# 547:	learn: 0.0005457	total: 718ms	remaining: 592ms
# 548:	learn: 0.0005422	total: 719ms	remaining: 591ms
# 549:	learn: 0.0005386	total: 720ms	remaining: 589ms
# 550:	learn: 0.0005351	total: 722ms	remaining: 588ms
# 551:	learn: 0.0005312	total: 723ms	remaining: 587ms
# 552:	learn: 0.0005266	total: 724ms	remaining: 585ms
# 553:	learn: 0.0005236	total: 725ms	remaining: 584ms
# 554:	learn: 0.0005197	total: 726ms	remaining: 582ms
# 555:	learn: 0.0005186	total: 728ms	remaining: 581ms
# 556:	learn: 0.0005155	total: 729ms	remaining: 580ms
# 557:	learn: 0.0005118	total: 730ms	remaining: 578ms
# 558:	learn: 0.0005085	total: 731ms	remaining: 577ms
# 559:	learn: 0.0005066	total: 733ms	remaining: 576ms
# 560:	learn: 0.0005048	total: 734ms	remaining: 574ms
# 561:	learn: 0.0005016	total: 735ms	remaining: 573ms
# 562:	learn: 0.0004997	total: 736ms	remaining: 571ms
# 563:	learn: 0.0004981	total: 737ms	remaining: 570ms
# 564:	learn: 0.0004963	total: 739ms	remaining: 569ms
# 565:	learn: 0.0004933	total: 740ms	remaining: 567ms
# 566:	learn: 0.0004917	total: 741ms	remaining: 566ms
# 567:	learn: 0.0004900	total: 742ms	remaining: 565ms
# 568:	learn: 0.0004871	total: 744ms	remaining: 563ms
# 569:	learn: 0.0004838	total: 745ms	remaining: 562ms
# 570:	learn: 0.0004800	total: 746ms	remaining: 561ms
# 571:	learn: 0.0004792	total: 747ms	remaining: 559ms
# 572:	learn: 0.0004764	total: 749ms	remaining: 558ms
# 573:	learn: 0.0004748	total: 750ms	remaining: 556ms
# 574:	learn: 0.0004731	total: 751ms	remaining: 555ms
# 575:	learn: 0.0004700	total: 752ms	remaining: 554ms
# 576:	learn: 0.0004685	total: 754ms	remaining: 552ms
# 577:	learn: 0.0004659	total: 755ms	remaining: 551ms
# 578:	learn: 0.0004651	total: 756ms	remaining: 550ms
# 579:	learn: 0.0004636	total: 757ms	remaining: 548ms
# 580:	learn: 0.0004607	total: 758ms	remaining: 547ms
# 581:	learn: 0.0004591	total: 760ms	remaining: 546ms
# 582:	learn: 0.0004581	total: 761ms	remaining: 544ms
# 583:	learn: 0.0004553	total: 762ms	remaining: 543ms
# 584:	learn: 0.0004538	total: 763ms	remaining: 541ms
# 585:	learn: 0.0004514	total: 765ms	remaining: 540ms
# 586:	learn: 0.0004487	total: 766ms	remaining: 539ms
# 587:	learn: 0.0004479	total: 767ms	remaining: 537ms
# 588:	learn: 0.0004465	total: 769ms	remaining: 537ms
# 589:	learn: 0.0004441	total: 771ms	remaining: 536ms
# 590:	learn: 0.0004433	total: 772ms	remaining: 535ms
# 591:	learn: 0.0004419	total: 774ms	remaining: 533ms
# 592:	learn: 0.0004387	total: 775ms	remaining: 532ms
# 593:	learn: 0.0004363	total: 777ms	remaining: 531ms
# 594:	learn: 0.0004337	total: 778ms	remaining: 530ms
# 595:	learn: 0.0004311	total: 780ms	remaining: 528ms
# 596:	learn: 0.0004297	total: 781ms	remaining: 527ms
# 597:	learn: 0.0004266	total: 782ms	remaining: 526ms
# 598:	learn: 0.0004243	total: 784ms	remaining: 525ms
# 599:	learn: 0.0004218	total: 785ms	remaining: 523ms
# 600:	learn: 0.0004196	total: 786ms	remaining: 522ms
# 601:	learn: 0.0004165	total: 788ms	remaining: 521ms
# 602:	learn: 0.0004135	total: 789ms	remaining: 519ms
# 603:	learn: 0.0004113	total: 790ms	remaining: 518ms
# 604:	learn: 0.0004089	total: 791ms	remaining: 517ms
# 605:	learn: 0.0004059	total: 793ms	remaining: 515ms
# 606:	learn: 0.0004044	total: 794ms	remaining: 514ms
# 607:	learn: 0.0004015	total: 795ms	remaining: 513ms
# 608:	learn: 0.0003985	total: 796ms	remaining: 511ms
# 609:	learn: 0.0003956	total: 798ms	remaining: 510ms
# 610:	learn: 0.0003928	total: 799ms	remaining: 509ms
# 611:	learn: 0.0003899	total: 800ms	remaining: 507ms
# 612:	learn: 0.0003879	total: 801ms	remaining: 506ms
# 613:	learn: 0.0003853	total: 803ms	remaining: 505ms
# 614:	learn: 0.0003831	total: 804ms	remaining: 503ms
# 615:	learn: 0.0003804	total: 805ms	remaining: 502ms
# 616:	learn: 0.0003782	total: 806ms	remaining: 501ms
# 617:	learn: 0.0003758	total: 808ms	remaining: 499ms
# 618:	learn: 0.0003731	total: 810ms	remaining: 498ms
# 619:	learn: 0.0003700	total: 811ms	remaining: 497ms
# 620:	learn: 0.0003693	total: 813ms	remaining: 496ms
# 621:	learn: 0.0003665	total: 814ms	remaining: 495ms
# 622:	learn: 0.0003639	total: 815ms	remaining: 493ms
# 623:	learn: 0.0003613	total: 816ms	remaining: 492ms
# 624:	learn: 0.0003587	total: 818ms	remaining: 491ms
# 625:	learn: 0.0003561	total: 819ms	remaining: 489ms
# 626:	learn: 0.0003537	total: 820ms	remaining: 488ms
# 627:	learn: 0.0003511	total: 821ms	remaining: 487ms
# 628:	learn: 0.0003486	total: 823ms	remaining: 485ms
# 629:	learn: 0.0003461	total: 824ms	remaining: 484ms
# 630:	learn: 0.0003450	total: 825ms	remaining: 482ms
# 631:	learn: 0.0003430	total: 826ms	remaining: 481ms
# 632:	learn: 0.0003419	total: 827ms	remaining: 480ms
# 633:	learn: 0.0003400	total: 829ms	remaining: 478ms
# 634:	learn: 0.0003389	total: 830ms	remaining: 477ms
# 635:	learn: 0.0003367	total: 831ms	remaining: 476ms
# 636:	learn: 0.0003357	total: 832ms	remaining: 474ms
# 637:	learn: 0.0003332	total: 834ms	remaining: 473ms
# 638:	learn: 0.0003322	total: 835ms	remaining: 472ms
# 639:	learn: 0.0003302	total: 836ms	remaining: 470ms
# 640:	learn: 0.0003294	total: 837ms	remaining: 469ms
# 641:	learn: 0.0003285	total: 839ms	remaining: 468ms
# 642:	learn: 0.0003266	total: 840ms	remaining: 466ms
# 643:	learn: 0.0003257	total: 841ms	remaining: 465ms
# 644:	learn: 0.0003249	total: 842ms	remaining: 464ms
# 645:	learn: 0.0003238	total: 843ms	remaining: 462ms
# 646:	learn: 0.0003219	total: 845ms	remaining: 461ms
# 647:	learn: 0.0003211	total: 846ms	remaining: 459ms
# 648:	learn: 0.0003192	total: 847ms	remaining: 458ms
# 649:	learn: 0.0003184	total: 848ms	remaining: 457ms
# 650:	learn: 0.0003176	total: 850ms	remaining: 455ms
# 651:	learn: 0.0003169	total: 851ms	remaining: 454ms
# 652:	learn: 0.0003147	total: 852ms	remaining: 453ms
# 653:	learn: 0.0003129	total: 853ms	remaining: 451ms
# 654:	learn: 0.0003108	total: 854ms	remaining: 450ms
# 655:	learn: 0.0003090	total: 856ms	remaining: 449ms
# 656:	learn: 0.0003080	total: 857ms	remaining: 447ms
# 657:	learn: 0.0003056	total: 858ms	remaining: 446ms
# 658:	learn: 0.0003033	total: 860ms	remaining: 445ms
# 659:	learn: 0.0003025	total: 861ms	remaining: 444ms
# 660:	learn: 0.0002999	total: 862ms	remaining: 442ms
# 661:	learn: 0.0002975	total: 863ms	remaining: 441ms
# 662:	learn: 0.0002952	total: 865ms	remaining: 440ms
# 663:	learn: 0.0002930	total: 866ms	remaining: 438ms
# 664:	learn: 0.0002904	total: 868ms	remaining: 437ms
# 665:	learn: 0.0002897	total: 869ms	remaining: 436ms
# 666:	learn: 0.0002874	total: 870ms	remaining: 434ms
# 667:	learn: 0.0002849	total: 871ms	remaining: 433ms
# 668:	learn: 0.0002825	total: 873ms	remaining: 432ms
# 669:	learn: 0.0002817	total: 874ms	remaining: 430ms
# 670:	learn: 0.0002793	total: 875ms	remaining: 429ms
# 671:	learn: 0.0002785	total: 876ms	remaining: 428ms
# 672:	learn: 0.0002766	total: 878ms	remaining: 426ms
# 673:	learn: 0.0002759	total: 879ms	remaining: 425ms
# 674:	learn: 0.0002736	total: 880ms	remaining: 424ms
# 675:	learn: 0.0002730	total: 881ms	remaining: 422ms
# 676:	learn: 0.0002710	total: 883ms	remaining: 421ms
# 677:	learn: 0.0002688	total: 884ms	remaining: 420ms
# 678:	learn: 0.0002681	total: 885ms	remaining: 418ms
# 679:	learn: 0.0002660	total: 886ms	remaining: 417ms
# 680:	learn: 0.0002641	total: 887ms	remaining: 416ms
# 681:	learn: 0.0002620	total: 889ms	remaining: 414ms
# 682:	learn: 0.0002602	total: 890ms	remaining: 413ms
# 683:	learn: 0.0002582	total: 891ms	remaining: 412ms
# 684:	learn: 0.0002576	total: 892ms	remaining: 410ms
# 685:	learn: 0.0002555	total: 893ms	remaining: 409ms
# 686:	learn: 0.0002541	total: 895ms	remaining: 408ms
# 687:	learn: 0.0002525	total: 896ms	remaining: 406ms
# 688:	learn: 0.0002511	total: 897ms	remaining: 405ms
# 689:	learn: 0.0002504	total: 898ms	remaining: 404ms
# 690:	learn: 0.0002498	total: 900ms	remaining: 402ms
# 691:	learn: 0.0002491	total: 901ms	remaining: 401ms
# 692:	learn: 0.0002485	total: 902ms	remaining: 400ms
# 693:	learn: 0.0002469	total: 903ms	remaining: 398ms
# 694:	learn: 0.0002454	total: 905ms	remaining: 397ms
# 695:	learn: 0.0002440	total: 906ms	remaining: 396ms
# 696:	learn: 0.0002425	total: 907ms	remaining: 394ms
# 697:	learn: 0.0002410	total: 908ms	remaining: 393ms
# 698:	learn: 0.0002399	total: 910ms	remaining: 392ms
# 699:	learn: 0.0002385	total: 911ms	remaining: 390ms
# 700:	learn: 0.0002380	total: 912ms	remaining: 389ms
# 701:	learn: 0.0002368	total: 914ms	remaining: 388ms
# 702:	learn: 0.0002352	total: 915ms	remaining: 387ms
# 703:	learn: 0.0002339	total: 916ms	remaining: 385ms
# 704:	learn: 0.0002327	total: 917ms	remaining: 384ms
# 705:	learn: 0.0002322	total: 919ms	remaining: 383ms
# 706:	learn: 0.0002307	total: 920ms	remaining: 381ms
# 707:	learn: 0.0002291	total: 921ms	remaining: 380ms
# 708:	learn: 0.0002273	total: 922ms	remaining: 379ms
# 709:	learn: 0.0002258	total: 924ms	remaining: 377ms
# 710:	learn: 0.0002247	total: 925ms	remaining: 376ms
# 711:	learn: 0.0002242	total: 926ms	remaining: 375ms
# 712:	learn: 0.0002225	total: 927ms	remaining: 373ms
# 713:	learn: 0.0002216	total: 929ms	remaining: 372ms
# 714:	learn: 0.0002207	total: 930ms	remaining: 371ms
# 715:	learn: 0.0002202	total: 931ms	remaining: 369ms
# 716:	learn: 0.0002187	total: 932ms	remaining: 368ms
# 717:	learn: 0.0002173	total: 934ms	remaining: 367ms
# 718:	learn: 0.0002167	total: 935ms	remaining: 365ms
# 719:	learn: 0.0002153	total: 936ms	remaining: 364ms
# 720:	learn: 0.0002138	total: 937ms	remaining: 363ms
# 721:	learn: 0.0002123	total: 939ms	remaining: 361ms
# 722:	learn: 0.0002109	total: 940ms	remaining: 360ms
# 723:	learn: 0.0002090	total: 941ms	remaining: 359ms
# 724:	learn: 0.0002076	total: 942ms	remaining: 357ms
# 725:	learn: 0.0002069	total: 944ms	remaining: 356ms
# 726:	learn: 0.0002054	total: 945ms	remaining: 355ms
# 727:	learn: 0.0002040	total: 946ms	remaining: 353ms
# 728:	learn: 0.0002026	total: 947ms	remaining: 352ms
# 729:	learn: 0.0002008	total: 949ms	remaining: 351ms
# 730:	learn: 0.0001995	total: 950ms	remaining: 349ms
# 731:	learn: 0.0001982	total: 951ms	remaining: 348ms
# 732:	learn: 0.0001969	total: 952ms	remaining: 347ms
# 733:	learn: 0.0001952	total: 953ms	remaining: 346ms
# 734:	learn: 0.0001946	total: 955ms	remaining: 344ms
# 735:	learn: 0.0001933	total: 956ms	remaining: 343ms
# 736:	learn: 0.0001922	total: 957ms	remaining: 342ms
# 737:	learn: 0.0001911	total: 958ms	remaining: 340ms
# 738:	learn: 0.0001898	total: 960ms	remaining: 339ms
# 739:	learn: 0.0001892	total: 962ms	remaining: 338ms
# 740:	learn: 0.0001887	total: 963ms	remaining: 337ms
# 741:	learn: 0.0001876	total: 965ms	remaining: 335ms
# 742:	learn: 0.0001869	total: 966ms	remaining: 334ms
# 743:	learn: 0.0001856	total: 967ms	remaining: 333ms
# 744:	learn: 0.0001847	total: 969ms	remaining: 332ms
# 745:	learn: 0.0001843	total: 970ms	remaining: 330ms
# 746:	learn: 0.0001831	total: 971ms	remaining: 329ms
# 747:	learn: 0.0001826	total: 972ms	remaining: 328ms
# 748:	learn: 0.0001811	total: 974ms	remaining: 326ms
# 749:	learn: 0.0001797	total: 975ms	remaining: 325ms
# 750:	learn: 0.0001782	total: 976ms	remaining: 324ms
# 751:	learn: 0.0001768	total: 977ms	remaining: 322ms
# 752:	learn: 0.0001753	total: 978ms	remaining: 321ms
# 753:	learn: 0.0001740	total: 980ms	remaining: 320ms
# 754:	learn: 0.0001726	total: 981ms	remaining: 318ms
# 755:	learn: 0.0001716	total: 982ms	remaining: 317ms
# 756:	learn: 0.0001702	total: 983ms	remaining: 316ms
# 757:	learn: 0.0001693	total: 985ms	remaining: 314ms
# 758:	learn: 0.0001685	total: 986ms	remaining: 313ms
# 759:	learn: 0.0001675	total: 987ms	remaining: 312ms
# 760:	learn: 0.0001667	total: 988ms	remaining: 310ms
# 761:	learn: 0.0001658	total: 990ms	remaining: 309ms
# 762:	learn: 0.0001648	total: 991ms	remaining: 308ms
# 763:	learn: 0.0001635	total: 992ms	remaining: 306ms
# 764:	learn: 0.0001626	total: 993ms	remaining: 305ms
# 765:	learn: 0.0001618	total: 995ms	remaining: 304ms
# 766:	learn: 0.0001609	total: 996ms	remaining: 303ms
# 767:	learn: 0.0001596	total: 997ms	remaining: 301ms
# 768:	learn: 0.0001591	total: 998ms	remaining: 300ms
# 769:	learn: 0.0001581	total: 999ms	remaining: 299ms
# 770:	learn: 0.0001573	total: 1s	remaining: 297ms
# 771:	learn: 0.0001561	total: 1s	remaining: 296ms
# 772:	learn: 0.0001549	total: 1s	remaining: 295ms
# 773:	learn: 0.0001542	total: 1s	remaining: 294ms
# 774:	learn: 0.0001530	total: 1.01s	remaining: 292ms
# 775:	learn: 0.0001523	total: 1.01s	remaining: 291ms
# 776:	learn: 0.0001511	total: 1.01s	remaining: 290ms
# 777:	learn: 0.0001502	total: 1.01s	remaining: 289ms
# 778:	learn: 0.0001492	total: 1.01s	remaining: 287ms
# 779:	learn: 0.0001482	total: 1.01s	remaining: 286ms
# 780:	learn: 0.0001475	total: 1.01s	remaining: 285ms
# 781:	learn: 0.0001464	total: 1.02s	remaining: 284ms
# 782:	learn: 0.0001458	total: 1.02s	remaining: 282ms
# 783:	learn: 0.0001447	total: 1.02s	remaining: 281ms
# 784:	learn: 0.0001436	total: 1.02s	remaining: 280ms
# 785:	learn: 0.0001426	total: 1.02s	remaining: 278ms
# 786:	learn: 0.0001419	total: 1.02s	remaining: 277ms
# 787:	learn: 0.0001408	total: 1.02s	remaining: 276ms
# 788:	learn: 0.0001398	total: 1.02s	remaining: 274ms
# 789:	learn: 0.0001387	total: 1.03s	remaining: 273ms
# 790:	learn: 0.0001377	total: 1.03s	remaining: 272ms
# 791:	learn: 0.0001366	total: 1.03s	remaining: 270ms
# 792:	learn: 0.0001360	total: 1.03s	remaining: 269ms
# 793:	learn: 0.0001350	total: 1.03s	remaining: 268ms
# 794:	learn: 0.0001343	total: 1.03s	remaining: 266ms
# 795:	learn: 0.0001337	total: 1.03s	remaining: 265ms
# 796:	learn: 0.0001326	total: 1.03s	remaining: 264ms
# 797:	learn: 0.0001318	total: 1.04s	remaining: 262ms
# 798:	learn: 0.0001313	total: 1.04s	remaining: 261ms
# 799:	learn: 0.0001304	total: 1.04s	remaining: 260ms
# 800:	learn: 0.0001298	total: 1.04s	remaining: 259ms
# 801:	learn: 0.0001289	total: 1.04s	remaining: 257ms
# 802:	learn: 0.0001279	total: 1.04s	remaining: 256ms
# 803:	learn: 0.0001272	total: 1.04s	remaining: 255ms
# 804:	learn: 0.0001263	total: 1.04s	remaining: 253ms
# 805:	learn: 0.0001254	total: 1.05s	remaining: 252ms
# 806:	learn: 0.0001247	total: 1.05s	remaining: 251ms
# 807:	learn: 0.0001241	total: 1.05s	remaining: 249ms
# 808:	learn: 0.0001235	total: 1.05s	remaining: 248ms
# 809:	learn: 0.0001229	total: 1.05s	remaining: 247ms
# 810:	learn: 0.0001225	total: 1.05s	remaining: 245ms
# 811:	learn: 0.0001220	total: 1.05s	remaining: 244ms
# 812:	learn: 0.0001216	total: 1.05s	remaining: 243ms
# 813:	learn: 0.0001211	total: 1.06s	remaining: 242ms
# 814:	learn: 0.0001201	total: 1.06s	remaining: 240ms
# 815:	learn: 0.0001191	total: 1.06s	remaining: 239ms
# 816:	learn: 0.0001188	total: 1.06s	remaining: 238ms
# 817:	learn: 0.0001185	total: 1.06s	remaining: 236ms
# 818:	learn: 0.0001176	total: 1.06s	remaining: 235ms
# 819:	learn: 0.0001170	total: 1.06s	remaining: 234ms
# 820:	learn: 0.0001161	total: 1.07s	remaining: 232ms
# 821:	learn: 0.0001158	total: 1.07s	remaining: 231ms
# 822:	learn: 0.0001148	total: 1.07s	remaining: 230ms
# 823:	learn: 0.0001145	total: 1.07s	remaining: 229ms
# 824:	learn: 0.0001138	total: 1.07s	remaining: 227ms
# 825:	learn: 0.0001135	total: 1.07s	remaining: 226ms
# 826:	learn: 0.0001128	total: 1.07s	remaining: 225ms
# 827:	learn: 0.0001123	total: 1.07s	remaining: 223ms
# 828:	learn: 0.0001114	total: 1.08s	remaining: 222ms
# 829:	learn: 0.0001111	total: 1.08s	remaining: 221ms
# 830:	learn: 0.0001105	total: 1.08s	remaining: 219ms
# 831:	learn: 0.0001098	total: 1.08s	remaining: 218ms
# 832:	learn: 0.0001091	total: 1.08s	remaining: 217ms
# 833:	learn: 0.0001084	total: 1.08s	remaining: 215ms
# 834:	learn: 0.0001081	total: 1.08s	remaining: 214ms
# 835:	learn: 0.0001073	total: 1.08s	remaining: 213ms
# 836:	learn: 0.0001064	total: 1.09s	remaining: 212ms
# 837:	learn: 0.0001057	total: 1.09s	remaining: 210ms
# 838:	learn: 0.0001054	total: 1.09s	remaining: 209ms
# 839:	learn: 0.0001046	total: 1.09s	remaining: 208ms
# 840:	learn: 0.0001038	total: 1.09s	remaining: 206ms
# 841:	learn: 0.0001030	total: 1.09s	remaining: 205ms
# 842:	learn: 0.0001028	total: 1.09s	remaining: 204ms
# 843:	learn: 0.0001021	total: 1.09s	remaining: 202ms
# 844:	learn: 0.0001019	total: 1.09s	remaining: 201ms
# 845:	learn: 0.0001012	total: 1.1s	remaining: 200ms
# 846:	learn: 0.0001010	total: 1.1s	remaining: 198ms
# 847:	learn: 0.0001003	total: 1.1s	remaining: 197ms
# 848:	learn: 0.0001001	total: 1.1s	remaining: 196ms
# 849:	learn: 0.0000999	total: 1.1s	remaining: 194ms
# 850:	learn: 0.0000996	total: 1.1s	remaining: 193ms
# 851:	learn: 0.0000990	total: 1.1s	remaining: 192ms
# 852:	learn: 0.0000983	total: 1.1s	remaining: 191ms
# 853:	learn: 0.0000978	total: 1.11s	remaining: 189ms
# 854:	learn: 0.0000972	total: 1.11s	remaining: 188ms
# 855:	learn: 0.0000966	total: 1.11s	remaining: 187ms
# 856:	learn: 0.0000958	total: 1.11s	remaining: 185ms
# 857:	learn: 0.0000953	total: 1.11s	remaining: 184ms
# 858:	learn: 0.0000947	total: 1.11s	remaining: 183ms
# 859:	learn: 0.0000941	total: 1.11s	remaining: 181ms
# 860:	learn: 0.0000934	total: 1.11s	remaining: 180ms
# 861:	learn: 0.0000929	total: 1.12s	remaining: 179ms
# 862:	learn: 0.0000924	total: 1.12s	remaining: 178ms
# 863:	learn: 0.0000922	total: 1.12s	remaining: 176ms
# 864:	learn: 0.0000916	total: 1.12s	remaining: 175ms
# 865:	learn: 0.0000911	total: 1.12s	remaining: 174ms
# 866:	learn: 0.0000906	total: 1.12s	remaining: 172ms
# 867:	learn: 0.0000901	total: 1.12s	remaining: 171ms
# 868:	learn: 0.0000895	total: 1.13s	remaining: 170ms
# 869:	learn: 0.0000890	total: 1.13s	remaining: 168ms
# 870:	learn: 0.0000885	total: 1.13s	remaining: 167ms
# 871:	learn: 0.0000881	total: 1.13s	remaining: 166ms
# 872:	learn: 0.0000875	total: 1.13s	remaining: 165ms
# 873:	learn: 0.0000872	total: 1.13s	remaining: 163ms
# 874:	learn: 0.0000868	total: 1.13s	remaining: 162ms
# 875:	learn: 0.0000863	total: 1.13s	remaining: 161ms
# 876:	learn: 0.0000858	total: 1.14s	remaining: 159ms
# 877:	learn: 0.0000852	total: 1.14s	remaining: 158ms
# 878:	learn: 0.0000846	total: 1.14s	remaining: 157ms
# 879:	learn: 0.0000844	total: 1.14s	remaining: 155ms
# 880:	learn: 0.0000839	total: 1.14s	remaining: 154ms
# 881:	learn: 0.0000833	total: 1.14s	remaining: 153ms
# 882:	learn: 0.0000827	total: 1.14s	remaining: 152ms
# 883:	learn: 0.0000825	total: 1.14s	remaining: 150ms
# 884:	learn: 0.0000819	total: 1.15s	remaining: 149ms
# 885:	learn: 0.0000813	total: 1.15s	remaining: 148ms
# 886:	learn: 0.0000809	total: 1.15s	remaining: 146ms
# 887:	learn: 0.0000802	total: 1.15s	remaining: 145ms
# 888:	learn: 0.0000796	total: 1.15s	remaining: 144ms
# 889:	learn: 0.0000790	total: 1.15s	remaining: 143ms
# 890:	learn: 0.0000785	total: 1.16s	remaining: 141ms
# 891:	learn: 0.0000778	total: 1.16s	remaining: 140ms
# 892:	learn: 0.0000774	total: 1.16s	remaining: 139ms
# 893:	learn: 0.0000769	total: 1.16s	remaining: 138ms
# 894:	learn: 0.0000763	total: 1.16s	remaining: 136ms
# 895:	learn: 0.0000759	total: 1.16s	remaining: 135ms
# 896:	learn: 0.0000753	total: 1.16s	remaining: 134ms
# 897:	learn: 0.0000752	total: 1.17s	remaining: 132ms
# 898:	learn: 0.0000746	total: 1.17s	remaining: 131ms
# 899:	learn: 0.0000740	total: 1.17s	remaining: 130ms
# 900:	learn: 0.0000737	total: 1.17s	remaining: 129ms
# 901:	learn: 0.0000732	total: 1.17s	remaining: 127ms
# 902:	learn: 0.0000730	total: 1.17s	remaining: 126ms
# 903:	learn: 0.0000725	total: 1.17s	remaining: 125ms
# 904:	learn: 0.0000721	total: 1.17s	remaining: 123ms
# 905:	learn: 0.0000716	total: 1.18s	remaining: 122ms
# 906:	learn: 0.0000711	total: 1.18s	remaining: 121ms
# 907:	learn: 0.0000706	total: 1.18s	remaining: 119ms
# 908:	learn: 0.0000702	total: 1.18s	remaining: 118ms
# 909:	learn: 0.0000696	total: 1.18s	remaining: 117ms
# 910:	learn: 0.0000692	total: 1.18s	remaining: 115ms
# 911:	learn: 0.0000687	total: 1.18s	remaining: 114ms
# 912:	learn: 0.0000682	total: 1.18s	remaining: 113ms
# 913:	learn: 0.0000678	total: 1.19s	remaining: 112ms
# 914:	learn: 0.0000672	total: 1.19s	remaining: 110ms
# 915:	learn: 0.0000668	total: 1.19s	remaining: 109ms
# 916:	learn: 0.0000663	total: 1.19s	remaining: 108ms
# 917:	learn: 0.0000659	total: 1.19s	remaining: 106ms
# 918:	learn: 0.0000654	total: 1.19s	remaining: 105ms
# 919:	learn: 0.0000652	total: 1.19s	remaining: 104ms
# 920:	learn: 0.0000649	total: 1.2s	remaining: 103ms
# 921:	learn: 0.0000644	total: 1.2s	remaining: 101ms
# 922:	learn: 0.0000641	total: 1.2s	remaining: 100ms
# 923:	learn: 0.0000639	total: 1.2s	remaining: 98.7ms
# 924:	learn: 0.0000634	total: 1.2s	remaining: 97.4ms
# 925:	learn: 0.0000630	total: 1.2s	remaining: 96ms
# 926:	learn: 0.0000627	total: 1.2s	remaining: 94.7ms
# 927:	learn: 0.0000624	total: 1.2s	remaining: 93.4ms
# 928:	learn: 0.0000620	total: 1.21s	remaining: 92.1ms
# 929:	learn: 0.0000615	total: 1.21s	remaining: 90.8ms
# 930:	learn: 0.0000613	total: 1.21s	remaining: 89.5ms
# 931:	learn: 0.0000609	total: 1.21s	remaining: 88.2ms
# 932:	learn: 0.0000606	total: 1.21s	remaining: 86.9ms
# 933:	learn: 0.0000604	total: 1.21s	remaining: 85.6ms
# 934:	learn: 0.0000599	total: 1.21s	remaining: 84.3ms
# 935:	learn: 0.0000596	total: 1.21s	remaining: 83ms
# 936:	learn: 0.0000592	total: 1.22s	remaining: 81.7ms
# 937:	learn: 0.0000588	total: 1.22s	remaining: 80.4ms
# 938:	learn: 0.0000584	total: 1.22s	remaining: 79.1ms
# 939:	learn: 0.0000580	total: 1.22s	remaining: 77.8ms
# 940:	learn: 0.0000576	total: 1.22s	remaining: 76.5ms
# 941:	learn: 0.0000572	total: 1.22s	remaining: 75.2ms
# 942:	learn: 0.0000569	total: 1.22s	remaining: 73.9ms
# 943:	learn: 0.0000566	total: 1.22s	remaining: 72.6ms
# 944:	learn: 0.0000563	total: 1.23s	remaining: 71.3ms
# 945:	learn: 0.0000559	total: 1.23s	remaining: 70ms
# 946:	learn: 0.0000556	total: 1.23s	remaining: 68.7ms
# 947:	learn: 0.0000553	total: 1.23s	remaining: 67.4ms
# 948:	learn: 0.0000549	total: 1.23s	remaining: 66.1ms
# 949:	learn: 0.0000546	total: 1.23s	remaining: 64.8ms
# 950:	learn: 0.0000542	total: 1.23s	remaining: 63.5ms
# 951:	learn: 0.0000539	total: 1.23s	remaining: 62.2ms
# 952:	learn: 0.0000536	total: 1.24s	remaining: 60.9ms
# 953:	learn: 0.0000533	total: 1.24s	remaining: 59.6ms
# 954:	learn: 0.0000530	total: 1.24s	remaining: 58.3ms
# 955:	learn: 0.0000526	total: 1.24s	remaining: 57ms
# 956:	learn: 0.0000524	total: 1.24s	remaining: 55.7ms
# 957:	learn: 0.0000521	total: 1.24s	remaining: 54.4ms
# 958:	learn: 0.0000518	total: 1.24s	remaining: 53.1ms
# 959:	learn: 0.0000515	total: 1.24s	remaining: 51.8ms
# 960:	learn: 0.0000512	total: 1.25s	remaining: 50.5ms
# 961:	learn: 0.0000509	total: 1.25s	remaining: 49.2ms
# 962:	learn: 0.0000507	total: 1.25s	remaining: 47.9ms
# 963:	learn: 0.0000504	total: 1.25s	remaining: 46.7ms
# 964:	learn: 0.0000501	total: 1.25s	remaining: 45.4ms
# 965:	learn: 0.0000498	total: 1.25s	remaining: 44.1ms
# 966:	learn: 0.0000497	total: 1.25s	remaining: 42.8ms
# 967:	learn: 0.0000494	total: 1.25s	remaining: 41.5ms
# 968:	learn: 0.0000492	total: 1.25s	remaining: 40.2ms
# 969:	learn: 0.0000489	total: 1.26s	remaining: 38.9ms
# 970:	learn: 0.0000485	total: 1.26s	remaining: 37.6ms
# 971:	learn: 0.0000483	total: 1.26s	remaining: 36.3ms
# 972:	learn: 0.0000479	total: 1.26s	remaining: 35ms
# 973:	learn: 0.0000477	total: 1.26s	remaining: 33.7ms
# 974:	learn: 0.0000475	total: 1.26s	remaining: 32.4ms
# 975:	learn: 0.0000471	total: 1.26s	remaining: 31.1ms
# 976:	learn: 0.0000469	total: 1.27s	remaining: 29.8ms
# 977:	learn: 0.0000468	total: 1.27s	remaining: 28.5ms
# 978:	learn: 0.0000465	total: 1.27s	remaining: 27.2ms
# 979:	learn: 0.0000461	total: 1.27s	remaining: 25.9ms
# 980:	learn: 0.0000459	total: 1.27s	remaining: 24.6ms
# 981:	learn: 0.0000458	total: 1.27s	remaining: 23.3ms
# 982:	learn: 0.0000456	total: 1.27s	remaining: 22ms
# 983:	learn: 0.0000453	total: 1.27s	remaining: 20.7ms
# 984:	learn: 0.0000451	total: 1.28s	remaining: 19.4ms
# 985:	learn: 0.0000450	total: 1.28s	remaining: 18.1ms
# 986:	learn: 0.0000447	total: 1.28s	remaining: 16.8ms
# 987:	learn: 0.0000444	total: 1.28s	remaining: 15.5ms
# 988:	learn: 0.0000443	total: 1.28s	remaining: 14.3ms
# 989:	learn: 0.0000439	total: 1.28s	remaining: 13ms
# 990:	learn: 0.0000438	total: 1.28s	remaining: 11.7ms
# 991:	learn: 0.0000435	total: 1.28s	remaining: 10.4ms
# 992:	learn: 0.0000434	total: 1.29s	remaining: 9.07ms
# 993:	learn: 0.0000431	total: 1.29s	remaining: 7.77ms
# 994:	learn: 0.0000429	total: 1.29s	remaining: 6.48ms
# 995:	learn: 0.0000426	total: 1.29s	remaining: 5.18ms
# 996:	learn: 0.0000423	total: 1.29s	remaining: 3.88ms
# 997:	learn: 0.0000421	total: 1.29s	remaining: 2.59ms
# 998:	learn: 0.0000417	total: 1.29s	remaining: 1.29ms
# 999:	learn: 0.0000415	total: 1.29s	remaining: 0us
# np.float64(0.999996933294098)

# %%
#Determine MAE with test data
y_pred_CB = np.array(CB.predict(X_test_path))
y_pred_CD_rank_paths = np.array(CB.predict(X_test_path))
mae_CB = mean_absolute_error(y_test_path, y_pred_CB)
mape_CB = mean_absolute_percentage_error(y_test_path, y_pred_CB)
print(f'Grandient Boosting Regression MAE: {mae_CB}')
# Out:
# Grandient Boosting Regression MAE: 0.01903250725879303

# %%
#Plot actual y_test vs predicted y_pred in scatterplot
sns.scatterplot(x=y_pred_CB, y=y_test_path)

# Add a line for perfect correlation.
plt.plot([y_test_path.min(), y_test_path.max()],
         [y_test_path.min(), y_test_path.max()],
         '--', color='red')

# Label it nicely
plt.xlabel('Predicted Pseudorank')
plt.ylabel('Actual Pseudorank')
plt.title('CatBoost Regressor Predicted vs Actual Pseudorank')
plt.show()

# %%
MAE_dict = {'Multiple Linear Regression': mae_LR, 'Random Forest Regressor': mae_RF, 'Gradient Boost Regressor': mae_GB, 'XGBoost Regressor': mae_XG, 'CatBoost Regressor': mae_CB}
MAPE_dict = {'Multiple Linear Regression': mape_LR, 'Random Forest Regressor': mape_RF, 'Gradient Boost Regressor': mape_GB, 'XGBoost Regressor': mape_XG, 'CatBoost Regressor': mape_CB}
Rsquared_dict = {'Multiple Linear Regression': LR.score(X_train_path, y_train_path), 'Random Forest Regressor': RF.score(X_train_path, y_train_path), 'Gradient Boost Regressor': GB.score(X_train_path, y_train_path),
                 'XGBoost Regressor': XG.score(X_train_path, y_train_path), 'CatBoost Regressor': CB.score(X_train_path, y_train_path)}
summary_pathways_rank = pd.DataFrame({'MAE': MAE_dict, 'MAPE': MAPE_dict, 'R²': Rsquared_dict})
summary_pathways_rank
# Out:
#                                  MAE      MAPE        R²
# Multiple Linear Regression  0.036782  0.048444  0.856043
# Random Forest Regressor     0.020233  0.026956  0.885370
# Gradient Boost Regressor    0.019064  0.025477  0.999760
# XGBoost Regressor           0.021314  0.028511  0.999690
# CatBoost Regressor          0.019033  0.025454  0.999997

# %% [markdown]
# ####Summary of Model Screening

# %%
summary_merged = pd.concat([summary_genes_score.add_prefix('genes_DE_'),
                            summary_genes_rank.add_prefix('genes_PR_'),
                            summary_pathways_score.add_prefix('pathways_DE_'),
                            summary_pathways_rank.add_prefix('pathways_PR_')], axis=1)

summary_merged
# Out:
#                             genes_DE_MAE  genes_DE_MAPE  genes_DE_R²  \
# Multiple Linear Regression      0.732187       0.278879     1.000000
# Random Forest Regressor         0.502607       0.220917     0.922504
# Gradient Boost Regressor        0.544240       0.233837     0.999945
# XGBoost Regressor               0.538127       0.229096     1.000000
# CatBoost Regressor              0.495887       0.217116     1.000000
#
#                             genes_PR_MAE  genes_PR_MAPE  genes_PR_R²  \
# Multiple Linear Regression      0.032925       0.042867     1.000000
# Random Forest Regressor         0.016535       0.022109     0.932746
# Gradient Boost Regressor        0.017312       0.023144     0.999974
# XGBoost Regressor               0.016227       0.021817     0.999701
# CatBoost Regressor              0.015455       0.020755     0.999999
#
#                             pathways_DE_MAE  pathways_DE_MAPE  pathways_DE_R²  \
# Multiple Linear Regression         0.630935          0.302210        0.926234
# Random Forest Regressor            0.477658          0.215585        0.918061
# Gradient Boost Regressor           0.474108          0.216221        0.999623
# XGBoost Regressor                  0.532262          0.230050        0.999999
# CatBoost Regressor                 0.510991          0.230386        0.999998
#
#                             pathways_PR_MAE  pathways_PR_MAPE  pathways_PR_R²
# Multiple Linear Regression         0.036782          0.048444        0.856043
# Random Forest Regressor            0.020233          0.026956        0.885370
# Gradient Boost Regressor           0.019064          0.025477        0.999760
# XGBoost Regressor                  0.021314          0.028511        0.999690
# CatBoost Regressor                 0.019033          0.025454        0.999997

# %% [markdown]
# The above summary table has a lot of information, so I'll make a smaller tables for the MAE and MAPE to help with comparisons.  The R2 values are pretty consisttent accross learners, so we will leave those for now.

# %%
summary_merged_MAE = summary_merged[['genes_DE_MAE', 'genes_PR_MAE', 'pathways_DE_MAE', 'pathways_PR_MAE']]
summary_merged_MAE
# Out:
#                             genes_DE_MAE  genes_PR_MAE  pathways_DE_MAE  \
# Multiple Linear Regression      0.732187      0.032925         0.630935
# Random Forest Regressor         0.502607      0.016535         0.477658
# Gradient Boost Regressor        0.544240      0.017312         0.474108
# XGBoost Regressor               0.538127      0.016227         0.532262
# CatBoost Regressor              0.495887      0.015455         0.510991
#
#                             pathways_PR_MAE
# Multiple Linear Regression         0.036782
# Random Forest Regressor            0.020233
# Gradient Boost Regressor           0.019064
# XGBoost Regressor                  0.021314
# CatBoost Regressor                 0.019033

# %% [markdown]
# From this summary of MAE, we learn the following:
#
# 1) MAE for PR predictions are way lower than for DE predictions.  This is partly due to the different scales between PR and DE, with DE being about 5x higher that PR, but the difference between MAE is closer to 20x.  We'll use MAPE to better compare predictions of PR and DE.
# 2) Predictions based on the correlating genes is marginally better than predicting with gene pathways.
# 3) Best Learners: CatBoost
#
# Note: I ran the model screening with a few different splits by changing the ranndom state seed and the MAE differneces between best learners (excluding Multiple Regression) are smaller than the MAE diffences with the same learner working with different splits (more on this below).  CatBoost genes_PR_MAE varied from 0.022 to 0.009 with my tests.  Random Forest and CatBoost were usually the best, but not every time.

# %%
summary_merged_MAPE = summary_merged[['genes_DE_MAPE', 'genes_PR_MAPE', 'pathways_DE_MAPE', 'pathways_PR_MAPE']]
summary_merged_MAPE
# Out:
#                             genes_DE_MAPE  genes_PR_MAPE  pathways_DE_MAPE  \
# Multiple Linear Regression       0.278879       0.042867          0.302210
# Random Forest Regressor          0.220917       0.022109          0.215585
# Gradient Boost Regressor         0.233837       0.023144          0.216221
# XGBoost Regressor                0.229096       0.021817          0.230050
# CatBoost Regressor               0.217116       0.020755          0.230386
#
#                             pathways_PR_MAPE
# Multiple Linear Regression          0.048444
# Random Forest Regressor             0.026956
# Gradient Boost Regressor            0.025477
# XGBoost Regressor                   0.028511
# CatBoost Regressor                  0.025454

# %% [markdown]
# From this summary of MAPE, we learn the following:
#
# 1) We confirm that predictions from PR are better than predictions from DE, as a percentage of the target values.  MAPE for DE is 5-10x higher than for PR.
# 2) Best Learners overall: Random Forest and CatBoost using genes to predict PR.
#
# Another approach to evaluating these models is to see how their predictions rank the donors relative to the actual order.  The most plausible 'real world' application of this type of model would be to select the top 5-10 donors for for validation in the lab.  We will look at this in the next section.

# %% [markdown]
# ##Assessing Donor Order
#
# To visualize this donor ranking, I'll use a slope chart comparing actual donor order to the new order based on predictions using Random Forest and CatBoost predictions from gene datasets.

# %%
donor_order_RF = pd.DataFrame({'actual_pr':y_test_rank,
                               'actual_de':y_test_score,
                               'pred_rank_genes':pd.Series(y_pred_RF_rank_genes, index=y_test_rank.index),
                               'pred_score_genes':pd.Series(y_pred_RF_score_genes, index=y_test_score.index)})
donor_order_CB = pd.DataFrame({'actual_pr':y_test_rank,
                               'actual_de':y_test_score,
                               'pred_rank_genes':pd.Series(y_pred_CB_rank_genes, index=y_test_rank.index),
                               'pred_score_genes':pd.Series(y_pred_CB_score_genes, index=y_test_score.index)})
donor_order_RF.head()
# Out:
#       actual_pr  actual_de  pred_rank_genes  pred_score_genes
# juuy   0.759697   1.790761         0.772004          2.689698
# pulk   0.726904   2.004846         0.750377          2.556422
# guyj   0.718967   1.538316         0.740756          2.527970
# iudw   0.736700   2.045526         0.762369          2.393493
# quls   0.735551   2.809054         0.746375          3.034382

# %%
donor_order_rank = pd.DataFrame({'actual_pr':y_test_rank,
                                 'pred_RF':pd.Series(y_pred_RF_rank_genes, index=y_test_rank.index),
                                 'pred_CB':pd.Series(y_pred_CB_rank_genes, index=y_test_rank.index)})
donor_order_score = pd.DataFrame({'actual_de':y_test_score,
                               'pred_RF':pd.Series(y_pred_RF_score_genes, index=y_test_score.index),
                               'pred_CB':pd.Series(y_pred_CB_score_genes, index=y_test_score.index)})
donor_order_rank.head()
# Out:
#       actual_pr   pred_RF   pred_CB
# juuy   0.759697  0.772004  0.772855
# pulk   0.726904  0.750377  0.746879
# guyj   0.718967  0.740756  0.741309
# iudw   0.736700  0.762369  0.768136
# quls   0.735551  0.746375  0.743201

# %%
def slope_chart(data, left_col, right_col, title):
  left=data[left_col].dropna()
  right=data[right_col].dropna()
  donors=data.dropna().index
  fig, ax = plt.subplots(figsize=(6,8))
  for donor in donors:
    ax.plot([0,1],[left.loc[donor], right.loc[donor]], marker='o', linewidth=1)
  ax.set_xticks([0,1])
  ax.set_xticklabels([left_col, right_col])
  ax.set_xlim(-0.1,1.1)
  ax.invert_yaxis()
  ax.set_ylabel('Rank')
  ax.set_title(title)
  plt.tight_layout()
  plt.show()

# %%
rank_PR = donor_order_rank.rank(ascending=False)
rank_DE = donor_order_score.rank(ascending=False)

slope_chart(rank_PR, 'actual_pr', 'pred_RF', 'Actual vs Predicted Rank: Random Forest Predicting Pseudorank')
slope_chart(rank_PR, 'actual_pr', 'pred_CB', 'Actual vs Predicted Rank: CatBoost Predicting Pseudorank')
slope_chart(rank_DE, 'actual_de', 'pred_RF', 'Actual vs Predicted Rank: Random Forest Predicting DE Score')
slope_chart(rank_DE, 'actual_de', 'pred_CB', 'Actual vs Predicted Rank: CatBoost Predicting DE Score')

# %% [markdown]
# These look pretty good - all four are to pull out the best donors and get the correct order at the top of our list.  Next, I'll look at some statistical metrics of these ranking systems.

# %%
def compare_ranks(data1, data2):
  spearman = spearmanr(data1, data2).statistic
  tau = kendalltau(data1, data2).statistic
  mean_rank_error = (data1 - data2).abs().mean()
  return spearman, tau, mean_rank_error

def top_five_overlap(data1, data2):
  top_five_actual = set(data1.nsmallest(5).index)
  top_five_predicted = set(data2.nsmallest(5).index)
  common = top_five_actual.intersection(top_five_predicted)
  return common

def top_three_overlap(data1, data2):
  top_three_actual = set(data1.nsmallest(3).index)
  top_three_predicted = set(data2.nsmallest(3).index)
  common = top_three_actual.intersection(top_three_predicted)
  return common

# %%
print(top_five_overlap(rank_PR['actual_pr'], rank_PR['pred_RF']),
      top_five_overlap(rank_PR['actual_pr'], rank_PR['pred_CB']),
      top_five_overlap(rank_DE['actual_de'], rank_DE['pred_RF']),
      top_five_overlap(rank_DE['actual_de'], rank_DE['pred_CB']))
# Out:
# {'veku', 'yelp', 'pahc', 'qunz'} {'veku', 'yelp', 'pahc', 'qunz'} {'tolg', 'qunz'} {'tolg', 'qunz'}

# %%
print(top_three_overlap(rank_PR['actual_pr'], rank_PR['pred_RF']),
      top_three_overlap(rank_PR['actual_pr'], rank_PR['pred_CB']),
      top_three_overlap(rank_DE['actual_de'], rank_DE['pred_RF']),
      top_three_overlap(rank_DE['actual_de'], rank_DE['pred_CB']))
# Out:
# {'yelp'} {'veku', 'yelp'} set() {'tolg'}

# %% [markdown]
# This tells us that the models predicting PR are able to find 4 of the top 5 donors correctly. Finding the top three is less reliable, but Catboost did a better job at this than Random Forest.  CatBoost predicitng PR found 2  of the top 3.  This suggests that models would succeed at getting the right donors selected for validation in the lab. Models predicting DE were less accurate.

# %%
spearman, tau, mean_rank_error = compare_ranks(rank_PR['actual_pr'], rank_PR['pred_RF'])
print(f'Random Forest ranking of Psueodorank - Spearman: {spearman}')
print(f'Random Forest ranking of Psueodorank - Kendall Tau: {tau}')
print(f'Random Forest ranking of Psueodorank - Mean Rank Error: {mean_rank_error}')
# Out:
# Random Forest ranking of Psueodorank - Spearman: 0.7315789473684211
# Random Forest ranking of Psueodorank - Kendall Tau: 0.5672514619883041
# Random Forest ranking of Psueodorank - Mean Rank Error: 3.0526315789473686

# %%
spearman, tau, mean_rank_error = compare_ranks(rank_PR['actual_pr'], rank_PR['pred_CB'])
print(f'CatBoost ranking of Psueodorank - Spearman: {spearman}')
print(f'CatBoost ranking of Psueodorank - Kendall Tau: {tau}')
print(f'CatBoost ranking of Psueodorank - Mean Rank Error: {mean_rank_error}')
# Out:
# CatBoost ranking of Psueodorank - Spearman: 0.863157894736842
# CatBoost ranking of Psueodorank - Kendall Tau: 0.6725146198830408
# CatBoost ranking of Psueodorank - Mean Rank Error: 2.3157894736842106

# %%
spearman, tau, mean_rank_error = compare_ranks(rank_DE['actual_de'], rank_DE['pred_RF'])
print(f'Random Forest ranking of DE Score - Spearman: {spearman}')
print(f'Random Forest ranking of DE Score - Kendall Tau: {tau}')
print(f'Random Forest ranking of DE Score - Mean Rank Error: {mean_rank_error}')
# Out:
# Random Forest ranking of DE Score - Spearman: 0.719298245614035
# Random Forest ranking of DE Score - Kendall Tau: 0.5087719298245613
# Random Forest ranking of DE Score - Mean Rank Error: 3.5789473684210527

# %%
spearman, tau, mean_rank_error = compare_ranks(rank_DE['actual_de'], rank_DE['pred_CB'])
print(f'CatBoost ranking of DE Score - Spearman: {spearman}')
print(f'CatBoost ranking of DE Score - Kendall Tau: {tau}')
print(f'CatBoost ranking of DE Score - Mean Rank Error: {mean_rank_error}')
# Out:
# CatBoost ranking of DE Score - Spearman: 0.6859649122807018
# CatBoost ranking of DE Score - Kendall Tau: 0.47368421052631576
# CatBoost ranking of DE Score - Mean Rank Error: 3.473684210526316

# %% [markdown]
# The above metrics look at the ranking over the entire test set, not just the top. Here again, the models predicting PR do better than models predicting DE. This also gives us the first clear distinction between the Random Forest and CatBoost learners predicting PR.  The Random Forest learners places donors an average of 3.2 ranks away from their actual rank, while the CatBoost learner places donros 2.3 ranks away from their actual rank.  Combined with the slightly lower MAE, this makes the CatBoost learner our selected model.

# %% [markdown]
# ##Model Building: Final Steps
#
# I the previous section, we selected the CatBoost learner, prediciting donor pseudorank as our preffered model.  We have selected hot to do Hyperparameter tuning as the risk of overfitting outweights the potential benefit of moderate improvements to the existing model.
#
# As a final step, we will refine out features selection.  The existing model was made from the top 100 genes correlating with donor pseudorank. In the following we will optimize gene number, starting from the top 200 genes.

# %% [markdown]
# ### With CB selection
#
# Instead of selecting genes based on a linear correlation with pseudorank, it is better practice to select features using a tree based model.  Here we will use CatBoost Rgressor to pick out the best 100 genes in place of the dataset we created earlier and see if this improves our model.

# %%
X = pd.DataFrame(donor_adata.X, columns=donor_adata.var_names, index=donor_adata.obs_names)
y_pr = donor_adata.obs['pseudorank']

X_train, X_test, y_train_pr, y_test_pr = train_test_split(X, y_pr, test_size=0.2, random_state=42)

# %%
CB_full = CatBoostRegressor(verbose=0)
CB_full.fit(X_train, y_train_pr)
y_pred_full = CB_full.predict(X_test)
import shap

explainer = shap.TreeExplainer(CB_full)
shap_values = explainer.shap_values(X_train)

shap_importance = np.abs(shap_values).mean(axis=0)
shap_rank = pd.Series(shap_importance, index=X_train.columns).sort_values(ascending=False)

# %%
# Loop through features lists of the top 50 to 1000 features to determine how many features are needed to maintain MAE in the Random Forest learner.
MAE_full = []
for i in range(5, 101, 5):
    X_train_short = X_train[shap_rank.index[:i]]
    X_test_short = X_test[shap_rank.index[:i]]
    CB_short = CatBoostRegressor(verbose=0)
    CB_short.fit(X_train_short, y_train_pr)
    y_pred_CBshort = CB_short.predict(X_test_short)
    y_pred_CBshort=np.asarray(y_pred_CBshort).ravel()
    mae_short = mean_absolute_error(y_test_pr, y_pred_CBshort)
    MAE_full.append(mae_short)

# %%
features = range(5, 101, 5)
summary_features = pd.DataFrame({'MAE':MAE_full}, index=features)
sns.lineplot(data=summary_features, x=features, y='MAE')
plt.title('CatBoost Regressor MAE for Top 200 Genes')
plt.xlabel('Number of Features')
plt.ylabel('MAE')
plt.axhline(y=0.0155, color='green', linestyle='--', linewidth=1)
plt.ylim(ymin=0, ymax=0.018)
plt.tight_layout()
plt.show()

# %% [markdown]
# These models all have an error around what we found with our 100 correlating genes, but there seems to be a lower error with smaller features numbers.  I'll repeat this with 1-20 features.

# %%
# Loop through features lists of the top 1 to 20 features to determine how many features are needed to maintain MAE in the CatBoost learner.
MAE_short = []
for i in range(1, 21, 1):
    X_train_short = X_train[shap_rank.index[:i]]
    X_test_short = X_test[shap_rank.index[:i]]
    CB_short = CatBoostRegressor(verbose=0)
    CB_short.fit(X_train_short, y_train_pr)
    y_pred_CBshort = CB_short.predict(X_test_short)
    y_pred_CBshort=np.asarray(y_pred_CBshort).ravel()
    mae_short = mean_absolute_error(y_test_pr, y_pred_CBshort)
    MAE_short.append(mae_short)

# %%
features_short = range(1, 21, 1)
summary_short = pd.DataFrame({'MAE':MAE_short}, index=features_short)

sns.lineplot(data=summary_short, x=features_short, y='MAE')
plt.axhline(y=0.0155, color='green', linestyle='--', linewidth=1)
plt.title('CatBoost Regressor MAE for Top 15 Genes')
plt.xlabel('Number of Features')
plt.ylabel('MAE')
plt.tight_layout()
plt.show()

# %% [markdown]
# This gives us a better idea of what is going on - the lowest MAE is 5-7 genes.  The error is consistently lower than we saw with our previous gene list (although I did have splits that got a lower error). Let's make a new dataset with the top 100 genes and do feature selection over multiple splits.

# %%
shap_rank_100 = shap_rank[0:100]
donor_rank_100 = donor_adata[:, shap_rank_100.index]

# %% [markdown]
# ###Feature Refinement Using Optimized Set of 100 genes
#
# As the attempt with gene selection using a model to pick from the list of 11,000 was unsuccessful, we will go back to our gene lists based on correlation and try to further refine our feature selection.

# %%
#Redo the split on this 'new' dataset
X = pd.DataFrame(donor_rank_100.X, columns=donor_rank_100.var_names, index=donor_rank_100.obs_names)
y_pr = donor_adata.obs['pseudorank']

X_train, X_test, y_train_pr, y_test_pr = train_test_split(X, y_pr, test_size=0.2, random_state=42)

# %%
CB_100 = CatBoostRegressor(verbose=0)
CB_100.fit(X_train, y_train_pr)
y_pred_100 = CB_100.predict(X_test)
importances = CB_100.get_feature_importance() #Get feature importances
CB_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False) #Sort genes in order of importance

# %%
# Loop through features lists of the top 5 to 100 features to determine how many features are needed to maintain MAE in the Random Forest learner.
MAE_100 = []
for i in range(5, 101, 5):
    X_train_short = X_train[CB_importances.index[:i]]
    X_test_short = X_test[CB_importances.index[:i]]
    CB_short = CatBoostRegressor(verbose=0)
    CB_short.fit(X_train_short, y_train_pr)
    y_pred_CBshort = CB_short.predict(X_test_short)
    y_pred_CBshort=np.asarray(y_pred_CBshort).ravel()
    mae_short = mean_absolute_error(y_test_pr, y_pred_CBshort)
    MAE_100.append(mae_short)

# %%
features = range(5, 101, 5)
summary_features = pd.DataFrame({'MAE':MAE_100}, index=features)

sns.lineplot(data=summary_features, x=features, y='MAE')
plt.axhline(y=0.0155, color='blue', linestyle='--', linewidth=1)
plt.title('CatBoost Regressor MAE for Top 100 Genes')
plt.xlabel('Number of Features')
plt.ylim(ymin=.014, ymax=0.017)
plt.ylabel('MAE')
plt.tight_layout()
plt.show()

# %% [markdown]
# Our error is essentially the same as our MAE for model screening. This looks like wer are past the plateau phase, so I'll repeat this with smaller numbers of genes.

# %%
# Loop through features lists of the top 50 to 1000 features to determine how many features are needed to maintain MAE in the Random Forest learner.
MAE_short = []
for i in range(1, 21, 1):
    X_train_short = X_train[CB_importances.index[:i]]
    X_test_short = X_test[CB_importances.index[:i]]
    CB_short = CatBoostRegressor(verbose=0)
    CB_short.fit(X_train_short, y_train_pr)
    y_pred_CBshort = CB_short.predict(X_test_short)
    y_pred_CBshort=np.asarray(y_pred_CBshort).ravel()
    mae_short = mean_absolute_error(y_test_pr, y_pred_CBshort)
    MAE_short.append(mae_short)

# %%
features_short = range(1, 21, 1)
summary_short = pd.DataFrame({'MAE':MAE_short}, index=features_short)

sns.lineplot(data=summary_short, x=features_short, y='MAE')
plt.axhline(y=0.0155, color='green', linestyle='--', linewidth=1)
plt.title('CatBoost Regressor MAE for Top 20 Genes')
plt.xlabel('Number of Features')
plt.ylabel('MAE')
plt.tight_layout()
plt.show()

# %% [markdown]
# With this split, the lowest error is with a model built on the top 6  or 8 genes.  Adding more genes leads to overfitting.
#
# This is a surprisingly small number of genes.  Let's see how stable the error and the selected genes are over multiple splits.  We'll collect the MAE for each number of features on each split as well as the most important 6, 10 and 24 genes.

# %%
n_splits = 20
top_6 = 6
top_10 = 10
top_24 = 24

selected_gene_6 = {}
selected_gene_10 = {}
selected_gene_24 = {}
mae_all = {}

for seed in range(n_splits):
  X_train, X_test, y_train, y_test = train_test_split(X, y_pr, test_size=0.2, random_state=seed) #Make Split
  full_model = CatBoostRegressor(verbose=0) #Fit full model
  full_model.fit(X_train, y_train)
  importances = full_model.get_feature_importance()
  importances_series = pd.Series(importances, index=X_train.columns).sort_values(ascending=False) #Calculate importances
  mae_split = []
  for i in range(1, 31, 1):
    selected_features = importances_series.head(i).index #Select top k genes
    X_train_short = X_train[selected_features]
    X_test_short = X_test[selected_features]
    model = CatBoostRegressor(verbose=0)
    model.fit(X_train_short, y_train)
    y_pred = model.predict(X_test_short)
    mae = mean_absolute_error(y_test, y_pred) #collect MAE
    mae_split.append(mae)
  mae_all[seed] = mae_split
  selected_gene_6[seed] = list(importances_series.head(top_6).index)
  selected_gene_10[seed] = list(importances_series.head(top_10).index)
  selected_gene_24[seed] = list(importances_series.head(top_24).index)

# %%
mae_all_df = pd.DataFrame.from_dict(mae_all, orient='index')
mae_all_df.index = [f"split_{i+1}" for i in mae_all_df.index]
mae_all_df.columns = [f"{i+1}_genes" for i in range(30)]
mae_all_df
# Out:
#            1_genes   2_genes   3_genes   4_genes   5_genes   6_genes  \
# split_1   0.025078  0.019251  0.017425  0.018508  0.017851  0.017330
# split_2   0.021925  0.025291  0.019981  0.018857  0.018127  0.016847
# split_3   0.021820  0.022019  0.022071  0.019917  0.018913  0.018124
# split_4   0.016265  0.015802  0.014865  0.014785  0.014165  0.011559
# split_5   0.022726  0.013942  0.012470  0.015146  0.012523  0.010997
# split_6   0.021657  0.014573  0.014061  0.013585  0.012226  0.013584
# split_7   0.016709  0.021009  0.019885  0.018019  0.018159  0.018737
# split_8   0.029282  0.023945  0.021511  0.018402  0.016533  0.015808
# split_9   0.020700  0.017713  0.013230  0.013212  0.009501  0.007862
# split_10  0.021401  0.017059  0.016451  0.014460  0.013767  0.013465
# split_11  0.021919  0.022510  0.022687  0.023419  0.023393  0.019955
# split_12  0.018538  0.016787  0.016665  0.016198  0.016143  0.016943
# split_13  0.020107  0.019441  0.017266  0.016660  0.017054  0.016806
# split_14  0.016630  0.018567  0.016537  0.015267  0.017121  0.015433
# split_15  0.017767  0.017163  0.016595  0.016523  0.014588  0.013410
# split_16  0.025226  0.022804  0.021847  0.017933  0.019024  0.015548
# split_17  0.019313  0.019189  0.013214  0.015118  0.012492  0.013251
# split_18  0.022583  0.018676  0.020478  0.018956  0.020038  0.018722
# split_19  0.029940  0.028077  0.025922  0.023458  0.022454  0.023037
# split_20  0.014095  0.017199  0.014026  0.014293  0.010130  0.010258
#
#            7_genes   8_genes   9_genes  10_genes  ...  21_genes  22_genes  \
# split_1   0.017553  0.017277  0.018049  0.017551  ...  0.016969  0.016652
# split_2   0.016833  0.017435  0.016843  0.017123  ...  0.014921  0.015467
# split_3   0.017652  0.017952  0.017347  0.016817  ...  0.017156  0.017106
# split_4   0.011786  0.012246  0.011249  0.010650  ...  0.008454  0.009702
# split_5   0.011029  0.010490  0.011415  0.010434  ...  0.009685  0.009704
# split_6   0.011996  0.012793  0.014169  0.011754  ...  0.011973  0.011540
# split_7   0.017775  0.017466  0.017677  0.016498  ...  0.017970  0.017614
# split_8   0.016232  0.015066  0.013244  0.012334  ...  0.013994  0.013810
# split_9   0.008423  0.007768  0.008585  0.008220  ...  0.008738  0.009120
# split_10  0.013371  0.014383  0.013127  0.013284  ...  0.012527  0.012856
# split_11  0.019236  0.020502  0.017706  0.017564  ...  0.016106  0.016216
# split_12  0.017140  0.015914  0.013984  0.013713  ...  0.012402  0.011649
# split_13  0.016265  0.016779  0.016560  0.017264  ...  0.018031  0.018430
# split_14  0.014151  0.014043  0.013388  0.013992  ...  0.014038  0.014183
# split_15  0.013548  0.014003  0.013348  0.012451  ...  0.012954  0.013144
# split_16  0.015184  0.015372  0.014510  0.014711  ...  0.014226  0.014029
# split_17  0.012916  0.011468  0.011433  0.011751  ...  0.009646  0.009817
# split_18  0.018104  0.017519  0.017698  0.016822  ...  0.014229  0.013858
# split_19  0.021771  0.022467  0.021660  0.021174  ...  0.022027  0.021332
# split_20  0.009643  0.010139  0.011122  0.011384  ...  0.010833  0.010724
#
#           23_genes  24_genes  25_genes  26_genes  27_genes  28_genes  \
# split_1   0.017178  0.017078  0.017096  0.016483  0.017145  0.017299
# split_2   0.015877  0.015288  0.015230  0.015319  0.015366  0.014848
# split_3   0.017134  0.017198  0.016607  0.016528  0.017018  0.016915
# split_4   0.009083  0.008518  0.009732  0.009304  0.009914  0.009262
# split_5   0.009948  0.009315  0.009348  0.009919  0.009901  0.009814
# split_6   0.011344  0.011880  0.010861  0.011370  0.011103  0.009603
# split_7   0.016729  0.017972  0.017519  0.017746  0.017691  0.017520
# split_8   0.014401  0.014559  0.014119  0.014453  0.014245  0.014495
# split_9   0.008534  0.008601  0.008546  0.008600  0.008516  0.008197
# split_10  0.012469  0.012076  0.012054  0.012615  0.012329  0.012193
# split_11  0.015503  0.015868  0.016576  0.015984  0.015617  0.016346
# split_12  0.011946  0.011584  0.011477  0.010666  0.010121  0.011252
# split_13  0.018133  0.017772  0.017852  0.017756  0.016877  0.017256
# split_14  0.014008  0.013094  0.013303  0.013568  0.013506  0.013569
# split_15  0.013477  0.013128  0.013582  0.014056  0.013609  0.012697
# split_16  0.014402  0.014117  0.014021  0.013778  0.013767  0.013636
# split_17  0.010176  0.009866  0.009479  0.009067  0.009146  0.009621
# split_18  0.014320  0.014160  0.014881  0.014785  0.014137  0.014837
# split_19  0.020993  0.021226  0.020299  0.021045  0.020329  0.020696
# split_20  0.010593  0.009885  0.009935  0.010039  0.010676  0.009696
#
#           29_genes  30_genes
# split_1   0.016655  0.016969
# split_2   0.015292  0.015552
# split_3   0.017962  0.017030
# split_4   0.009158  0.008966
# split_5   0.009875  0.009662
# split_6   0.010430  0.010150
# split_7   0.017456  0.017611
# split_8   0.013727  0.013548
# split_9   0.008535  0.008964
# split_10  0.012461  0.012656
# split_11  0.016085  0.016511
# split_12  0.011259  0.010552
# split_13  0.017115  0.016728
# split_14  0.013472  0.014110
# split_15  0.013035  0.013739
# split_16  0.013561  0.014083
# split_17  0.009189  0.009086
# split_18  0.014990  0.015036
# split_19  0.021288  0.020683
# split_20  0.009895  0.010104
#
# [20 rows x 30 columns]

# %%
plt.figure(figsize=(10, 6))
for idx, row in mae_all_df.iterrows():
  plt.plot(mae_all_df.columns, row.values, label=idx)
plt.xlabel('Number of Genes')
plt.axhline(y=0.0155, color='black', linestyle='--', linewidth=1)
plt.ylabel('MAE')
plt.xticks(rotation=45)
plt.title('MAE vs Number of Genes over 20 splits')
plt.show()

# %% [markdown]
# We can see here that there is lots of variabilty between splits.  We can't get rid of the varibaility, but we can try to build a model that is as robust to this variability as possible.  First, let's look at the MAE for the average split.

# %%
mae_all_mean = mae_all_df.mean(axis=0)
plt.figure(figsize=(10, 6))
plt.plot(mae_all_df.columns, mae_all_mean.values, label=idx)
plt.xlabel('Number of Genes')
plt.ylabel('MAE')
plt.xticks(rotation=45)
plt.axhline(y=0.0155, color='green', linestyle='--', linewidth=1)
plt.title('MAE vs Number of Genes, averaged 20 splits')
plt.show()

# %% [markdown]
# Out mean MAE is lowest at 6 genes but then stays low and moves around within the range of noise until 30 genes without going up.  This gives us some leeway - we don't have to get the number exact to have a reliable model.  This suggests that we have a fair amount of redundancy in our model - it might only take 20 genes to make predictions, but it's not always the same 20 genes. Not only that, the specific genes probably very from dataset to dataset, so picking a specific gene list might limit our ability to generalize this model.
#
# To test this assumption, the next step is to see if the model picks the same genes with different splits.

# %%
from collections import Counter
def count_gene_use(selected_gene_dict):
  all_genes = []
  for genes in selected_gene_dict.values():
    all_genes.extend(genes)
  gene_counts = Counter(all_genes)
  df = pd.DataFrame.from_dict(gene_counts, orient='index', columns=['count'])
  return df.sort_values(by='count', ascending=False)

# %%
gene_counts_24_df = count_gene_use(selected_gene_24)
gene_counts_10_df = count_gene_use(selected_gene_10)
gene_counts_6_df = count_gene_use(selected_gene_6)

# %%
for k, group in [(6, gene_counts_6_df), (10, gene_counts_10_df), (24, gene_counts_24_df)]:
  plt.figure(figsize=(10, 6))
  sns.barplot(data=group, x=group.index, y='count')
  plt.title(f"Gene Selection in top {k} Genes, Summed Over 20 Splits")
  plt.ylabel("Count")
  plt.xticks(rotation=90)
  plt.show()

# %%
print(f'Number of genes in most important 24 genes over 20 splits: {gene_counts_24_df.shape[0]}')
print(f'Number of genes in most important 10 genes over 20 splits: {gene_counts_10_df.shape[0]}')
print(f'Number of genes in most important 6 genes over 20 splits: {gene_counts_6_df.shape[0]}')
# Out:
# Number of genes in most important 24 genes over 20 splits: 74
# Number of genes in most important 10 genes over 20 splits: 43
# Number of genes in most important 6 genes over 20 splits: 28

# %% [markdown]
# These results show us two things:
#
# 1) Out lists of 'top 6 genes' has 28 genes in it.  This confirms that there is redundancy in our model such that different sets of genes can be used to make predictions.
# 2) Some genes are more likely to be selected than others.  Some genes, like SLC25A5 are selected as being very important almost every time.
#
# Let's look at the overlap between the ~20 of genes most commonly in the top 24 and the genes in the top 10 or top 6.

# %%
top_22 = gene_counts_24_df[gene_counts_24_df['count'] >= 9]
common_10 = list(set(gene_counts_10_df.index) & set(top_22.index))
common_6 = list(set(gene_counts_6_df.index) & set(top_22.index))
print(f'Number of genes with 9+ selections in most important 24 genes: {len(top_22)}')
print(f'Number of common genes also in top 10 most important genes: {len(common_10)}')
print(f'Number of common genes also in top 6 most important genes: {len(common_6)}')
# Out:
# Number of genes with 9+ selections in most important 24 genes: 22
# Number of common genes also in top 10 most important genes: 21
# Number of common genes also in top 6 most important genes: 19

# %% [markdown]
# ### Comparing Maual or Automated Gene Selection
#
# This shows us that there is a group of 20 genes at the top that are selected most often.  Let's try building a model with just those 22 genes over multiple splits.
#
# The above plots show our average model success if we allow the model to pick it's own genes for each split. The question is whether it is better to use a set of common genes (our top_22) or allow the model to select any 22 genes.  We will now compare these two options over 20 splits each.
#
# First, with our definied list of 22 genes.

# %% [markdown]
# ####Manual Gene Selection

# %%
top_22genes = list(top_22.index)
top_22genes
# Out:
# ['ENSG00000005022_SLC25A5',
#  'ENSG00000182749_PAQR7',
#  'ENSG00000188816_HMX2',
#  'ENSG00000198467_TPM2',
#  'ENSG00000173950_XXYLT1',
#  'ENSG00000176410_DNAJC30',
#  'ENSG00000149115_TNKS1BP1',
#  'ENSG00000127774_EMC6',
#  'ENSG00000163530_DPPA2',
#  'ENSG00000119760_SUPT7L',
#  'ENSG00000167695_FAM57A',
#  'ENSG00000169715_MT1E',
#  'ENSG00000154102_C16orf74',
#  'ENSG00000104332_SFRP1',
#  'ENSG00000185515_BRCC3',
#  'ENSG00000172889_EGFL7',
#  'ENSG00000105671_DDX49',
#  'ENSG00000243709_LEFTY1',
#  'ENSG00000241468_ATP5J2',
#  'ENSG00000116761_CTH',
#  'ENSG00000176087_SLC35A4',
#  'ENSG00000170542_SERPINB9']

# %%
#Remake the dataset with the top 22 genes for safety
donor_rank_22 = donor_adata[:, top_22genes].copy()

# %%
n_splits = 20
mae_all = {}
importances_dict = {}
X_22 = pd.DataFrame(donor_rank_22.X, columns=donor_rank_22.var_names, index=donor_rank_22.obs_names)
y_pr = donor_adata.obs['pseudorank']

for seed in range(n_splits):
  X_train, X_test, y_train, y_test = train_test_split(X_22, y_pr, test_size=0.2, random_state=seed) #Make Split
  full_model = CatBoostRegressor(verbose=0) #Fit full model
  full_model.fit(X_train, y_train)
  importances = full_model.get_feature_importance()
  importances_series = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)
  importances_dict[seed] = pd.Series(100 * importances / importances.sum(), index=X_train.columns).sort_values(ascending=False)
  mae_split = []
  for i in range(1, 23, 1):
    selected_features = importances_series.head(i).index #Select top k genes
    X_train_short = X_train[selected_features]
    X_test_short = X_test[selected_features]
    model = CatBoostRegressor(verbose=0)
    model.fit(X_train_short, y_train)
    y_pred = model.predict(X_test_short)
    mae = mean_absolute_error(y_test, y_pred) #collect MAE
    mae_split.append(mae)
  mae_all[seed] = mae_split

# %%
mae_22_df = pd.DataFrame.from_dict(mae_all, orient='index')
mae_22_df.index = [f"split_{i+1}" for i in mae_22_df.index]
mae_22_df.columns = [f"{i+1}_genes" for i in range(22)]

# %%
plt.figure(figsize=(10, 6))
for idx, row in mae_22_df.iterrows():
  plt.plot(mae_22_df.columns, row.values, label=idx)
plt.xlabel('Number of Genes')
plt.axhline(y=0.0155, color='black', linestyle='--', linewidth=1)
plt.ylabel('MAE')
plt.xticks(rotation=45)
plt.title('MAE vs Number of Genes with Set 22 Genes over 20 splits')
plt.show()

# %% [markdown]
# We can also look at the relative importance of each gene, averaged over the 20 splits.

# %%
importances_df = pd.DataFrame.from_dict(importances_dict)
importances_df_mean = importances_df.mean(axis=1).sort_values(ascending=False)
importances_df_mean
# Out:
# Unnamed: 0
# ENSG00000005022_SLC25A5     10.677369
# ENSG00000176410_DNAJC30      6.156343
# ENSG00000154102_C16orf74     6.094147
# ENSG00000127774_EMC6         5.946591
# ENSG00000172889_EGFL7        5.858165
# ENSG00000188816_HMX2         5.558307
# ENSG00000182749_PAQR7        5.536196
# ENSG00000105671_DDX49        5.290932
# ENSG00000149115_TNKS1BP1     4.948534
# ENSG00000198467_TPM2         4.829835
# ENSG00000163530_DPPA2        4.519964
# ENSG00000169715_MT1E         4.080560
# ENSG00000173950_XXYLT1       3.927053
# ENSG00000176087_SLC35A4      3.562600
# ENSG00000104332_SFRP1        3.403611
# ENSG00000241468_ATP5J2       3.333767
# ENSG00000170542_SERPINB9     3.316389
# ENSG00000185515_BRCC3        2.878811
# ENSG00000167695_FAM57A       2.635313
# ENSG00000116761_CTH          2.619197
# ENSG00000243709_LEFTY1       2.486129
# ENSG00000119760_SUPT7L       2.340188
# dtype: float64

# %%
#Plot feature importances
fig, ax = plt.subplots(figsize=(8,8))
importances_df_mean.plot.barh(ax=ax)
ax.set_title("Mean CatBoost Regression Feature importances - Manual Gene Selection")
ax.set_xlabel("Percent of Total Importance")
fig.tight_layout()
plt.show()

# %% [markdown]
# ####Automated Gene Selection
#
# Now let's try again with setting the model to pick any 22 genes from out list of 100.

# %%
n_splits = 20
mae_all = {}
importances_dict = {}
X_100 = pd.DataFrame(donor_rank_100.X, columns=donor_rank_100.var_names, index=donor_rank_100.obs_names)
y_pr = donor_adata.obs['pseudorank']

for seed in range(n_splits):
  X_train, X_test, y_train, y_test = train_test_split(X_100, y_pr, test_size=0.2, random_state=seed) #Make Split
  selector_model = CatBoostRegressor(verbose=0) #Fit full model
  summary = selector_model.select_features(
        X_train,
        y_train,
        features_for_select=list(range(X_train.shape[1])),  #select genes from entire list of 100
        num_features_to_select=22, #Optimal number of genes
        algorithm='RecursiveByShapValues',
        steps=1,
        logging_level='Silent',
    )
  selected_features = X_train.columns[summary['selected_features']]
  full_model.fit(X_train[selected_features], y_train)
  importances = full_model.get_feature_importance()
  importances_series = pd.Series(importances, index=selected_features).sort_values(ascending=False)
  importances_dict[seed] = 100 * importances / importances.sum()
  mae_split = []
  for i in range(1, 23, 1):
    selected_features_short = selected_features[:i] #Select top k genes
    X_train_short = X_train[selected_features_short]
    X_test_short = X_test[selected_features_short]
    model = CatBoostRegressor(verbose=0)
    model.fit(X_train_short, y_train)
    y_pred = model.predict(X_test_short)
    mae = mean_absolute_error(y_test, y_pred) #collect MAE
    mae_split.append(mae)
  mae_all[seed] = mae_split

# %%
mae_auto_df = pd.DataFrame.from_dict(mae_all, orient='index')
mae_auto_df.index = [f"split_{i+1}" for i in mae_auto_df.index]
mae_auto_df.columns = [f"{i+1}_genes" for i in range(22)]

# %%
plt.figure(figsize=(10, 6))
for idx, row in mae_auto_df.iterrows():
  plt.plot(mae_auto_df.columns, row.values, label=idx)
plt.xlabel('Number of Genes')
plt.axhline(y=0.0155, color='black', linestyle='--', linewidth=1)
plt.ylabel('MAE')
plt.xticks(rotation=45)
plt.title('MAE vs Number of Genes With Automatic Selection of Top 22 Genes over 20 splits')
plt.show()

# %%
mae_22_mean = mae_22_df.mean(axis=0)
mae_auto_mean = mae_auto_df.mean(axis=0)
plt.figure(figsize=(10, 6))
plt.plot(mae_auto_df.columns, mae_auto_mean.values, label='Automatic Selection')
plt.plot(mae_22_df.columns, mae_22_mean.values, label='Manual Selection')
plt.xlabel('Number of Genes')
plt.ylabel('MAE')
plt.xticks(rotation=45)
plt.axhline(y=0.0155, color='green', linestyle='--', linewidth=1)
plt.title('Manual vs Automatic Gene Selection MAE, averaged 20 splits')
plt.legend()
plt.show()

# %%
importances_df_auto = pd.DataFrame.from_dict(importances_dict)
importances_df_auto_mean = importances_df.mean(axis=1).sort_values(ascending=False)

# %%
#Plot feature importances
fig, ax = plt.subplots(figsize=(8,8))
importances_df_auto_mean.plot.barh(ax=ax)
ax.set_title("Mean CatBoost Regression Feature importances - Automatic Gene Selection")
ax.set_xlabel("Percent of Total Importance")
fig.tight_layout()
plt.show()

# %% [markdown]
# This comparison between manually selecting specific genes and letting the model automatically select genes for each split shows us that we get a lower error when we manually choose the genes if we use 7 or more genes.  If we wanted to use fewer than 7 genes, the automatic selection is superior.
#
# This does not mean that manual gene selection makes the best model for new data.  New data will be from different RNAseq batches and might get better predictions from a different set of genes than what we used here.  Without testing this on new datasets, using manual selection in our final model is risky.  I recommend making a model that is based on our 22 genes, and a model able to do gene selction based on the specifics of the new dataset.
#
# The last question for our model with automatic gene selection is whether we should choose 22 genes, or up to 22 genes. I will compare these two scenarios.

# %%
n_splits = 20
shap_threshold = [.01, .005, .001, .0005, .0001] #The best threshold for Shap values is unknown, so we will try a few
mae_shap = {}
selected_genes_dict = {}

for shap_threshold in shap_threshold:
  mae_splits = {}
  selected_genes_len = {}
  for seed in range(n_splits):
    X_train, X_test, y_train, y_test = train_test_split(X_100, y_pr, test_size=0.2, random_state=seed) #Make Split
    train_pool = Pool(X_train, y_train)
    selector_model = CatBoostRegressor(loss_function = 'MAE', verbose=0) #Fit full model
    selector_model.fit(X_train, y_train)
    shap_values = selector_model.get_feature_importance(data=train_pool, type='ShapValues') #Calculate shap values
    feature_importance = np.abs(shap_values).mean(axis=0) #Calculate feature importance
    sorted_features = sorted(zip(X_train.columns, feature_importance), key=lambda x: x[1], reverse=True)
    selected_genes = [f for f,val in zip(X_train.columns, feature_importance) if val > shap_threshold] #fine genes above threshold
    selected_genes = selected_genes[:22]
    if len(selected_genes) == 0:
      selected_genes = [f for f, _ in sorted_features[:5]]
    selected_genes_len[seed] = len(selected_genes)
    model_final = CatBoostRegressor(loss_function = 'MAE', verbose=0) #train new model on selected_genes
    model_final.fit(X_train[selected_genes], y_train)
    y_pred = model_final.predict(X_test[selected_genes])
    mae_splits[seed] = mean_absolute_error(y_test, y_pred)
  mae_shap[shap_threshold] = mae_splits
  selected_genes_dict[shap_threshold] = selected_genes_len

# %%
mae_shap_df = pd.DataFrame(mae_shap)
mae_shap_df.index = [f"split_{i+1}" for i in mae_shap_df.index]
mae_shap_df.columns = ['Shap_.01', 'Shap_.005', 'Shap_.001', 'Shap_.0005', 'Shap_.0001']
mae_shap_df_mean = mae_shap_df.mean(axis=0).to_frame(name='MAE')
mae_shap_df_std = mae_shap_df.std(axis=0).to_frame(name='Std')

# %%
mae_shap_df_mean
# Out:
#                  MAE
# Shap_.01    0.015965
# Shap_.005   0.015965
# Shap_.001   0.017264
# Shap_.0005  0.013232
# Shap_.0001  0.013626

# %%
manual_mean = mae_22_df.loc[:, '22_genes'].mean()
manual_std = mae_22_df.loc[:, '22_genes'].std()
auto_mean = mae_auto_df.loc[:, '22_genes'].mean()
auto_std = mae_auto_df.loc[:, '22_genes'].mean()

# %%
means = [manual_mean, auto_mean]
stds = [manual_std, auto_std]
means_df = pd.concat([pd.DataFrame(means, index=['Manual', 'Automatic_RFE'], columns=['MAE']), mae_shap_df_mean])
stds_df = pd.concat([pd.DataFrame(stds, index=['Manual', 'Automatic_RFE'], columns=['Std']), mae_shap_df_std])
comp_df = pd.concat([means_df, stds_df], axis=1)

# %%
comp_df
# Out:
#                     MAE       Std
# Manual         0.012118  0.003131
# Automatic_RFE  0.013727  0.013727
# Shap_.01       0.015965  0.003335
# Shap_.005      0.015965  0.003335
# Shap_.001      0.017264  0.003938
# Shap_.0005     0.013232  0.003323
# Shap_.0001     0.013626  0.003023

# %%
plt.bar(data=comp_df, x=comp_df.index, height='MAE', yerr='Std')
plt.title('Mean MAE by Gene Selection Method')
plt.ylabel('Mean MAE Over Twenty Splits')
plt.xlabel('Gene Selection Method')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From this we can see that the Recusive Feature Elimination that we used for the first model with Automatic Gene Selection is highly variable.  Gene selction through Shap values is much more stable accross splits, so we will use this for the final model with gene selection.
#
# These resutls suggest that the optimal Shap Threshold is .0005, as this has the lowest error of the models with automatic gene selection. We are looking for a threshold that selects almost 22 genes, but not quite that many if there are not enough genes making the cutoff for that split.  We can confirm if .0005 fits this description by looking at the number of selected genes.

# %%
selected_genes_len_df = pd.DataFrame(selected_genes_dict)
selected_genes_len_df.index = [f"split_{i+1}" for i in selected_genes_len_df.index]
selected_genes_len_df.columns = ['Shap_.01', 'Shap_.005', 'Shap_.001', 'Shap_.0005', 'Shap_.0001']
selected_genes_len_df_mean = selected_genes_len_df.mean(axis=0).to_frame(name='MAE')
selected_genes_len_df_std = selected_genes_len_df.std(axis=0).to_frame(name='Std')

# %%
x_labels = selected_genes_len_df_mean.index
heights = selected_genes_len_df_mean['MAE']
yerr = selected_genes_len_df_std['Std']

plt.figure(figsize=(8,6))
plt.bar(x_labels, heights, yerr=yerr, capsize=5)
plt.ylabel('Number of Genes Selected (Mean ± Std)')
plt.xlabel('SHAP Threshold')
plt.title('Selected Genes per Split')
plt.show()

# %% [markdown]
# This confirms our suspicions that .0005 results in almost 22 genes being selected depending on their importance.  We will use this threshold in our final model.

# %% [markdown]
# ##Final Model
#
# In our final model, we must build something that will be as reslient as possible to differences between new datasets, even if that means sacrificing MAE with the existing dataset.  For that reason, I will use recursive feature elimination to select genes based on the split, rather than using the genes we have already identified for our split with random state 42.

# %%
#Final Model with Manual Gene Selection
X_22 = pd.DataFrame(donor_rank_22.X, columns=donor_rank_22.var_names, index=donor_rank_22.obs_names)
y_pr = donor_adata.obs['pseudorank']

X_train, X_test, y_train, y_test = train_test_split(X_22, y_pr, test_size=0.2, random_state=seed)
CB_final_manual = CatBoostRegressor(verbose=0)
CB_final_manual.fit(X_train, y_train)
y_pred_manual = CB_final_manual.predict(X_test)
mae_manual = mean_absolute_error(y_test, y_pred_manual )

# %%
X_100 = pd.DataFrame(donor_rank_100.X, columns=donor_rank_100.var_names, index=donor_rank_100.obs_names)
y_pr = donor_adata.obs['pseudorank']
shap_threshold = .0005

X_train, X_test, y_train, y_test = train_test_split(X_100, y_pr, test_size=0.2, random_state=seed) #Perform Split

train_pool = Pool(X_train, y_train)
selector_model = CatBoostRegressor(loss_function = 'MAE', verbose=0) #Build Selector Model for calculating Shap Values
selector_model.fit(X_train, y_train)
shap_values = selector_model.get_feature_importance(data=train_pool, type='ShapValues') #Calculate shap values
feature_importance = np.abs(shap_values).mean(axis=0) #Calculate feature importance
sorted_features = sorted(zip(X_train.columns, feature_importance), key=lambda x: x[1], reverse=True)
selected_genes = [f for f,val in zip(X_train.columns, feature_importance) if val > shap_threshold] #fine genes above threshold
selected_genes = selected_genes[:22]
if len(selected_genes) == 0:
  selected_genes = [f for f, _ in sorted_features[:5]]
CB_final_auto = CatBoostRegressor(loss_function = 'MAE', verbose=0) #train new model on selected_genes
CB_final_auto.fit(X_train[selected_genes], y_train)
y_pred_auto = CB_final_auto.predict(X_test[selected_genes])
mae_auto = mean_absolute_error(y_test, y_pred_auto)

# %%
print(f'MAE for Manual Gene Selection: {mae_manual}')
print(f'MAE for Automatic Gene Selection: {mae_auto}')
# Out:
# MAE for Manual Gene Selection: 0.0099860100793652
# MAE for Automatic Gene Selection: 0.010170355417938088

# %%
#Save final dataset used for manual and automatic models
donor_rank_100.write_h5ad("/content/drive/MyDrive/Springboard/Capstone3_iPSC/donor_100_automatic.h5ad")
donor_rank_22.write_h5ad("/content/drive/MyDrive/Springboard/Capstone3_iPSC/donor_22_manual.h5ad")

# %%
CB_final_manual.save_model("/content/drive/MyDrive/Springboard/Capstone3_iPSC/CB_final_manual.cbm")
CB_final_auto.save_model("/content/drive/MyDrive/Springboard/Capstone3_iPSC/CB_final_automatic.cbm")
